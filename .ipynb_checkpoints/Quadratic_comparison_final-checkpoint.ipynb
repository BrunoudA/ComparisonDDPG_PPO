# %%
#1) Import libraries
from qpsolvers import solve_qp
import time
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import Environments
import pandas as pd

# %%
#2) Create functions for quadratic computing
def H_funct(n):
    # H = np.zeros((3*n,3*n))
    H = np.diag([1e-5]*(3*n))
    for i in range(n):
        H[i*3+1,i*3+1] = 1.
    return H

def Q_funct(n,vd):
    Q = np.zeros((3*n,))
    for i in range(n):
        Q[i*3+1]=-vd
    return Q

def A2_funct(n,dt):
    A = np.zeros((2*n+1,3*n))
    for i in range(0,2):
        A[i,i]=1.
        A[i+2*(n-1),i+2*(n-1)+(n-1)]=0
    for i in range(2,2*n):
        j=i+(i//2)
        #if(i<2*(n-1)):
        A[i,j]=-1.
        A[i,j-3]=1.
        A[i,j-2]=dt
        if(i%2==0): 
            A[i,j-1]=dt**2 /2.
    for i in range(2*n,2*n+1):
        j=i+(i//2)-3
        A[i,j]=1.
    return A

def A_funct(n,dt):
    A = np.zeros((2*n+1,3*n))
    for i in range(0,2):
        A[i,i]=1.
        A[i+2*(n-1),i+2*(n-1)+(n-1)]=0.
    for i in range(2,2*n):
        j=i+(i//2)
        #if(i<2*(n-1)):
        A[i,j]=-1.
        A[i,j-3]=1.
        A[i,j-2]=dt
        if(i%2==0): 
            A[i,j-1]=dt**2 /2.
    for i in range(2*n,2*n+1):
        j=i+(i//2)-3
        A[i,j+1]=1
    return A

def B2_funct(n,xi,xf):
    B = np.zeros((2*n+1,))
    B[0]=xi[0]
    B[1]=xi[1]
    B[2*n]=xf[0]
   # B[2*n+1]=xf[1]
    return B

def B_funct(n,xi,xf):
    B = np.zeros((2*n+1,))
    B[0]=xi[0]
    B[1]=xi[1]
    #B[2*n]=xf[0]
    B[2*n]=xf[1]
    return B

def bounds(n,bds):
    bounds= np.zeros((3*n))
    for i in range(n):
        bounds[i*3:i*3+3]=bds
    return bounds

# %%
#3) Quadratic programming model
class Model_QP():
    """
        Class: select action
        :param dt: time step
        :param lb: lower bounds [position, speed, acceleration]
        :param ub: upper bounds [position, speed, acceleration]
    """
    def __init__(self, dt, lb, ub):
        self.dt = dt
        self.lb = lb
        self.ub = ub
        
    def new_action_position(self, n, x_init, x_final):
        """
        New action : 
        :param n: number of steps
        :param x_init: initial position & speed
        :param x_final: final position & speed
        :return: [position, speed, acceleration]
        """ 
        H=H_funct(n)
        q=Q_funct(n,x_final[1])
        A=A2_funct(n,self.dt)
        B=B2_funct(n,x_init,x_final)
        lbs=bounds(n,self.lb)
        ubs=bounds(n,self.ub)
        return solve_qp(H, q, A=A, b=B, lb=lbs, ub=ubs)
    
    def new_action_speed(self, n, x_init, x_final):
        """
        New action : 
        :param n: number of steps
        :param x_init: initial position & speed
        :param x_final: final position & speed
        :return: [position, speed, acceleration]
        """ 
        H=H_funct(n)
        q=Q_funct(n,x_final[1])
        A=A_funct(n,self.dt)
        B=B_funct(n,x_init,x_final)
        lbs=bounds(n,self.lb)
        ubs=bounds(n,self.ub)
        return solve_qp(H, q, A=A, b=B, lb=lbs, ub=ubs)

# %%
#4) Rollout on the environment:
class Env_rollout:
    """ 
        Class : iterate on the environment
        :param env: our environment
        :param max_steps: max steps per episode
        :param dt: time step
        :param cross: size crosswalk
        :param acc_max: maximal acceleration
        :param acc_min: minimal acceleration
        :param tau: reaction time
    """
    def __init__(self, env, max_steps, dt, cross, acc_max, acc_min, tau):
        self.env = env
        self.max_steps = max_steps
        self.dt = dt
        self.cross = cross
        self.prev_state = env.reset()
        self.acc_max=acc_max
        self.acc_min=acc_min
        self.tau=tau
        
    
    def delta_l(self, x, v):
        """
        Compute safety factor
        :param x: distance between the car and the crosswalk (negative value) 
        :param v: vehicle speed
        :return: safety factor
        """    
        return -x - (v * v / (-2.0 * self.acc_min) + self.tau * v)
    
    def tranformation_action(self,value):
        """
        Transform the value for environment (before step iteration)
        :param value: element compute with QP
        :return: transformed value
        """  
        a=2./(self.acc_max-self.acc_min)
        b=-(self.acc_max+self.acc_min)/(self.acc_max-self.acc_min)
        return a*value+b
    
    def iterations(self, model, nbr_episodes):
        """
        Iterate on the environment.
        :param model: current policy
        :param nbr_episodes: episode number
        :return: Tensors; state batch, action batch, reward batch
        """
        batch_obs=[]
        batch_acts=[]
        batch_rews=[]
        for ep in range(nbr_episodes):
            prev_state = env.reset()
            self.ds=prev_state[1]
            self.ped_speed=prev_state[3]
            self.choice_car=(self.delta_l(prev_state[2], prev_state[1]) >= 0)
            for step_ep in range(self.max_steps):
                car_parameters=[0., 0., 0.]
                initial_state = prev_state[1:3][1::-1]
                if(prev_state[2]>=0. or prev_state[4]>=self.cross): # if car already pass the crosswalk
                    n=1+math.ceil((self.ds-prev_state[1])/(self.dt*self.acc_max))
                    if(self.ds-prev_state[1]>0.):
                        final_state = [prev_state[2]+n*self.ds*self.dt, self.ds]
                        car_parameters = model.new_action_speed(n, initial_state, final_state)
                        if(car_parameters is None):
                            car_parameters=[0., 0., prev_state[0]+0.1]
                    
                #elif(prev_state[3]<=0.1): # if pedestrian stops (not still cross)
                #    car_parameters=[0., 0., prev_state[0]]
                    
                else:
                    if(prev_state[1]<0.0):
                        car_parameters=[0., 0., 0.2]
                    elif(prev_state[3]<0.1):
                        final_state = [0., self.ds]
                        car_parameters = model.new_action_position(8, initial_state, final_state)
                        while(car_parameters is None and n<20):
                            car_parameters = model.new_action_position(n, initial_state, final_state)
                            n=n+1
                        if(car_parameters is None):
                            car_parameters=[0., 0., self.acc_min]
                    else:
                        n=4+math.ceil((self.cross-prev_state[4])/(self.dt*self.ped_speed))#,int((self.ds-prev_state[1])*self.dt/2.0)) #security factor
                        if(n==2):
                            acc=-2.*(prev_state[1]*self.dt + prev_state[2])/(self.dt**2)
                            car_parameters=[0., 0., acc]
                        if(n>2):
                            final_state = [0., self.ds]
                            car_parameters = model.new_action_position(n, initial_state, final_state)
                            #if(car_parameters is None):
                            #    print("Wait _ Initial state: "+str(initial_state))
                            #    print("Wait _ Final state: "+str(final_state))
                            #    print("Wait _ N: "+str(n))
                            while(car_parameters is None and n<8):
                                car_parameters = model.new_action_position(n, initial_state, final_state)
                                n=n+1
                                #print("Change trajectory ... "+str(n))
                                #print((self.cross-prev_state[4]))
                                #car_parameters=[0., 0., 0.]
                            if(car_parameters is None):
                                car_parameters=[0., 0., prev_state[0]+0.2]
                if(not self.choice_car):
                    car_parameters=[0., 0., 0.]
                action=self.tranformation_action(car_parameters[2])
                state, reward, done, _ = self.env.step(np.clip([action],-1.0,1.0))
                batch_obs.append(prev_state)
                batch_acts.append(car_parameters[2])
                batch_rews.append(reward)
                prev_state = state
                if done:
                    break
            avg_reward = np.mean(batch_rews[-10:])
            print("Episode * {} * Avg Reward is ==> {} And Number of steps is ==> {}".format(ep, avg_reward,ep))
        return batch_obs, batch_acts, batch_rews

# %%
#4) QP Algorithm:
class Algo_QP():
    """ 
    QP algorithm : testing
    :param policy_class: policy
    :param env: environment
    :param hyperparameters: other hyperparameters
    """
    def __init__(self, policy_class, env, **hyperparameters):
        
        self._init_hyperparameters(hyperparameters)
        self.model = policy_class(self.dt, self.l_b, self.u_b)
        self.rollout = Env_rollout(env, self.max_steps, self.dt, self.cross,self.u_b[2], self.l_b[2], self.tau)
    
    def evaluate(self, nbr_episodes):
        """
        Testing
        :param nbr_episodes: episode number 
        :return: state batch, action batch, and reward batch
        """
        state_batch, action_batch, rewards_batch = self.rollout.iterations(self.model, nbr_episodes)
        return state_batch, action_batch, rewards_batch
    
    def _init_hyperparameters(self, hyperparameters):
        """
        Initialize hyperparameters. 
        :param hyperparameters: hyperparameter list
        """
        for param, val in hyperparameters.items():
            exec('self.' + param + ' = ' + str(val))
        self.num_algo = 1
        self.max_steps = 90
        self.total_loop = 0
        self.dt = 0.3
        self.cross = 5.0

# %%
#5) Computing part:
# Import environment
problem = "Crosswalk_comparison2-v0"
u_b = [2.0, 11.0, -12.5, 1.1, -1.0]
l_b = [-4.0, 9.0, -32.5, 0.9, -2.0]

env = gym.make(problem,dt=0.3,Vm=2.5,tau=1.0,lower_bounds=l_b, upper_bounds=u_b,simulation="sin")

# Initialize the algorithm
num_states = env.observation_space.shape[0]
num_actions = env.action_space.shape[0]
num_algo=1
u_b2=[200.0,15.0,2.0]
l_b2=[-45.0,0.0,-4.0]
algo=Algo_QP(Model_QP, env, num_algo= num_algo, num_states=num_states, num_actions=num_actions,l_b=l_b2, u_b=u_b2, tau=1.0)
#algo.loading(1,1000)
# Out:
# C:\Users\abrunoud\Anaconda3\envs\ppotest\lib\site-packages\gym\logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))

# %%
#Stock an evaluation sample
states, actions, rewards = algo.evaluate(1000)
states=np.array(states)
ep_action=states[:,0]
ep_speed_car=states[:,1]
ep_pos_car=states[:,2]
ep_speed_ped=states[:,3]
ep_pos_ped=states[:,4]
ep_time=states[:,9]
ep_reward=rewards
t=0
# Out:
# Episode * 0 * Avg Reward is ==> -1.0263966165164344 And Number of steps is ==> 0
# Episode * 1 * Avg Reward is ==> -3.918247887823482 And Number of steps is ==> 1
# Episode * 2 * Avg Reward is ==> 0.9767652854065082 And Number of steps is ==> 2
# Episode * 3 * Avg Reward is ==> 0.8183080711927303 And Number of steps is ==> 3
# Episode * 4 * Avg Reward is ==> 0.9408344321849285 And Number of steps is ==> 4
# Episode * 5 * Avg Reward is ==> -3.663338976855859 And Number of steps is ==> 5
# Episode * 6 * Avg Reward is ==> 0.8506104058879647 And Number of steps is ==> 6
# Episode * 7 * Avg Reward is ==> 0.12476976578631435 And Number of steps is ==> 7
# Episode * 8 * Avg Reward is ==> 0.8453590289532918 And Number of steps is ==> 8
# Episode * 9 * Avg Reward is ==> 0.7609053104109632 And Number of steps is ==> 9
# Episode * 10 * Avg Reward is ==> -3.5615503744201376 And Number of steps is ==> 10
# Episode * 11 * Avg Reward is ==> -3.9610154142259133 And Number of steps is ==> 11
# Episode * 12 * Avg Reward is ==> 0.7927986985051708 And Number of steps is ==> 12
# Episode * 13 * Avg Reward is ==> 1.0344229212910439 And Number of steps is ==> 13
# Episode * 14 * Avg Reward is ==> -3.6162213911841676 And Number of steps is ==> 14
# Episode * 15 * Avg Reward is ==> 0.8926536092698154 And Number of steps is ==> 15
# Episode * 16 * Avg Reward is ==> 1.0705459896165324 And Number of steps is ==> 16
# Episode * 17 * Avg Reward is ==> -3.6604803966612875 And Number of steps is ==> 17
# Episode * 18 * Avg Reward is ==> 0.7746905843580845 And Number of steps is ==> 18
# Episode * 19 * Avg Reward is ==> 0.8854711467149109 And Number of steps is ==> 19
# Episode * 20 * Avg Reward is ==> 0.7970462512490951 And Number of steps is ==> 20
# Episode * 21 * Avg Reward is ==> -3.556748464407618 And Number of steps is ==> 21
# Episode * 22 * Avg Reward is ==> -3.554650827077059 And Number of steps is ==> 22
# Episode * 23 * Avg Reward is ==> 0.8583889292741101 And Number of steps is ==> 23
# Episode * 24 * Avg Reward is ==> -3.6101142305879224 And Number of steps is ==> 24
# Episode * 25 * Avg Reward is ==> 0.760951033762268 And Number of steps is ==> 25
# Episode * 26 * Avg Reward is ==> 0.7430270262769391 And Number of steps is ==> 26
# Episode * 27 * Avg Reward is ==> -3.662299259643903 And Number of steps is ==> 27
# Episode * 28 * Avg Reward is ==> -3.9640392664078363 And Number of steps is ==> 28
# Episode * 29 * Avg Reward is ==> -3.6658447509776964 And Number of steps is ==> 29
# Episode * 30 * Avg Reward is ==> 1.0635837994722916 And Number of steps is ==> 30
# Episode * 31 * Avg Reward is ==> -3.660417465081288 And Number of steps is ==> 31
# Episode * 32 * Avg Reward is ==> -4.264061130514564 And Number of steps is ==> 32
# Episode * 33 * Avg Reward is ==> 0.9560676589427668 And Number of steps is ==> 33
# Episode * 34 * Avg Reward is ==> 0.810998308654702 And Number of steps is ==> 34
# Episode * 35 * Avg Reward is ==> -0.021937292003079544 And Number of steps is ==> 35
# Episode * 36 * Avg Reward is ==> 0.7331716947136006 And Number of steps is ==> 36
# Episode * 37 * Avg Reward is ==> -3.61092787651362 And Number of steps is ==> 37
# Episode * 38 * Avg Reward is ==> -3.963961004791547 And Number of steps is ==> 38
# Episode * 39 * Avg Reward is ==> -3.611531825837426 And Number of steps is ==> 39
# Episode * 40 * Avg Reward is ==> 0.8108091475893231 And Number of steps is ==> 40
# Episode * 41 * Avg Reward is ==> 1.0037812442124991 And Number of steps is ==> 41
# Episode * 42 * Avg Reward is ==> -3.616581349012006 And Number of steps is ==> 42
# Episode * 43 * Avg Reward is ==> 0.8484169089344334 And Number of steps is ==> 43
# Episode * 44 * Avg Reward is ==> -3.6101809128567495 And Number of steps is ==> 44
# Episode * 45 * Avg Reward is ==> -4.521893726511168 And Number of steps is ==> 45
# Episode * 46 * Avg Reward is ==> 0.7851490448757537 And Number of steps is ==> 46
# Episode * 47 * Avg Reward is ==> 0.8210634515229241 And Number of steps is ==> 47
# Episode * 48 * Avg Reward is ==> 0.8397094326934657 And Number of steps is ==> 48
# Episode * 49 * Avg Reward is ==> 0.7869679088953523 And Number of steps is ==> 49
# Episode * 50 * Avg Reward is ==> 0.7503299892453434 And Number of steps is ==> 50
# Episode * 51 * Avg Reward is ==> 1.0460589398284035 And Number of steps is ==> 51
# Episode * 52 * Avg Reward is ==> -3.5 And Number of steps is ==> 52
# Episode * 53 * Avg Reward is ==> -0.5819149404241599 And Number of steps is ==> 53
# Episode * 54 * Avg Reward is ==> 0.7971161565902853 And Number of steps is ==> 54
# Episode * 55 * Avg Reward is ==> 0.9240190207209501 And Number of steps is ==> 55
# Episode * 56 * Avg Reward is ==> 0.848568339496094 And Number of steps is ==> 56
# Episode * 57 * Avg Reward is ==> 0.7876209436150824 And Number of steps is ==> 57
# Episode * 58 * Avg Reward is ==> -3.6121209077496332 And Number of steps is ==> 58
# Episode * 59 * Avg Reward is ==> -4.5224812441274205 And Number of steps is ==> 59
# Episode * 60 * Avg Reward is ==> 0.9573275660154106 And Number of steps is ==> 60
# Episode * 61 * Avg Reward is ==> -3.610065408297961 And Number of steps is ==> 61
# Episode * 62 * Avg Reward is ==> 0.8820529144560364 And Number of steps is ==> 62
# Episode * 63 * Avg Reward is ==> 0.8526571892794461 And Number of steps is ==> 63
# Episode * 64 * Avg Reward is ==> -3.6600944818149714 And Number of steps is ==> 64
# Episode * 65 * Avg Reward is ==> 0.8239427079993733 And Number of steps is ==> 65
# Episode * 66 * Avg Reward is ==> 1.4999999999999996 And Number of steps is ==> 66
# Episode * 67 * Avg Reward is ==> -3.9657606001042587 And Number of steps is ==> 67
# Episode * 68 * Avg Reward is ==> 0.7362706238571839 And Number of steps is ==> 68
# Episode * 69 * Avg Reward is ==> -3.917673450903213 And Number of steps is ==> 69
# Episode * 70 * Avg Reward is ==> 0.7490369785138734 And Number of steps is ==> 70
# Episode * 71 * Avg Reward is ==> -3.9619747920974175 And Number of steps is ==> 71
# Episode * 72 * Avg Reward is ==> 0.7910184156599704 And Number of steps is ==> 72
# Episode * 73 * Avg Reward is ==> -3.6101249916807134 And Number of steps is ==> 73
# Episode * 74 * Avg Reward is ==> 0.7466404012405464 And Number of steps is ==> 74
# Episode * 75 * Avg Reward is ==> 0.8191174977639173 And Number of steps is ==> 75
# Episode * 76 * Avg Reward is ==> -3.6121177168599994 And Number of steps is ==> 76
# Episode * 77 * Avg Reward is ==> -4.263065017978947 And Number of steps is ==> 77
# Episode * 78 * Avg Reward is ==> 0.7413589891750505 And Number of steps is ==> 78
# Episode * 79 * Avg Reward is ==> 0.9277221280808275 And Number of steps is ==> 79
# Episode * 80 * Avg Reward is ==> -3.5000000000000027 And Number of steps is ==> 80
# Episode * 81 * Avg Reward is ==> -3.9611088989586434 And Number of steps is ==> 81
# Episode * 82 * Avg Reward is ==> -4.26365625207278 And Number of steps is ==> 82
# Episode * 83 * Avg Reward is ==> 0.804710065998713 And Number of steps is ==> 83
# Episode * 84 * Avg Reward is ==> -3.6653819031784254 And Number of steps is ==> 84
# Episode * 85 * Avg Reward is ==> -1.0773120017562607 And Number of steps is ==> 85
# Episode * 86 * Avg Reward is ==> 0.7948691258915229 And Number of steps is ==> 86
# Episode * 87 * Avg Reward is ==> -3.5 And Number of steps is ==> 87
# Episode * 88 * Avg Reward is ==> -3.96110209825573 And Number of steps is ==> 88
# Episode * 89 * Avg Reward is ==> -4.264363832470176 And Number of steps is ==> 89
# Episode * 90 * Avg Reward is ==> 0.7620105088535389 And Number of steps is ==> 90
# Episode * 91 * Avg Reward is ==> 0.8463814774720936 And Number of steps is ==> 91
# Episode * 92 * Avg Reward is ==> 0.7739325189421702 And Number of steps is ==> 92
# Episode * 93 * Avg Reward is ==> 1.0797892318919824 And Number of steps is ==> 93
# Episode * 94 * Avg Reward is ==> -3.660677611251458 And Number of steps is ==> 94
# Episode * 95 * Avg Reward is ==> -3.567448209800343 And Number of steps is ==> 95
# Episode * 96 * Avg Reward is ==> -3.9185915601517456 And Number of steps is ==> 96
# Episode * 97 * Avg Reward is ==> -5.1434874467858025 And Number of steps is ==> 97
# Episode * 98 * Avg Reward is ==> -4.266338527145614 And Number of steps is ==> 98
# Episode * 99 * Avg Reward is ==> 0.789373257837364 And Number of steps is ==> 99
# Episode * 100 * Avg Reward is ==> 0.7758729121889925 And Number of steps is ==> 100
# Episode * 101 * Avg Reward is ==> -3.9203431186901114 And Number of steps is ==> 101
# Episode * 102 * Avg Reward is ==> -0.2686400139251059 And Number of steps is ==> 102
# Episode * 103 * Avg Reward is ==> -1.0661463465951813 And Number of steps is ==> 103
# Episode * 104 * Avg Reward is ==> -3.664215314391698 And Number of steps is ==> 104
# Episode * 105 * Avg Reward is ==> -3.664735019137107 And Number of steps is ==> 105
# Episode * 106 * Avg Reward is ==> 0.8121009583902353 And Number of steps is ==> 106
# Episode * 107 * Avg Reward is ==> 1.0949715865329583 And Number of steps is ==> 107
# Episode * 108 * Avg Reward is ==> 0.7776377584956948 And Number of steps is ==> 108
# Episode * 109 * Avg Reward is ==> -3.6601134998911773 And Number of steps is ==> 109
# Episode * 110 * Avg Reward is ==> 1.4999999999999987 And Number of steps is ==> 110
# Episode * 111 * Avg Reward is ==> 0.7922795845565125 And Number of steps is ==> 111
# Episode * 112 * Avg Reward is ==> 0.7839427590082888 And Number of steps is ==> 112
# Episode * 113 * Avg Reward is ==> 0.793583213079246 And Number of steps is ==> 113
# Episode * 114 * Avg Reward is ==> -3.6109188268424264 And Number of steps is ==> 114
# Episode * 115 * Avg Reward is ==> 0.9700578791555777 And Number of steps is ==> 115
# Episode * 116 * Avg Reward is ==> 0.8306552974041871 And Number of steps is ==> 116
# Episode * 117 * Avg Reward is ==> 0.7531732754612253 And Number of steps is ==> 117
# Episode * 118 * Avg Reward is ==> -3.9647380793541087 And Number of steps is ==> 118
# Episode * 119 * Avg Reward is ==> -4.5687348259938 And Number of steps is ==> 119
# Episode * 120 * Avg Reward is ==> 0.7918681006699476 And Number of steps is ==> 120
# Episode * 121 * Avg Reward is ==> -3.5579768313517617 And Number of steps is ==> 121
# Episode * 122 * Avg Reward is ==> 0.7738371957011527 And Number of steps is ==> 122
# Episode * 123 * Avg Reward is ==> 0.7519014758562952 And Number of steps is ==> 123
# Episode * 124 * Avg Reward is ==> -4.218738394503442 And Number of steps is ==> 124
# Episode * 125 * Avg Reward is ==> -3.961047414964738 And Number of steps is ==> 125
# Episode * 126 * Avg Reward is ==> 0.7898909228952539 And Number of steps is ==> 126
# Episode * 127 * Avg Reward is ==> 0.8448360225150463 And Number of steps is ==> 127
# Episode * 128 * Avg Reward is ==> 0.744918814636266 And Number of steps is ==> 128
# Episode * 129 * Avg Reward is ==> 0.8055407597782848 And Number of steps is ==> 129
# Episode * 130 * Avg Reward is ==> -3.6119521228644063 And Number of steps is ==> 130
# Episode * 131 * Avg Reward is ==> 1.0375650357945816 And Number of steps is ==> 131
# Episode * 132 * Avg Reward is ==> -4.521022005798164 And Number of steps is ==> 132
# Episode * 133 * Avg Reward is ==> 0.8091317488018406 And Number of steps is ==> 133
# Episode * 134 * Avg Reward is ==> -3.6124004744092604 And Number of steps is ==> 134
# Episode * 135 * Avg Reward is ==> 0.8934607633669257 And Number of steps is ==> 135
# Episode * 136 * Avg Reward is ==> 0.7929231149924266 And Number of steps is ==> 136
# Episode * 137 * Avg Reward is ==> 0.8496790201703781 And Number of steps is ==> 137
# Episode * 138 * Avg Reward is ==> 0.8535204862616492 And Number of steps is ==> 138
# Episode * 139 * Avg Reward is ==> -3.500000000000001 And Number of steps is ==> 139
# Episode * 140 * Avg Reward is ==> 0.8030859986526908 And Number of steps is ==> 140
# Episode * 141 * Avg Reward is ==> -3.6192028354740247 And Number of steps is ==> 141
# Episode * 142 * Avg Reward is ==> -3.619388377040395 And Number of steps is ==> 142
# Episode * 143 * Avg Reward is ==> -4.264011827095452 And Number of steps is ==> 143
# Episode * 144 * Avg Reward is ==> -3.5536015681125726 And Number of steps is ==> 144
# Episode * 145 * Avg Reward is ==> -3.500000000000001 And Number of steps is ==> 145
# Episode * 146 * Avg Reward is ==> -3.558788491941808 And Number of steps is ==> 146
# Episode * 147 * Avg Reward is ==> -3.9626211122048938 And Number of steps is ==> 147
# Episode * 148 * Avg Reward is ==> -3.6640421128139935 And Number of steps is ==> 148
# Episode * 149 * Avg Reward is ==> 0.7779443968889974 And Number of steps is ==> 149
# Episode * 150 * Avg Reward is ==> 0.7790191520264665 And Number of steps is ==> 150
# Episode * 151 * Avg Reward is ==> 0.7507114253160562 And Number of steps is ==> 151
# Episode * 152 * Avg Reward is ==> -3.56121944537992 And Number of steps is ==> 152
# Episode * 153 * Avg Reward is ==> -3.9616894469613593 And Number of steps is ==> 153
# Episode * 154 * Avg Reward is ==> 0.7680094542692383 And Number of steps is ==> 154
# Episode * 155 * Avg Reward is ==> 0.81499159695197 And Number of steps is ==> 155
# Episode * 156 * Avg Reward is ==> 0.7652433160296381 And Number of steps is ==> 156
# Episode * 157 * Avg Reward is ==> 0.7959531533993365 And Number of steps is ==> 157
# Episode * 158 * Avg Reward is ==> -3.500000000000001 And Number of steps is ==> 158
# Episode * 159 * Avg Reward is ==> 0.8044243250533221 And Number of steps is ==> 159
# Episode * 160 * Avg Reward is ==> 0.7785937511446331 And Number of steps is ==> 160
# Episode * 161 * Avg Reward is ==> -3.5 And Number of steps is ==> 161
# Episode * 162 * Avg Reward is ==> 1.0373431187718865 And Number of steps is ==> 162
# Episode * 163 * Avg Reward is ==> 0.7375660639047131 And Number of steps is ==> 163
# Episode * 164 * Avg Reward is ==> -3.96277925951036 And Number of steps is ==> 164
# Episode * 165 * Avg Reward is ==> -3.9649872269361963 And Number of steps is ==> 165
# Episode * 166 * Avg Reward is ==> -3.6119872698841355 And Number of steps is ==> 166
# Episode * 167 * Avg Reward is ==> 0.7999291854058516 And Number of steps is ==> 167
# Episode * 168 * Avg Reward is ==> -3.6606226485655724 And Number of steps is ==> 168
# Episode * 169 * Avg Reward is ==> -4.575094640245757 And Number of steps is ==> 169
# Episode * 170 * Avg Reward is ==> -3.6645429309507165 And Number of steps is ==> 170
# Episode * 171 * Avg Reward is ==> 1.038868401667769 And Number of steps is ==> 171
# Episode * 172 * Avg Reward is ==> 0.8296593547046471 And Number of steps is ==> 172
# Episode * 173 * Avg Reward is ==> -3.6600987247968617 And Number of steps is ==> 173
# Episode * 174 * Avg Reward is ==> -4.263772831453361 And Number of steps is ==> 174
# Episode * 175 * Avg Reward is ==> 0.763125655227016 And Number of steps is ==> 175
# Episode * 176 * Avg Reward is ==> 1.4999999999999987 And Number of steps is ==> 176
# Episode * 177 * Avg Reward is ==> 0.36618147795727 And Number of steps is ==> 177
# Episode * 178 * Avg Reward is ==> 0.840972076810322 And Number of steps is ==> 178
# Episode * 179 * Avg Reward is ==> 0.8538399860893044 And Number of steps is ==> 179
# Episode * 180 * Avg Reward is ==> 0.8294290487925657 And Number of steps is ==> 180
# Episode * 181 * Avg Reward is ==> -3.919635714903621 And Number of steps is ==> 181
# Episode * 182 * Avg Reward is ==> -3.5550922352914376 And Number of steps is ==> 182
# Episode * 183 * Avg Reward is ==> -3.660106663018027 And Number of steps is ==> 183
# Episode * 184 * Avg Reward is ==> 0.7951631723188899 And Number of steps is ==> 184
# Episode * 185 * Avg Reward is ==> 0.7632055396004136 And Number of steps is ==> 185
# Episode * 186 * Avg Reward is ==> -1.0941902263548136 And Number of steps is ==> 186
# Episode * 187 * Avg Reward is ==> 0.8449977523427471 And Number of steps is ==> 187
# Episode * 188 * Avg Reward is ==> 0.8430039093389918 And Number of steps is ==> 188
# Episode * 189 * Avg Reward is ==> 0.7496893613142522 And Number of steps is ==> 189
# Episode * 190 * Avg Reward is ==> 0.7752499426919541 And Number of steps is ==> 190
# Episode * 191 * Avg Reward is ==> 0.7679713971467603 And Number of steps is ==> 191
# Episode * 192 * Avg Reward is ==> -4.264298255571335 And Number of steps is ==> 192
# Episode * 193 * Avg Reward is ==> -3.553170181731042 And Number of steps is ==> 193
# Episode * 194 * Avg Reward is ==> -3.6103618868202103 And Number of steps is ==> 194
# Episode * 195 * Avg Reward is ==> -3.663307839199414 And Number of steps is ==> 195
# Episode * 196 * Avg Reward is ==> -3.66206651925023 And Number of steps is ==> 196
# Episode * 197 * Avg Reward is ==> 0.7469371712481163 And Number of steps is ==> 197
# Episode * 198 * Avg Reward is ==> 0.7538145758841335 And Number of steps is ==> 198
# Episode * 199 * Avg Reward is ==> -3.9663605278964127 And Number of steps is ==> 199
# Episode * 200 * Avg Reward is ==> 0.8211029337713909 And Number of steps is ==> 200
# Episode * 201 * Avg Reward is ==> 1.083785120537165 And Number of steps is ==> 201
# Episode * 202 * Avg Reward is ==> 0.7552304724985206 And Number of steps is ==> 202
# Episode * 203 * Avg Reward is ==> 0.8542010740033849 And Number of steps is ==> 203
# Episode * 204 * Avg Reward is ==> -3.6659811614384736 And Number of steps is ==> 204
# Episode * 205 * Avg Reward is ==> 0.9667446609873084 And Number of steps is ==> 205
# Episode * 206 * Avg Reward is ==> -1.0478102310516506 And Number of steps is ==> 206
# Episode * 207 * Avg Reward is ==> 0.8045248006241851 And Number of steps is ==> 207
# Episode * 208 * Avg Reward is ==> 0.7653175005263951 And Number of steps is ==> 208
# Episode * 209 * Avg Reward is ==> 0.8284361412751556 And Number of steps is ==> 209
# Episode * 210 * Avg Reward is ==> -3.919115832653643 And Number of steps is ==> 210
# Episode * 211 * Avg Reward is ==> -3.610106796941867 And Number of steps is ==> 211
# Episode * 212 * Avg Reward is ==> -3.5 And Number of steps is ==> 212
# Episode * 213 * Avg Reward is ==> -4.265256845122417 And Number of steps is ==> 213
# Episode * 214 * Avg Reward is ==> 0.7650902640017379 And Number of steps is ==> 214
# Episode * 215 * Avg Reward is ==> -3.5568222699410414 And Number of steps is ==> 215
# Episode * 216 * Avg Reward is ==> -3.6113331023229023 And Number of steps is ==> 216
# Episode * 217 * Avg Reward is ==> -3.9171108563710364 And Number of steps is ==> 217
# Episode * 218 * Avg Reward is ==> -3.961157803588267 And Number of steps is ==> 218
# Episode * 219 * Avg Reward is ==> -3.610337582937864 And Number of steps is ==> 219
# Episode * 220 * Avg Reward is ==> -3.6107135328743625 And Number of steps is ==> 220
# Episode * 221 * Avg Reward is ==> -4.874716601365673 And Number of steps is ==> 221
# Episode * 222 * Avg Reward is ==> 0.7714866674130434 And Number of steps is ==> 222
# Episode * 223 * Avg Reward is ==> 0.784446762881144 And Number of steps is ==> 223
# Episode * 224 * Avg Reward is ==> -3.662483000242724 And Number of steps is ==> 224
# Episode * 225 * Avg Reward is ==> -3.5582378736119606 And Number of steps is ==> 225
# Episode * 226 * Avg Reward is ==> -3.5 And Number of steps is ==> 226
# Episode * 227 * Avg Reward is ==> -3.9611858904443813 And Number of steps is ==> 227
# Episode * 228 * Avg Reward is ==> 0.8102951884797545 And Number of steps is ==> 228
# Episode * 229 * Avg Reward is ==> 0.7457462694167791 And Number of steps is ==> 229
# Episode * 230 * Avg Reward is ==> -3.6606256264750208 And Number of steps is ==> 230
# Episode * 231 * Avg Reward is ==> -3.560930710275154 And Number of steps is ==> 231
# Episode * 232 * Avg Reward is ==> -3.660351479123014 And Number of steps is ==> 232
# Episode * 233 * Avg Reward is ==> 0.8280186449959537 And Number of steps is ==> 233
# Episode * 234 * Avg Reward is ==> 0.7813354711387437 And Number of steps is ==> 234
# Episode * 235 * Avg Reward is ==> 0.7683926611447397 And Number of steps is ==> 235
# Episode * 236 * Avg Reward is ==> 0.8450329776067264 And Number of steps is ==> 236
# Episode * 237 * Avg Reward is ==> -3.6168550881876933 And Number of steps is ==> 237
# Episode * 238 * Avg Reward is ==> -3.960748210152585 And Number of steps is ==> 238
# Episode * 239 * Avg Reward is ==> 0.8265670073199873 And Number of steps is ==> 239
# Episode * 240 * Avg Reward is ==> 0.7455874027988018 And Number of steps is ==> 240
# Episode * 241 * Avg Reward is ==> 1.0769661529995997 And Number of steps is ==> 241
# Episode * 242 * Avg Reward is ==> 0.7770324327003271 And Number of steps is ==> 242
# Episode * 243 * Avg Reward is ==> -3.6195758498347876 And Number of steps is ==> 243
# Episode * 244 * Avg Reward is ==> 0.7513545005875868 And Number of steps is ==> 244
# Episode * 245 * Avg Reward is ==> 1.0718782686220614 And Number of steps is ==> 245
# Episode * 246 * Avg Reward is ==> -4.265671711793354 And Number of steps is ==> 246
# Episode * 247 * Avg Reward is ==> 0.8090001009840279 And Number of steps is ==> 247
# Episode * 248 * Avg Reward is ==> -0.6275965818067075 And Number of steps is ==> 248
# Episode * 249 * Avg Reward is ==> 1.0970577840980709 And Number of steps is ==> 249
# Episode * 250 * Avg Reward is ==> -3.963019147195895 And Number of steps is ==> 250
# Episode * 251 * Avg Reward is ==> 0.8474536287956335 And Number of steps is ==> 251
# Episode * 252 * Avg Reward is ==> 0.7672965513140187 And Number of steps is ==> 252
# Episode * 253 * Avg Reward is ==> 0.7947933704751626 And Number of steps is ==> 253
# Episode * 254 * Avg Reward is ==> 0.791503836128806 And Number of steps is ==> 254
# Episode * 255 * Avg Reward is ==> -3.6133507370669777 And Number of steps is ==> 255
# Episode * 256 * Avg Reward is ==> 0.7987359754072084 And Number of steps is ==> 256
# Episode * 257 * Avg Reward is ==> -4.264687326809101 And Number of steps is ==> 257
# Episode * 258 * Avg Reward is ==> 0.8294506912641662 And Number of steps is ==> 258
# Episode * 259 * Avg Reward is ==> -3.556053774778565 And Number of steps is ==> 259
# Episode * 260 * Avg Reward is ==> -4.218473055919377 And Number of steps is ==> 260
# Episode * 261 * Avg Reward is ==> -1.0395777433043734 And Number of steps is ==> 261
# Episode * 262 * Avg Reward is ==> 0.7849537034291225 And Number of steps is ==> 262
# Episode * 263 * Avg Reward is ==> 0.81204919805028 And Number of steps is ==> 263
# Episode * 264 * Avg Reward is ==> -3.9640950717936705 And Number of steps is ==> 264
# Episode * 265 * Avg Reward is ==> -0.03969634090563416 And Number of steps is ==> 265
# Episode * 266 * Avg Reward is ==> -3.611035026104692 And Number of steps is ==> 266
# Episode * 267 * Avg Reward is ==> 0.9105755254517245 And Number of steps is ==> 267
# Episode * 268 * Avg Reward is ==> -4.263059647010342 And Number of steps is ==> 268
# Episode * 269 * Avg Reward is ==> -3.663459253579081 And Number of steps is ==> 269
# Episode * 270 * Avg Reward is ==> 0.7497541195762276 And Number of steps is ==> 270
# Episode * 271 * Avg Reward is ==> -4.52422436776813 And Number of steps is ==> 271
# Episode * 272 * Avg Reward is ==> 0.8111621281021522 And Number of steps is ==> 272
# Episode * 273 * Avg Reward is ==> 0.7801286974035136 And Number of steps is ==> 273
# Episode * 274 * Avg Reward is ==> -3.6101266971596333 And Number of steps is ==> 274
# Episode * 275 * Avg Reward is ==> 0.9100695937410741 And Number of steps is ==> 275
# Episode * 276 * Avg Reward is ==> -3.610843245002689 And Number of steps is ==> 276
# Episode * 277 * Avg Reward is ==> 0.8589498979757714 And Number of steps is ==> 277
# Episode * 278 * Avg Reward is ==> -3.918142718199019 And Number of steps is ==> 278
# Episode * 279 * Avg Reward is ==> -4.2185566378931325 And Number of steps is ==> 279
# Episode * 280 * Avg Reward is ==> 0.9377580574312419 And Number of steps is ==> 280
# Episode * 281 * Avg Reward is ==> -3.6615333942177566 And Number of steps is ==> 281
# Episode * 282 * Avg Reward is ==> -3.6602719635078302 And Number of steps is ==> 282
# Episode * 283 * Avg Reward is ==> -3.6640367063872836 And Number of steps is ==> 283
# Episode * 284 * Avg Reward is ==> 0.7634328526077162 And Number of steps is ==> 284
# Episode * 285 * Avg Reward is ==> -3.962017665804826 And Number of steps is ==> 285
# Episode * 286 * Avg Reward is ==> 0.8711658396094626 And Number of steps is ==> 286
# Episode * 287 * Avg Reward is ==> -3.5 And Number of steps is ==> 287
# Episode * 288 * Avg Reward is ==> 1.0400229685484308 And Number of steps is ==> 288
# Episode * 289 * Avg Reward is ==> -3.6131009367251226 And Number of steps is ==> 289
# Episode * 290 * Avg Reward is ==> -3.9614624477464533 And Number of steps is ==> 290
# Episode * 291 * Avg Reward is ==> 0.8074258004516228 And Number of steps is ==> 291
# Episode * 292 * Avg Reward is ==> -3.9185237517107625 And Number of steps is ==> 292
# Episode * 293 * Avg Reward is ==> 0.7486971255966732 And Number of steps is ==> 293
# Episode * 294 * Avg Reward is ==> 0.8373877910476342 And Number of steps is ==> 294
# Episode * 295 * Avg Reward is ==> -3.9648914371776653 And Number of steps is ==> 295
# Episode * 296 * Avg Reward is ==> 0.77358275592234 And Number of steps is ==> 296
# Episode * 297 * Avg Reward is ==> 0.7884492966119614 And Number of steps is ==> 297
# Episode * 298 * Avg Reward is ==> 0.9236594221116746 And Number of steps is ==> 298
# Episode * 299 * Avg Reward is ==> -3.6602479219366777 And Number of steps is ==> 299
# Episode * 300 * Avg Reward is ==> -3.6609741002370955 And Number of steps is ==> 300
# Episode * 301 * Avg Reward is ==> 1.5 And Number of steps is ==> 301
# Episode * 302 * Avg Reward is ==> -3.6618989409516303 And Number of steps is ==> 302
# Episode * 303 * Avg Reward is ==> 0.8524129303298279 And Number of steps is ==> 303
# Episode * 304 * Avg Reward is ==> -3.611537917741633 And Number of steps is ==> 304
# Episode * 305 * Avg Reward is ==> -3.618268158119754 And Number of steps is ==> 305
# Episode * 306 * Avg Reward is ==> 0.8015170343957836 And Number of steps is ==> 306
# Episode * 307 * Avg Reward is ==> 0.7825298988001903 And Number of steps is ==> 307
# Episode * 308 * Avg Reward is ==> 0.8230443545818789 And Number of steps is ==> 308
# Episode * 309 * Avg Reward is ==> -3.6600839557648945 And Number of steps is ==> 309
# Episode * 310 * Avg Reward is ==> -3.9622887834546576 And Number of steps is ==> 310
# Episode * 311 * Avg Reward is ==> -3.61130884888964 And Number of steps is ==> 311
# Episode * 312 * Avg Reward is ==> -0.6339557866564606 And Number of steps is ==> 312
# Episode * 313 * Avg Reward is ==> -3.5000000000000013 And Number of steps is ==> 313
# Episode * 314 * Avg Reward is ==> -3.6137691207809626 And Number of steps is ==> 314
# Episode * 315 * Avg Reward is ==> -3.9170648401600254 And Number of steps is ==> 315
# Episode * 316 * Avg Reward is ==> -0.27854892252716296 And Number of steps is ==> 316
# Episode * 317 * Avg Reward is ==> 0.5012812387006365 And Number of steps is ==> 317
# Episode * 318 * Avg Reward is ==> -3.552993870600994 And Number of steps is ==> 318
# Episode * 319 * Avg Reward is ==> -0.6938391673843343 And Number of steps is ==> 319
# Episode * 320 * Avg Reward is ==> 0.7599035911649388 And Number of steps is ==> 320
# Episode * 321 * Avg Reward is ==> 0.8151436443361663 And Number of steps is ==> 321
# Episode * 322 * Avg Reward is ==> -3.6605139969954927 And Number of steps is ==> 322
# Episode * 323 * Avg Reward is ==> -3.9663904037581217 And Number of steps is ==> 323
# Episode * 324 * Avg Reward is ==> 0.7535676904545101 And Number of steps is ==> 324
# Episode * 325 * Avg Reward is ==> -3.5502269465449223 And Number of steps is ==> 325
# Episode * 326 * Avg Reward is ==> 0.8870556762593077 And Number of steps is ==> 326
# Episode * 327 * Avg Reward is ==> -3.5679054945148727 And Number of steps is ==> 327
# Episode * 328 * Avg Reward is ==> 0.7752123046617742 And Number of steps is ==> 328
# Episode * 329 * Avg Reward is ==> -3.551118555723582 And Number of steps is ==> 329
# Episode * 330 * Avg Reward is ==> 0.7674261228859732 And Number of steps is ==> 330
# Episode * 331 * Avg Reward is ==> 0.7937948764375852 And Number of steps is ==> 331
# Episode * 332 * Avg Reward is ==> 0.738268831360949 And Number of steps is ==> 332
# Episode * 333 * Avg Reward is ==> -4.56737417298711 And Number of steps is ==> 333
# Episode * 334 * Avg Reward is ==> 0.11865013221067851 And Number of steps is ==> 334
# Episode * 335 * Avg Reward is ==> -3.500000000000001 And Number of steps is ==> 335
# Episode * 336 * Avg Reward is ==> -3.9640087919569984 And Number of steps is ==> 336
# Episode * 337 * Avg Reward is ==> -3.9666964745544733 And Number of steps is ==> 337
# Episode * 338 * Avg Reward is ==> -3.61150474822036 And Number of steps is ==> 338
# Episode * 339 * Avg Reward is ==> -3.5621125421454694 And Number of steps is ==> 339
# Episode * 340 * Avg Reward is ==> 0.8173268173455888 And Number of steps is ==> 340
# Episode * 341 * Avg Reward is ==> -3.919202084490199 And Number of steps is ==> 341
# Episode * 342 * Avg Reward is ==> -3.9609850176187207 And Number of steps is ==> 342
# Episode * 343 * Avg Reward is ==> 0.8570336561829915 And Number of steps is ==> 343
# Episode * 344 * Avg Reward is ==> 0.7997738521327211 And Number of steps is ==> 344
# Episode * 345 * Avg Reward is ==> -3.6604211856439037 And Number of steps is ==> 345
# Episode * 346 * Avg Reward is ==> 0.760373475438892 And Number of steps is ==> 346
# Episode * 347 * Avg Reward is ==> 0.9161849106395991 And Number of steps is ==> 347
# Episode * 348 * Avg Reward is ==> -3.5 And Number of steps is ==> 348
# Episode * 349 * Avg Reward is ==> 0.820052701858849 And Number of steps is ==> 349
# Episode * 350 * Avg Reward is ==> 0.9029222809070744 And Number of steps is ==> 350
# Episode * 351 * Avg Reward is ==> -3.568843972348006 And Number of steps is ==> 351
# Episode * 352 * Avg Reward is ==> -4.263480746199217 And Number of steps is ==> 352
# Episode * 353 * Avg Reward is ==> 0.7732016364881453 And Number of steps is ==> 353
# Episode * 354 * Avg Reward is ==> 0.8509170353077316 And Number of steps is ==> 354
# Episode * 355 * Avg Reward is ==> 1.0714894016330656 And Number of steps is ==> 355
# Episode * 356 * Avg Reward is ==> -3.6132393784535672 And Number of steps is ==> 356
# Episode * 357 * Avg Reward is ==> -3.6197421718077343 And Number of steps is ==> 357
# Episode * 358 * Avg Reward is ==> 0.806216462441883 And Number of steps is ==> 358
# Episode * 359 * Avg Reward is ==> 0.8439030005095652 And Number of steps is ==> 359
# Episode * 360 * Avg Reward is ==> 0.7893181494112784 And Number of steps is ==> 360
# Episode * 361 * Avg Reward is ==> 0.768973747640041 And Number of steps is ==> 361
# Episode * 362 * Avg Reward is ==> -4.569919351641235 And Number of steps is ==> 362
# Episode * 363 * Avg Reward is ==> 0.8104293933053015 And Number of steps is ==> 363
# Episode * 364 * Avg Reward is ==> 0.7591241509355324 And Number of steps is ==> 364
# Episode * 365 * Avg Reward is ==> 0.8811319747353424 And Number of steps is ==> 365
# Episode * 366 * Avg Reward is ==> -3.5000000000000013 And Number of steps is ==> 366
# Episode * 367 * Avg Reward is ==> 0.9421097337032831 And Number of steps is ==> 367
# Episode * 368 * Avg Reward is ==> -1.0648854392205378 And Number of steps is ==> 368
# Episode * 369 * Avg Reward is ==> -3.66028081561846 And Number of steps is ==> 369
# Episode * 370 * Avg Reward is ==> 0.892822047683481 And Number of steps is ==> 370
# Episode * 371 * Avg Reward is ==> -3.6163357982062934 And Number of steps is ==> 371
# Episode * 372 * Avg Reward is ==> -3.6101245275120974 And Number of steps is ==> 372
# Episode * 373 * Avg Reward is ==> 0.7766037446040229 And Number of steps is ==> 373
# Episode * 374 * Avg Reward is ==> -0.014631597756183723 And Number of steps is ==> 374
# Episode * 375 * Avg Reward is ==> -3.661988581301027 And Number of steps is ==> 375
# Episode * 376 * Avg Reward is ==> 1.0416844611180704 And Number of steps is ==> 376
# Episode * 377 * Avg Reward is ==> 0.7749601394900771 And Number of steps is ==> 377
# Episode * 378 * Avg Reward is ==> 0.7674449335925915 And Number of steps is ==> 378
# Episode * 379 * Avg Reward is ==> 0.8321952206063647 And Number of steps is ==> 379
# Episode * 380 * Avg Reward is ==> 0.788958391204986 And Number of steps is ==> 380
# Episode * 381 * Avg Reward is ==> 0.81038065128663 And Number of steps is ==> 381
# Episode * 382 * Avg Reward is ==> 0.7766021518924526 And Number of steps is ==> 382
# Episode * 383 * Avg Reward is ==> 0.7805466317834938 And Number of steps is ==> 383
# Episode * 384 * Avg Reward is ==> 0.7991597685336597 And Number of steps is ==> 384
# Episode * 385 * Avg Reward is ==> -3.6124932906404146 And Number of steps is ==> 385
# Episode * 386 * Avg Reward is ==> -3.6602045154738443 And Number of steps is ==> 386
# Episode * 387 * Avg Reward is ==> 1.0389806202789287 And Number of steps is ==> 387
# Episode * 388 * Avg Reward is ==> 1.4999999999999993 And Number of steps is ==> 388
# Episode * 389 * Avg Reward is ==> -3.9610385741129632 And Number of steps is ==> 389
# Episode * 390 * Avg Reward is ==> -0.5965303363021162 And Number of steps is ==> 390
# Episode * 391 * Avg Reward is ==> 1.0145583876998345 And Number of steps is ==> 391
# Episode * 392 * Avg Reward is ==> 0.10752110880710367 And Number of steps is ==> 392
# Episode * 393 * Avg Reward is ==> 1.038348662083426 And Number of steps is ==> 393
# Episode * 394 * Avg Reward is ==> 1.4998056094287182 And Number of steps is ==> 394
# Episode * 395 * Avg Reward is ==> -3.612775157852139 And Number of steps is ==> 395
# Episode * 396 * Avg Reward is ==> -4.219400397189092 And Number of steps is ==> 396
# Episode * 397 * Avg Reward is ==> 0.7935094881426024 And Number of steps is ==> 397
# Episode * 398 * Avg Reward is ==> -3.5566155818833813 And Number of steps is ==> 398
# Episode * 399 * Avg Reward is ==> 0.8818303148753645 And Number of steps is ==> 399
# Episode * 400 * Avg Reward is ==> -3.6641641968050562 And Number of steps is ==> 400
# Episode * 401 * Avg Reward is ==> 0.7838707607235236 And Number of steps is ==> 401
# Episode * 402 * Avg Reward is ==> -3.6604649312688506 And Number of steps is ==> 402
# Episode * 403 * Avg Reward is ==> 0.7951506987536451 And Number of steps is ==> 403
# Episode * 404 * Avg Reward is ==> -3.9193655888512353 And Number of steps is ==> 404
# Episode * 405 * Avg Reward is ==> -3.6127863545369423 And Number of steps is ==> 405
# Episode * 406 * Avg Reward is ==> -3.9654381096949534 And Number of steps is ==> 406
# Episode * 407 * Avg Reward is ==> -4.567942435935564 And Number of steps is ==> 407
# Episode * 408 * Avg Reward is ==> 0.7528711163632636 And Number of steps is ==> 408
# Episode * 409 * Avg Reward is ==> 0.8098628591869348 And Number of steps is ==> 409
# Episode * 410 * Avg Reward is ==> 0.7336590484052953 And Number of steps is ==> 410
# Episode * 411 * Avg Reward is ==> -3.5000000000000013 And Number of steps is ==> 411
# Episode * 412 * Avg Reward is ==> -4.522213987588785 And Number of steps is ==> 412
# Episode * 413 * Avg Reward is ==> 0.7504310943114028 And Number of steps is ==> 413
# Episode * 414 * Avg Reward is ==> 0.7967771128815577 And Number of steps is ==> 414
# Episode * 415 * Avg Reward is ==> -3.5 And Number of steps is ==> 415
# Episode * 416 * Avg Reward is ==> -3.500000000000001 And Number of steps is ==> 416
# Episode * 417 * Avg Reward is ==> 0.3514665300082689 And Number of steps is ==> 417
# Episode * 418 * Avg Reward is ==> 0.776394476085638 And Number of steps is ==> 418
# Episode * 419 * Avg Reward is ==> 0.802548456808241 And Number of steps is ==> 419
# Episode * 420 * Avg Reward is ==> -3.5000000000000013 And Number of steps is ==> 420
# Episode * 421 * Avg Reward is ==> -3.6637312620881417 And Number of steps is ==> 421
# Episode * 422 * Avg Reward is ==> -3.6135444263226844 And Number of steps is ==> 422
# Episode * 423 * Avg Reward is ==> -4.263107518290121 And Number of steps is ==> 423
# Episode * 424 * Avg Reward is ==> 0.8031503421875301 And Number of steps is ==> 424
# Episode * 425 * Avg Reward is ==> -3.964819420547162 And Number of steps is ==> 425
# Episode * 426 * Avg Reward is ==> -3.9181792515078895 And Number of steps is ==> 426
# Episode * 427 * Avg Reward is ==> 0.8444707756988545 And Number of steps is ==> 427
# Episode * 428 * Avg Reward is ==> 0.8084916897280735 And Number of steps is ==> 428
# Episode * 429 * Avg Reward is ==> 0.7714409798086914 And Number of steps is ==> 429
# Episode * 430 * Avg Reward is ==> 0.8081948647269732 And Number of steps is ==> 430
# Episode * 431 * Avg Reward is ==> 0.9382280461087037 And Number of steps is ==> 431
# Episode * 432 * Avg Reward is ==> -3.6601437337746794 And Number of steps is ==> 432
# Episode * 433 * Avg Reward is ==> -3.9651265797739144 And Number of steps is ==> 433
# Episode * 434 * Avg Reward is ==> -3.6184379457404434 And Number of steps is ==> 434
# Episode * 435 * Avg Reward is ==> 0.8058812815922096 And Number of steps is ==> 435
# Episode * 436 * Avg Reward is ==> -3.6633754862967605 And Number of steps is ==> 436
# Episode * 437 * Avg Reward is ==> -3.611063433038653 And Number of steps is ==> 437
# Episode * 438 * Avg Reward is ==> 0.7663096014506444 And Number of steps is ==> 438
# Episode * 439 * Avg Reward is ==> 0.793634513614536 And Number of steps is ==> 439
# Episode * 440 * Avg Reward is ==> 0.8435222342277591 And Number of steps is ==> 440
# Episode * 441 * Avg Reward is ==> 0.8295375681290513 And Number of steps is ==> 441
# Episode * 442 * Avg Reward is ==> 0.7713197474366073 And Number of steps is ==> 442
# Episode * 443 * Avg Reward is ==> 0.7847391876014846 And Number of steps is ==> 443
# Episode * 444 * Avg Reward is ==> 0.7474171689574368 And Number of steps is ==> 444
# Episode * 445 * Avg Reward is ==> -3.568668915900851 And Number of steps is ==> 445
# Episode * 446 * Avg Reward is ==> -0.3775311875521048 And Number of steps is ==> 446
# Episode * 447 * Avg Reward is ==> 0.8332496934551349 And Number of steps is ==> 447
# Episode * 448 * Avg Reward is ==> 0.8058853381650888 And Number of steps is ==> 448
# Episode * 449 * Avg Reward is ==> 0.7571830331512244 And Number of steps is ==> 449
# Episode * 450 * Avg Reward is ==> -3.9185387038069415 And Number of steps is ==> 450
# Episode * 451 * Avg Reward is ==> -4.220774059941138 And Number of steps is ==> 451
# Episode * 452 * Avg Reward is ==> 0.9375272869045833 And Number of steps is ==> 452
# Episode * 453 * Avg Reward is ==> 0.8507524935542001 And Number of steps is ==> 453
# Episode * 454 * Avg Reward is ==> -3.6102029413520045 And Number of steps is ==> 454
# Episode * 455 * Avg Reward is ==> 0.7782454474736857 And Number of steps is ==> 455
# Episode * 456 * Avg Reward is ==> 0.9704826308757999 And Number of steps is ==> 456
# Episode * 457 * Avg Reward is ==> -3.9614529491956203 And Number of steps is ==> 457
# Episode * 458 * Avg Reward is ==> -3.5523962038994794 And Number of steps is ==> 458
# Episode * 459 * Avg Reward is ==> 0.7918033510835814 And Number of steps is ==> 459
# Episode * 460 * Avg Reward is ==> 0.7619747412002816 And Number of steps is ==> 460
# Episode * 461 * Avg Reward is ==> 0.8424277346378549 And Number of steps is ==> 461
# Episode * 462 * Avg Reward is ==> -4.2654363182331965 And Number of steps is ==> 462
# Episode * 463 * Avg Reward is ==> 0.7654913673902181 And Number of steps is ==> 463
# Episode * 464 * Avg Reward is ==> -3.919230806385851 And Number of steps is ==> 464
# Episode * 465 * Avg Reward is ==> -3.551287786053602 And Number of steps is ==> 465
# Episode * 466 * Avg Reward is ==> 0.7759714355979501 And Number of steps is ==> 466
# Episode * 467 * Avg Reward is ==> 0.7847286036409559 And Number of steps is ==> 467
# Episode * 468 * Avg Reward is ==> -3.561940628220357 And Number of steps is ==> 468
# Episode * 469 * Avg Reward is ==> 0.8442274281556769 And Number of steps is ==> 469
# Episode * 470 * Avg Reward is ==> 0.7384816493587948 And Number of steps is ==> 470
# Episode * 471 * Avg Reward is ==> 0.772462386053476 And Number of steps is ==> 471
# Episode * 472 * Avg Reward is ==> -0.24687063042893734 And Number of steps is ==> 472
# Episode * 473 * Avg Reward is ==> -5.187159635019178 And Number of steps is ==> 473
# Episode * 474 * Avg Reward is ==> -3.5 And Number of steps is ==> 474
# Episode * 475 * Avg Reward is ==> -3.663029851171116 And Number of steps is ==> 475
# Episode * 476 * Avg Reward is ==> 1.0006304183140409 And Number of steps is ==> 476
# Episode * 477 * Avg Reward is ==> 0.8207769178616686 And Number of steps is ==> 477
# Episode * 478 * Avg Reward is ==> 1.4999999999999987 And Number of steps is ==> 478
# Episode * 479 * Avg Reward is ==> -3.66022902674856 And Number of steps is ==> 479
# Episode * 480 * Avg Reward is ==> -3.5506364680028666 And Number of steps is ==> 480
# Episode * 481 * Avg Reward is ==> -3.5589168683643946 And Number of steps is ==> 481
# Episode * 482 * Avg Reward is ==> -3.6645790273682786 And Number of steps is ==> 482
# Episode * 483 * Avg Reward is ==> 0.8510410547778712 And Number of steps is ==> 483
# Episode * 484 * Avg Reward is ==> -3.563398914674879 And Number of steps is ==> 484
# Episode * 485 * Avg Reward is ==> 0.7927178320902155 And Number of steps is ==> 485
# Episode * 486 * Avg Reward is ==> 0.7845386758554209 And Number of steps is ==> 486
# Episode * 487 * Avg Reward is ==> 0.7880882498975639 And Number of steps is ==> 487
# Episode * 488 * Avg Reward is ==> -4.268645576001594 And Number of steps is ==> 488
# Episode * 489 * Avg Reward is ==> -4.26421788274999 And Number of steps is ==> 489
# Episode * 490 * Avg Reward is ==> 0.7713463466527111 And Number of steps is ==> 490
# Episode * 491 * Avg Reward is ==> 0.8120878436360037 And Number of steps is ==> 491
# Episode * 492 * Avg Reward is ==> -3.618870757028831 And Number of steps is ==> 492
# Episode * 493 * Avg Reward is ==> 0.7562079754475937 And Number of steps is ==> 493
# Episode * 494 * Avg Reward is ==> -1.026852387550465 And Number of steps is ==> 494
# Episode * 495 * Avg Reward is ==> 0.8714846799789683 And Number of steps is ==> 495
# Episode * 496 * Avg Reward is ==> 0.7861141189374744 And Number of steps is ==> 496
# Episode * 497 * Avg Reward is ==> -3.6100026466024957 And Number of steps is ==> 497
# Episode * 498 * Avg Reward is ==> 0.7884522986907626 And Number of steps is ==> 498
# Episode * 499 * Avg Reward is ==> 1.0387910074950255 And Number of steps is ==> 499
# Episode * 500 * Avg Reward is ==> 0.7663041165669089 And Number of steps is ==> 500
# Episode * 501 * Avg Reward is ==> -0.6763705775076094 And Number of steps is ==> 501
# Episode * 502 * Avg Reward is ==> -4.267666961493886 And Number of steps is ==> 502
# Episode * 503 * Avg Reward is ==> -3.6106077944846646 And Number of steps is ==> 503
# Episode * 504 * Avg Reward is ==> -4.569540973884848 And Number of steps is ==> 504
# Episode * 505 * Avg Reward is ==> -3.610598302378931 And Number of steps is ==> 505
# Episode * 506 * Avg Reward is ==> 0.8003810690528086 And Number of steps is ==> 506
# Episode * 507 * Avg Reward is ==> -3.6103847026487714 And Number of steps is ==> 507
# Episode * 508 * Avg Reward is ==> -3.610399600859565 And Number of steps is ==> 508
# Episode * 509 * Avg Reward is ==> 0.7765398742135514 And Number of steps is ==> 509
# Episode * 510 * Avg Reward is ==> 0.7850266629332129 And Number of steps is ==> 510
# Episode * 511 * Avg Reward is ==> -3.610073146789387 And Number of steps is ==> 511
# Episode * 512 * Avg Reward is ==> 0.7678115175684834 And Number of steps is ==> 512
# Episode * 513 * Avg Reward is ==> -3.6175258553413747 And Number of steps is ==> 513
# Episode * 514 * Avg Reward is ==> 0.7994997537025238 And Number of steps is ==> 514
# Episode * 515 * Avg Reward is ==> 0.7714470279571348 And Number of steps is ==> 515
# Episode * 516 * Avg Reward is ==> -3.569796206623142 And Number of steps is ==> 516
# Episode * 517 * Avg Reward is ==> 1.4999999999999998 And Number of steps is ==> 517
# Episode * 518 * Avg Reward is ==> 0.8554893640046597 And Number of steps is ==> 518
# Episode * 519 * Avg Reward is ==> 0.8123901020549651 And Number of steps is ==> 519
# Episode * 520 * Avg Reward is ==> 0.4335846051544811 And Number of steps is ==> 520
# Episode * 521 * Avg Reward is ==> -3.660427764980107 And Number of steps is ==> 521
# Episode * 522 * Avg Reward is ==> -3.9609132247492105 And Number of steps is ==> 522
# Episode * 523 * Avg Reward is ==> 0.8034974569040407 And Number of steps is ==> 523
# Episode * 524 * Avg Reward is ==> -3.6608607540442493 And Number of steps is ==> 524
# Episode * 525 * Avg Reward is ==> -3.5591033922076347 And Number of steps is ==> 525
# Episode * 526 * Avg Reward is ==> -5.136517499179556 And Number of steps is ==> 526
# Episode * 527 * Avg Reward is ==> -3.6623143464017494 And Number of steps is ==> 527
# Episode * 528 * Avg Reward is ==> -3.96344225103298 And Number of steps is ==> 528
# Episode * 529 * Avg Reward is ==> -3.614399629994056 And Number of steps is ==> 529
# Episode * 530 * Avg Reward is ==> -3.96545005207757 And Number of steps is ==> 530
# Episode * 531 * Avg Reward is ==> 0.8195171278702086 And Number of steps is ==> 531
# Episode * 532 * Avg Reward is ==> 0.9292662290439715 And Number of steps is ==> 532
# Episode * 533 * Avg Reward is ==> 0.7780236436131911 And Number of steps is ==> 533
# Episode * 534 * Avg Reward is ==> -3.6100270068086173 And Number of steps is ==> 534
# Episode * 535 * Avg Reward is ==> -3.6627937396942323 And Number of steps is ==> 535
# Episode * 536 * Avg Reward is ==> 0.7764078057894567 And Number of steps is ==> 536
# Episode * 537 * Avg Reward is ==> 0.11914879948971482 And Number of steps is ==> 537
# Episode * 538 * Avg Reward is ==> 0.880908294922264 And Number of steps is ==> 538
# Episode * 539 * Avg Reward is ==> -3.611000767084916 And Number of steps is ==> 539
# Episode * 540 * Avg Reward is ==> 0.7599904475748905 And Number of steps is ==> 540
# Episode * 541 * Avg Reward is ==> 0.8906113234654871 And Number of steps is ==> 541
# Episode * 542 * Avg Reward is ==> -3.613028909247732 And Number of steps is ==> 542
# Episode * 543 * Avg Reward is ==> -3.5682543238709705 And Number of steps is ==> 543
# Episode * 544 * Avg Reward is ==> 0.8102857664528245 And Number of steps is ==> 544
# Episode * 545 * Avg Reward is ==> -3.500000000000001 And Number of steps is ==> 545
# Episode * 546 * Avg Reward is ==> 0.7958898316258727 And Number of steps is ==> 546
# Episode * 547 * Avg Reward is ==> 1.0346360293198704 And Number of steps is ==> 547
# Episode * 548 * Avg Reward is ==> 0.7922882370869979 And Number of steps is ==> 548
# Episode * 549 * Avg Reward is ==> 0.7339082403774894 And Number of steps is ==> 549
# Episode * 550 * Avg Reward is ==> -3.663996534676353 And Number of steps is ==> 550
# Episode * 551 * Avg Reward is ==> -3.918121364518677 And Number of steps is ==> 551
# Episode * 552 * Avg Reward is ==> 0.8979773685875123 And Number of steps is ==> 552
# Episode * 553 * Avg Reward is ==> -3.9661292696522095 And Number of steps is ==> 553
# Episode * 554 * Avg Reward is ==> -4.266895941821692 And Number of steps is ==> 554
# Episode * 555 * Avg Reward is ==> 1.4998944322953438 And Number of steps is ==> 555
# Episode * 556 * Avg Reward is ==> -3.610991784783546 And Number of steps is ==> 556
# Episode * 557 * Avg Reward is ==> 0.8162772160812617 And Number of steps is ==> 557
# Episode * 558 * Avg Reward is ==> 0.8438596311713651 And Number of steps is ==> 558
# Episode * 559 * Avg Reward is ==> -3.6100080864838326 And Number of steps is ==> 559
# Episode * 560 * Avg Reward is ==> 0.8008571428309775 And Number of steps is ==> 560
# Episode * 561 * Avg Reward is ==> 0.9838571498395856 And Number of steps is ==> 561
# Episode * 562 * Avg Reward is ==> -0.03704424066306711 And Number of steps is ==> 562
# Episode * 563 * Avg Reward is ==> 0.8045546748899634 And Number of steps is ==> 563
# Episode * 564 * Avg Reward is ==> 1.4999999999999998 And Number of steps is ==> 564
# Episode * 565 * Avg Reward is ==> 0.7633206706937743 And Number of steps is ==> 565
# Episode * 566 * Avg Reward is ==> -3.665437250929736 And Number of steps is ==> 566
# Episode * 567 * Avg Reward is ==> 0.7335711464675961 And Number of steps is ==> 567
# Episode * 568 * Avg Reward is ==> 0.758671431457832 And Number of steps is ==> 568
# Episode * 569 * Avg Reward is ==> -3.662207073739688 And Number of steps is ==> 569
# Episode * 570 * Avg Reward is ==> -3.5648242647044377 And Number of steps is ==> 570
# Episode * 571 * Avg Reward is ==> 0.7985935203706147 And Number of steps is ==> 571
# Episode * 572 * Avg Reward is ==> -0.018186582863393187 And Number of steps is ==> 572
# Episode * 573 * Avg Reward is ==> 0.8279249245986211 And Number of steps is ==> 573
# ...
# Episode * 810 * Avg Reward is ==> 0.8117004949957813 And Number of steps is ==> 810
# Episode * 811 * Avg Reward is ==> 0.8538164075153999 And Number of steps is ==> 811
# Episode * 812 * Avg Reward is ==> 0.8586992204070274 And Number of steps is ==> 812
# Episode * 813 * Avg Reward is ==> 0.8087851805715653 And Number of steps is ==> 813
# Episode * 814 * Avg Reward is ==> 0.8919058957225147 And Number of steps is ==> 814
# Episode * 815 * Avg Reward is ==> 0.7697874538326239 And Number of steps is ==> 815
# Episode * 816 * Avg Reward is ==> -3.9609889779766805 And Number of steps is ==> 816
# Episode * 817 * Avg Reward is ==> -4.263852322296669 And Number of steps is ==> 817
# Episode * 818 * Avg Reward is ==> 0.8554378687489255 And Number of steps is ==> 818
# Episode * 819 * Avg Reward is ==> 0.7620537180421942 And Number of steps is ==> 819
# Episode * 820 * Avg Reward is ==> 0.8046092622701277 And Number of steps is ==> 820
# Episode * 821 * Avg Reward is ==> 0.8136922519162422 And Number of steps is ==> 821
# Episode * 822 * Avg Reward is ==> -3.660927710548865 And Number of steps is ==> 822
# Episode * 823 * Avg Reward is ==> -4.264164949648806 And Number of steps is ==> 823
# Episode * 824 * Avg Reward is ==> -3.660098748533501 And Number of steps is ==> 824
# Episode * 825 * Avg Reward is ==> -3.615046513713897 And Number of steps is ==> 825
# Episode * 826 * Avg Reward is ==> -3.612053753351881 And Number of steps is ==> 826
# Episode * 827 * Avg Reward is ==> -3.962706275974707 And Number of steps is ==> 827
# Episode * 828 * Avg Reward is ==> -4.571070367382543 And Number of steps is ==> 828
# Episode * 829 * Avg Reward is ==> -4.265470425991122 And Number of steps is ==> 829
# Episode * 830 * Avg Reward is ==> 0.8010337193888578 And Number of steps is ==> 830
# Episode * 831 * Avg Reward is ==> 0.8994937995603978 And Number of steps is ==> 831
# Episode * 832 * Avg Reward is ==> 0.7345387165902884 And Number of steps is ==> 832
# Episode * 833 * Avg Reward is ==> 0.8021237804285983 And Number of steps is ==> 833
# Episode * 834 * Avg Reward is ==> 1.0344525631669144 And Number of steps is ==> 834
# Episode * 835 * Avg Reward is ==> -4.219578189121724 And Number of steps is ==> 835
# Episode * 836 * Avg Reward is ==> 0.7882774486079525 And Number of steps is ==> 836
# Episode * 837 * Avg Reward is ==> 0.7919302939724284 And Number of steps is ==> 837
# Episode * 838 * Avg Reward is ==> 1.4999999999999987 And Number of steps is ==> 838
# Episode * 839 * Avg Reward is ==> 0.8255194076952886 And Number of steps is ==> 839
# Episode * 840 * Avg Reward is ==> -4.218127222055268 And Number of steps is ==> 840
# Episode * 841 * Avg Reward is ==> 0.8026554772979541 And Number of steps is ==> 841
# Episode * 842 * Avg Reward is ==> -0.14207472944508276 And Number of steps is ==> 842
# Episode * 843 * Avg Reward is ==> -1.0436542490079481 And Number of steps is ==> 843
# Episode * 844 * Avg Reward is ==> -3.6178733939497034 And Number of steps is ==> 844
# Episode * 845 * Avg Reward is ==> -3.6134639101818635 And Number of steps is ==> 845
# Episode * 846 * Avg Reward is ==> -3.611385939085195 And Number of steps is ==> 846
# Episode * 847 * Avg Reward is ==> -3.610127406628745 And Number of steps is ==> 847
# Episode * 848 * Avg Reward is ==> -3.6133434394423913 And Number of steps is ==> 848
# Episode * 849 * Avg Reward is ==> 0.8256816226688481 And Number of steps is ==> 849
# Episode * 850 * Avg Reward is ==> 0.7923769028297174 And Number of steps is ==> 850
# Episode * 851 * Avg Reward is ==> -4.220085395437429 And Number of steps is ==> 851
# Episode * 852 * Avg Reward is ==> -3.961012544377282 And Number of steps is ==> 852
# Episode * 853 * Avg Reward is ==> -3.6635778551834663 And Number of steps is ==> 853
# Episode * 854 * Avg Reward is ==> -3.5635108745889745 And Number of steps is ==> 854
# Episode * 855 * Avg Reward is ==> -4.523071213937256 And Number of steps is ==> 855
# Episode * 856 * Avg Reward is ==> -3.6195784827227064 And Number of steps is ==> 856
# Episode * 857 * Avg Reward is ==> 0.7426032536465954 And Number of steps is ==> 857
# Episode * 858 * Avg Reward is ==> 0.8202066513930723 And Number of steps is ==> 858
# Episode * 859 * Avg Reward is ==> 1.4485800175636523 And Number of steps is ==> 859
# Episode * 860 * Avg Reward is ==> -3.9652444664105886 And Number of steps is ==> 860
# Episode * 861 * Avg Reward is ==> -3.6109131960041516 And Number of steps is ==> 861
# Episode * 862 * Avg Reward is ==> -3.9627223345479363 And Number of steps is ==> 862
# Episode * 863 * Avg Reward is ==> -3.660077082615061 And Number of steps is ==> 863
# Episode * 864 * Avg Reward is ==> 1.0933774645921885 And Number of steps is ==> 864
# Episode * 865 * Avg Reward is ==> -3.5531310939830307 And Number of steps is ==> 865
# Episode * 866 * Avg Reward is ==> 0.8112269797989999 And Number of steps is ==> 866
# Episode * 867 * Avg Reward is ==> 0.8071883100712463 And Number of steps is ==> 867
# Episode * 868 * Avg Reward is ==> -3.9620947956726553 And Number of steps is ==> 868
# Episode * 869 * Avg Reward is ==> -3.5 And Number of steps is ==> 869
# Episode * 870 * Avg Reward is ==> -3.612112296395734 And Number of steps is ==> 870
# Episode * 871 * Avg Reward is ==> -3.6107643440735018 And Number of steps is ==> 871
# Episode * 872 * Avg Reward is ==> 0.76168051341844 And Number of steps is ==> 872
# Episode * 873 * Avg Reward is ==> 0.8038547607352244 And Number of steps is ==> 873
# Episode * 874 * Avg Reward is ==> -3.9610444861411835 And Number of steps is ==> 874
# Episode * 875 * Avg Reward is ==> -3.960916195731469 And Number of steps is ==> 875
# Episode * 876 * Avg Reward is ==> 0.7849313153009778 And Number of steps is ==> 876
# Episode * 877 * Avg Reward is ==> -3.610444182187821 And Number of steps is ==> 877
# Episode * 878 * Avg Reward is ==> 0.7809685553942378 And Number of steps is ==> 878
# Episode * 879 * Avg Reward is ==> -3.6103131196020066 And Number of steps is ==> 879
# Episode * 880 * Avg Reward is ==> -4.8721750733881075 And Number of steps is ==> 880
# Episode * 881 * Avg Reward is ==> 0.7406512379782232 And Number of steps is ==> 881
# Episode * 882 * Avg Reward is ==> -3.5000000000000013 And Number of steps is ==> 882
# Episode * 883 * Avg Reward is ==> -3.61008214411806 And Number of steps is ==> 883
# Episode * 884 * Avg Reward is ==> -3.6109676269661386 And Number of steps is ==> 884
# Episode * 885 * Avg Reward is ==> -3.9612691008274354 And Number of steps is ==> 885
# Episode * 886 * Avg Reward is ==> -3.663665934421021 And Number of steps is ==> 886
# Episode * 887 * Avg Reward is ==> -3.9647426977737736 And Number of steps is ==> 887
# Episode * 888 * Avg Reward is ==> -3.5000000000000013 And Number of steps is ==> 888
# Episode * 889 * Avg Reward is ==> -4.22057327072979 And Number of steps is ==> 889
# Episode * 890 * Avg Reward is ==> -4.219550528722619 And Number of steps is ==> 890
# Episode * 891 * Avg Reward is ==> 0.8436275701506153 And Number of steps is ==> 891
# Episode * 892 * Avg Reward is ==> 0.763906534689976 And Number of steps is ==> 892
# Episode * 893 * Avg Reward is ==> -3.610149040930853 And Number of steps is ==> 893
# Episode * 894 * Avg Reward is ==> 0.8217498920682329 And Number of steps is ==> 894
# Episode * 895 * Avg Reward is ==> 1.1180334354205097 And Number of steps is ==> 895
# Episode * 896 * Avg Reward is ==> 0.9538526215474024 And Number of steps is ==> 896
# Episode * 897 * Avg Reward is ==> 0.8159967086158172 And Number of steps is ==> 897
# Episode * 898 * Avg Reward is ==> -3.6619597916005233 And Number of steps is ==> 898
# Episode * 899 * Avg Reward is ==> 0.7801549005434245 And Number of steps is ==> 899
# Episode * 900 * Avg Reward is ==> 1.0809242786401547 And Number of steps is ==> 900
# Episode * 901 * Avg Reward is ==> -3.619529280733468 And Number of steps is ==> 901
# Episode * 902 * Avg Reward is ==> -1.0388178029274497 And Number of steps is ==> 902
# Episode * 903 * Avg Reward is ==> 0.8130982553599786 And Number of steps is ==> 903
# Episode * 904 * Avg Reward is ==> -3.6600856412288083 And Number of steps is ==> 904
# Episode * 905 * Avg Reward is ==> 0.7737743388587199 And Number of steps is ==> 905
# Episode * 906 * Avg Reward is ==> 1.4494944725282726 And Number of steps is ==> 906
# Episode * 907 * Avg Reward is ==> 0.80639818016215 And Number of steps is ==> 907
# Episode * 908 * Avg Reward is ==> 0.7455964789255325 And Number of steps is ==> 908
# Episode * 909 * Avg Reward is ==> -1.0522043784851283 And Number of steps is ==> 909
# Episode * 910 * Avg Reward is ==> 0.7441207940679491 And Number of steps is ==> 910
# Episode * 911 * Avg Reward is ==> -3.5 And Number of steps is ==> 911
# Episode * 912 * Avg Reward is ==> -3.5 And Number of steps is ==> 912
# Episode * 913 * Avg Reward is ==> -3.617239459358648 And Number of steps is ==> 913
# Episode * 914 * Avg Reward is ==> 0.7991027178399956 And Number of steps is ==> 914
# Episode * 915 * Avg Reward is ==> 0.7674220821265709 And Number of steps is ==> 915
# Episode * 916 * Avg Reward is ==> -3.9630319270199394 And Number of steps is ==> 916
# Episode * 917 * Avg Reward is ==> 0.7650441391230732 And Number of steps is ==> 917
# Episode * 918 * Avg Reward is ==> -3.661119357752566 And Number of steps is ==> 918
# Episode * 919 * Avg Reward is ==> -3.963864898305148 And Number of steps is ==> 919
# Episode * 920 * Avg Reward is ==> -3.6662521271298374 And Number of steps is ==> 920
# Episode * 921 * Avg Reward is ==> -3.5513037750029754 And Number of steps is ==> 921
# Episode * 922 * Avg Reward is ==> -3.6195078736910515 And Number of steps is ==> 922
# Episode * 923 * Avg Reward is ==> 0.8532015554102612 And Number of steps is ==> 923
# Episode * 924 * Avg Reward is ==> 0.7686926198003572 And Number of steps is ==> 924
# Episode * 925 * Avg Reward is ==> 1.4999999999999998 And Number of steps is ==> 925
# Episode * 926 * Avg Reward is ==> 0.7920980426821218 And Number of steps is ==> 926
# Episode * 927 * Avg Reward is ==> -3.5546315015154546 And Number of steps is ==> 927
# Episode * 928 * Avg Reward is ==> 0.8632324940533476 And Number of steps is ==> 928
# Episode * 929 * Avg Reward is ==> 0.7900713770409504 And Number of steps is ==> 929
# Episode * 930 * Avg Reward is ==> -3.9611970814130744 And Number of steps is ==> 930
# Episode * 931 * Avg Reward is ==> 0.7683232156035843 And Number of steps is ==> 931
# Episode * 932 * Avg Reward is ==> 0.8661244133950916 And Number of steps is ==> 932
# Episode * 933 * Avg Reward is ==> 0.8095675537895722 And Number of steps is ==> 933
# Episode * 934 * Avg Reward is ==> 0.7792141795884527 And Number of steps is ==> 934
# Episode * 935 * Avg Reward is ==> 0.7784284253947986 And Number of steps is ==> 935
# Episode * 936 * Avg Reward is ==> 0.8354657339710421 And Number of steps is ==> 936
# Episode * 937 * Avg Reward is ==> 0.882798477978065 And Number of steps is ==> 937
# Episode * 938 * Avg Reward is ==> 0.7640764772104858 And Number of steps is ==> 938
# Episode * 939 * Avg Reward is ==> 0.32058839037404663 And Number of steps is ==> 939
# Episode * 940 * Avg Reward is ==> -3.5579860278443056 And Number of steps is ==> 940
# Episode * 941 * Avg Reward is ==> 0.7906056625491624 And Number of steps is ==> 941
# Episode * 942 * Avg Reward is ==> 0.8131032088212494 And Number of steps is ==> 942
# Episode * 943 * Avg Reward is ==> 0.8756896335798929 And Number of steps is ==> 943
# Episode * 944 * Avg Reward is ==> 0.9375650956888654 And Number of steps is ==> 944
# Episode * 945 * Avg Reward is ==> -3.6192122954918693 And Number of steps is ==> 945
# Episode * 946 * Avg Reward is ==> 0.8029239601549764 And Number of steps is ==> 946
# Episode * 947 * Avg Reward is ==> -3.610158821106343 And Number of steps is ==> 947
# Episode * 948 * Avg Reward is ==> 0.8546606477293903 And Number of steps is ==> 948
# Episode * 949 * Avg Reward is ==> -3.5670147057282144 And Number of steps is ==> 949
# Episode * 950 * Avg Reward is ==> -3.66057310745256 And Number of steps is ==> 950
# Episode * 951 * Avg Reward is ==> 0.781476493147914 And Number of steps is ==> 951
# Episode * 952 * Avg Reward is ==> -3.6626574480074674 And Number of steps is ==> 952
# Episode * 953 * Avg Reward is ==> -3.9652556777405623 And Number of steps is ==> 953
# Episode * 954 * Avg Reward is ==> -3.610111325102771 And Number of steps is ==> 954
# Episode * 955 * Avg Reward is ==> -3.5678245545604534 And Number of steps is ==> 955
# Episode * 956 * Avg Reward is ==> 0.7384776887292877 And Number of steps is ==> 956
# Episode * 957 * Avg Reward is ==> 0.7655147309979891 And Number of steps is ==> 957
# Episode * 958 * Avg Reward is ==> 0.7580840738763406 And Number of steps is ==> 958
# Episode * 959 * Avg Reward is ==> 0.7687885798145776 And Number of steps is ==> 959
# Episode * 960 * Avg Reward is ==> 0.9569817273593724 And Number of steps is ==> 960
# Episode * 961 * Avg Reward is ==> 0.7641518110929924 And Number of steps is ==> 961
# Episode * 962 * Avg Reward is ==> -3.6601799878220698 And Number of steps is ==> 962
# Episode * 963 * Avg Reward is ==> 0.8490299865675816 And Number of steps is ==> 963
# Episode * 964 * Avg Reward is ==> 0.800695336359017 And Number of steps is ==> 964
# Episode * 965 * Avg Reward is ==> 0.8406704876699754 And Number of steps is ==> 965
# Episode * 966 * Avg Reward is ==> 0.8388064929097286 And Number of steps is ==> 966
# Episode * 967 * Avg Reward is ==> 0.9294898824595483 And Number of steps is ==> 967
# Episode * 968 * Avg Reward is ==> 0.8179212910408833 And Number of steps is ==> 968
# Episode * 969 * Avg Reward is ==> -3.9610131334514262 And Number of steps is ==> 969
# Episode * 970 * Avg Reward is ==> -3.9177955422308264 And Number of steps is ==> 970
# Episode * 971 * Avg Reward is ==> 0.7809088496285141 And Number of steps is ==> 971
# Episode * 972 * Avg Reward is ==> 0.7666377087557145 And Number of steps is ==> 972
# Episode * 973 * Avg Reward is ==> -3.9611442053407515 And Number of steps is ==> 973
# Episode * 974 * Avg Reward is ==> -3.9615507106574754 And Number of steps is ==> 974
# Episode * 975 * Avg Reward is ==> -3.66166841526909 And Number of steps is ==> 975
# Episode * 976 * Avg Reward is ==> -3.660872111851299 And Number of steps is ==> 976
# Episode * 977 * Avg Reward is ==> -3.9167241596431905 And Number of steps is ==> 977
# Episode * 978 * Avg Reward is ==> 0.9151856697680675 And Number of steps is ==> 978
# Episode * 979 * Avg Reward is ==> 0.7621906208022885 And Number of steps is ==> 979
# Episode * 980 * Avg Reward is ==> -3.9651028619130684 And Number of steps is ==> 980
# Episode * 981 * Avg Reward is ==> -3.965914425049756 And Number of steps is ==> 981
# Episode * 982 * Avg Reward is ==> -3.551818478392396 And Number of steps is ==> 982
# Episode * 983 * Avg Reward is ==> -0.7311973685452609 And Number of steps is ==> 983
# Episode * 984 * Avg Reward is ==> 0.9672017948340368 And Number of steps is ==> 984
# Episode * 985 * Avg Reward is ==> -0.6435497983747267 And Number of steps is ==> 985
# Episode * 986 * Avg Reward is ==> 0.7937776204720433 And Number of steps is ==> 986
# Episode * 987 * Avg Reward is ==> 0.7855299585469818 And Number of steps is ==> 987
# Episode * 988 * Avg Reward is ==> 1.0386485918957429 And Number of steps is ==> 988
# Episode * 989 * Avg Reward is ==> -3.6171350496380184 And Number of steps is ==> 989
# Episode * 990 * Avg Reward is ==> -3.550469199277191 And Number of steps is ==> 990
# Episode * 991 * Avg Reward is ==> 0.7595696294430067 And Number of steps is ==> 991
# Episode * 992 * Avg Reward is ==> -3.6610098761929377 And Number of steps is ==> 992
# Episode * 993 * Avg Reward is ==> 0.7925433806695876 And Number of steps is ==> 993
# Episode * 994 * Avg Reward is ==> -3.5 And Number of steps is ==> 994
# Episode * 995 * Avg Reward is ==> -3.610107384878559 And Number of steps is ==> 995
# Episode * 996 * Avg Reward is ==> -3.5000000000000013 And Number of steps is ==> 996
# Episode * 997 * Avg Reward is ==> -3.9188505067565367 And Number of steps is ==> 997
# Episode * 998 * Avg Reward is ==> -4.265846332190838 And Number of steps is ==> 998
# Episode * 999 * Avg Reward is ==> 1.4999999999999993 And Number of steps is ==> 999

# %%
#Positions des agents
t=0
plt.title("Vehicle and Pedestrian Positions versus time")
plt.xlabel("time (s)")
plt.ylabel("position (m)")
j=0
while t+1<len(ep_time):
    t_init=t
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        t+=1
    plt.plot(ep_time[t_init:t],ep_pos_car[t_init:t])#, label="car"+str(j)
    plt.plot(ep_time[t_init:t],ep_pos_ped[t_init:t])
    plt.axhline(y=5, color='r', linestyle='-.')
    plt.axhline(y=0, color='r', linestyle='-.')
    t+=1
    j+=1
_=plt.axhline(y=5, color='r', linestyle='-.')
_=plt.axhline(y=0, color='r', linestyle='-.')
#_=plt.legend()

# %%
#Showing Vehicle Acceleration Diagram, Vehicle Speed Diagram, Vehicle and Pedestrian Position Diagram
#All three over time in an episode

#t=0
if (t+1>=len(ep_time)):
    t=0
t_init=t
while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
    t+=1
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(18, 4))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.plot(ep_time[t_init:t],ep_action[t_init:t],color='r')

ax2.set_title('Car and Pedestrian Position')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Position (m)")
ax2.plot(ep_time[t_init:t],ep_pos_car[t_init:t],label='car')
ax2.plot(ep_time[t_init:t],ep_pos_ped[t_init:t],label='pedestrian')
ax2.axhline(y=5, color='r', linestyle='-.')
ax2.axhline(y=0, color='r', linestyle='-.')
ax2.legend()

ax3.set_title('Car Speed')
ax3.set_xlabel("Time (s)")
ax3.set_ylabel("Speed (m/s)")
ax3.plot(ep_time[t_init:t+1],ep_speed_car[t_init:t+1],color='r')

ax4.set_title('Pedestrian Speed')
ax4.set_xlabel("Time (s)")
ax4.set_ylabel("Speed (m/s)")
ax4.plot(ep_time[t_init:t+1],ep_speed_ped[t_init:t+1],color='r')
t+=1

# %%
#Show general information about the final algorithm performance: average speed, CO2 emission, end-time

LDV = pd.read_csv('LDV.csv', sep=';',names=["sp","acc","step","em_name","em_val"])
LDV.pop('step')
m = LDV == 0.0
LDV['acc'] = LDV['acc'].replace(1.27676e-15,0.0)
LDV['acc'] = LDV['acc'].astype(float)
LDV_array = np.array(LDV.values)

def info_co2(states,LDV):
    """
        Evaluate the CO2 emission per episode 
        :param states: state list
        :param LDV: CO2 emission chart
    """
    t=0
    total_emission=[]
    while t+1<len(ep_time):
        t_init=t
        emission_val=[]
        while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
            acc=math.trunc(((states[t,0].item()//0.2)*0.2)*10.)/10.
            speed=math.trunc(((states[t,1].item()//0.5)*0.5)*10.)/10.
            cond=(LDV.sp==speed)&(LDV.acc==acc)&(LDV.em_name=="CO2")
            res=LDV[cond]['em_val'].item() *0.3
            emission_val.append(res)
            t+=1
        total_emission.append(np.sum(np.array(emission_val),axis=0))
        t+=1
    torch_total_emission=np.array(total_emission)
    total_emission_mean=np.mean(torch_total_emission)
    total_emission_std=np.std(torch_total_emission)
    print("\nThe average CO2 emission is {:.2f}mg and its standard deviation is {:.2f} mg".format(total_emission_mean.item(),total_emission_std.item()))
    
def get_average(states,LDV):
    ep_time=states[:,9]
    mean_speed=np.mean(states[:,1])
    sqrt_speed=np.std(states[:,1])
    print("The average car speed is {:.2f} m/s and its standard deviation is {:.2f} m/s".format(mean_speed.item(),sqrt_speed.item()))
    mean_acc=np.mean(states[:,0])
    sqrt_acc=np.std(states[:,0])
    print("\nThe average car acceleration is {:.2f} m/s2 and its standard deviation is {:.2f} m/s2".format(mean_acc.item(),sqrt_acc.item()))
    mean_speed_p=np.mean(states[:,3])
    sqrt_speed_p=np.std(states[:,3])
    print("\nThe average pedestrian speed is {:.2f} m/s and its standard deviation is {:.2f} m/s".format(mean_speed_p.item(),sqrt_speed_p.item()))    
    mean_reward=np.mean(ep_reward)
    std_reward=np.std(ep_reward)
    print("\nThe average reward is {:.2f} and its standard deviation is {:.2f}".format(mean_reward.item(),std_reward.item()))
    info_co2(states,LDV) #CO2 info
    temps=[]
    t=0
    while t+1<len(ep_time):
        temps_i=np.array([0.,0.]) #respectively: end-time car/pedestrian
        t_init=t
        while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
            if(states[t,2]<0.0 and states[t+1,2]>=0.0):
                temps_i[0]=(t-t_init)*0.3
            if(states[t,4]<5.0 and states[t+1,4]>=5.0):
                temps_i[1]=(t-t_init)*0.3
            t+=1
        if(temps_i[1]==0.0):
            temps_i[1]=(t-t_init)*0.3
        temps.append([(t-t_init)*0.3,temps_i[0],temps_i[1]])
        t+=1
    total_temps=np.array([temps]).reshape((-1,3))
    total_temps_mean=np.mean(total_temps,axis=0)
    print("\n Average End-times:")
    print("Total: {:.2f} s".format(total_temps_mean[0].item()))
    print("Car: {:.2f} s".format(total_temps_mean[1].item()))
    print("Pedestrian: {:.2f} s".format(total_temps_mean[2].item()))
get_average(states,LDV)
# Out:
# The average car speed is 7.33 m/s and its standard deviation is 3.32 m/s
#
# The average car acceleration is -0.00 m/s2 and its standard deviation is 1.53 m/s2
#
# The average pedestrian speed is 0.99 m/s and its standard deviation is 0.38 m/s
#
# The average reward is -1.85 and its standard deviation is 3.43
#
# The average CO2 emission is 21698.75mg and its standard deviation is 7022.41 mg
#
#  Average End-times:
# Total: 9.50 s
# Car: 4.43 s
# Pedestrian: 6.59 s

# %%
#Accélération, Reward, Vitesse de la voiture
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(18, 4))

t=0
ax1.set_title("Car Acceleration versus time per episode")
ax1.set_xlabel("time (s)")
ax1.set_ylabel("acceleration (m/s2)")

ax2.set_title("Reward versus time per episode")
ax2.set_xlabel("time (s)")
ax2.set_ylabel("reward")

ax3.set_title("Car Speed versus time per episode")
ax3.set_xlabel("time (s)")
ax3.set_ylabel("speed (m/s)")

ax4.set_title('Pedestrian Speed')
ax4.set_xlabel("Position (m)")
ax4.set_ylabel("Speed (m/s)")
while t+1<len(ep_time):
    t_init=t
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        t+=1
    ax1.plot(ep_time[t_init:t],ep_action[t_init:t])
    ax2.plot(ep_time[t_init:t],ep_reward[t_init:t])
    ax3.plot(ep_time[t_init:t],ep_speed_car[t_init:t])
    ax4.plot(states[t_init:t,4],states[t_init:t,3])
    t+=1

# %%
#6) Edges Cases: 
#decided, change_speed, stops (with imminent decision)
#decided cases do not work because of the reward structure
problem = "Crosswalk_test-v0"
u_b = [2.0, 11.0, -20.0, 1.1, -1.0]
l_b = [-4.0, 9.0, -25.0, 0.9, -1.5]

env = gym.make(problem,dt=0.3,Vm=2.5,lower_bounds=l_b, upper_bounds=u_b,simulation="sin",initial_mode="stops")

# Initialize the algorithm
num_states = env.observation_space.shape[0]
num_actions = env.action_space.shape[0]
num_algo=1
u_b2=[200.0,15.0,2.0]
l_b2=[-45.0,0.0,-4.0]
algo=Algo_QP(Model_QP, env, num_algo= num_algo, num_states=num_states, num_actions=num_actions,l_b=l_b2, u_b=u_b2, tau=1.0)
# Out:
# C:\Users\abrunoud\Anaconda3\envs\ppotest\lib\site-packages\gym\logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))

# %%
#Stock an evaluation sample
states, actions, rewards = algo.evaluate(100)
states=np.array(states)
ep_action=states[:,0]
ep_speed_car=states[:,1]
ep_pos_car=states[:,2]
ep_speed_ped=states[:,3]
ep_pos_ped=states[:,4]
ep_time=states[:,9]
ep_reward=rewards
t=0
# Out:
# Episode * 0 * Avg Reward is ==> -4.566143373400576 And Number of steps is ==> 0
# Episode * 1 * Avg Reward is ==> -4.5643571260059606 And Number of steps is ==> 1
# Episode * 2 * Avg Reward is ==> -4.165982116368378 And Number of steps is ==> 2
# Episode * 3 * Avg Reward is ==> -5.363266463400038 And Number of steps is ==> 3
# Episode * 4 * Avg Reward is ==> -4.239727688477923 And Number of steps is ==> 4
# Episode * 5 * Avg Reward is ==> -4.262193377995715 And Number of steps is ==> 5
# Episode * 6 * Avg Reward is ==> -4.87495344559003 And Number of steps is ==> 6
# Episode * 7 * Avg Reward is ==> -3.657344995244993 And Number of steps is ==> 7
# Episode * 8 * Avg Reward is ==> -3.8902458283489345 And Number of steps is ==> 8
# Episode * 9 * Avg Reward is ==> -4.211230005042718 And Number of steps is ==> 9
# Episode * 10 * Avg Reward is ==> -4.247184007536485 And Number of steps is ==> 10
# Episode * 11 * Avg Reward is ==> -4.160287052680322 And Number of steps is ==> 11
# Episode * 12 * Avg Reward is ==> -4.225295416300248 And Number of steps is ==> 12
# Episode * 13 * Avg Reward is ==> -3.9101898768414713 And Number of steps is ==> 13
# Episode * 14 * Avg Reward is ==> -4.239559616628698 And Number of steps is ==> 14
# Episode * 15 * Avg Reward is ==> -3.9102929593003553 And Number of steps is ==> 15
# Episode * 16 * Avg Reward is ==> -3.655238420442952 And Number of steps is ==> 16
# Episode * 17 * Avg Reward is ==> -4.823348164790901 And Number of steps is ==> 17
# Episode * 18 * Avg Reward is ==> -4.528426302665092 And Number of steps is ==> 18
# Episode * 19 * Avg Reward is ==> -4.045571895637698 And Number of steps is ==> 19
# Accident!
# Episode * 20 * Avg Reward is ==> -54.56344301465949 And Number of steps is ==> 20
# Episode * 21 * Avg Reward is ==> -4.023903021527998 And Number of steps is ==> 21
# Episode * 22 * Avg Reward is ==> -3.956378251184443 And Number of steps is ==> 22
# Episode * 23 * Avg Reward is ==> -3.6564779353337764 And Number of steps is ==> 23
# Episode * 24 * Avg Reward is ==> -3.655148466449431 And Number of steps is ==> 24
# Episode * 25 * Avg Reward is ==> -4.87317700997058 And Number of steps is ==> 25
# Episode * 26 * Avg Reward is ==> -4.189150307615369 And Number of steps is ==> 26
# Episode * 27 * Avg Reward is ==> -4.144547865862786 And Number of steps is ==> 27
# Episode * 28 * Avg Reward is ==> -4.163065970372402 And Number of steps is ==> 28
# Episode * 29 * Avg Reward is ==> -3.5553186713328 And Number of steps is ==> 29
# Episode * 30 * Avg Reward is ==> -4.235706404520872 And Number of steps is ==> 30
# Episode * 31 * Avg Reward is ==> -4.925498374590413 And Number of steps is ==> 31
# Episode * 32 * Avg Reward is ==> -4.970762660594224 And Number of steps is ==> 32
# Episode * 33 * Avg Reward is ==> -4.259610366496138 And Number of steps is ==> 33
# Episode * 34 * Avg Reward is ==> -4.241928321939004 And Number of steps is ==> 34
# Episode * 35 * Avg Reward is ==> -4.822493551632341 And Number of steps is ==> 35
# Episode * 36 * Avg Reward is ==> -5.6397559316869845 And Number of steps is ==> 36
# Episode * 37 * Avg Reward is ==> -4.157860557899967 And Number of steps is ==> 37
# Episode * 38 * Avg Reward is ==> -3.9580859014597136 And Number of steps is ==> 38
# Accident!
# Episode * 39 * Avg Reward is ==> -55.777682398506236 And Number of steps is ==> 39
# Episode * 40 * Avg Reward is ==> -3.656070217348644 And Number of steps is ==> 40
# Episode * 41 * Avg Reward is ==> -5.200997770573643 And Number of steps is ==> 41
# Accident!
# Episode * 42 * Avg Reward is ==> -53.65545014570053 And Number of steps is ==> 42
# Episode * 43 * Avg Reward is ==> -4.253025761217872 And Number of steps is ==> 43
# Episode * 44 * Avg Reward is ==> -4.246729213996262 And Number of steps is ==> 44
# Episode * 45 * Avg Reward is ==> -4.258368342198373 And Number of steps is ==> 45
# Episode * 46 * Avg Reward is ==> -4.009370388176218 And Number of steps is ==> 46
# Episode * 47 * Avg Reward is ==> -4.823627464814785 And Number of steps is ==> 47
# Episode * 48 * Avg Reward is ==> -4.8772665387865635 And Number of steps is ==> 48
# Episode * 49 * Avg Reward is ==> -3.9561887033063052 And Number of steps is ==> 49
# Episode * 50 * Avg Reward is ==> -4.915995063557039 And Number of steps is ==> 50
# Episode * 51 * Avg Reward is ==> -4.246786857171147 And Number of steps is ==> 51
# Accident!
# Episode * 52 * Avg Reward is ==> -53.95621919144348 And Number of steps is ==> 52
# Episode * 53 * Avg Reward is ==> -5.503834096769105 And Number of steps is ==> 53
# Episode * 54 * Avg Reward is ==> -6.052907773470439 And Number of steps is ==> 54
# Episode * 55 * Avg Reward is ==> -3.655210393358355 And Number of steps is ==> 55
# Episode * 56 * Avg Reward is ==> -4.258909486042588 And Number of steps is ==> 56
# Episode * 57 * Avg Reward is ==> -6.5037448770233866 And Number of steps is ==> 57
# Accident!
# Episode * 58 * Avg Reward is ==> -54.25973740257608 And Number of steps is ==> 58
# Episode * 59 * Avg Reward is ==> -4.2400826926823125 And Number of steps is ==> 59
# Episode * 60 * Avg Reward is ==> -4.995403212011984 And Number of steps is ==> 60
# Episode * 61 * Avg Reward is ==> -4.5675829300820165 And Number of steps is ==> 61
# Episode * 62 * Avg Reward is ==> -4.932099507952128 And Number of steps is ==> 62
# Episode * 63 * Avg Reward is ==> -3.878183629947661 And Number of steps is ==> 63
# Episode * 64 * Avg Reward is ==> -4.166206908739026 And Number of steps is ==> 64
# Episode * 65 * Avg Reward is ==> -3.956423302548012 And Number of steps is ==> 65
# Episode * 66 * Avg Reward is ==> -3.9563676315258314 And Number of steps is ==> 66
# Episode * 67 * Avg Reward is ==> -4.164762899948583 And Number of steps is ==> 67
# Episode * 68 * Avg Reward is ==> -4.258903633570694 And Number of steps is ==> 68
# Episode * 69 * Avg Reward is ==> -4.1961468269434015 And Number of steps is ==> 69
# Episode * 70 * Avg Reward is ==> -5.8400231621064265 And Number of steps is ==> 70
# Episode * 71 * Avg Reward is ==> -4.211359094681912 And Number of steps is ==> 71
# Episode * 72 * Avg Reward is ==> -4.184767630733916 And Number of steps is ==> 72
# Episode * 73 * Avg Reward is ==> -4.178081467763064 And Number of steps is ==> 73
# Episode * 74 * Avg Reward is ==> -4.563834460983378 And Number of steps is ==> 74
# Episode * 75 * Avg Reward is ==> -3.606048506378433 And Number of steps is ==> 75
# Episode * 76 * Avg Reward is ==> -4.189400669740737 And Number of steps is ==> 76
# Accident!
# Episode * 77 * Avg Reward is ==> -55.139451903953024 And Number of steps is ==> 77
# Episode * 78 * Avg Reward is ==> -3.6551397383959605 And Number of steps is ==> 78
# Episode * 79 * Avg Reward is ==> -4.210864464009697 And Number of steps is ==> 79
# Episode * 80 * Avg Reward is ==> -4.253429137883194 And Number of steps is ==> 80
# Episode * 81 * Avg Reward is ==> -4.218570316781817 And Number of steps is ==> 81
# Episode * 82 * Avg Reward is ==> -4.564770561048361 And Number of steps is ==> 82
# Episode * 83 * Avg Reward is ==> -4.872299342769971 And Number of steps is ==> 83
# Episode * 84 * Avg Reward is ==> -5.614665730118394 And Number of steps is ==> 84
# Episode * 85 * Avg Reward is ==> -3.956605047060652 And Number of steps is ==> 85
# Episode * 86 * Avg Reward is ==> -4.871558547987812 And Number of steps is ==> 86
# Episode * 87 * Avg Reward is ==> -4.2590599177012916 And Number of steps is ==> 87
# Episode * 88 * Avg Reward is ==> -4.238738469081466 And Number of steps is ==> 88
# Episode * 89 * Avg Reward is ==> -4.825353962833093 And Number of steps is ==> 89
# Episode * 90 * Avg Reward is ==> -4.568399049142282 And Number of steps is ==> 90
# Episode * 91 * Avg Reward is ==> -6.0295256245249345 And Number of steps is ==> 91
# Episode * 92 * Avg Reward is ==> -4.174541128732069 And Number of steps is ==> 92
# Episode * 93 * Avg Reward is ==> -4.104286793113424 And Number of steps is ==> 93
# Episode * 94 * Avg Reward is ==> -4.1814814286560535 And Number of steps is ==> 94
# Episode * 95 * Avg Reward is ==> -4.9467753064689814 And Number of steps is ==> 95
# Accident!
# Episode * 96 * Avg Reward is ==> -54.87690822637129 And Number of steps is ==> 96
# Episode * 97 * Avg Reward is ==> -5.19442767031426 And Number of steps is ==> 97
# Episode * 98 * Avg Reward is ==> -3.656664327925481 And Number of steps is ==> 98
# Episode * 99 * Avg Reward is ==> -4.565204500611188 And Number of steps is ==> 99

# %%
#Showing Vehicle Acceleration Diagram, Vehicle Speed Diagram, Vehicle and Pedestrian Position Diagram
#All three over time in an episode

#t=0
if (t+1>=len(ep_time)):
    t=0
t_init=t
while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
    t+=1
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(18, 4))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.plot(ep_time[t_init:t],ep_action[t_init:t],color='r')

ax2.set_title('Car and Pedestrian Position')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Position (m)")
ax2.plot(ep_time[t_init:t],ep_pos_car[t_init:t],label='car')
ax2.plot(ep_time[t_init:t],ep_pos_ped[t_init:t],label='pedestrian')
ax2.axhline(y=5, color='r', linestyle='-.')
ax2.axhline(y=0, color='r', linestyle='-.')
ax2.legend()

ax3.set_title('Car Speed')
ax3.set_xlabel("Time (s)")
ax3.set_ylabel("Speed (m/s)")
ax3.plot(ep_time[t_init:t+1],ep_speed_car[t_init:t+1],color='r')

ax4.set_title('Pedestrian Speed')
ax4.set_xlabel("Time (s)")
ax4.set_ylabel("Speed (m/s)")
ax4.plot(ep_time[t_init:t+1],ep_speed_ped[t_init:t+1],color='r')
t+=1

# %%
ep_pos_ped
# Out:
# array([-1.1433388e+00, -8.5894656e-01, -5.7455432e-01, -2.9016209e-01,
#        -5.7698376e-03,  0.0000000e+00,  0.0000000e+00,  3.9806075e-02,
#         1.5795666e-01,  3.5068926e-01,  6.1186635e-01,  9.3317080e-01,
#         1.3043706e+00,  1.7136451e+00,  2.1479609e+00,  2.5934880e+00,
#         3.0360377e+00,  3.4615173e+00,  3.8563776e+00,  4.2080441e+00,
#         4.4924364e+00,  4.7768288e+00,  4.7768288e+00,  4.7768288e+00,
#         4.7768288e+00,  5.0612211e+00,  5.3456135e+00,  5.6300058e+00,
#         5.9143982e+00,  6.1987906e+00,  6.4831829e+00,  6.7675753e+00,
#         7.0519676e+00,  7.3363600e+00,  7.6207523e+00,  7.9051447e+00,
#         8.1895370e+00,  8.4739294e+00,  8.7583218e+00,  9.0427141e+00],
#       dtype=float32)

# %%
ep_pos_car
# Out:
# array([-2.2288103e+01, -1.9562809e+01, -1.7197515e+01, -1.5192222e+01,
#        -1.3546928e+01, -1.2261635e+01, -1.1336341e+01, -1.0771048e+01,
#        -1.0299980e+01, -9.7585402e+00, -9.2330923e+00, -8.7086401e+00,
#        -8.1849728e+00, -7.6408443e+00, -7.0759749e+00, -6.5115094e+00,
#        -5.9132037e+00, -5.2291131e+00, -4.4930353e+00, -3.7567811e+00,
#        -3.0198758e+00, -2.1928105e+00, -1.1864053e+00, -9.0000806e-03,
#         1.3214052e+00,  2.8138103e+00,  4.4862156e+00,  6.3386207e+00,
#         8.3710260e+00,  1.0583431e+01,  1.2975837e+01,  1.5548242e+01,
#         1.8300648e+01,  2.1174498e+01,  2.4079790e+01,  2.6985083e+01,
#         2.9890375e+01,  3.2795670e+01,  3.5700962e+01,  3.8606255e+01],
#       dtype=float32)
