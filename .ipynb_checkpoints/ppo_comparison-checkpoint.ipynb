# %%
#1) Import libraries
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import namedtuple, deque
import Environments
from collections import OrderedDict
from torch.distributions import MultivariateNormal
import pandas as pd

# I use the work of Eric Yu to help me build this algorithm. Link: https://github.com/ericyangyu/PPO-for-Beginners

# %%
#2) Set up Neural Network functions and classes

class Model_PPO(nn.Module):
    """
        Class: actor NN
        :param np_inputs: size input of the NN (size state)
        :param nb_outputs: size output of the NN (size action)
    """  
    def __init__(self, np_inputs, nb_outputs):
        super(Model_PPO, self).__init__()   
        self.layer1 = nn.Linear(np_inputs, 64)
        self.layer2 = nn.Linear(64, 64)
        self.layer3 = nn.Linear(64, nb_outputs)
        torch.nn.init.uniform_(self.layer3.weight,0.003, 0.006)

    def forward(self, input1):
        """
        Forward NN : compute the NN with respect the current state
        :param input1: state
        :return: output of the NN, action
        """ 
        if isinstance(input1, np.ndarray):
            input1 = torch.tensor(input1, dtype=torch.float)
        activation1 = F.relu(self.layer1(input1))
        activation2 = F.relu(self.layer2(activation1))
        output = self.layer3(activation2)
        return output

# %%
#3) Rollout on the environment:

class Env_rollout:
    """ 
        Class : iterate on the environment
        :param env: our environment
        :param max_steps: max steps per episode
    """
    def __init__(self, env, max_steps):
        self.env = env
        self.max_steps = max_steps
        self.prev_state = env.reset()
        self.batch_obs=[]
        self.batch_acts=[]
        self.batch_log_probs=[]
        self.batch_rews = []
    
    def reset(self):
        """
        Reset: reinitilization (lists et environment).
        """
        self.prev_state = env.reset()
        self.batch_obs=[]
        self.batch_acts=[]
        self.batch_log_probs=[]
        self.batch_rews = []
    
    def iterations(self,actor_net, nbr_episodes):
        """
        Iterate on the environment.
        :param actor_net: current policy (actor NN)
        :param nbr_episodes: episode number
        :return: Tensors; state batch, action batch
        """
        for ep in range(nbr_episodes):
            ep_rews = []
            prev_state = self.env.reset()
            for step_ep in range(self.max_steps): 
                with torch.no_grad():
                    action = torch.squeeze(actor_net(torch.unsqueeze(torch.tensor(prev_state), dim=0).float()))
                    if(action.dim()==0):
                        action=torch.unsqueeze(action,dim=0)
                    action_all=np.array([])
                    action_all=np.append(action_all,np.clip(action[0].detach().numpy(), -1.0, 1.0))
                    #action_all=np.append(action_all,np.argmax(action[1:4].detach().numpy()))
                    state, reward, done, _ = self.env.step(action_all)
                    self.batch_obs.append(prev_state)
                    self.batch_acts.append(action_all)
                    ep_rews.append(reward)
                    prev_state = state
                if done:
                    break
            self.batch_rews.append(ep_rews)
        return torch.tensor(self.batch_obs, dtype=torch.float), torch.tensor(self.batch_acts, dtype=torch.float)
    
    def iterations_rand(self,actor_net, cov_mat, batch_size):
        """
        Iterate on the environment.
        :param actor_net: current policy (actor NN)
        :param cov_mat: covariance matrix used for exploration
        :param batch_size: batch size
        :return: Tensors; state batch, action batch, log_proba batch
        """
        t = 0
        while t<batch_size:
            ep_rews = []
            prev_state = self.env.reset()
            for step_ep in range(self.max_steps): 
                t += 1
                with torch.no_grad():
                    parameters_based = torch.squeeze(actor_net(torch.unsqueeze(torch.tensor(prev_state), dim=0).float()))
                    if(parameters_based.dim()==0):
                        parameters_based=torch.unsqueeze(parameters_based,dim=0)
                    distribution_p = MultivariateNormal(parameters_based, cov_mat)
                    action = distribution_p.sample()
                    log_proba = distribution_p.log_prob(action)
                    action_all=np.array([])
                    action_all=np.append(action_all,np.clip(action[0].detach().numpy(), -1.0, 1.0))
                    state, reward, done, _ = self.env.step(action_all)
                    self.batch_obs.append(prev_state)
                    self.batch_acts.append(action.detach().numpy())
                    self.batch_log_probs.append(log_proba)
                    ep_rews.append(reward)
                    prev_state = state
                if done:
                    break
            self.batch_rews.append(ep_rews)
        return torch.tensor(self.batch_obs, dtype=torch.float), torch.tensor(self.batch_acts, dtype=torch.float), torch.tensor(self.batch_log_probs, dtype=torch.float)

    def immediate_rewards(self):
        """
        Immediate rewards
        :return: Tensor; batch reward
        """
        batch_rewards = []
        for ep_rews in self.batch_rews:
            for rew in reversed(ep_rews):
                batch_rewards.insert(0,rew)
        return torch.tensor(batch_rewards, dtype=torch.float)
    
    def futur_rewards(self):
        """
        Expected futures rewards
        :return: Tensor; batch reward-to-go
        """
        batch_rtgs = []
        for ep_rews in reversed(self.batch_rews):
            episodic_reward=0.0
            for rew in reversed(ep_rews):
                episodic_reward= rew + 0.99*episodic_reward
                batch_rtgs.insert(0,episodic_reward)
        return torch.tensor(batch_rtgs, dtype=torch.float)

# %%
#4) Algorithm DDPG:
class Algo_PPO():
    """ 
    PPO algorithm : training and testing
    :param policy_class: policy (actor model)
    :param env: environment
    :param hyperparameters: other hyperparameters
    """
    def __init__(self, policy_class, env, **hyperparameters):
        
        self._init_hyperparameters(hyperparameters)
        self.actor_net = policy_class(self.num_states, self.num_actions)
        self.critic_net = policy_class(self.num_states, 1)
        self.optimizer_critic = optim.Adam(self.critic_net.parameters(), self.critic_lr)
        self.optimizer_actor = optim.Adam(self.actor_net.parameters(), self.actor_lr)
        self.cov_var = torch.full(size=(self.num_actions,), fill_value=0.5)
        self.cov_mat = torch.diag(self.cov_var)
        self.rollout = Env_rollout(env, self.max_steps)
        self.ep_reward_list=[]
    
    def evaluate(self, nbr_episodes):
        """
        Testing
        :param nbr_episodes: episode number 
        :return: state batch, action batch, and reward batch
        """
        self.rollout.reset()
        state_batch, action_batch = self.rollout.iterations(self.actor_net, nbr_episodes)
        rew_batch = self.rollout.immediate_rewards()
        return state_batch, action_batch, rew_batch
        
    def train(self, nb_loop):
        """ 
        Training
        :param nb_loop: number of batch iterations
        """
        for ep in range(nb_loop):
            state_batch,action_batch,log_prob_batch = self.rollout.iterations_rand(self.actor_net,self.cov_mat,self.batch_size)
            batch_rtgs = self.rollout.futur_rewards()
            #batch_rews = self.rollout.immediate_rewards()
            self.rollout.reset()
            for i in range(10):
                V_batch = torch.squeeze(self.critic_net(state_batch))
                advantage_batch = batch_rtgs - V_batch
                advantage_batch = (advantage_batch - advantage_batch.mean()) / (advantage_batch.std() + 1e-10)
                
                parameters_batch = torch.squeeze(self.actor_net(state_batch).unsqueeze(-1))
                if(parameters_batch.dim()==1):
                        parameters_batch=torch.unsqueeze(parameters_batch,dim=1)
                distribution_p = MultivariateNormal(parameters_batch, self.cov_mat)
                log_prob_current_batch = distribution_p.log_prob(action_batch)
                ratio_batch = torch.exp(log_prob_current_batch - log_prob_batch)
                ratio_loss = torch.mul(ratio_batch,advantage_batch)
                clip_loss = torch.mul(torch.clamp(ratio_loss, 0.8, 1.2),advantage_batch)
                actor_loss = (-torch.min(ratio_loss, clip_loss)).mean()

                criterion=nn.MSELoss(reduction='mean')
                critic_loss = criterion(V_batch.float(), batch_rtgs.float())
                self.optimizer_actor.zero_grad()
                actor_loss.backward(retain_graph=True)
                self.optimizer_actor.step()
                self.optimizer_critic.zero_grad()
                critic_loss.backward()
                self.optimizer_critic.step()
                
            state_batch, action_batch = self.rollout.iterations(self.actor_net, 30)
            batch_rews = self.rollout.immediate_rewards()
            self.ep_reward_list.append(batch_rews.mean().numpy())
            avg_reward = np.mean(self.ep_reward_list[-10:])
            self.rollout.reset()
    
            print("Episode * {} * Avg Reward is ==> {} And Number of steps is ==> {}".format(ep, avg_reward,ep*self.batch_size ))
            self.total_loop= self.total_loop +1
        path='load_model/parameters/ppo-{num_algo:02d}-{name}-{epoch:03d}000.npy'
        with open(path.format(num_algo=self.num_algo,epoch=int(self.total_loop/1000),name="reward"), 'wb') as f:
            np.save(f, np.array(self.ep_reward_list))
        print("Complete")
        
    def _init_hyperparameters(self, hyperparameters):
        """
        Initialize hyperparameters. 
        :param hyperparameters: hyperparameter list
        """
        self.num_algo = 1
        self.max_steps = 90
        self.total_loop = 0
        self.batch_size = 2000
        self.gamma = 0.99
        self.critic_lr = 3e-4
        self.actor_lr = 3e-4
        for param, val in hyperparameters.items():
            exec('self.' + param + ' = ' + str(val))
            
    def loading(self, num_algo, total_loop):
        """
        Loading NN weights 
        :param num_algo: algorithm number
        :param total_loop: number of total batch iterations
        """
        self.num_algo = num_algo
        self.total_loop = total_loop
        checkpoint_path1 = "load_model/weights/torch-ppo-{num_algo:02d}-actor-{epoch:03d}0.pth"
        self.actor_net.load_state_dict(torch.load(checkpoint_path1.format(epoch=int(self.total_loop/10), num_algo=self.num_algo)))
        checkpoint_path2 = "load_model/weights/torch-ppo-{num_algo:02d}-critic-{epoch:03d}0.pth"
        self.critic_net.load_state_dict(torch.load(checkpoint_path2.format(epoch=int(self.total_loop/10), num_algo=self.num_algo)))
    
    def saving(self):
        """
        Saving NN weights 
        """
        checkpoint_path = "load_model/weights/torch-ppo-{num_algo:02d}-actor-{epoch:03d}0.pth"
        torch.save(self.actor_net.state_dict(),checkpoint_path.format(epoch=int(self.total_loop/10), num_algo=self.num_algo))
        checkpoint_path = "load_model/weights/torch-ppo-{num_algo:02d}-critic-{epoch:03d}0.pth"
        torch.save(self.critic_net.state_dict(),checkpoint_path.format(epoch=int(self.total_loop/10), num_algo=self.num_algo))

# %%
#5) Computing part:
# Import environment
problem = "Crossway_comparison-v0"
u_b = [2.0, 11.0, -12.5, 1.1, -1.0]
l_b = [-4.0, 9.0, -32.5, 0.9, -2.0]

env = gym.make(problem,dt=0.3,Vm=2.5,tau=1.0,lower_bounds=l_b, upper_bounds=u_b,simulation="sin")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the algorithm
num_states = env.observation_space.shape[0]
num_actions = env.action_space.shape[0]
num_algo=11

algo=Algo_PPO(Model_PPO, env, num_algo= num_algo, num_states=num_states, num_actions=num_actions)
#algo.loading(1,1000)

# %%
#Training
import time
start = time.process_time()
algo.train(1000)
algo.saving()
end = time.process_time()
print("Running time: "+str(end-start))
# Out:
# Episode * 0 * Avg Reward is ==> -4.701624870300293 And Number of steps is ==> 0
# Episode * 1 * Avg Reward is ==> -4.129057884216309 And Number of steps is ==> 2000
# Accident!
# Accident!
# Episode * 2 * Avg Reward is ==> -4.2605156898498535 And Number of steps is ==> 4000
# Episode * 3 * Avg Reward is ==> -4.53954553604126 And Number of steps is ==> 6000
# Episode * 4 * Avg Reward is ==> -4.700287818908691 And Number of steps is ==> 8000
# Accident!
# Accident!
# Episode * 5 * Avg Reward is ==> -4.518410682678223 And Number of steps is ==> 10000
# Accident!
# Accident!
# Episode * 6 * Avg Reward is ==> -4.539999961853027 And Number of steps is ==> 12000
# Episode * 7 * Avg Reward is ==> -4.42772912979126 And Number of steps is ==> 14000
# Episode * 8 * Avg Reward is ==> -4.543269634246826 And Number of steps is ==> 16000
# Episode * 9 * Avg Reward is ==> -4.504900932312012 And Number of steps is ==> 18000
# Accident!
# Accident!
# Episode * 10 * Avg Reward is ==> -4.643017292022705 And Number of steps is ==> 20000
# Accident!
# Accident!
# Episode * 11 * Avg Reward is ==> -4.6502790451049805 And Number of steps is ==> 22000
# Episode * 12 * Avg Reward is ==> -4.538649559020996 And Number of steps is ==> 24000
# Episode * 13 * Avg Reward is ==> -4.375673294067383 And Number of steps is ==> 26000
# Episode * 14 * Avg Reward is ==> -4.189594745635986 And Number of steps is ==> 28000
# Episode * 15 * Avg Reward is ==> -4.434996128082275 And Number of steps is ==> 30000
# Episode * 16 * Avg Reward is ==> -4.313510417938232 And Number of steps is ==> 32000
# Accident!
# Episode * 17 * Avg Reward is ==> -4.382863521575928 And Number of steps is ==> 34000
# Episode * 18 * Avg Reward is ==> -4.174704551696777 And Number of steps is ==> 36000
# Accident!
# Episode * 19 * Avg Reward is ==> -4.17806339263916 And Number of steps is ==> 38000
# Episode * 20 * Avg Reward is ==> -3.820981979370117 And Number of steps is ==> 40000
# Accident!
# Episode * 21 * Avg Reward is ==> -3.790623426437378 And Number of steps is ==> 42000
# Episode * 22 * Avg Reward is ==> -3.709043502807617 And Number of steps is ==> 44000
# Episode * 23 * Avg Reward is ==> -3.7491283416748047 And Number of steps is ==> 46000
# Accident!
# Episode * 24 * Avg Reward is ==> -3.7989723682403564 And Number of steps is ==> 48000
# Accident!
# Accident!
# Episode * 25 * Avg Reward is ==> -3.4475226402282715 And Number of steps is ==> 50000
# Accident!
# Accident!
# Episode * 26 * Avg Reward is ==> -3.3414528369903564 And Number of steps is ==> 52000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 27 * Avg Reward is ==> -3.9277045726776123 And Number of steps is ==> 54000
# Accident!
# Accident!
# Accident!
# Episode * 28 * Avg Reward is ==> -3.828669309616089 And Number of steps is ==> 56000
# Accident!
# Episode * 29 * Avg Reward is ==> -3.69085955619812 And Number of steps is ==> 58000
# Accident!
# Accident!
# Episode * 30 * Avg Reward is ==> -3.675114154815674 And Number of steps is ==> 60000
# Accident!
# Episode * 31 * Avg Reward is ==> -3.6320061683654785 And Number of steps is ==> 62000
# Episode * 32 * Avg Reward is ==> -3.6753909587860107 And Number of steps is ==> 64000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 33 * Avg Reward is ==> -3.678717851638794 And Number of steps is ==> 66000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 34 * Avg Reward is ==> -3.5536446571350098 And Number of steps is ==> 68000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 35 * Avg Reward is ==> -3.667980194091797 And Number of steps is ==> 70000
# Accident!
# Accident!
# Accident!
# Episode * 36 * Avg Reward is ==> -3.6547000408172607 And Number of steps is ==> 72000
# Accident!
# Accident!
# Episode * 37 * Avg Reward is ==> -2.7854387760162354 And Number of steps is ==> 74000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 38 * Avg Reward is ==> -2.7833633422851562 And Number of steps is ==> 76000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 39 * Avg Reward is ==> -2.6386938095092773 And Number of steps is ==> 78000
# Accident!
# Accident!
# Episode * 40 * Avg Reward is ==> -2.6935601234436035 And Number of steps is ==> 80000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 41 * Avg Reward is ==> -2.669965982437134 And Number of steps is ==> 82000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 42 * Avg Reward is ==> -2.5802412033081055 And Number of steps is ==> 84000
# Accident!
# Accident!
# Episode * 43 * Avg Reward is ==> -2.404414176940918 And Number of steps is ==> 86000
# Accident!
# Accident!
# Episode * 44 * Avg Reward is ==> -2.3322906494140625 And Number of steps is ==> 88000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 45 * Avg Reward is ==> -2.2865192890167236 And Number of steps is ==> 90000
# Accident!
# Accident!
# Accident!
# Episode * 46 * Avg Reward is ==> -2.378370761871338 And Number of steps is ==> 92000
# Accident!
# Episode * 47 * Avg Reward is ==> -2.3316705226898193 And Number of steps is ==> 94000
# Accident!
# Accident!
# Accident!
# Episode * 48 * Avg Reward is ==> -2.9364211559295654 And Number of steps is ==> 96000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 49 * Avg Reward is ==> -3.109373092651367 And Number of steps is ==> 98000
# Accident!
# Episode * 50 * Avg Reward is ==> -3.0008583068847656 And Number of steps is ==> 100000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 51 * Avg Reward is ==> -3.024013042449951 And Number of steps is ==> 102000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 52 * Avg Reward is ==> -3.051440477371216 And Number of steps is ==> 104000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 53 * Avg Reward is ==> -3.2107276916503906 And Number of steps is ==> 106000
# Accident!
# Accident!
# Accident!
# Episode * 54 * Avg Reward is ==> -3.2626349925994873 And Number of steps is ==> 108000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 55 * Avg Reward is ==> -3.2573413848876953 And Number of steps is ==> 110000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 56 * Avg Reward is ==> -3.2277400493621826 And Number of steps is ==> 112000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 57 * Avg Reward is ==> -3.3610663414001465 And Number of steps is ==> 114000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 58 * Avg Reward is ==> -2.6800384521484375 And Number of steps is ==> 116000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 59 * Avg Reward is ==> -2.6633501052856445 And Number of steps is ==> 118000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 60 * Avg Reward is ==> -2.6400787830352783 And Number of steps is ==> 120000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 61 * Avg Reward is ==> -2.7744970321655273 And Number of steps is ==> 122000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 62 * Avg Reward is ==> -3.744248151779175 And Number of steps is ==> 124000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 63 * Avg Reward is ==> -4.221137046813965 And Number of steps is ==> 126000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 64 * Avg Reward is ==> -4.192863464355469 And Number of steps is ==> 128000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 65 * Avg Reward is ==> -3.9788899421691895 And Number of steps is ==> 130000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 66 * Avg Reward is ==> -3.8838272094726562 And Number of steps is ==> 132000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 67 * Avg Reward is ==> -3.7682127952575684 And Number of steps is ==> 134000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 68 * Avg Reward is ==> -3.783778667449951 And Number of steps is ==> 136000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 69 * Avg Reward is ==> -3.7848007678985596 And Number of steps is ==> 138000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 70 * Avg Reward is ==> -3.888411045074463 And Number of steps is ==> 140000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 71 * Avg Reward is ==> -3.761462450027466 And Number of steps is ==> 142000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 72 * Avg Reward is ==> -2.806102991104126 And Number of steps is ==> 144000
# Accident!
# Accident!
# Episode * 73 * Avg Reward is ==> -2.1869826316833496 And Number of steps is ==> 146000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 74 * Avg Reward is ==> -2.1530442237854004 And Number of steps is ==> 148000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 75 * Avg Reward is ==> -3.021515369415283 And Number of steps is ==> 150000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 76 * Avg Reward is ==> -3.113823175430298 And Number of steps is ==> 152000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 77 * Avg Reward is ==> -3.3743395805358887 And Number of steps is ==> 154000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 78 * Avg Reward is ==> -3.5768656730651855 And Number of steps is ==> 156000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 79 * Avg Reward is ==> -3.58140230178833 And Number of steps is ==> 158000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 80 * Avg Reward is ==> -4.558729648590088 And Number of steps is ==> 160000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 81 * Avg Reward is ==> -4.609915733337402 And Number of steps is ==> 162000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 82 * Avg Reward is ==> -4.68186616897583 And Number of steps is ==> 164000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 83 * Avg Reward is ==> -4.698376655578613 And Number of steps is ==> 166000
# Accident!
# Accident!
# Accident!
# Episode * 84 * Avg Reward is ==> -4.816421985626221 And Number of steps is ==> 168000
# Accident!
# Accident!
# Episode * 85 * Avg Reward is ==> -4.232809543609619 And Number of steps is ==> 170000
# Accident!
# Accident!
# Episode * 86 * Avg Reward is ==> -4.167494773864746 And Number of steps is ==> 172000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 87 * Avg Reward is ==> -4.062638282775879 And Number of steps is ==> 174000
# Accident!
# Accident!
# Accident!
# Episode * 88 * Avg Reward is ==> -3.9807193279266357 And Number of steps is ==> 176000
# Accident!
# Accident!
# Episode * 89 * Avg Reward is ==> -3.711458921432495 And Number of steps is ==> 178000
# Accident!
# Accident!
# Episode * 90 * Avg Reward is ==> -2.626237630844116 And Number of steps is ==> 180000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 91 * Avg Reward is ==> -2.622584342956543 And Number of steps is ==> 182000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 92 * Avg Reward is ==> -2.5675277709960938 And Number of steps is ==> 184000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 93 * Avg Reward is ==> -2.5504543781280518 And Number of steps is ==> 186000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 94 * Avg Reward is ==> -2.539928913116455 And Number of steps is ==> 188000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 95 * Avg Reward is ==> -2.4247069358825684 And Number of steps is ==> 190000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 96 * Avg Reward is ==> -2.564119338989258 And Number of steps is ==> 192000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 97 * Avg Reward is ==> -2.5790393352508545 And Number of steps is ==> 194000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 98 * Avg Reward is ==> -2.5118088722229004 And Number of steps is ==> 196000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 99 * Avg Reward is ==> -2.7192509174346924 And Number of steps is ==> 198000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 100 * Avg Reward is ==> -2.9070417881011963 And Number of steps is ==> 200000
# Accident!
# Accident!
# Accident!
# Episode * 101 * Avg Reward is ==> -2.7145628929138184 And Number of steps is ==> 202000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 102 * Avg Reward is ==> -2.5835862159729004 And Number of steps is ==> 204000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 103 * Avg Reward is ==> -2.362508773803711 And Number of steps is ==> 206000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 104 * Avg Reward is ==> -2.3515162467956543 And Number of steps is ==> 208000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 105 * Avg Reward is ==> -2.248807430267334 And Number of steps is ==> 210000
# Accident!
# Accident!
# Accident!
# Episode * 106 * Avg Reward is ==> -1.9942598342895508 And Number of steps is ==> 212000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 107 * Avg Reward is ==> -1.849412202835083 And Number of steps is ==> 214000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 108 * Avg Reward is ==> -1.87478768825531 And Number of steps is ==> 216000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 109 * Avg Reward is ==> -1.9254251718521118 And Number of steps is ==> 218000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 110 * Avg Reward is ==> -1.8654801845550537 And Number of steps is ==> 220000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 111 * Avg Reward is ==> -1.9118402004241943 And Number of steps is ==> 222000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 112 * Avg Reward is ==> -2.0674026012420654 And Number of steps is ==> 224000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 113 * Avg Reward is ==> -2.1132025718688965 And Number of steps is ==> 226000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 114 * Avg Reward is ==> -2.0011954307556152 And Number of steps is ==> 228000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 115 * Avg Reward is ==> -2.0624661445617676 And Number of steps is ==> 230000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 116 * Avg Reward is ==> -2.1592934131622314 And Number of steps is ==> 232000
# Accident!
# Accident!
# Episode * 117 * Avg Reward is ==> -2.151527166366577 And Number of steps is ==> 234000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 118 * Avg Reward is ==> -1.9772405624389648 And Number of steps is ==> 236000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 119 * Avg Reward is ==> -1.924163818359375 And Number of steps is ==> 238000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 120 * Avg Reward is ==> -1.901741623878479 And Number of steps is ==> 240000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 121 * Avg Reward is ==> -1.7487819194793701 And Number of steps is ==> 242000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 122 * Avg Reward is ==> -1.6626590490341187 And Number of steps is ==> 244000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 123 * Avg Reward is ==> -1.7746658325195312 And Number of steps is ==> 246000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 124 * Avg Reward is ==> -1.7731825113296509 And Number of steps is ==> 248000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 125 * Avg Reward is ==> -1.777726411819458 And Number of steps is ==> 250000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 126 * Avg Reward is ==> -1.9107745885849 And Number of steps is ==> 252000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 127 * Avg Reward is ==> -1.9777076244354248 And Number of steps is ==> 254000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 128 * Avg Reward is ==> -2.0449538230895996 And Number of steps is ==> 256000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 129 * Avg Reward is ==> -2.014169216156006 And Number of steps is ==> 258000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 130 * Avg Reward is ==> -1.9048343896865845 And Number of steps is ==> 260000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 131 * Avg Reward is ==> -2.0520360469818115 And Number of steps is ==> 262000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 132 * Avg Reward is ==> -2.066166877746582 And Number of steps is ==> 264000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 133 * Avg Reward is ==> -2.1347687244415283 And Number of steps is ==> 266000
# Accident!
# Accident!
# Episode * 134 * Avg Reward is ==> -2.1574277877807617 And Number of steps is ==> 268000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 135 * Avg Reward is ==> -2.2586073875427246 And Number of steps is ==> 270000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 136 * Avg Reward is ==> -2.2978262901306152 And Number of steps is ==> 272000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 137 * Avg Reward is ==> -2.3154642581939697 And Number of steps is ==> 274000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 138 * Avg Reward is ==> -2.300081729888916 And Number of steps is ==> 276000
# Accident!
# Accident!
# Accident!
# Episode * 139 * Avg Reward is ==> -2.126363754272461 And Number of steps is ==> 278000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 140 * Avg Reward is ==> -2.1599555015563965 And Number of steps is ==> 280000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 141 * Avg Reward is ==> -2.097057819366455 And Number of steps is ==> 282000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 142 * Avg Reward is ==> -1.923156976699829 And Number of steps is ==> 284000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 143 * Avg Reward is ==> -1.9402506351470947 And Number of steps is ==> 286000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 144 * Avg Reward is ==> -1.9012982845306396 And Number of steps is ==> 288000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 145 * Avg Reward is ==> -1.581488013267517 And Number of steps is ==> 290000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 146 * Avg Reward is ==> -1.4533069133758545 And Number of steps is ==> 292000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 147 * Avg Reward is ==> -1.4405311346054077 And Number of steps is ==> 294000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 148 * Avg Reward is ==> -1.5262157917022705 And Number of steps is ==> 296000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 149 * Avg Reward is ==> -1.6838947534561157 And Number of steps is ==> 298000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 150 * Avg Reward is ==> -1.5957226753234863 And Number of steps is ==> 300000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 151 * Avg Reward is ==> -1.6247485876083374 And Number of steps is ==> 302000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 152 * Avg Reward is ==> -1.793583869934082 And Number of steps is ==> 304000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 153 * Avg Reward is ==> -1.6713428497314453 And Number of steps is ==> 306000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 154 * Avg Reward is ==> -1.8351194858551025 And Number of steps is ==> 308000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 155 * Avg Reward is ==> -1.9283697605133057 And Number of steps is ==> 310000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 156 * Avg Reward is ==> -1.7627216577529907 And Number of steps is ==> 312000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 157 * Avg Reward is ==> -1.650526762008667 And Number of steps is ==> 314000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 158 * Avg Reward is ==> -1.5482407808303833 And Number of steps is ==> 316000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 159 * Avg Reward is ==> -1.4849187135696411 And Number of steps is ==> 318000
# Accident!
# Accident!
# Accident!
# Episode * 160 * Avg Reward is ==> -1.4713952541351318 And Number of steps is ==> 320000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 161 * Avg Reward is ==> -1.384836196899414 And Number of steps is ==> 322000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 162 * Avg Reward is ==> -1.1909077167510986 And Number of steps is ==> 324000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 163 * Avg Reward is ==> -1.1528915166854858 And Number of steps is ==> 326000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 164 * Avg Reward is ==> -0.8452020883560181 And Number of steps is ==> 328000
# Accident!
# Accident!
# Accident!
# Episode * 165 * Avg Reward is ==> -0.8793686628341675 And Number of steps is ==> 330000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 166 * Avg Reward is ==> -0.9603308439254761 And Number of steps is ==> 332000
# Episode * 167 * Avg Reward is ==> -1.0394597053527832 And Number of steps is ==> 334000
# Accident!
# Accident!
# Accident!
# Episode * 168 * Avg Reward is ==> -0.8830307126045227 And Number of steps is ==> 336000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 169 * Avg Reward is ==> -0.8510026931762695 And Number of steps is ==> 338000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 170 * Avg Reward is ==> -0.9280062913894653 And Number of steps is ==> 340000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 171 * Avg Reward is ==> -0.9424108266830444 And Number of steps is ==> 342000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 172 * Avg Reward is ==> -0.9799785614013672 And Number of steps is ==> 344000
# Accident!
# Accident!
# Accident!
# Episode * 173 * Avg Reward is ==> -0.9007000923156738 And Number of steps is ==> 346000
# Accident!
# Accident!
# Accident!
# Episode * 174 * Avg Reward is ==> -0.9183057546615601 And Number of steps is ==> 348000
# Accident!
# Accident!
# Accident!
# Episode * 175 * Avg Reward is ==> -0.8354656100273132 And Number of steps is ==> 350000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 176 * Avg Reward is ==> -0.789382815361023 And Number of steps is ==> 352000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 177 * Avg Reward is ==> -0.7452734708786011 And Number of steps is ==> 354000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 178 * Avg Reward is ==> -0.801088809967041 And Number of steps is ==> 356000
# Accident!
# Accident!
# Episode * 179 * Avg Reward is ==> -0.6934815049171448 And Number of steps is ==> 358000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 180 * Avg Reward is ==> -0.6043089628219604 And Number of steps is ==> 360000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 181 * Avg Reward is ==> -0.5662634968757629 And Number of steps is ==> 362000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 182 * Avg Reward is ==> -0.702797532081604 And Number of steps is ==> 364000
# Accident!
# Accident!
# Episode * 183 * Avg Reward is ==> -0.7148479223251343 And Number of steps is ==> 366000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 184 * Avg Reward is ==> -0.7278741002082825 And Number of steps is ==> 368000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 185 * Avg Reward is ==> -0.7133775353431702 And Number of steps is ==> 370000
# Episode * 186 * Avg Reward is ==> -0.6288487315177917 And Number of steps is ==> 372000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 187 * Avg Reward is ==> -0.5438862442970276 And Number of steps is ==> 374000
# Accident!
# Accident!
# Accident!
# Episode * 188 * Avg Reward is ==> -0.6228145360946655 And Number of steps is ==> 376000
# Accident!
# Accident!
# Episode * 189 * Avg Reward is ==> -0.6957160234451294 And Number of steps is ==> 378000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 190 * Avg Reward is ==> -0.7332899570465088 And Number of steps is ==> 380000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 191 * Avg Reward is ==> -0.7796584963798523 And Number of steps is ==> 382000
# Accident!
# Accident!
# Accident!
# Episode * 192 * Avg Reward is ==> -0.6508525013923645 And Number of steps is ==> 384000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 193 * Avg Reward is ==> -0.8482058644294739 And Number of steps is ==> 386000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 194 * Avg Reward is ==> -1.025221347808838 And Number of steps is ==> 388000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 195 * Avg Reward is ==> -1.148577094078064 And Number of steps is ==> 390000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 196 * Avg Reward is ==> -1.2110286951065063 And Number of steps is ==> 392000
# Accident!
# Accident!
# Accident!
# Episode * 197 * Avg Reward is ==> -1.3069486618041992 And Number of steps is ==> 394000
# Accident!
# Accident!
# Accident!
# Episode * 198 * Avg Reward is ==> -1.3117754459381104 And Number of steps is ==> 396000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 199 * Avg Reward is ==> -1.3823344707489014 And Number of steps is ==> 398000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 200 * Avg Reward is ==> -1.4543343782424927 And Number of steps is ==> 400000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 201 * Avg Reward is ==> -1.6230541467666626 And Number of steps is ==> 402000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 202 * Avg Reward is ==> -1.7239090204238892 And Number of steps is ==> 404000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 203 * Avg Reward is ==> -1.509682297706604 And Number of steps is ==> 406000
# Accident!
# Accident!
# Episode * 204 * Avg Reward is ==> -1.3732695579528809 And Number of steps is ==> 408000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 205 * Avg Reward is ==> -1.3865420818328857 And Number of steps is ==> 410000
# Accident!
# Accident!
# Accident!
# Episode * 206 * Avg Reward is ==> -1.428497552871704 And Number of steps is ==> 412000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 207 * Avg Reward is ==> -1.4003159999847412 And Number of steps is ==> 414000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 208 * Avg Reward is ==> -1.4580676555633545 And Number of steps is ==> 416000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 209 * Avg Reward is ==> -1.484276294708252 And Number of steps is ==> 418000
# Accident!
# Accident!
# Episode * 210 * Avg Reward is ==> -1.3081421852111816 And Number of steps is ==> 420000
# Accident!
# Episode * 211 * Avg Reward is ==> -1.0734437704086304 And Number of steps is ==> 422000
# Accident!
# Accident!
# Accident!
# Episode * 212 * Avg Reward is ==> -1.0310523509979248 And Number of steps is ==> 424000
# Accident!
# Accident!
# Accident!
# Episode * 213 * Avg Reward is ==> -0.9970008134841919 And Number of steps is ==> 426000
# Accident!
# Accident!
# Episode * 214 * Avg Reward is ==> -1.0191190242767334 And Number of steps is ==> 428000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 215 * Avg Reward is ==> -0.8666671514511108 And Number of steps is ==> 430000
# Accident!
# Accident!
# Episode * 216 * Avg Reward is ==> -0.704362690448761 And Number of steps is ==> 432000
# Accident!
# Accident!
# Episode * 217 * Avg Reward is ==> -0.5394371747970581 And Number of steps is ==> 434000
# Episode * 218 * Avg Reward is ==> -0.33641737699508667 And Number of steps is ==> 436000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 219 * Avg Reward is ==> -0.1498076468706131 And Number of steps is ==> 438000
# Accident!
# Accident!
# Accident!
# Episode * 220 * Avg Reward is ==> -0.12313814461231232 And Number of steps is ==> 440000
# Accident!
# Episode * 221 * Avg Reward is ==> -0.06773819774389267 And Number of steps is ==> 442000
# Accident!
# Accident!
# Episode * 222 * Avg Reward is ==> 0.10167865455150604 And Number of steps is ==> 444000
# Accident!
# Accident!
# Episode * 223 * Avg Reward is ==> 0.14196448028087616 And Number of steps is ==> 446000
# Episode * 224 * Avg Reward is ==> 0.2796863913536072 And Number of steps is ==> 448000
# Episode * 225 * Avg Reward is ==> 0.3563588261604309 And Number of steps is ==> 450000
# Accident!
# Accident!
# Episode * 226 * Avg Reward is ==> 0.37785789370536804 And Number of steps is ==> 452000
# Accident!
# Episode * 227 * Avg Reward is ==> 0.32154154777526855 And Number of steps is ==> 454000
# Accident!
# Episode * 228 * Avg Reward is ==> 0.32857322692871094 And Number of steps is ==> 456000
# Episode * 229 * Avg Reward is ==> 0.35441750288009644 And Number of steps is ==> 458000
# Episode * 230 * Avg Reward is ==> 0.38698238134384155 And Number of steps is ==> 460000
# Accident!
# Episode * 231 * Avg Reward is ==> 0.38395625352859497 And Number of steps is ==> 462000
# Accident!
# Episode * 232 * Avg Reward is ==> 0.4154089093208313 And Number of steps is ==> 464000
# Accident!
# Episode * 233 * Avg Reward is ==> 0.41292327642440796 And Number of steps is ==> 466000
# Episode * 234 * Avg Reward is ==> 0.46276363730430603 And Number of steps is ==> 468000
# Accident!
# Accident!
# Episode * 235 * Avg Reward is ==> 0.4310077130794525 And Number of steps is ==> 470000
# Episode * 236 * Avg Reward is ==> 0.43779444694519043 And Number of steps is ==> 472000
# Episode * 237 * Avg Reward is ==> 0.522508978843689 And Number of steps is ==> 474000
# Accident!
# Episode * 238 * Avg Reward is ==> 0.537858247756958 And Number of steps is ==> 476000
# Episode * 239 * Avg Reward is ==> 0.5540148615837097 And Number of steps is ==> 478000
# Episode * 240 * Avg Reward is ==> 0.5792511105537415 And Number of steps is ==> 480000
# Episode * 241 * Avg Reward is ==> 0.6444476842880249 And Number of steps is ==> 482000
# Episode * 242 * Avg Reward is ==> 0.6621681451797485 And Number of steps is ==> 484000
# Episode * 243 * Avg Reward is ==> 0.7117618322372437 And Number of steps is ==> 486000
# Episode * 244 * Avg Reward is ==> 0.6925672292709351 And Number of steps is ==> 488000
# Accident!
# Episode * 245 * Avg Reward is ==> 0.7623725533485413 And Number of steps is ==> 490000
# Accident!
# Episode * 246 * Avg Reward is ==> 0.7238583564758301 And Number of steps is ==> 492000
# Accident!
# Episode * 247 * Avg Reward is ==> 0.6675430536270142 And Number of steps is ==> 494000
# Accident!
# Accident!
# Episode * 248 * Avg Reward is ==> 0.6152026653289795 And Number of steps is ==> 496000
# Accident!
# Episode * 249 * Avg Reward is ==> 0.6111860275268555 And Number of steps is ==> 498000
# Accident!
# Episode * 250 * Avg Reward is ==> 0.5816708207130432 And Number of steps is ==> 500000
# Episode * 251 * Avg Reward is ==> 0.5493906736373901 And Number of steps is ==> 502000
# Episode * 252 * Avg Reward is ==> 0.5209912657737732 And Number of steps is ==> 504000
# Accident!
# Episode * 253 * Avg Reward is ==> 0.49494871497154236 And Number of steps is ==> 506000
# Accident!
# Episode * 254 * Avg Reward is ==> 0.45944684743881226 And Number of steps is ==> 508000
# Episode * 255 * Avg Reward is ==> 0.43010491132736206 And Number of steps is ==> 510000
# Accident!
# Accident!
# Episode * 256 * Avg Reward is ==> 0.38077619671821594 And Number of steps is ==> 512000
# Episode * 257 * Avg Reward is ==> 0.4241270422935486 And Number of steps is ==> 514000
# Episode * 258 * Avg Reward is ==> 0.482339471578598 And Number of steps is ==> 516000
# Episode * 259 * Avg Reward is ==> 0.49294716119766235 And Number of steps is ==> 518000
# Accident!
# Episode * 260 * Avg Reward is ==> 0.4961775839328766 And Number of steps is ==> 520000
# Accident!
# Episode * 261 * Avg Reward is ==> 0.4998314380645752 And Number of steps is ==> 522000
# Episode * 262 * Avg Reward is ==> 0.49989908933639526 And Number of steps is ==> 524000
# Episode * 263 * Avg Reward is ==> 0.5045773386955261 And Number of steps is ==> 526000
# Episode * 264 * Avg Reward is ==> 0.5461639165878296 And Number of steps is ==> 528000
# Accident!
# Episode * 265 * Avg Reward is ==> 0.5650619864463806 And Number of steps is ==> 530000
# Episode * 266 * Avg Reward is ==> 0.6612519025802612 And Number of steps is ==> 532000
# Episode * 267 * Avg Reward is ==> 0.6509373188018799 And Number of steps is ==> 534000
# Episode * 268 * Avg Reward is ==> 0.6260961294174194 And Number of steps is ==> 536000
# Episode * 269 * Avg Reward is ==> 0.6022576689720154 And Number of steps is ==> 538000
# Episode * 270 * Avg Reward is ==> 0.6418347358703613 And Number of steps is ==> 540000
# Episode * 271 * Avg Reward is ==> 0.6638537049293518 And Number of steps is ==> 542000
# Accident!
# Episode * 272 * Avg Reward is ==> 0.6728459596633911 And Number of steps is ==> 544000
# Episode * 273 * Avg Reward is ==> 0.679577648639679 And Number of steps is ==> 546000
# Episode * 274 * Avg Reward is ==> 0.69060218334198 And Number of steps is ==> 548000
# Episode * 275 * Avg Reward is ==> 0.6881656646728516 And Number of steps is ==> 550000
# Episode * 276 * Avg Reward is ==> 0.7124189734458923 And Number of steps is ==> 552000
# Episode * 277 * Avg Reward is ==> 0.7460735440254211 And Number of steps is ==> 554000
# Accident!
# Accident!
# Episode * 278 * Avg Reward is ==> 0.665325939655304 And Number of steps is ==> 556000
# Episode * 279 * Avg Reward is ==> 0.6764187812805176 And Number of steps is ==> 558000
# Accident!
# Accident!
# Episode * 280 * Avg Reward is ==> 0.6882967352867126 And Number of steps is ==> 560000
# Episode * 281 * Avg Reward is ==> 0.6978017091751099 And Number of steps is ==> 562000
# Accident!
# Episode * 282 * Avg Reward is ==> 0.7096376419067383 And Number of steps is ==> 564000
# Episode * 283 * Avg Reward is ==> 0.7096372842788696 And Number of steps is ==> 566000
# Episode * 284 * Avg Reward is ==> 0.7085681557655334 And Number of steps is ==> 568000
# Episode * 285 * Avg Reward is ==> 0.7169333696365356 And Number of steps is ==> 570000
# Episode * 286 * Avg Reward is ==> 0.7059355974197388 And Number of steps is ==> 572000
# Episode * 287 * Avg Reward is ==> 0.7191921472549438 And Number of steps is ==> 574000
# Accident!
# Episode * 288 * Avg Reward is ==> 0.8268449902534485 And Number of steps is ==> 576000
# Episode * 289 * Avg Reward is ==> 0.8573563694953918 And Number of steps is ==> 578000
# Episode * 290 * Avg Reward is ==> 0.8376302719116211 And Number of steps is ==> 580000
# Episode * 291 * Avg Reward is ==> 0.8219587206840515 And Number of steps is ==> 582000
# Accident!
# Episode * 292 * Avg Reward is ==> 0.8250377774238586 And Number of steps is ==> 584000
# Episode * 293 * Avg Reward is ==> 0.8557588458061218 And Number of steps is ==> 586000
# Episode * 294 * Avg Reward is ==> 0.876297652721405 And Number of steps is ==> 588000
# Episode * 295 * Avg Reward is ==> 0.8686434626579285 And Number of steps is ==> 590000
# Accident!
# Episode * 296 * Avg Reward is ==> 0.818233847618103 And Number of steps is ==> 592000
# Episode * 297 * Avg Reward is ==> 0.7829259634017944 And Number of steps is ==> 594000
# Accident!
# Episode * 298 * Avg Reward is ==> 0.7877367734909058 And Number of steps is ==> 596000
# Episode * 299 * Avg Reward is ==> 0.7670966982841492 And Number of steps is ==> 598000
# Episode * 300 * Avg Reward is ==> 0.7536518573760986 And Number of steps is ==> 600000
# Episode * 301 * Avg Reward is ==> 0.7721563577651978 And Number of steps is ==> 602000
# Episode * 302 * Avg Reward is ==> 0.7746122479438782 And Number of steps is ==> 604000
# Episode * 303 * Avg Reward is ==> 0.7584506273269653 And Number of steps is ==> 606000
# Episode * 304 * Avg Reward is ==> 0.7452297806739807 And Number of steps is ==> 608000
# Episode * 305 * Avg Reward is ==> 0.7620689272880554 And Number of steps is ==> 610000
# Accident!
# Accident!
# Episode * 306 * Avg Reward is ==> 0.7036725282669067 And Number of steps is ==> 612000
# Episode * 307 * Avg Reward is ==> 0.7064942121505737 And Number of steps is ==> 614000
# Accident!
# Episode * 308 * Avg Reward is ==> 0.6494470238685608 And Number of steps is ==> 616000
# Accident!
# Episode * 309 * Avg Reward is ==> 0.6574889421463013 And Number of steps is ==> 618000
# Accident!
# Episode * 310 * Avg Reward is ==> 0.6656268835067749 And Number of steps is ==> 620000
# Episode * 311 * Avg Reward is ==> 0.6406415104866028 And Number of steps is ==> 622000
# Episode * 312 * Avg Reward is ==> 0.6373077630996704 And Number of steps is ==> 624000
# Episode * 313 * Avg Reward is ==> 0.6222571134567261 And Number of steps is ==> 626000
# Episode * 314 * Avg Reward is ==> 0.6228491067886353 And Number of steps is ==> 628000
# Episode * 315 * Avg Reward is ==> 0.6369156837463379 And Number of steps is ==> 630000
# Episode * 316 * Avg Reward is ==> 0.7562305927276611 And Number of steps is ==> 632000
# Episode * 317 * Avg Reward is ==> 0.7756081819534302 And Number of steps is ==> 634000
# Episode * 318 * Avg Reward is ==> 0.811565101146698 And Number of steps is ==> 636000
# Episode * 319 * Avg Reward is ==> 0.8122889399528503 And Number of steps is ==> 638000
# Episode * 320 * Avg Reward is ==> 0.8111357688903809 And Number of steps is ==> 640000
# Episode * 321 * Avg Reward is ==> 0.8110103607177734 And Number of steps is ==> 642000
# Episode * 322 * Avg Reward is ==> 0.8084656596183777 And Number of steps is ==> 644000
# Episode * 323 * Avg Reward is ==> 0.8248132467269897 And Number of steps is ==> 646000
# Episode * 324 * Avg Reward is ==> 0.8092353940010071 And Number of steps is ==> 648000
# Episode * 325 * Avg Reward is ==> 0.7810102701187134 And Number of steps is ==> 650000
# Episode * 326 * Avg Reward is ==> 0.7897526025772095 And Number of steps is ==> 652000
# Episode * 327 * Avg Reward is ==> 0.7770923376083374 And Number of steps is ==> 654000
# Episode * 328 * Avg Reward is ==> 0.7967317700386047 And Number of steps is ==> 656000
# Episode * 329 * Avg Reward is ==> 0.7838269472122192 And Number of steps is ==> 658000
# Episode * 330 * Avg Reward is ==> 0.7897223830223083 And Number of steps is ==> 660000
# Episode * 331 * Avg Reward is ==> 0.8061636090278625 And Number of steps is ==> 662000
# Accident!
# Accident!
# Accident!
# Episode * 332 * Avg Reward is ==> 0.6947277784347534 And Number of steps is ==> 664000
# Accident!
# Episode * 333 * Avg Reward is ==> 0.6983636617660522 And Number of steps is ==> 666000
# Episode * 334 * Avg Reward is ==> 0.7164989709854126 And Number of steps is ==> 668000
# Episode * 335 * Avg Reward is ==> 0.7405406832695007 And Number of steps is ==> 670000
# Episode * 336 * Avg Reward is ==> 0.7322202324867249 And Number of steps is ==> 672000
# Episode * 337 * Avg Reward is ==> 0.7600015997886658 And Number of steps is ==> 674000
# Episode * 338 * Avg Reward is ==> 0.7726936936378479 And Number of steps is ==> 676000
# Episode * 339 * Avg Reward is ==> 0.792778730392456 And Number of steps is ==> 678000
# Episode * 340 * Avg Reward is ==> 0.8053352236747742 And Number of steps is ==> 680000
# Episode * 341 * Avg Reward is ==> 0.8247345685958862 And Number of steps is ==> 682000
# Episode * 342 * Avg Reward is ==> 0.9603208303451538 And Number of steps is ==> 684000
# Episode * 343 * Avg Reward is ==> 0.9696574211120605 And Number of steps is ==> 686000
# Episode * 344 * Avg Reward is ==> 0.9691234827041626 And Number of steps is ==> 688000
# Episode * 345 * Avg Reward is ==> 0.9644659757614136 And Number of steps is ==> 690000
# Accident!
# Episode * 346 * Avg Reward is ==> 0.9167858958244324 And Number of steps is ==> 692000
# Episode * 347 * Avg Reward is ==> 0.920062243938446 And Number of steps is ==> 694000
# Episode * 348 * Avg Reward is ==> 0.9154364466667175 And Number of steps is ==> 696000
# Accident!
# Episode * 349 * Avg Reward is ==> 0.9086330533027649 And Number of steps is ==> 698000
# Episode * 350 * Avg Reward is ==> 0.9027968645095825 And Number of steps is ==> 700000
# Episode * 351 * Avg Reward is ==> 0.870254397392273 And Number of steps is ==> 702000
# Episode * 352 * Avg Reward is ==> 0.8689818382263184 And Number of steps is ==> 704000
# Episode * 353 * Avg Reward is ==> 0.876910388469696 And Number of steps is ==> 706000
# Episode * 354 * Avg Reward is ==> 0.8755618929862976 And Number of steps is ==> 708000
# Episode * 355 * Avg Reward is ==> 0.8750849962234497 And Number of steps is ==> 710000
# Episode * 356 * Avg Reward is ==> 0.9382875561714172 And Number of steps is ==> 712000
# Episode * 357 * Avg Reward is ==> 0.9323310852050781 And Number of steps is ==> 714000
# Episode * 358 * Avg Reward is ==> 0.9506728053092957 And Number of steps is ==> 716000
# Episode * 359 * Avg Reward is ==> 0.9754540324211121 And Number of steps is ==> 718000
# Episode * 360 * Avg Reward is ==> 0.9722162485122681 And Number of steps is ==> 720000
# Episode * 361 * Avg Reward is ==> 1.0074478387832642 And Number of steps is ==> 722000
# Accident!
# Episode * 362 * Avg Reward is ==> 0.9414584040641785 And Number of steps is ==> 724000
# Accident!
# Episode * 363 * Avg Reward is ==> 0.8442733883857727 And Number of steps is ==> 726000
# Accident!
# Episode * 364 * Avg Reward is ==> 0.7669498324394226 And Number of steps is ==> 728000
# Accident!
# Episode * 365 * Avg Reward is ==> 0.7893210649490356 And Number of steps is ==> 730000
# Accident!
# Episode * 366 * Avg Reward is ==> 0.6802922487258911 And Number of steps is ==> 732000
# Accident!
# Episode * 367 * Avg Reward is ==> 0.627463161945343 And Number of steps is ==> 734000
# Accident!
# Accident!
# Accident!
# Episode * 368 * Avg Reward is ==> 0.48252877593040466 And Number of steps is ==> 736000
# Accident!
# Accident!
# Episode * 369 * Avg Reward is ==> 0.37985238432884216 And Number of steps is ==> 738000
# Episode * 370 * Avg Reward is ==> 0.36803850531578064 And Number of steps is ==> 740000
# Episode * 371 * Avg Reward is ==> 0.3456025719642639 And Number of steps is ==> 742000
# Accident!
# Episode * 372 * Avg Reward is ==> 0.32997846603393555 And Number of steps is ==> 744000
# Episode * 373 * Avg Reward is ==> 0.4111599028110504 And Number of steps is ==> 746000
# Episode * 374 * Avg Reward is ==> 0.48253029584884644 And Number of steps is ==> 748000
# Accident!
# Episode * 375 * Avg Reward is ==> 0.40558186173439026 And Number of steps is ==> 750000
# Accident!
# Accident!
# Episode * 376 * Avg Reward is ==> 0.42378830909729004 And Number of steps is ==> 752000
# Accident!
# Accident!
# Episode * 377 * Avg Reward is ==> 0.3503797948360443 And Number of steps is ==> 754000
# Episode * 378 * Avg Reward is ==> 0.4656605124473572 And Number of steps is ==> 756000
# Accident!
# Episode * 379 * Avg Reward is ==> 0.4839077889919281 And Number of steps is ==> 758000
# Accident!
# Episode * 380 * Avg Reward is ==> 0.499305784702301 And Number of steps is ==> 760000
# Episode * 381 * Avg Reward is ==> 0.5185528993606567 And Number of steps is ==> 762000
# Accident!
# Episode * 382 * Avg Reward is ==> 0.6011906862258911 And Number of steps is ==> 764000
# Episode * 383 * Avg Reward is ==> 0.6177237033843994 And Number of steps is ==> 766000
# Episode * 384 * Avg Reward is ==> 0.6295275688171387 And Number of steps is ==> 768000
# Episode * 385 * Avg Reward is ==> 0.7009466290473938 And Number of steps is ==> 770000
# Episode * 386 * Avg Reward is ==> 0.8104144930839539 And Number of steps is ==> 772000
# Episode * 387 * Avg Reward is ==> 0.9384018182754517 And Number of steps is ==> 774000
# Episode * 388 * Avg Reward is ==> 0.9525507688522339 And Number of steps is ==> 776000
# Episode * 389 * Avg Reward is ==> 1.028928279876709 And Number of steps is ==> 778000
# Episode * 390 * Avg Reward is ==> 1.0271459817886353 And Number of steps is ==> 780000
# Episode * 391 * Avg Reward is ==> 1.036670446395874 And Number of steps is ==> 782000
# Episode * 392 * Avg Reward is ==> 1.0354773998260498 And Number of steps is ==> 784000
# Accident!
# Episode * 393 * Avg Reward is ==> 1.031779408454895 And Number of steps is ==> 786000
# Episode * 394 * Avg Reward is ==> 1.0264627933502197 And Number of steps is ==> 788000
# Episode * 395 * Avg Reward is ==> 1.023890733718872 And Number of steps is ==> 790000
# Episode * 396 * Avg Reward is ==> 0.9852421879768372 And Number of steps is ==> 792000
# Episode * 397 * Avg Reward is ==> 1.0104390382766724 And Number of steps is ==> 794000
# Accident!
# Episode * 398 * Avg Reward is ==> 1.0063146352767944 And Number of steps is ==> 796000
# Episode * 399 * Avg Reward is ==> 0.9890247583389282 And Number of steps is ==> 798000
# Episode * 400 * Avg Reward is ==> 0.9815253019332886 And Number of steps is ==> 800000
# Accident!
# Episode * 401 * Avg Reward is ==> 0.9100605249404907 And Number of steps is ==> 802000
# Episode * 402 * Avg Reward is ==> 0.8926429748535156 And Number of steps is ==> 804000
# Episode * 403 * Avg Reward is ==> 0.8873324394226074 And Number of steps is ==> 806000
# Episode * 404 * Avg Reward is ==> 0.8873978853225708 And Number of steps is ==> 808000
# Accident!
# Episode * 405 * Avg Reward is ==> 0.8179324269294739 And Number of steps is ==> 810000
# Accident!
# Episode * 406 * Avg Reward is ==> 0.7684551477432251 And Number of steps is ==> 812000
# Episode * 407 * Avg Reward is ==> 0.7329530715942383 And Number of steps is ==> 814000
# Accident!
# Accident!
# Episode * 408 * Avg Reward is ==> 0.7180824279785156 And Number of steps is ==> 816000
# Accident!
# Episode * 409 * Avg Reward is ==> 0.6597524881362915 And Number of steps is ==> 818000
# Accident!
# Episode * 410 * Avg Reward is ==> 0.6578474044799805 And Number of steps is ==> 820000
# Episode * 411 * Avg Reward is ==> 0.7064646482467651 And Number of steps is ==> 822000
# Accident!
# Episode * 412 * Avg Reward is ==> 0.6810600161552429 And Number of steps is ==> 824000
# Episode * 413 * Avg Reward is ==> 0.6663029789924622 And Number of steps is ==> 826000
# Accident!
# Accident!
# Episode * 414 * Avg Reward is ==> 0.653485894203186 And Number of steps is ==> 828000
# Episode * 415 * Avg Reward is ==> 0.6651569604873657 And Number of steps is ==> 830000
# Accident!
# Accident!
# Episode * 416 * Avg Reward is ==> 0.7025132179260254 And Number of steps is ==> 832000
# Episode * 417 * Avg Reward is ==> 0.6936016082763672 And Number of steps is ==> 834000
# Episode * 418 * Avg Reward is ==> 0.7191093564033508 And Number of steps is ==> 836000
# Episode * 419 * Avg Reward is ==> 0.7702711820602417 And Number of steps is ==> 838000
# Episode * 420 * Avg Reward is ==> 0.7865641117095947 And Number of steps is ==> 840000
# Episode * 421 * Avg Reward is ==> 0.7875291705131531 And Number of steps is ==> 842000
# Accident!
# Episode * 422 * Avg Reward is ==> 0.7577177882194519 And Number of steps is ==> 844000
# Episode * 423 * Avg Reward is ==> 0.7687621712684631 And Number of steps is ==> 846000
# Accident!
# Accident!
# Episode * 424 * Avg Reward is ==> 0.7995497584342957 And Number of steps is ==> 848000
# Episode * 425 * Avg Reward is ==> 0.8270757794380188 And Number of steps is ==> 850000
# Episode * 426 * Avg Reward is ==> 0.8374168276786804 And Number of steps is ==> 852000
# Episode * 427 * Avg Reward is ==> 0.8641344904899597 And Number of steps is ==> 854000
# Episode * 428 * Avg Reward is ==> 0.8602210879325867 And Number of steps is ==> 856000
# Episode * 429 * Avg Reward is ==> 0.8681599497795105 And Number of steps is ==> 858000
# Episode * 430 * Avg Reward is ==> 0.8593316078186035 And Number of steps is ==> 860000
# Episode * 431 * Avg Reward is ==> 0.8474024534225464 And Number of steps is ==> 862000
# ...
# Episode * 824 * Avg Reward is ==> 0.9319196939468384 And Number of steps is ==> 1648000
# Accident!
# Episode * 825 * Avg Reward is ==> 0.8631622195243835 And Number of steps is ==> 1650000
# Episode * 826 * Avg Reward is ==> 0.8467131853103638 And Number of steps is ==> 1652000
# Episode * 827 * Avg Reward is ==> 0.8794452548027039 And Number of steps is ==> 1654000
# Accident!
# Accident!
# Episode * 828 * Avg Reward is ==> 0.7912261486053467 And Number of steps is ==> 1656000
# Episode * 829 * Avg Reward is ==> 0.7845041751861572 And Number of steps is ==> 1658000
# Accident!
# Accident!
# Episode * 830 * Avg Reward is ==> 0.7273950576782227 And Number of steps is ==> 1660000
# Episode * 831 * Avg Reward is ==> 0.7540892362594604 And Number of steps is ==> 1662000
# Accident!
# Episode * 832 * Avg Reward is ==> 0.7163466215133667 And Number of steps is ==> 1664000
# Episode * 833 * Avg Reward is ==> 0.7730075120925903 And Number of steps is ==> 1666000
# Episode * 834 * Avg Reward is ==> 0.7579971551895142 And Number of steps is ==> 1668000
# Episode * 835 * Avg Reward is ==> 0.8284104466438293 And Number of steps is ==> 1670000
# Accident!
# Episode * 836 * Avg Reward is ==> 0.8434022068977356 And Number of steps is ==> 1672000
# Episode * 837 * Avg Reward is ==> 0.8170909881591797 And Number of steps is ==> 1674000
# Episode * 838 * Avg Reward is ==> 0.9004355669021606 And Number of steps is ==> 1676000
# Episode * 839 * Avg Reward is ==> 0.8832226991653442 And Number of steps is ==> 1678000
# Episode * 840 * Avg Reward is ==> 0.9122174382209778 And Number of steps is ==> 1680000
# Episode * 841 * Avg Reward is ==> 0.9089759588241577 And Number of steps is ==> 1682000
# Accident!
# Episode * 842 * Avg Reward is ==> 0.9643457531929016 And Number of steps is ==> 1684000
# Episode * 843 * Avg Reward is ==> 0.9664336442947388 And Number of steps is ==> 1686000
# Accident!
# Episode * 844 * Avg Reward is ==> 0.9607393145561218 And Number of steps is ==> 1688000
# Episode * 845 * Avg Reward is ==> 0.9332135319709778 And Number of steps is ==> 1690000
# Episode * 846 * Avg Reward is ==> 0.9413356781005859 And Number of steps is ==> 1692000
# Episode * 847 * Avg Reward is ==> 0.9486153721809387 And Number of steps is ==> 1694000
# Episode * 848 * Avg Reward is ==> 0.9294252395629883 And Number of steps is ==> 1696000
# Episode * 849 * Avg Reward is ==> 0.962149977684021 And Number of steps is ==> 1698000
# Episode * 850 * Avg Reward is ==> 0.9842921495437622 And Number of steps is ==> 1700000
# Episode * 851 * Avg Reward is ==> 0.9826003909111023 And Number of steps is ==> 1702000
# Accident!
# Episode * 852 * Avg Reward is ==> 0.8959676623344421 And Number of steps is ==> 1704000
# Episode * 853 * Avg Reward is ==> 0.8993798494338989 And Number of steps is ==> 1706000
# Episode * 854 * Avg Reward is ==> 0.889984130859375 And Number of steps is ==> 1708000
# Accident!
# Accident!
# Episode * 855 * Avg Reward is ==> 0.8863655924797058 And Number of steps is ==> 1710000
# Episode * 856 * Avg Reward is ==> 0.8732721209526062 And Number of steps is ==> 1712000
# Episode * 857 * Avg Reward is ==> 0.8510422706604004 And Number of steps is ==> 1714000
# Accident!
# Accident!
# Episode * 858 * Avg Reward is ==> 0.8467720150947571 And Number of steps is ==> 1716000
# Episode * 859 * Avg Reward is ==> 0.8102002143859863 And Number of steps is ==> 1718000
# Episode * 860 * Avg Reward is ==> 0.8104678392410278 And Number of steps is ==> 1720000
# Episode * 861 * Avg Reward is ==> 0.7820080518722534 And Number of steps is ==> 1722000
# Episode * 862 * Avg Reward is ==> 0.8503295183181763 And Number of steps is ==> 1724000
# Episode * 863 * Avg Reward is ==> 0.8458386659622192 And Number of steps is ==> 1726000
# Accident!
# Episode * 864 * Avg Reward is ==> 0.7675990462303162 And Number of steps is ==> 1728000
# Accident!
# Episode * 865 * Avg Reward is ==> 0.7947845458984375 And Number of steps is ==> 1730000
# Episode * 866 * Avg Reward is ==> 0.787265419960022 And Number of steps is ==> 1732000
# Episode * 867 * Avg Reward is ==> 0.7973099946975708 And Number of steps is ==> 1734000
# Episode * 868 * Avg Reward is ==> 0.8106406331062317 And Number of steps is ==> 1736000
# Accident!
# Episode * 869 * Avg Reward is ==> 0.8138622045516968 And Number of steps is ==> 1738000
# Episode * 870 * Avg Reward is ==> 0.795252799987793 And Number of steps is ==> 1740000
# Episode * 871 * Avg Reward is ==> 0.7965447902679443 And Number of steps is ==> 1742000
# Episode * 872 * Avg Reward is ==> 0.8225988149642944 And Number of steps is ==> 1744000
# Episode * 873 * Avg Reward is ==> 0.8094608187675476 And Number of steps is ==> 1746000
# Episode * 874 * Avg Reward is ==> 0.9043666124343872 And Number of steps is ==> 1748000
# Episode * 875 * Avg Reward is ==> 0.8880961537361145 And Number of steps is ==> 1750000
# Episode * 876 * Avg Reward is ==> 0.8917608261108398 And Number of steps is ==> 1752000
# Episode * 877 * Avg Reward is ==> 0.8798809051513672 And Number of steps is ==> 1754000
# Episode * 878 * Avg Reward is ==> 0.893036961555481 And Number of steps is ==> 1756000
# Episode * 879 * Avg Reward is ==> 0.9096638560295105 And Number of steps is ==> 1758000
# Episode * 880 * Avg Reward is ==> 0.8949407339096069 And Number of steps is ==> 1760000
# Episode * 881 * Avg Reward is ==> 0.8883819580078125 And Number of steps is ==> 1762000
# Episode * 882 * Avg Reward is ==> 0.8709602355957031 And Number of steps is ==> 1764000
# Episode * 883 * Avg Reward is ==> 0.8668417930603027 And Number of steps is ==> 1766000
# Episode * 884 * Avg Reward is ==> 0.853010356426239 And Number of steps is ==> 1768000
# Episode * 885 * Avg Reward is ==> 0.8659749031066895 And Number of steps is ==> 1770000
# Episode * 886 * Avg Reward is ==> 0.8749727010726929 And Number of steps is ==> 1772000
# Episode * 887 * Avg Reward is ==> 0.8768388032913208 And Number of steps is ==> 1774000
# Episode * 888 * Avg Reward is ==> 0.8526714444160461 And Number of steps is ==> 1776000
# Episode * 889 * Avg Reward is ==> 0.8533101081848145 And Number of steps is ==> 1778000
# Episode * 890 * Avg Reward is ==> 0.8642356991767883 And Number of steps is ==> 1780000
# Episode * 891 * Avg Reward is ==> 0.8879631757736206 And Number of steps is ==> 1782000
# Episode * 892 * Avg Reward is ==> 0.8816450834274292 And Number of steps is ==> 1784000
# Episode * 893 * Avg Reward is ==> 0.9112192988395691 And Number of steps is ==> 1786000
# Episode * 894 * Avg Reward is ==> 0.9066322445869446 And Number of steps is ==> 1788000
# Episode * 895 * Avg Reward is ==> 0.8799607157707214 And Number of steps is ==> 1790000
# Episode * 896 * Avg Reward is ==> 0.8579509854316711 And Number of steps is ==> 1792000
# Episode * 897 * Avg Reward is ==> 0.8699216842651367 And Number of steps is ==> 1794000
# Accident!
# Episode * 898 * Avg Reward is ==> 0.7994850873947144 And Number of steps is ==> 1796000
# Episode * 899 * Avg Reward is ==> 0.778927743434906 And Number of steps is ==> 1798000
# Accident!
# Episode * 900 * Avg Reward is ==> 0.7499736547470093 And Number of steps is ==> 1800000
# Episode * 901 * Avg Reward is ==> 0.7659744024276733 And Number of steps is ==> 1802000
# Episode * 902 * Avg Reward is ==> 0.7830329537391663 And Number of steps is ==> 1804000
# Accident!
# Episode * 903 * Avg Reward is ==> 0.6894603967666626 And Number of steps is ==> 1806000
# Accident!
# Episode * 904 * Avg Reward is ==> 0.6833232641220093 And Number of steps is ==> 1808000
# Episode * 905 * Avg Reward is ==> 0.7142156362533569 And Number of steps is ==> 1810000
# Episode * 906 * Avg Reward is ==> 0.7482304573059082 And Number of steps is ==> 1812000
# Accident!
# Accident!
# Episode * 907 * Avg Reward is ==> 0.7695385217666626 And Number of steps is ==> 1814000
# Accident!
# Episode * 908 * Avg Reward is ==> 0.8609256744384766 And Number of steps is ==> 1816000
# Episode * 909 * Avg Reward is ==> 0.8799964189529419 And Number of steps is ==> 1818000
# Episode * 910 * Avg Reward is ==> 0.8975850939750671 And Number of steps is ==> 1820000
# Episode * 911 * Avg Reward is ==> 0.8810341954231262 And Number of steps is ==> 1822000
# Episode * 912 * Avg Reward is ==> 0.8826704025268555 And Number of steps is ==> 1824000
# Accident!
# Episode * 913 * Avg Reward is ==> 0.9800211191177368 And Number of steps is ==> 1826000
# Episode * 914 * Avg Reward is ==> 0.9925624132156372 And Number of steps is ==> 1828000
# Episode * 915 * Avg Reward is ==> 0.9946492910385132 And Number of steps is ==> 1830000
# Episode * 916 * Avg Reward is ==> 0.9790735244750977 And Number of steps is ==> 1832000
# Episode * 917 * Avg Reward is ==> 0.9522413015365601 And Number of steps is ==> 1834000
# Episode * 918 * Avg Reward is ==> 0.9517993927001953 And Number of steps is ==> 1836000
# Accident!
# Episode * 919 * Avg Reward is ==> 0.8839110136032104 And Number of steps is ==> 1838000
# Accident!
# Episode * 920 * Avg Reward is ==> 0.8496842384338379 And Number of steps is ==> 1840000
# Episode * 921 * Avg Reward is ==> 0.8416902422904968 And Number of steps is ==> 1842000
# Accident!
# Episode * 922 * Avg Reward is ==> 0.831531822681427 And Number of steps is ==> 1844000
# Episode * 923 * Avg Reward is ==> 0.833382785320282 And Number of steps is ==> 1846000
# Episode * 924 * Avg Reward is ==> 0.8325473070144653 And Number of steps is ==> 1848000
# Accident!
# Episode * 925 * Avg Reward is ==> 0.7448925375938416 And Number of steps is ==> 1850000
# Accident!
# Episode * 926 * Avg Reward is ==> 0.6759610176086426 And Number of steps is ==> 1852000
# Accident!
# Episode * 927 * Avg Reward is ==> 0.6082904934883118 And Number of steps is ==> 1854000
# Accident!
# Episode * 928 * Avg Reward is ==> 0.5285603404045105 And Number of steps is ==> 1856000
# Episode * 929 * Avg Reward is ==> 0.5908910036087036 And Number of steps is ==> 1858000
# Episode * 930 * Avg Reward is ==> 0.6673686504364014 And Number of steps is ==> 1860000
# Episode * 931 * Avg Reward is ==> 0.7033884525299072 And Number of steps is ==> 1862000
# Episode * 932 * Avg Reward is ==> 0.7127566337585449 And Number of steps is ==> 1864000
# Episode * 933 * Avg Reward is ==> 0.6972637176513672 And Number of steps is ==> 1866000
# Episode * 934 * Avg Reward is ==> 0.701126754283905 And Number of steps is ==> 1868000
# Episode * 935 * Avg Reward is ==> 0.7861484885215759 And Number of steps is ==> 1870000
# Episode * 936 * Avg Reward is ==> 0.8334956169128418 And Number of steps is ==> 1872000
# Episode * 937 * Avg Reward is ==> 0.9046456217765808 And Number of steps is ==> 1874000
# Episode * 938 * Avg Reward is ==> 0.9831401109695435 And Number of steps is ==> 1876000
# Episode * 939 * Avg Reward is ==> 0.9819239377975464 And Number of steps is ==> 1878000
# Episode * 940 * Avg Reward is ==> 0.9642395973205566 And Number of steps is ==> 1880000
# Episode * 941 * Avg Reward is ==> 0.928980827331543 And Number of steps is ==> 1882000
# Episode * 942 * Avg Reward is ==> 0.9221105575561523 And Number of steps is ==> 1884000
# Episode * 943 * Avg Reward is ==> 0.9356991648674011 And Number of steps is ==> 1886000
# Episode * 944 * Avg Reward is ==> 0.95329350233078 And Number of steps is ==> 1888000
# Accident!
# Episode * 945 * Avg Reward is ==> 0.9451063275337219 And Number of steps is ==> 1890000
# Accident!
# Episode * 946 * Avg Reward is ==> 0.9618385434150696 And Number of steps is ==> 1892000
# Episode * 947 * Avg Reward is ==> 0.9492042660713196 And Number of steps is ==> 1894000
# Episode * 948 * Avg Reward is ==> 0.9508023262023926 And Number of steps is ==> 1896000
# Accident!
# Accident!
# Episode * 949 * Avg Reward is ==> 0.9511040449142456 And Number of steps is ==> 1898000
# Episode * 950 * Avg Reward is ==> 0.9408611059188843 And Number of steps is ==> 1900000
# Episode * 951 * Avg Reward is ==> 0.9477993249893188 And Number of steps is ==> 1902000
# Episode * 952 * Avg Reward is ==> 0.9500323534011841 And Number of steps is ==> 1904000
# Episode * 953 * Avg Reward is ==> 0.9586701393127441 And Number of steps is ==> 1906000
# Episode * 954 * Avg Reward is ==> 0.9502814412117004 And Number of steps is ==> 1908000
# Episode * 955 * Avg Reward is ==> 0.9564231634140015 And Number of steps is ==> 1910000
# Episode * 956 * Avg Reward is ==> 0.959765613079071 And Number of steps is ==> 1912000
# Episode * 957 * Avg Reward is ==> 0.9693115949630737 And Number of steps is ==> 1914000
# Episode * 958 * Avg Reward is ==> 0.9404847025871277 And Number of steps is ==> 1916000
# Episode * 959 * Avg Reward is ==> 0.9430688619613647 And Number of steps is ==> 1918000
# Episode * 960 * Avg Reward is ==> 0.9678075909614563 And Number of steps is ==> 1920000
# Episode * 961 * Avg Reward is ==> 0.9924091100692749 And Number of steps is ==> 1922000
# Accident!
# Accident!
# Episode * 962 * Avg Reward is ==> 0.9309719204902649 And Number of steps is ==> 1924000
# Episode * 963 * Avg Reward is ==> 0.9100303649902344 And Number of steps is ==> 1926000
# Accident!
# Episode * 964 * Avg Reward is ==> 0.8935168385505676 And Number of steps is ==> 1928000
# Episode * 965 * Avg Reward is ==> 0.9026354551315308 And Number of steps is ==> 1930000
# Episode * 966 * Avg Reward is ==> 0.8984768986701965 And Number of steps is ==> 1932000
# Episode * 967 * Avg Reward is ==> 0.8998736143112183 And Number of steps is ==> 1934000
# Episode * 968 * Avg Reward is ==> 0.9186371564865112 And Number of steps is ==> 1936000
# Episode * 969 * Avg Reward is ==> 0.9230455160140991 And Number of steps is ==> 1938000
# Episode * 970 * Avg Reward is ==> 0.8939234018325806 And Number of steps is ==> 1940000
# Episode * 971 * Avg Reward is ==> 0.8611153364181519 And Number of steps is ==> 1942000
# Episode * 972 * Avg Reward is ==> 0.922612190246582 And Number of steps is ==> 1944000
# Episode * 973 * Avg Reward is ==> 0.933520495891571 And Number of steps is ==> 1946000
# Episode * 974 * Avg Reward is ==> 0.9296307563781738 And Number of steps is ==> 1948000
# Episode * 975 * Avg Reward is ==> 0.9052212834358215 And Number of steps is ==> 1950000
# Accident!
# Episode * 976 * Avg Reward is ==> 0.9015040397644043 And Number of steps is ==> 1952000
# Accident!
# Episode * 977 * Avg Reward is ==> 0.9288820028305054 And Number of steps is ==> 1954000
# Episode * 978 * Avg Reward is ==> 0.9216150045394897 And Number of steps is ==> 1956000
# Episode * 979 * Avg Reward is ==> 0.9212929010391235 And Number of steps is ==> 1958000
# Episode * 980 * Avg Reward is ==> 0.9419934153556824 And Number of steps is ==> 1960000
# Episode * 981 * Avg Reward is ==> 0.9567916989326477 And Number of steps is ==> 1962000
# Episode * 982 * Avg Reward is ==> 0.9551190137863159 And Number of steps is ==> 1964000
# Episode * 983 * Avg Reward is ==> 0.9503433108329773 And Number of steps is ==> 1966000
# Episode * 984 * Avg Reward is ==> 0.9612299799919128 And Number of steps is ==> 1968000
# Episode * 985 * Avg Reward is ==> 0.9780298471450806 And Number of steps is ==> 1970000
# Accident!
# Episode * 986 * Avg Reward is ==> 0.9647345542907715 And Number of steps is ==> 1972000
# Episode * 987 * Avg Reward is ==> 0.9666960835456848 And Number of steps is ==> 1974000
# Episode * 988 * Avg Reward is ==> 0.9823300242424011 And Number of steps is ==> 1976000
# Episode * 989 * Avg Reward is ==> 0.9871856570243835 And Number of steps is ==> 1978000
# Episode * 990 * Avg Reward is ==> 0.9957464337348938 And Number of steps is ==> 1980000
# Episode * 991 * Avg Reward is ==> 1.0014612674713135 And Number of steps is ==> 1982000
# Episode * 992 * Avg Reward is ==> 1.0207369327545166 And Number of steps is ==> 1984000
# Episode * 993 * Avg Reward is ==> 1.0154719352722168 And Number of steps is ==> 1986000
# Accident!
# Episode * 994 * Avg Reward is ==> 1.0301793813705444 And Number of steps is ==> 1988000
# Episode * 995 * Avg Reward is ==> 1.0416334867477417 And Number of steps is ==> 1990000
# Episode * 996 * Avg Reward is ==> 1.0566258430480957 And Number of steps is ==> 1992000
# Episode * 997 * Avg Reward is ==> 1.0370488166809082 And Number of steps is ==> 1994000
# Episode * 998 * Avg Reward is ==> 1.0472577810287476 And Number of steps is ==> 1996000
# Episode * 999 * Avg Reward is ==> 1.0440971851348877 And Number of steps is ==> 1998000
# Complete
# Running time: 5720.109375

# %%
#Stock an evaluation sample
states, actions, rewards = algo.evaluate(1000)
ep_action=states[:,0]
ep_speed_car=states[:,1]
ep_pos_car=states[:,2]
ep_speed_ped=states[:,3]
ep_pos_ped=states[:,4]
ep_time=states[:,9]
ep_reward=rewards
t=0

# %%
#Show general information about the final algorithm performance: average speed, CO2 emission, end-time

LDV = pd.read_csv('LDV.csv', sep=';',names=["sp","acc","step","em_name","em_val"])
LDV.pop('step')
m = LDV == 0.0
LDV['acc'] = LDV['acc'].replace(1.27676e-15,0.0)
LDV['acc'] = LDV['acc'].astype(float)
LDV_array = np.array(LDV.values)

def info_co2(states,LDV):
    """
        Evaluate the CO2 emission per episode 
        :param states: state list
        :param LDV: CO2 emission chart
    """
    t=0
    total_emission=[]
    while t+1<len(ep_time):
        t_init=t
        emission_val=[]
        while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
            acc=math.trunc(((states[t,0].item()//0.2)*0.2)*10.)/10.
            speed=math.trunc(((states[t,1].item()//0.5)*0.5)*10.)/10.
            cond=(LDV.sp==speed)&(LDV.acc==acc)&(LDV.em_name=="CO2")
            res=LDV[cond]['em_val'].item() *0.3
            emission_val.append(res)
            t+=1
        total_emission.append(torch.sum(torch.tensor(emission_val),dim=0))
        t+=1
    torch_total_emission=torch.tensor(total_emission)
    total_emission_mean=torch.mean(torch_total_emission)
    total_emission_std=torch.std(torch_total_emission)
    print("\nThe average CO2 emission is {:.2f}mg and its standard deviation is {:.2f} mg".format(total_emission_mean.item(),total_emission_std.item()))
    
def get_average(states,LDV):
    ep_time=states[:,9]
    mean_speed=torch.mean(states[:,1])
    sqrt_speed=torch.std(states[:,1])
    print("The average car speed is {:.2f} m/s and its standard deviation is {:.2f} m/s".format(mean_speed.item(),sqrt_speed.item()))
    mean_acc=torch.mean(states[:,0])
    sqrt_acc=torch.std(states[:,0])
    print("\nThe average car acceleration is {:.2f} m/s2 and its standard deviation is {:.2f} m/s2".format(mean_acc.item(),sqrt_acc.item()))
    mean_speed_p=torch.mean(states[:,3])
    sqrt_speed_p=torch.std(states[:,3])
    print("\nThe average pedestrian speed is {:.2f} m/s2 and its standard deviation is {:.2f} m/s2".format(mean_speed_p.item(),sqrt_speed_p.item()))    
    mean_reward=torch.mean(ep_reward)
    std_reward=torch.std(ep_reward)
    print("\nThe average reward is {:.2f} and its standard deviation is {:.2f}".format(mean_reward.item(),std_reward.item()))
    info_co2(states,LDV) #CO2 info
    temps=[]
    t=0
    while t+1<len(ep_time):
        temps_i=np.array([0.,0.]) #respectively: end-time car/pedestrian
        t_init=t
        while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
            if(states[t,2]<0.0 and states[t+1,2]>=0.0):
                temps_i[0]=(t-t_init)*0.3
            if(states[t,4]<5.0 and states[t+1,4]>=5.0):
                temps_i[1]=(t-t_init)*0.3
            t+=1
        if(temps_i[1]==0.0):
            temps_i[1]=(t-t_init)*0.3
        temps.append([(t-t_init)*0.3,temps_i[0],temps_i[1]])
        t+=1
    total_temps=torch.tensor([temps]).reshape((-1,3))
    total_temps_mean=torch.mean(total_temps,dim=0)
    print("\n Average End-times:")
    print("Total: {:.2f} s".format(total_temps_mean[0].item()))
    print("Car: {:.2f} s".format(total_temps_mean[1].item()))
    print("Pedestrian: {:.2f} s".format(total_temps_mean[2].item()))
get_average(states,LDV)
# Out:
# The average car speed is 6.71 m/s and its standard deviation is 3.40 m/s
#
# The average car acceleration is -0.01 m/s2 and its standard deviation is 1.56 m/s2
#
# The average pedestrian speed is 0.99 m/s2 and its standard deviation is 0.37 m/s2
#
# The average reward is 0.99 and its standard deviation is 2.48
#
# The average CO2 emission is 21246.33mg and its standard deviation is 10254.12 mg
#
#  Average End-times:
# Total: 10.06 s
# Car: 5.00 s
# Pedestrian: 6.59 s

# %%
#Positions des agents
t=0
plt.title("Vehicle and Pedestrian Positions versus time")
plt.xlabel("time (s)")
plt.ylabel("position (m)")
while t+1<len(ep_time):
    t_init=t
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        t+=1
    plt.plot(ep_time[t_init:t],ep_pos_car[t_init:t])
    plt.plot(ep_time[t_init:t],ep_pos_ped[t_init:t])
    plt.axhline(y=5, color='r', linestyle='-.')
    plt.axhline(y=0, color='r', linestyle='-.')
    t+=1
_=plt.axhline(y=5, color='r', linestyle='-.')
_=plt.axhline(y=0, color='r', linestyle='-.')

# %%
#Accélération, Reward, Vitesse de la voiture
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(18, 4))

t=0
ax1.set_title("Car Acceleration versus time per episode")
ax1.set_xlabel("time (s)")
ax1.set_ylabel("acceleration (m/s2)")

ax2.set_title("Reward versus time per episode")
ax2.set_xlabel("time (s)")
ax2.set_ylabel("reward")

ax3.set_title("Car Speed versus time per episode")
ax3.set_xlabel("time (s)")
ax3.set_ylabel("speed (m/s)")

ax4.set_title('Pedestrian Speed')
ax4.set_xlabel("Position (m)")
ax4.set_ylabel("Speed (m/s)")
while t+1<len(ep_time):
    t_init=t
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        t+=1
    ax1.plot(ep_time[t_init:t],ep_action[t_init:t])
    ax2.plot(ep_time[t_init:t],ep_reward[t_init:t])
    ax3.plot(ep_time[t_init:t],ep_speed_car[t_init:t])
    ax4.plot(states[t_init:t,4],states[t_init:t,3])
    t+=1

# %%
t=0
cross_speed=[]
wait_speed=[]
cross_acc=[]
wait_acc=[]
size_wait=17
size_cross=37

while t+1<len(ep_time):
    t_init=t
    choice=False
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        choice=choice+(ep_speed_car[t]<2.0)
        t+=1
    if(choice):
        cross_speed.append(np.array(ep_speed_car[t_init:t_init+size_cross]))
        cross_acc.append(np.array(states[t_init:t_init+size_cross,0]))
    else:
        wait_speed.append(np.array(ep_speed_car[t_init:t_init+size_wait]))
        wait_acc.append(np.array(states[t_init:t_init+size_wait,0]))
    t+=1
cross_speed=np.array(cross_speed)
wait_speed=np.array(wait_speed)
cross_acc=np.array(cross_acc)
wait_acc=np.array(wait_acc)

# %%
x1=[0.3*i for i in range(size_cross)]
mean_speed=np.mean(cross_speed,axis=0)
std_speed=np.std(cross_speed,axis=0)
mean_acc=np.mean(cross_acc,axis=0)
std_acc=np.std(cross_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')
fig.savefig("PDF_results/car_cross_ppo11.pdf")

# %%
x1=[0.3*i for i in range(size_wait)]
mean_speed=np.mean(wait_speed,axis=0)
std_speed=np.std(wait_speed,axis=0)
mean_acc=np.mean(wait_acc,axis=0)
std_acc=np.std(wait_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')
fig.savefig("PDF_results/car_wait_ppo11.pdf")

# %%
#Showing Vehicle Acceleration Diagram, Vehicle Speed Diagram, Vehicle and Pedestrian Position Diagram
#All three over time in an episode
#t=0
if (t+1>=len(ep_time)):
    t=0
t_init=t
while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
    t+=1
fig, (ax1, ax2, ax3) = plt.subplots(1, 3,figsize=(20, 3))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-1.1,1.1)
ax1.plot(ep_time[t_init:t+1],actions[t_init:t+1,0],color='r')

ax2.set_title('Car and Pedestrian Position')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Position (m)")
ax2.plot(ep_time[t_init:t],ep_pos_car[t_init:t],label='car')
ax2.plot(ep_time[t_init:t+1],ep_pos_ped[t_init:t+1],label='pedestrian')
ax2.axhline(y=5, color='r', linestyle='-.')
ax2.axhline(y=0, color='r', linestyle='-.')
ax2.legend()

ax3.set_title('Car Speed')
ax3.set_xlabel("Time (s)")
ax3.set_ylabel("Speed (m/s)")
ax3.plot(ep_time[t_init:t+1],ep_speed_car[t_init:t+1],color='r')
t+=1

# %%
plt.title('Pedestrian Speed')
plt.xlabel("Position (m)")
plt.ylabel("Speed (m/s)")
plt.plot(states[t_init:t-10,4],states[t_init:t-10,3], color='olivedrab')
#plt.savefig("PDF_results/ped_speed.pdf")
