# %%
#1) Import libraries
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import namedtuple, deque
import Environments
from collections import OrderedDict
from torch.distributions import MultivariateNormal
import pandas as pd

# I use the work of Eric Yu to help me build this algorithm. Link: https://github.com/ericyangyu/PPO-for-Beginners

# %%
#2) Set up Neural Network functions and classes

class Model_PPO(nn.Module):
    """
        Class: actor NN
        :param np_inputs: size input of the NN (size state)
        :param nb_outputs: size output of the NN (size action)
    """  
    def __init__(self, np_inputs, nb_outputs):
        super(Model_PPO, self).__init__()   
        self.layer1 = nn.Linear(np_inputs, 64)
        self.layer2 = nn.Linear(64, 64)
        self.layer3 = nn.Linear(64, nb_outputs)
        torch.nn.init.uniform_(self.layer3.weight,0.003, 0.006)

    def forward(self, input1):
        """
        Forward NN : compute the NN with respect the current state
        :param input1: state
        :return: output of the NN, action
        """ 
        if isinstance(input1, np.ndarray):
            input1 = torch.tensor(input1, dtype=torch.float)
        activation1 = F.relu(self.layer1(input1))
        activation2 = F.relu(self.layer2(activation1))
        output = self.layer3(activation2)
        return output

# %%
#3) Rollout on the environment:

class Env_rollout:
    """ 
        Class : iterate on the environment
        :param env: our environment
        :param max_steps: max steps per episode
    """
    def __init__(self, env, max_steps):
        self.env = env
        self.max_steps = max_steps
        self.prev_state = env.reset()
        self.batch_obs=[]
        self.batch_acts=[]
        self.batch_log_probs=[]
        self.batch_rews = []
    
    def reset(self):
        """
        Reset: reinitilization (lists et environment).
        """
        self.prev_state = env.reset()
        self.batch_obs=[]
        self.batch_acts=[]
        self.batch_log_probs=[]
        self.batch_rews = []
    
    def iterations(self,actor_net, nbr_episodes):
        """
        Iterate on the environment.
        :param actor_net: current policy (actor NN)
        :param nbr_episodes: episode number
        :return: Tensors; state batch, action batch
        """
        for ep in range(nbr_episodes):
            ep_rews = []
            prev_state = self.env.reset()
            for step_ep in range(self.max_steps): 
                with torch.no_grad():
                    action = torch.squeeze(actor_net(torch.unsqueeze(torch.tensor(prev_state), dim=0).float()))
                    if(action.dim()==0):
                        action=torch.unsqueeze(action,dim=0)
                    action_all=np.array([])
                    action_all=np.append(action_all,np.clip(action[0].detach().numpy(), -1.0, 1.0))
                    #action_all=np.append(action_all,np.argmax(action[1:4].detach().numpy()))
                    state, reward, done, _ = self.env.step(action_all)
                    self.batch_obs.append(prev_state)
                    self.batch_acts.append(action_all)
                    ep_rews.append(reward)
                    prev_state = state
                if done:
                    break
            self.batch_rews.append(ep_rews)
        return torch.tensor(self.batch_obs, dtype=torch.float), torch.tensor(self.batch_acts, dtype=torch.float)
    
    def iterations_rand(self,actor_net, cov_mat, batch_size):
        """
        Iterate on the environment.
        :param actor_net: current policy (actor NN)
        :param cov_mat: covariance matrix used for exploration
        :param batch_size: batch size
        :return: Tensors; state batch, action batch, log_proba batch
        """
        t = 0
        while t<batch_size:
            ep_rews = []
            prev_state = self.env.reset()
            for step_ep in range(self.max_steps): 
                t += 1
                with torch.no_grad():
                    parameters_based = torch.squeeze(actor_net(torch.unsqueeze(torch.tensor(prev_state), dim=0).float()))
                    if(parameters_based.dim()==0):
                        parameters_based=torch.unsqueeze(parameters_based,dim=0)
                    distribution_p = MultivariateNormal(parameters_based, cov_mat)
                    action = distribution_p.sample()
                    log_proba = distribution_p.log_prob(action)
                    action_all=np.array([])
                    action_all=np.append(action_all,np.clip(action[0].detach().numpy(), -1.0, 1.0))
                    state, reward, done, _ = self.env.step(action_all)
                    self.batch_obs.append(prev_state)
                    self.batch_acts.append(action.detach().numpy())
                    self.batch_log_probs.append(log_proba)
                    ep_rews.append(reward)
                    prev_state = state
                if done:
                    break
            self.batch_rews.append(ep_rews)
        return torch.tensor(self.batch_obs, dtype=torch.float), torch.tensor(self.batch_acts, dtype=torch.float), torch.tensor(self.batch_log_probs, dtype=torch.float)

    def immediate_rewards(self):
        """
        Immediate rewards
        :return: Tensor; batch reward
        """
        batch_rewards = []
        for ep_rews in self.batch_rews:
            for rew in reversed(ep_rews):
                batch_rewards.insert(0,rew)
        return torch.tensor(batch_rewards, dtype=torch.float)
    
    def futur_rewards(self):
        """
        Expected futures rewards
        :return: Tensor; batch reward-to-go
        """
        batch_rtgs = []
        for ep_rews in reversed(self.batch_rews):
            episodic_reward=0.0
            for rew in reversed(ep_rews):
                episodic_reward= rew + 0.99*episodic_reward
                batch_rtgs.insert(0,episodic_reward)
        return torch.tensor(batch_rtgs, dtype=torch.float)

# %%
#4) Algorithm DDPG:
class Algo_PPO():
    """ 
    PPO algorithm : training and testing
    :param policy_class: policy (actor model)
    :param env: environment
    :param hyperparameters: other hyperparameters
    """
    def __init__(self, policy_class, env, **hyperparameters):
        
        self._init_hyperparameters(hyperparameters)
        self.actor_net = policy_class(self.num_states, self.num_actions)
        self.critic_net = policy_class(self.num_states, 1)
        self.optimizer_critic = optim.Adam(self.critic_net.parameters(), self.critic_lr)
        self.optimizer_actor = optim.Adam(self.actor_net.parameters(), self.actor_lr)
        self.cov_var = torch.full(size=(self.num_actions,), fill_value=0.25)
        self.cov_mat = torch.diag(self.cov_var)
        self.rollout = Env_rollout(env, self.max_steps)
        self.ep_reward_list=[]
    
    def evaluate(self, nbr_episodes):
        """
        Testing
        :param nbr_episodes: episode number 
        :return: state batch, action batch, and reward batch
        """
        self.rollout.reset()
        state_batch, action_batch = self.rollout.iterations(self.actor_net, nbr_episodes)
        rew_batch = self.rollout.immediate_rewards()
        return state_batch, action_batch, rew_batch
        
    def train(self, nb_loop):
        """ 
        Training
        :param nb_loop: number of batch iterations
        """
        for ep in range(nb_loop):
            state_batch,action_batch,log_prob_batch = self.rollout.iterations_rand(self.actor_net,self.cov_mat,self.batch_size)
            batch_rtgs = self.rollout.futur_rewards()
            #batch_rews = self.rollout.immediate_rewards()
            self.rollout.reset()
            for i in range(10):
                V_batch = torch.squeeze(self.critic_net(state_batch))
                advantage_batch = batch_rtgs - V_batch
                advantage_batch = (advantage_batch - advantage_batch.mean()) / (advantage_batch.std() + 1e-10)
                
                parameters_batch = torch.squeeze(self.actor_net(state_batch).unsqueeze(-1))
                if(parameters_batch.dim()==1):
                        parameters_batch=torch.unsqueeze(parameters_batch,dim=1)
                distribution_p = MultivariateNormal(parameters_batch, self.cov_mat)
                log_prob_current_batch = distribution_p.log_prob(action_batch)
                ratio_batch = torch.exp(log_prob_current_batch - log_prob_batch)
                ratio_loss = torch.mul(ratio_batch,advantage_batch)
                clip_loss = torch.mul(torch.clamp(ratio_loss, 0.8, 1.2),advantage_batch)
                actor_loss = (-torch.min(ratio_loss, clip_loss)).mean()

                criterion=nn.MSELoss(reduction='mean')
                critic_loss = criterion(V_batch.float(), batch_rtgs.float())
                self.optimizer_actor.zero_grad()
                actor_loss.backward(retain_graph=True)
                self.optimizer_actor.step()
                self.optimizer_critic.zero_grad()
                critic_loss.backward()
                self.optimizer_critic.step()
                
            state_batch, action_batch = self.rollout.iterations(self.actor_net, 30)
            batch_rews = self.rollout.immediate_rewards()
            self.ep_reward_list.append(batch_rews.mean().numpy())
            avg_reward = np.mean(self.ep_reward_list[-10:])
            self.rollout.reset()
    
            print("Episode * {} * Avg Reward is ==> {} And Number of steps is ==> {}".format(ep, avg_reward,ep*self.batch_size ))
            self.total_loop= self.total_loop +1
        path='load_model/parameters/ppo-{num_algo:02d}-{name}-{epoch:03d}000.npy'
        with open(path.format(num_algo=self.num_algo,epoch=int(self.total_loop/1000),name="reward"), 'wb') as f:
            np.save(f, np.array(self.ep_reward_list))
        print("Complete")
        
    def _init_hyperparameters(self, hyperparameters):
        """
        Initialize hyperparameters. 
        :param hyperparameters: hyperparameter list
        """
        self.num_algo = 1
        self.max_steps = 90
        self.total_loop = 0
        self.batch_size = 2000
        self.gamma = 0.99
        self.critic_lr = 3e-4
        self.actor_lr = 3e-4
        for param, val in hyperparameters.items():
            exec('self.' + param + ' = ' + str(val))
            
    def loading(self, num_algo, total_loop):
        """
        Loading NN weights 
        :param num_algo: algorithm number
        :param total_loop: number of total batch iterations
        """
        self.num_algo = num_algo
        self.total_loop = total_loop
        checkpoint_path1 = "load_model/weights/torch-ppo-{num_algo:02d}-actor-{epoch:03d}0.pth"
        self.actor_net.load_state_dict(torch.load(checkpoint_path1.format(epoch=int(self.total_loop/10), num_algo=self.num_algo)))
        checkpoint_path2 = "load_model/weights/torch-ppo-{num_algo:02d}-critic-{epoch:03d}0.pth"
        self.critic_net.load_state_dict(torch.load(checkpoint_path2.format(epoch=int(self.total_loop/10), num_algo=self.num_algo)))
    
    def saving(self):
        """
        Saving NN weights 
        """
        checkpoint_path = "load_model/weights/torch-ppo-{num_algo:02d}-actor-{epoch:03d}0.pth"
        torch.save(self.actor_net.state_dict(),checkpoint_path.format(epoch=int(self.total_loop/10), num_algo=self.num_algo))
        checkpoint_path = "load_model/weights/torch-ppo-{num_algo:02d}-critic-{epoch:03d}0.pth"
        torch.save(self.critic_net.state_dict(),checkpoint_path.format(epoch=int(self.total_loop/10), num_algo=self.num_algo))

# %%
#5) Computing part:
# Import environment
problem = "Crosswalk_comparison-v0"
u_b = [2.0, 11.0, -12.5, 1.1, -1.0]
l_b = [-4.0, 9.0, -32.5, 0.9, -2.0]

env = gym.make(problem,dt=0.3,Vm=2.5,tau=1.0,lower_bounds=l_b, upper_bounds=u_b,simulation="sin")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the algorithm
num_states = env.observation_space.shape[0]
num_actions = env.action_space.shape[0]
num_algo=12

algo=Algo_PPO(Model_PPO, env, num_algo= num_algo, num_states=num_states, num_actions=num_actions)
#algo.loading(1,1000)
# Out:
# C:\Users\abrunoud\Anaconda3\envs\ppotest\lib\site-packages\gym\logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))

# %%
#Training
import time
start = time.process_time()
algo.train(1000)
algo.saving()
end = time.process_time()
print("Running time: "+str(end-start))
# Out:
# Accident!
# Accident!
# Episode * 0 * Avg Reward is ==> -10.289246559143066 And Number of steps is ==> 0
# Episode * 1 * Avg Reward is ==> -7.82522439956665 And Number of steps is ==> 2000
# Episode * 2 * Avg Reward is ==> -6.358514785766602 And Number of steps is ==> 4000
# Episode * 3 * Avg Reward is ==> -6.159162521362305 And Number of steps is ==> 6000
# Accident!
# Episode * 4 * Avg Reward is ==> -5.957197189331055 And Number of steps is ==> 8000
# Episode * 5 * Avg Reward is ==> -5.836606502532959 And Number of steps is ==> 10000
# Accident!
# Accident!
# Episode * 6 * Avg Reward is ==> -5.481276512145996 And Number of steps is ==> 12000
# Accident!
# Accident!
# Episode * 7 * Avg Reward is ==> -5.366491794586182 And Number of steps is ==> 14000
# Accident!
# Accident!
# Episode * 8 * Avg Reward is ==> -5.175483226776123 And Number of steps is ==> 16000
# Episode * 9 * Avg Reward is ==> -5.352333068847656 And Number of steps is ==> 18000
# Episode * 10 * Avg Reward is ==> -4.808370590209961 And Number of steps is ==> 20000
# Episode * 11 * Avg Reward is ==> -4.86804723739624 And Number of steps is ==> 22000
# Accident!
# Accident!
# Episode * 12 * Avg Reward is ==> -4.957973480224609 And Number of steps is ==> 24000
# Episode * 13 * Avg Reward is ==> -4.698758602142334 And Number of steps is ==> 26000
# Episode * 14 * Avg Reward is ==> -4.629075050354004 And Number of steps is ==> 28000
# Accident!
# Episode * 15 * Avg Reward is ==> -4.374505519866943 And Number of steps is ==> 30000
# Accident!
# Episode * 16 * Avg Reward is ==> -4.415994644165039 And Number of steps is ==> 32000
# Accident!
# Accident!
# Episode * 17 * Avg Reward is ==> -4.3393988609313965 And Number of steps is ==> 34000
# Accident!
# Episode * 18 * Avg Reward is ==> -4.535645484924316 And Number of steps is ==> 36000
# Accident!
# Episode * 19 * Avg Reward is ==> -4.224031448364258 And Number of steps is ==> 38000
# Accident!
# Episode * 20 * Avg Reward is ==> -4.177430152893066 And Number of steps is ==> 40000
# Accident!
# Episode * 21 * Avg Reward is ==> -3.913140058517456 And Number of steps is ==> 42000
# Episode * 22 * Avg Reward is ==> -3.8654072284698486 And Number of steps is ==> 44000
# Episode * 23 * Avg Reward is ==> -3.9776737689971924 And Number of steps is ==> 46000
# Episode * 24 * Avg Reward is ==> -3.8477745056152344 And Number of steps is ==> 48000
# Accident!
# Episode * 25 * Avg Reward is ==> -3.8460986614227295 And Number of steps is ==> 50000
# Accident!
# Episode * 26 * Avg Reward is ==> -3.6945438385009766 And Number of steps is ==> 52000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 27 * Avg Reward is ==> -3.7387924194335938 And Number of steps is ==> 54000
# Accident!
# Episode * 28 * Avg Reward is ==> -3.2849113941192627 And Number of steps is ==> 56000
# Accident!
# Accident!
# Accident!
# Episode * 29 * Avg Reward is ==> -4.580801486968994 And Number of steps is ==> 58000
# Accident!
# Accident!
# Accident!
# Episode * 30 * Avg Reward is ==> -5.8499579429626465 And Number of steps is ==> 60000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 31 * Avg Reward is ==> -5.683701992034912 And Number of steps is ==> 62000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 32 * Avg Reward is ==> -5.469073295593262 And Number of steps is ==> 64000
# Accident!
# Episode * 33 * Avg Reward is ==> -5.3004937171936035 And Number of steps is ==> 66000
# Accident!
# Accident!
# Episode * 34 * Avg Reward is ==> -5.412946701049805 And Number of steps is ==> 68000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 35 * Avg Reward is ==> -5.305200576782227 And Number of steps is ==> 70000
# Accident!
# Accident!
# Accident!
# Episode * 36 * Avg Reward is ==> -5.31097412109375 And Number of steps is ==> 72000
# Accident!
# Episode * 37 * Avg Reward is ==> -5.926077842712402 And Number of steps is ==> 74000
# Accident!
# Accident!
# Episode * 38 * Avg Reward is ==> -6.0822014808654785 And Number of steps is ==> 76000
# Accident!
# Accident!
# Episode * 39 * Avg Reward is ==> -4.635173797607422 And Number of steps is ==> 78000
# Accident!
# Accident!
# Accident!
# Episode * 40 * Avg Reward is ==> -3.173597812652588 And Number of steps is ==> 80000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 41 * Avg Reward is ==> -3.144815444946289 And Number of steps is ==> 82000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 42 * Avg Reward is ==> -3.2315773963928223 And Number of steps is ==> 84000
# Accident!
# Accident!
# Episode * 43 * Avg Reward is ==> -3.2422776222229004 And Number of steps is ==> 86000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 44 * Avg Reward is ==> -3.1316399574279785 And Number of steps is ==> 88000
# Accident!
# Accident!
# Episode * 45 * Avg Reward is ==> -3.2849578857421875 And Number of steps is ==> 90000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 46 * Avg Reward is ==> -3.315962314605713 And Number of steps is ==> 92000
# Accident!
# Episode * 47 * Avg Reward is ==> -2.6298024654388428 And Number of steps is ==> 94000
# Accident!
# Accident!
# Episode * 48 * Avg Reward is ==> -2.6347744464874268 And Number of steps is ==> 96000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 49 * Avg Reward is ==> -2.543116569519043 And Number of steps is ==> 98000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 50 * Avg Reward is ==> -2.570366621017456 And Number of steps is ==> 100000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 51 * Avg Reward is ==> -2.7461867332458496 And Number of steps is ==> 102000
# Episode * 52 * Avg Reward is ==> -2.7228400707244873 And Number of steps is ==> 104000
# Accident!
# Episode * 53 * Avg Reward is ==> -2.839478015899658 And Number of steps is ==> 106000
# Accident!
# Accident!
# Episode * 54 * Avg Reward is ==> -2.7468597888946533 And Number of steps is ==> 108000
# Accident!
# Accident!
# Accident!
# Episode * 55 * Avg Reward is ==> -2.683948278427124 And Number of steps is ==> 110000
# Episode * 56 * Avg Reward is ==> -2.6940665245056152 And Number of steps is ==> 112000
# Accident!
# Accident!
# Episode * 57 * Avg Reward is ==> -2.5184998512268066 And Number of steps is ==> 114000
# Accident!
# Accident!
# Accident!
# Episode * 58 * Avg Reward is ==> -2.3837265968322754 And Number of steps is ==> 116000
# Accident!
# Episode * 59 * Avg Reward is ==> -2.4395413398742676 And Number of steps is ==> 118000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 60 * Avg Reward is ==> -2.4440367221832275 And Number of steps is ==> 120000
# Episode * 61 * Avg Reward is ==> -2.405902624130249 And Number of steps is ==> 122000
# Accident!
# Episode * 62 * Avg Reward is ==> -2.535783052444458 And Number of steps is ==> 124000
# Accident!
# Accident!
# Episode * 63 * Avg Reward is ==> -2.528578519821167 And Number of steps is ==> 126000
# Accident!
# Episode * 64 * Avg Reward is ==> -2.557080030441284 And Number of steps is ==> 128000
# Accident!
# Accident!
# Accident!
# Episode * 65 * Avg Reward is ==> -2.6543993949890137 And Number of steps is ==> 130000
# Accident!
# Accident!
# Accident!
# Episode * 66 * Avg Reward is ==> -2.77130126953125 And Number of steps is ==> 132000
# Accident!
# Accident!
# Episode * 67 * Avg Reward is ==> -2.8709559440612793 And Number of steps is ==> 134000
# Accident!
# Episode * 68 * Avg Reward is ==> -2.9720921516418457 And Number of steps is ==> 136000
# Accident!
# Accident!
# Accident!
# Episode * 69 * Avg Reward is ==> -3.140798568725586 And Number of steps is ==> 138000
# Accident!
# Episode * 70 * Avg Reward is ==> -3.1717944145202637 And Number of steps is ==> 140000
# Accident!
# Accident!
# Episode * 71 * Avg Reward is ==> -3.185826063156128 And Number of steps is ==> 142000
# Accident!
# Episode * 72 * Avg Reward is ==> -3.0055124759674072 And Number of steps is ==> 144000
# Accident!
# Accident!
# Episode * 73 * Avg Reward is ==> -2.9989306926727295 And Number of steps is ==> 146000
# Episode * 74 * Avg Reward is ==> -2.9664106369018555 And Number of steps is ==> 148000
# Accident!
# Episode * 75 * Avg Reward is ==> -2.8977062702178955 And Number of steps is ==> 150000
# Accident!
# Episode * 76 * Avg Reward is ==> -2.840259552001953 And Number of steps is ==> 152000
# Accident!
# Accident!
# Accident!
# Episode * 77 * Avg Reward is ==> -2.9645683765411377 And Number of steps is ==> 154000
# Accident!
# Episode * 78 * Avg Reward is ==> -3.0224618911743164 And Number of steps is ==> 156000
# Accident!
# Accident!
# Episode * 79 * Avg Reward is ==> -2.856130599975586 And Number of steps is ==> 158000
# Accident!
# Accident!
# Accident!
# Episode * 80 * Avg Reward is ==> -2.784418821334839 And Number of steps is ==> 160000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 81 * Avg Reward is ==> -2.8358919620513916 And Number of steps is ==> 162000
# Episode * 82 * Avg Reward is ==> -2.9608030319213867 And Number of steps is ==> 164000
# Accident!
# Accident!
# Episode * 83 * Avg Reward is ==> -3.0132973194122314 And Number of steps is ==> 166000
# Accident!
# Episode * 84 * Avg Reward is ==> -3.0766708850860596 And Number of steps is ==> 168000
# Accident!
# Accident!
# Episode * 85 * Avg Reward is ==> -3.0967681407928467 And Number of steps is ==> 170000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 86 * Avg Reward is ==> -3.125110626220703 And Number of steps is ==> 172000
# Accident!
# Episode * 87 * Avg Reward is ==> -2.9785094261169434 And Number of steps is ==> 174000
# Accident!
# Accident!
# Episode * 88 * Avg Reward is ==> -3.037496328353882 And Number of steps is ==> 176000
# Episode * 89 * Avg Reward is ==> -3.1587772369384766 And Number of steps is ==> 178000
# Episode * 90 * Avg Reward is ==> -3.173734188079834 And Number of steps is ==> 180000
# Accident!
# Episode * 91 * Avg Reward is ==> -3.121084690093994 And Number of steps is ==> 182000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 92 * Avg Reward is ==> -3.000230073928833 And Number of steps is ==> 184000
# Accident!
# Accident!
# Accident!
# Episode * 93 * Avg Reward is ==> -2.948620319366455 And Number of steps is ==> 186000
# Accident!
# Accident!
# Accident!
# Episode * 94 * Avg Reward is ==> -2.942811965942383 And Number of steps is ==> 188000
# Accident!
# Accident!
# Accident!
# Episode * 95 * Avg Reward is ==> -2.9332101345062256 And Number of steps is ==> 190000
# Accident!
# Accident!
# Episode * 96 * Avg Reward is ==> -2.712059497833252 And Number of steps is ==> 192000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 97 * Avg Reward is ==> -2.791264533996582 And Number of steps is ==> 194000
# Accident!
# Episode * 98 * Avg Reward is ==> -2.8267440795898438 And Number of steps is ==> 196000
# Accident!
# Episode * 99 * Avg Reward is ==> -2.8652939796447754 And Number of steps is ==> 198000
# Accident!
# Accident!
# Episode * 100 * Avg Reward is ==> -2.8797783851623535 And Number of steps is ==> 200000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 101 * Avg Reward is ==> -2.9525489807128906 And Number of steps is ==> 202000
# Accident!
# Accident!
# Accident!
# Episode * 102 * Avg Reward is ==> -3.048252820968628 And Number of steps is ==> 204000
# Accident!
# Episode * 103 * Avg Reward is ==> -2.9839940071105957 And Number of steps is ==> 206000
# Accident!
# Accident!
# Episode * 104 * Avg Reward is ==> -3.001835346221924 And Number of steps is ==> 208000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 105 * Avg Reward is ==> -2.9463162422180176 And Number of steps is ==> 210000
# Accident!
# Accident!
# Episode * 106 * Avg Reward is ==> -3.131443500518799 And Number of steps is ==> 212000
# Accident!
# Episode * 107 * Avg Reward is ==> -3.0185530185699463 And Number of steps is ==> 214000
# Accident!
# Accident!
# Episode * 108 * Avg Reward is ==> -2.9711081981658936 And Number of steps is ==> 216000
# Accident!
# Accident!
# Episode * 109 * Avg Reward is ==> -2.995391368865967 And Number of steps is ==> 218000
# Accident!
# Episode * 110 * Avg Reward is ==> -3.045112133026123 And Number of steps is ==> 220000
# Accident!
# Accident!
# Episode * 111 * Avg Reward is ==> -2.887293577194214 And Number of steps is ==> 222000
# Accident!
# Accident!
# Episode * 112 * Avg Reward is ==> -2.7332637310028076 And Number of steps is ==> 224000
# Accident!
# Accident!
# Accident!
# Episode * 113 * Avg Reward is ==> -2.5642168521881104 And Number of steps is ==> 226000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 114 * Avg Reward is ==> -2.5497887134552 And Number of steps is ==> 228000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 115 * Avg Reward is ==> -2.594956874847412 And Number of steps is ==> 230000
# Accident!
# Accident!
# Accident!
# Episode * 116 * Avg Reward is ==> -2.662604331970215 And Number of steps is ==> 232000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 117 * Avg Reward is ==> -2.8447558879852295 And Number of steps is ==> 234000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 118 * Avg Reward is ==> -2.8058714866638184 And Number of steps is ==> 236000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 119 * Avg Reward is ==> -2.697117328643799 And Number of steps is ==> 238000
# Accident!
# Episode * 120 * Avg Reward is ==> -2.691518783569336 And Number of steps is ==> 240000
# Accident!
# Accident!
# Accident!
# Episode * 121 * Avg Reward is ==> -2.751713275909424 And Number of steps is ==> 242000
# Accident!
# Accident!
# Episode * 122 * Avg Reward is ==> -2.8463613986968994 And Number of steps is ==> 244000
# Accident!
# Episode * 123 * Avg Reward is ==> -2.9777991771698 And Number of steps is ==> 246000
# Accident!
# Episode * 124 * Avg Reward is ==> -2.914607524871826 And Number of steps is ==> 248000
# Episode * 125 * Avg Reward is ==> -2.8661255836486816 And Number of steps is ==> 250000
# Accident!
# Episode * 126 * Avg Reward is ==> -2.7109413146972656 And Number of steps is ==> 252000
# Episode * 127 * Avg Reward is ==> -2.5971732139587402 And Number of steps is ==> 254000
# Accident!
# Episode * 128 * Avg Reward is ==> -2.5520524978637695 And Number of steps is ==> 256000
# Accident!
# Accident!
# Episode * 129 * Avg Reward is ==> -2.477646589279175 And Number of steps is ==> 258000
# Accident!
# Accident!
# Episode * 130 * Avg Reward is ==> -2.627012252807617 And Number of steps is ==> 260000
# Accident!
# Episode * 131 * Avg Reward is ==> -2.719221591949463 And Number of steps is ==> 262000
# Accident!
# Episode * 132 * Avg Reward is ==> -2.721142530441284 And Number of steps is ==> 264000
# Accident!
# Accident!
# Episode * 133 * Avg Reward is ==> -2.7344963550567627 And Number of steps is ==> 266000
# Accident!
# Episode * 134 * Avg Reward is ==> -2.84306001663208 And Number of steps is ==> 268000
# Episode * 135 * Avg Reward is ==> -2.860330581665039 And Number of steps is ==> 270000
# Accident!
# Accident!
# Accident!
# Episode * 136 * Avg Reward is ==> -2.8884787559509277 And Number of steps is ==> 272000
# Accident!
# Accident!
# Accident!
# Episode * 137 * Avg Reward is ==> -2.992943286895752 And Number of steps is ==> 274000
# Accident!
# Episode * 138 * Avg Reward is ==> -2.9777748584747314 And Number of steps is ==> 276000
# Episode * 139 * Avg Reward is ==> -3.1450355052948 And Number of steps is ==> 278000
# Accident!
# Episode * 140 * Avg Reward is ==> -2.9836068153381348 And Number of steps is ==> 280000
# Accident!
# Accident!
# Episode * 141 * Avg Reward is ==> -2.8508951663970947 And Number of steps is ==> 282000
# Episode * 142 * Avg Reward is ==> -2.916307210922241 And Number of steps is ==> 284000
# Episode * 143 * Avg Reward is ==> -3.01655912399292 And Number of steps is ==> 286000
# Accident!
# Episode * 144 * Avg Reward is ==> -2.938892364501953 And Number of steps is ==> 288000
# Episode * 145 * Avg Reward is ==> -3.0261197090148926 And Number of steps is ==> 290000
# Episode * 146 * Avg Reward is ==> -3.0349628925323486 And Number of steps is ==> 292000
# Episode * 147 * Avg Reward is ==> -2.905644416809082 And Number of steps is ==> 294000
# Accident!
# Episode * 148 * Avg Reward is ==> -3.0181379318237305 And Number of steps is ==> 296000
# Accident!
# Episode * 149 * Avg Reward is ==> -2.9335336685180664 And Number of steps is ==> 298000
# Accident!
# Accident!
# Episode * 150 * Avg Reward is ==> -2.826629400253296 And Number of steps is ==> 300000
# Accident!
# Episode * 151 * Avg Reward is ==> -2.8960039615631104 And Number of steps is ==> 302000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 152 * Avg Reward is ==> -2.9846203327178955 And Number of steps is ==> 304000
# Episode * 153 * Avg Reward is ==> -2.8263702392578125 And Number of steps is ==> 306000
# Accident!
# Episode * 154 * Avg Reward is ==> -2.7683939933776855 And Number of steps is ==> 308000
# Episode * 155 * Avg Reward is ==> -2.795438051223755 And Number of steps is ==> 310000
# Accident!
# Episode * 156 * Avg Reward is ==> -2.6952767372131348 And Number of steps is ==> 312000
# Episode * 157 * Avg Reward is ==> -2.597001314163208 And Number of steps is ==> 314000
# Accident!
# Episode * 158 * Avg Reward is ==> -2.448976993560791 And Number of steps is ==> 316000
# Accident!
# Episode * 159 * Avg Reward is ==> -2.509525775909424 And Number of steps is ==> 318000
# Accident!
# Episode * 160 * Avg Reward is ==> -2.584993839263916 And Number of steps is ==> 320000
# Accident!
# Accident!
# Episode * 161 * Avg Reward is ==> -2.547119617462158 And Number of steps is ==> 322000
# Episode * 162 * Avg Reward is ==> -2.373286485671997 And Number of steps is ==> 324000
# Accident!
# Accident!
# Accident!
# Episode * 163 * Avg Reward is ==> -2.4196877479553223 And Number of steps is ==> 326000
# Episode * 164 * Avg Reward is ==> -2.501417398452759 And Number of steps is ==> 328000
# Accident!
# Accident!
# Episode * 165 * Avg Reward is ==> -2.430952787399292 And Number of steps is ==> 330000
# Accident!
# Accident!
# Episode * 166 * Avg Reward is ==> -2.4881832599639893 And Number of steps is ==> 332000
# Accident!
# Accident!
# Accident!
# Episode * 167 * Avg Reward is ==> -2.6088194847106934 And Number of steps is ==> 334000
# Accident!
# Episode * 168 * Avg Reward is ==> -2.693012237548828 And Number of steps is ==> 336000
# Episode * 169 * Avg Reward is ==> -2.674246311187744 And Number of steps is ==> 338000
# Accident!
# Episode * 170 * Avg Reward is ==> -2.685908794403076 And Number of steps is ==> 340000
# Accident!
# Episode * 171 * Avg Reward is ==> -2.67291259765625 And Number of steps is ==> 342000
# Accident!
# Episode * 172 * Avg Reward is ==> -2.5262513160705566 And Number of steps is ==> 344000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 173 * Avg Reward is ==> -2.5967249870300293 And Number of steps is ==> 346000
# Accident!
# Accident!
# Accident!
# Episode * 174 * Avg Reward is ==> -2.5084872245788574 And Number of steps is ==> 348000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 175 * Avg Reward is ==> -2.391054630279541 And Number of steps is ==> 350000
# Episode * 176 * Avg Reward is ==> -2.3828117847442627 And Number of steps is ==> 352000
# Accident!
# Episode * 177 * Avg Reward is ==> -2.4185330867767334 And Number of steps is ==> 354000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 178 * Avg Reward is ==> -2.3449158668518066 And Number of steps is ==> 356000
# Accident!
# Accident!
# Episode * 179 * Avg Reward is ==> -2.2533202171325684 And Number of steps is ==> 358000
# Accident!
# Episode * 180 * Avg Reward is ==> -2.3087635040283203 And Number of steps is ==> 360000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 181 * Avg Reward is ==> -2.4236884117126465 And Number of steps is ==> 362000
# Accident!
# Accident!
# Episode * 182 * Avg Reward is ==> -2.6950430870056152 And Number of steps is ==> 364000
# Accident!
# Episode * 183 * Avg Reward is ==> -2.5727250576019287 And Number of steps is ==> 366000
# Episode * 184 * Avg Reward is ==> -2.6587586402893066 And Number of steps is ==> 368000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 185 * Avg Reward is ==> -2.777653217315674 And Number of steps is ==> 370000
# Accident!
# Accident!
# Episode * 186 * Avg Reward is ==> -2.8000221252441406 And Number of steps is ==> 372000
# Accident!
# Accident!
# Episode * 187 * Avg Reward is ==> -2.6703450679779053 And Number of steps is ==> 374000
# Episode * 188 * Avg Reward is ==> -2.7111964225769043 And Number of steps is ==> 376000
# Accident!
# Accident!
# Accident!
# Episode * 189 * Avg Reward is ==> -2.7253241539001465 And Number of steps is ==> 378000
# Accident!
# Episode * 190 * Avg Reward is ==> -2.7054858207702637 And Number of steps is ==> 380000
# Accident!
# Episode * 191 * Avg Reward is ==> -2.5910353660583496 And Number of steps is ==> 382000
# Episode * 192 * Avg Reward is ==> -2.5494160652160645 And Number of steps is ==> 384000
# Episode * 193 * Avg Reward is ==> -2.558962106704712 And Number of steps is ==> 386000
# Episode * 194 * Avg Reward is ==> -2.4294238090515137 And Number of steps is ==> 388000
# Accident!
# Episode * 195 * Avg Reward is ==> -2.3483622074127197 And Number of steps is ==> 390000
# Episode * 196 * Avg Reward is ==> -2.320244312286377 And Number of steps is ==> 392000
# Accident!
# Episode * 197 * Avg Reward is ==> -2.46466064453125 And Number of steps is ==> 394000
# Episode * 198 * Avg Reward is ==> -2.5879111289978027 And Number of steps is ==> 396000
# Accident!
# Accident!
# Accident!
# Episode * 199 * Avg Reward is ==> -2.7587671279907227 And Number of steps is ==> 398000
# Accident!
# Episode * 200 * Avg Reward is ==> -2.606203079223633 And Number of steps is ==> 400000
# Accident!
# Episode * 201 * Avg Reward is ==> -2.6641597747802734 And Number of steps is ==> 402000
# Accident!
# Accident!
# Episode * 202 * Avg Reward is ==> -2.727468252182007 And Number of steps is ==> 404000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 203 * Avg Reward is ==> -2.715402841567993 And Number of steps is ==> 406000
# Accident!
# Accident!
# Episode * 204 * Avg Reward is ==> -2.79105281829834 And Number of steps is ==> 408000
# Accident!
# Accident!
# Episode * 205 * Avg Reward is ==> -2.9105496406555176 And Number of steps is ==> 410000
# Accident!
# Accident!
# Accident!
# Episode * 206 * Avg Reward is ==> -2.9784085750579834 And Number of steps is ==> 412000
# Accident!
# Accident!
# Episode * 207 * Avg Reward is ==> -2.8672683238983154 And Number of steps is ==> 414000
# Accident!
# Episode * 208 * Avg Reward is ==> -2.804187297821045 And Number of steps is ==> 416000
# Accident!
# Episode * 209 * Avg Reward is ==> -2.6781177520751953 And Number of steps is ==> 418000
# Accident!
# Episode * 210 * Avg Reward is ==> -2.7225146293640137 And Number of steps is ==> 420000
# Accident!
# Episode * 211 * Avg Reward is ==> -2.5756537914276123 And Number of steps is ==> 422000
# Accident!
# Accident!
# Episode * 212 * Avg Reward is ==> -2.6353323459625244 And Number of steps is ==> 424000
# Accident!
# Episode * 213 * Avg Reward is ==> -2.713679790496826 And Number of steps is ==> 426000
# Accident!
# Episode * 214 * Avg Reward is ==> -2.7000608444213867 And Number of steps is ==> 428000
# Accident!
# Episode * 215 * Avg Reward is ==> -2.631864070892334 And Number of steps is ==> 430000
# Accident!
# Episode * 216 * Avg Reward is ==> -2.5700135231018066 And Number of steps is ==> 432000
# Accident!
# Accident!
# Accident!
# Episode * 217 * Avg Reward is ==> -2.673002243041992 And Number of steps is ==> 434000
# Episode * 218 * Avg Reward is ==> -2.511009693145752 And Number of steps is ==> 436000
# Episode * 219 * Avg Reward is ==> -2.485945224761963 And Number of steps is ==> 438000
# Accident!
# Episode * 220 * Avg Reward is ==> -2.57625150680542 And Number of steps is ==> 440000
# Episode * 221 * Avg Reward is ==> -2.684579849243164 And Number of steps is ==> 442000
# Accident!
# Episode * 222 * Avg Reward is ==> -2.4521658420562744 And Number of steps is ==> 444000
# Episode * 223 * Avg Reward is ==> -2.3819684982299805 And Number of steps is ==> 446000
# Accident!
# Accident!
# Episode * 224 * Avg Reward is ==> -2.4298672676086426 And Number of steps is ==> 448000
# Accident!
# Accident!
# Episode * 225 * Avg Reward is ==> -2.4503324031829834 And Number of steps is ==> 450000
# Accident!
# Accident!
# Episode * 226 * Avg Reward is ==> -2.409499406814575 And Number of steps is ==> 452000
# Accident!
# Episode * 227 * Avg Reward is ==> -2.217982053756714 And Number of steps is ==> 454000
# Episode * 228 * Avg Reward is ==> -2.2951254844665527 And Number of steps is ==> 456000
# Accident!
# Episode * 229 * Avg Reward is ==> -2.32257080078125 And Number of steps is ==> 458000
# Episode * 230 * Avg Reward is ==> -2.2911341190338135 And Number of steps is ==> 460000
# Accident!
# Accident!
# Episode * 231 * Avg Reward is ==> -2.2939090728759766 And Number of steps is ==> 462000
# Accident!
# Episode * 232 * Avg Reward is ==> -2.385835886001587 And Number of steps is ==> 464000
# Accident!
# Episode * 233 * Avg Reward is ==> -2.4531092643737793 And Number of steps is ==> 466000
# Episode * 234 * Avg Reward is ==> -2.4171433448791504 And Number of steps is ==> 468000
# Accident!
# Episode * 235 * Avg Reward is ==> -2.369311809539795 And Number of steps is ==> 470000
# Episode * 236 * Avg Reward is ==> -2.3170320987701416 And Number of steps is ==> 472000
# Accident!
# Accident!
# Episode * 237 * Avg Reward is ==> -2.3733716011047363 And Number of steps is ==> 474000
# Episode * 238 * Avg Reward is ==> -2.337618112564087 And Number of steps is ==> 476000
# Accident!
# Episode * 239 * Avg Reward is ==> -2.2959036827087402 And Number of steps is ==> 478000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 240 * Avg Reward is ==> -2.26277756690979 And Number of steps is ==> 480000
# Accident!
# Episode * 241 * Avg Reward is ==> -2.2099220752716064 And Number of steps is ==> 482000
# Episode * 242 * Avg Reward is ==> -2.154369354248047 And Number of steps is ==> 484000
# Episode * 243 * Avg Reward is ==> -2.1100919246673584 And Number of steps is ==> 486000
# Episode * 244 * Avg Reward is ==> -2.2199244499206543 And Number of steps is ==> 488000
# Accident!
# Episode * 245 * Avg Reward is ==> -2.3458895683288574 And Number of steps is ==> 490000
# Episode * 246 * Avg Reward is ==> -2.441157579421997 And Number of steps is ==> 492000
# Episode * 247 * Avg Reward is ==> -2.442178249359131 And Number of steps is ==> 494000
# Episode * 248 * Avg Reward is ==> -2.491711139678955 And Number of steps is ==> 496000
# Accident!
# Accident!
# Episode * 249 * Avg Reward is ==> -2.468379497528076 And Number of steps is ==> 498000
# Accident!
# Accident!
# Accident!
# Episode * 250 * Avg Reward is ==> -2.5540611743927 And Number of steps is ==> 500000
# Episode * 251 * Avg Reward is ==> -2.4960436820983887 And Number of steps is ==> 502000
# Accident!
# Episode * 252 * Avg Reward is ==> -2.6096720695495605 And Number of steps is ==> 504000
# Episode * 253 * Avg Reward is ==> -2.6112074851989746 And Number of steps is ==> 506000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 254 * Avg Reward is ==> -2.540797710418701 And Number of steps is ==> 508000
# Accident!
# Episode * 255 * Avg Reward is ==> -2.453702211380005 And Number of steps is ==> 510000
# Accident!
# Episode * 256 * Avg Reward is ==> -2.4879794120788574 And Number of steps is ==> 512000
# Episode * 257 * Avg Reward is ==> -2.4680895805358887 And Number of steps is ==> 514000
# Accident!
# Accident!
# Episode * 258 * Avg Reward is ==> -2.4160947799682617 And Number of steps is ==> 516000
# Episode * 259 * Avg Reward is ==> -2.4950976371765137 And Number of steps is ==> 518000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 260 * Avg Reward is ==> -2.5092010498046875 And Number of steps is ==> 520000
# Accident!
# Episode * 261 * Avg Reward is ==> -2.5722033977508545 And Number of steps is ==> 522000
# Accident!
# Accident!
# Episode * 262 * Avg Reward is ==> -2.497807264328003 And Number of steps is ==> 524000
# Accident!
# Episode * 263 * Avg Reward is ==> -2.479271650314331 And Number of steps is ==> 526000
# Episode * 264 * Avg Reward is ==> -2.488783597946167 And Number of steps is ==> 528000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 265 * Avg Reward is ==> -2.4949543476104736 And Number of steps is ==> 530000
# Accident!
# Episode * 266 * Avg Reward is ==> -2.4312005043029785 And Number of steps is ==> 532000
# Accident!
# Episode * 267 * Avg Reward is ==> -2.5438482761383057 And Number of steps is ==> 534000
# Accident!
# Accident!
# Episode * 268 * Avg Reward is ==> -2.6264584064483643 And Number of steps is ==> 536000
# Accident!
# Accident!
# Accident!
# Episode * 269 * Avg Reward is ==> -2.634216785430908 And Number of steps is ==> 538000
# Episode * 270 * Avg Reward is ==> -2.51057767868042 And Number of steps is ==> 540000
# Accident!
# Accident!
# Episode * 271 * Avg Reward is ==> -2.5686967372894287 And Number of steps is ==> 542000
# Accident!
# Accident!
# Episode * 272 * Avg Reward is ==> -2.631697416305542 And Number of steps is ==> 544000
# Accident!
# Accident!
# Accident!
# Episode * 273 * Avg Reward is ==> -2.6846258640289307 And Number of steps is ==> 546000
# Episode * 274 * Avg Reward is ==> -2.6586790084838867 And Number of steps is ==> 548000
# Accident!
# Episode * 275 * Avg Reward is ==> -2.602464437484741 And Number of steps is ==> 550000
# Accident!
# Episode * 276 * Avg Reward is ==> -2.6744515895843506 And Number of steps is ==> 552000
# Accident!
# Accident!
# Accident!
# Episode * 277 * Avg Reward is ==> -2.6225292682647705 And Number of steps is ==> 554000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 278 * Avg Reward is ==> -2.693317413330078 And Number of steps is ==> 556000
# Episode * 279 * Avg Reward is ==> -2.5639383792877197 And Number of steps is ==> 558000
# Accident!
# Episode * 280 * Avg Reward is ==> -2.62431001663208 And Number of steps is ==> 560000
# Accident!
# Accident!
# Accident!
# Episode * 281 * Avg Reward is ==> -2.5456793308258057 And Number of steps is ==> 562000
# Episode * 282 * Avg Reward is ==> -2.48169207572937 And Number of steps is ==> 564000
# Accident!
# Episode * 283 * Avg Reward is ==> -2.4388580322265625 And Number of steps is ==> 566000
# Accident!
# Accident!
# Episode * 284 * Avg Reward is ==> -2.4485249519348145 And Number of steps is ==> 568000
# Accident!
# Episode * 285 * Avg Reward is ==> -2.4161570072174072 And Number of steps is ==> 570000
# Episode * 286 * Avg Reward is ==> -2.3181304931640625 And Number of steps is ==> 572000
# Accident!
# Accident!
# Episode * 287 * Avg Reward is ==> -2.281141757965088 And Number of steps is ==> 574000
# Episode * 288 * Avg Reward is ==> -2.197906017303467 And Number of steps is ==> 576000
# Accident!
# Episode * 289 * Avg Reward is ==> -2.284660816192627 And Number of steps is ==> 578000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 290 * Avg Reward is ==> -2.1954879760742188 And Number of steps is ==> 580000
# Accident!
# Episode * 291 * Avg Reward is ==> -2.2328908443450928 And Number of steps is ==> 582000
# Episode * 292 * Avg Reward is ==> -2.2674965858459473 And Number of steps is ==> 584000
# Accident!
# Episode * 293 * Avg Reward is ==> -2.3136088848114014 And Number of steps is ==> 586000
# Accident!
# Episode * 294 * Avg Reward is ==> -2.258784770965576 And Number of steps is ==> 588000
# Accident!
# Episode * 295 * Avg Reward is ==> -2.3829288482666016 And Number of steps is ==> 590000
# Episode * 296 * Avg Reward is ==> -2.5008814334869385 And Number of steps is ==> 592000
# Accident!
# Episode * 297 * Avg Reward is ==> -2.5517048835754395 And Number of steps is ==> 594000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 298 * Avg Reward is ==> -2.6312763690948486 And Number of steps is ==> 596000
# Accident!
# Accident!
# Accident!
# Episode * 299 * Avg Reward is ==> -2.590487003326416 And Number of steps is ==> 598000
# Accident!
# Accident!
# Episode * 300 * Avg Reward is ==> -2.7200100421905518 And Number of steps is ==> 600000
# Accident!
# Accident!
# Accident!
# Episode * 301 * Avg Reward is ==> -2.7745604515075684 And Number of steps is ==> 602000
# Accident!
# Accident!
# Episode * 302 * Avg Reward is ==> -2.754335403442383 And Number of steps is ==> 604000
# Accident!
# Episode * 303 * Avg Reward is ==> -2.6063504219055176 And Number of steps is ==> 606000
# Accident!
# Episode * 304 * Avg Reward is ==> -2.637854814529419 And Number of steps is ==> 608000
# Episode * 305 * Avg Reward is ==> -2.5208747386932373 And Number of steps is ==> 610000
# Accident!
# Accident!
# Episode * 306 * Avg Reward is ==> -2.3914542198181152 And Number of steps is ==> 612000
# Accident!
# Accident!
# Accident!
# Episode * 307 * Avg Reward is ==> -2.417804479598999 And Number of steps is ==> 614000
# Accident!
# Accident!
# Episode * 308 * Avg Reward is ==> -2.3470492362976074 And Number of steps is ==> 616000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 309 * Avg Reward is ==> -2.2604820728302 And Number of steps is ==> 618000
# Accident!
# Accident!
# Episode * 310 * Avg Reward is ==> -2.2370822429656982 And Number of steps is ==> 620000
# Accident!
# Accident!
# Episode * 311 * Avg Reward is ==> -2.342259645462036 And Number of steps is ==> 622000
# Accident!
# Accident!
# Episode * 312 * Avg Reward is ==> -2.2287728786468506 And Number of steps is ==> 624000
# Accident!
# Episode * 313 * Avg Reward is ==> -2.4121878147125244 And Number of steps is ==> 626000
# Accident!
# Accident!
# Episode * 314 * Avg Reward is ==> -2.3851704597473145 And Number of steps is ==> 628000
# Accident!
# Episode * 315 * Avg Reward is ==> -2.4805526733398438 And Number of steps is ==> 630000
# Accident!
# Episode * 316 * Avg Reward is ==> -2.6236202716827393 And Number of steps is ==> 632000
# Accident!
# Episode * 317 * Avg Reward is ==> -2.556457281112671 And Number of steps is ==> 634000
# Accident!
# Episode * 318 * Avg Reward is ==> -2.541731357574463 And Number of steps is ==> 636000
# Accident!
# Accident!
# Episode * 319 * Avg Reward is ==> -2.5612285137176514 And Number of steps is ==> 638000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 320 * Avg Reward is ==> -2.4493932723999023 And Number of steps is ==> 640000
# Accident!
# Episode * 321 * Avg Reward is ==> -2.3858120441436768 And Number of steps is ==> 642000
# Accident!
# Accident!
# Accident!
# Episode * 322 * Avg Reward is ==> -2.5340957641601562 And Number of steps is ==> 644000
# Accident!
# Accident!
# Accident!
# Episode * 323 * Avg Reward is ==> -2.443803310394287 And Number of steps is ==> 646000
# Episode * 324 * Avg Reward is ==> -2.4499268531799316 And Number of steps is ==> 648000
# Accident!
# Accident!
# Episode * 325 * Avg Reward is ==> -2.3535964488983154 And Number of steps is ==> 650000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 326 * Avg Reward is ==> -2.198777437210083 And Number of steps is ==> 652000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 327 * Avg Reward is ==> -2.2411458492279053 And Number of steps is ==> 654000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 328 * Avg Reward is ==> -2.136430263519287 And Number of steps is ==> 656000
# Episode * 329 * Avg Reward is ==> -2.16615891456604 And Number of steps is ==> 658000
# Accident!
# Accident!
# Episode * 330 * Avg Reward is ==> -2.2037460803985596 And Number of steps is ==> 660000
# Accident!
# Episode * 331 * Avg Reward is ==> -2.049156665802002 And Number of steps is ==> 662000
# Episode * 332 * Avg Reward is ==> -1.9036859273910522 And Number of steps is ==> 664000
# Accident!
# Episode * 333 * Avg Reward is ==> -1.9112812280654907 And Number of steps is ==> 666000
# Accident!
# Episode * 334 * Avg Reward is ==> -1.8068039417266846 And Number of steps is ==> 668000
# Accident!
# Accident!
# Episode * 335 * Avg Reward is ==> -1.7855428457260132 And Number of steps is ==> 670000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 336 * Avg Reward is ==> -1.8095296621322632 And Number of steps is ==> 672000
# Accident!
# Episode * 337 * Avg Reward is ==> -1.7937405109405518 And Number of steps is ==> 674000
# Accident!
# Accident!
# Accident!
# Episode * 338 * Avg Reward is ==> -1.9152696132659912 And Number of steps is ==> 676000
# Accident!
# Episode * 339 * Avg Reward is ==> -1.784440040588379 And Number of steps is ==> 678000
# Accident!
# Accident!
# Accident!
# Episode * 340 * Avg Reward is ==> -1.8244941234588623 And Number of steps is ==> 680000
# Accident!
# Accident!
# Episode * 341 * Avg Reward is ==> -1.8752148151397705 And Number of steps is ==> 682000
# Accident!
# Accident!
# Accident!
# Episode * 342 * Avg Reward is ==> -1.8474050760269165 And Number of steps is ==> 684000
# Accident!
# Accident!
# Accident!
# Episode * 343 * Avg Reward is ==> -1.7909519672393799 And Number of steps is ==> 686000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 344 * Avg Reward is ==> -1.9663035869598389 And Number of steps is ==> 688000
# Accident!
# Accident!
# Episode * 345 * Avg Reward is ==> -1.9724050760269165 And Number of steps is ==> 690000
# Accident!
# Accident!
# Accident!
# Episode * 346 * Avg Reward is ==> -1.9197736978530884 And Number of steps is ==> 692000
# Accident!
# Accident!
# Accident!
# Episode * 347 * Avg Reward is ==> -1.775368332862854 And Number of steps is ==> 694000
# Episode * 348 * Avg Reward is ==> -1.651802659034729 And Number of steps is ==> 696000
# Accident!
# Episode * 349 * Avg Reward is ==> -1.724405288696289 And Number of steps is ==> 698000
# Episode * 350 * Avg Reward is ==> -1.6763023138046265 And Number of steps is ==> 700000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 351 * Avg Reward is ==> -1.6473926305770874 And Number of steps is ==> 702000
# Accident!
# Accident!
# Episode * 352 * Avg Reward is ==> -1.687677025794983 And Number of steps is ==> 704000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 353 * Avg Reward is ==> -1.7142159938812256 And Number of steps is ==> 706000
# Accident!
# Episode * 354 * Avg Reward is ==> -1.540149450302124 And Number of steps is ==> 708000
# Episode * 355 * Avg Reward is ==> -1.443854808807373 And Number of steps is ==> 710000
# Accident!
# Accident!
# Episode * 356 * Avg Reward is ==> -1.474263072013855 And Number of steps is ==> 712000
# Accident!
# Accident!
# Episode * 357 * Avg Reward is ==> -1.50255286693573 And Number of steps is ==> 714000
# Accident!
# Accident!
# Accident!
# Episode * 358 * Avg Reward is ==> -1.382412314414978 And Number of steps is ==> 716000
# Accident!
# Accident!
# Episode * 359 * Avg Reward is ==> -1.4503934383392334 And Number of steps is ==> 718000
# Accident!
# Accident!
# Episode * 360 * Avg Reward is ==> -1.3999030590057373 And Number of steps is ==> 720000
# Accident!
# Accident!
# Episode * 361 * Avg Reward is ==> -1.2416961193084717 And Number of steps is ==> 722000
# Accident!
# Accident!
# Accident!
# Episode * 362 * Avg Reward is ==> -1.1630027294158936 And Number of steps is ==> 724000
# Accident!
# Episode * 363 * Avg Reward is ==> -1.0199077129364014 And Number of steps is ==> 726000
# Episode * 364 * Avg Reward is ==> -0.9504979848861694 And Number of steps is ==> 728000
# Accident!
# Accident!
# Episode * 365 * Avg Reward is ==> -0.9670255780220032 And Number of steps is ==> 730000
# Accident!
# Episode * 366 * Avg Reward is ==> -0.9667547941207886 And Number of steps is ==> 732000
# Accident!
# Accident!
# Accident!
# Episode * 367 * Avg Reward is ==> -0.9316131472587585 And Number of steps is ==> 734000
# Episode * 368 * Avg Reward is ==> -0.9456365704536438 And Number of steps is ==> 736000
# Accident!
# Accident!
# Episode * 369 * Avg Reward is ==> -0.87114018201828 And Number of steps is ==> 738000
# Accident!
# Accident!
# Episode * 370 * Avg Reward is ==> -0.7804791927337646 And Number of steps is ==> 740000
# Accident!
# Episode * 371 * Avg Reward is ==> -0.8788875341415405 And Number of steps is ==> 742000
# Accident!
# Accident!
# Episode * 372 * Avg Reward is ==> -0.9339300394058228 And Number of steps is ==> 744000
# Accident!
# Accident!
# Episode * 373 * Avg Reward is ==> -0.8950352668762207 And Number of steps is ==> 746000
# Accident!
# Episode * 374 * Avg Reward is ==> -0.8984858393669128 And Number of steps is ==> 748000
# Accident!
# Episode * 375 * Avg Reward is ==> -0.8259684443473816 And Number of steps is ==> 750000
# Episode * 376 * Avg Reward is ==> -0.6665612459182739 And Number of steps is ==> 752000
# Accident!
# Accident!
# Episode * 377 * Avg Reward is ==> -0.6297956705093384 And Number of steps is ==> 754000
# Accident!
# Episode * 378 * Avg Reward is ==> -0.6569080352783203 And Number of steps is ==> 756000
# Accident!
# Episode * 379 * Avg Reward is ==> -0.5950711965560913 And Number of steps is ==> 758000
# Episode * 380 * Avg Reward is ==> -0.5512310862541199 And Number of steps is ==> 760000
# Episode * 381 * Avg Reward is ==> -0.44801703095436096 And Number of steps is ==> 762000
# Accident!
# Accident!
# Episode * 382 * Avg Reward is ==> -0.35739654302597046 And Number of steps is ==> 764000
# Accident!
# Episode * 383 * Avg Reward is ==> -0.4108773171901703 And Number of steps is ==> 766000
# Episode * 384 * Avg Reward is ==> -0.4015386700630188 And Number of steps is ==> 768000
# Accident!
# Accident!
# Episode * 385 * Avg Reward is ==> -0.5082713961601257 And Number of steps is ==> 770000
# Accident!
# Accident!
# Episode * 386 * Avg Reward is ==> -0.5648569464683533 And Number of steps is ==> 772000
# Episode * 387 * Avg Reward is ==> -0.5453985929489136 And Number of steps is ==> 774000
# Episode * 388 * Avg Reward is ==> -0.5125024318695068 And Number of steps is ==> 776000
# Accident!
# Episode * 389 * Avg Reward is ==> -0.47652140259742737 And Number of steps is ==> 778000
# Episode * 390 * Avg Reward is ==> -0.4717863202095032 And Number of steps is ==> 780000
# Episode * 391 * Avg Reward is ==> -0.45137014985084534 And Number of steps is ==> 782000
# Accident!
# Episode * 392 * Avg Reward is ==> -0.3845145106315613 And Number of steps is ==> 784000
# Accident!
# Episode * 393 * Avg Reward is ==> -0.3332476019859314 And Number of steps is ==> 786000
# Episode * 394 * Avg Reward is ==> -0.3084355592727661 And Number of steps is ==> 788000
# Episode * 395 * Avg Reward is ==> -0.16186538338661194 And Number of steps is ==> 790000
# Accident!
# Accident!
# Episode * 396 * Avg Reward is ==> -0.1091538667678833 And Number of steps is ==> 792000
# Accident!
# Accident!
# Episode * 397 * Avg Reward is ==> -0.06529809534549713 And Number of steps is ==> 794000
# Episode * 398 * Avg Reward is ==> 0.00408625602722168 And Number of steps is ==> 796000
# Episode * 399 * Avg Reward is ==> 0.06143386289477348 And Number of steps is ==> 798000
# Episode * 400 * Avg Reward is ==> 0.1132579818367958 And Number of steps is ==> 800000
# Episode * 401 * Avg Reward is ==> 0.1346626579761505 And Number of steps is ==> 802000
# Accident!
# Episode * 402 * Avg Reward is ==> 0.13854549825191498 And Number of steps is ==> 804000
# Episode * 403 * Avg Reward is ==> 0.177151620388031 And Number of steps is ==> 806000
# Episode * 404 * Avg Reward is ==> 0.2060205489397049 And Number of steps is ==> 808000
# Episode * 405 * Avg Reward is ==> 0.22847095131874084 And Number of steps is ==> 810000
# Episode * 406 * Avg Reward is ==> 0.25795429944992065 And Number of steps is ==> 812000
# Episode * 407 * Avg Reward is ==> 0.28170323371887207 And Number of steps is ==> 814000
# Episode * 408 * Avg Reward is ==> 0.29156407713890076 And Number of steps is ==> 816000
# Episode * 409 * Avg Reward is ==> 0.25870272517204285 And Number of steps is ==> 818000
# Accident!
# Accident!
# Episode * 410 * Avg Reward is ==> 0.2756568491458893 And Number of steps is ==> 820000
# Episode * 411 * Avg Reward is ==> 0.3190004825592041 And Number of steps is ==> 822000
# Accident!
# Episode * 412 * Avg Reward is ==> 0.3387492895126343 And Number of steps is ==> 824000
# Episode * 413 * Avg Reward is ==> 0.3535645604133606 And Number of steps is ==> 826000
# Episode * 414 * Avg Reward is ==> 0.3800930380821228 And Number of steps is ==> 828000
# Episode * 415 * Avg Reward is ==> 0.3824306130409241 And Number of steps is ==> 830000
# Episode * 416 * Avg Reward is ==> 0.3893339931964874 And Number of steps is ==> 832000
# Episode * 417 * Avg Reward is ==> 0.4071815609931946 And Number of steps is ==> 834000
# Episode * 418 * Avg Reward is ==> 0.40390849113464355 And Number of steps is ==> 836000
# Episode * 419 * Avg Reward is ==> 0.47531232237815857 And Number of steps is ==> 838000
# Episode * 420 * Avg Reward is ==> 0.4740180969238281 And Number of steps is ==> 840000
# Episode * 421 * Avg Reward is ==> 0.47918766736984253 And Number of steps is ==> 842000
# Episode * 422 * Avg Reward is ==> 0.49447956681251526 And Number of steps is ==> 844000
# Episode * 423 * Avg Reward is ==> 0.49852609634399414 And Number of steps is ==> 846000
# Episode * 424 * Avg Reward is ==> 0.48983854055404663 And Number of steps is ==> 848000
# Episode * 425 * Avg Reward is ==> 0.517169713973999 And Number of steps is ==> 850000
# Episode * 426 * Avg Reward is ==> 0.536817193031311 And Number of steps is ==> 852000
# Accident!
# Episode * 427 * Avg Reward is ==> 0.5308676362037659 And Number of steps is ==> 854000
# Episode * 428 * Avg Reward is ==> 0.5662963390350342 And Number of steps is ==> 856000
# Accident!
# Episode * 429 * Avg Reward is ==> 0.5121740102767944 And Number of steps is ==> 858000
# Episode * 430 * Avg Reward is ==> 0.4957556128501892 And Number of steps is ==> 860000
# Accident!
# Episode * 431 * Avg Reward is ==> 0.4933129847049713 And Number of steps is ==> 862000
# Episode * 432 * Avg Reward is ==> 0.5066863298416138 And Number of steps is ==> 864000
# Accident!
# Episode * 433 * Avg Reward is ==> 0.5313959121704102 And Number of steps is ==> 866000
# Episode * 434 * Avg Reward is ==> 0.5527446866035461 And Number of steps is ==> 868000
# Episode * 435 * Avg Reward is ==> 0.5530038475990295 And Number of steps is ==> 870000
# Episode * 436 * Avg Reward is ==> 0.5457867383956909 And Number of steps is ==> 872000
# Episode * 437 * Avg Reward is ==> 0.5700809359550476 And Number of steps is ==> 874000
# Episode * 438 * Avg Reward is ==> 0.5502035617828369 And Number of steps is ==> 876000
# Episode * 439 * Avg Reward is ==> 0.6043354868888855 And Number of steps is ==> 878000
# Episode * 440 * Avg Reward is ==> 0.6520124673843384 And Number of steps is ==> 880000
# Episode * 441 * Avg Reward is ==> 0.6801251173019409 And Number of steps is ==> 882000
# Episode * 442 * Avg Reward is ==> 0.6957069039344788 And Number of steps is ==> 884000
# Episode * 443 * Avg Reward is ==> 0.7061498761177063 And Number of steps is ==> 886000
# Episode * 444 * Avg Reward is ==> 0.7167505621910095 And Number of steps is ==> 888000
# Accident!
# Episode * 445 * Avg Reward is ==> 0.6675249338150024 And Number of steps is ==> 890000
# Episode * 446 * Avg Reward is ==> 0.6770248413085938 And Number of steps is ==> 892000
# Accident!
# Accident!
# Episode * 447 * Avg Reward is ==> 0.6728962063789368 And Number of steps is ==> 894000
# Episode * 448 * Avg Reward is ==> 0.7010139226913452 And Number of steps is ==> 896000
# Episode * 449 * Avg Reward is ==> 0.7057315111160278 And Number of steps is ==> 898000
# Episode * 450 * Avg Reward is ==> 0.6992709040641785 And Number of steps is ==> 900000
# Accident!
# Episode * 451 * Avg Reward is ==> 0.6840023994445801 And Number of steps is ==> 902000
# Episode * 452 * Avg Reward is ==> 0.6829332113265991 And Number of steps is ==> 904000
# Episode * 453 * Avg Reward is ==> 0.6905010342597961 And Number of steps is ==> 906000
# Episode * 454 * Avg Reward is ==> 0.6926490664482117 And Number of steps is ==> 908000
# Episode * 455 * Avg Reward is ==> 0.7546130418777466 And Number of steps is ==> 910000
# Episode * 456 * Avg Reward is ==> 0.7730041742324829 And Number of steps is ==> 912000
# Episode * 457 * Avg Reward is ==> 0.7761391401290894 And Number of steps is ==> 914000
# Episode * 458 * Avg Reward is ==> 0.7733026742935181 And Number of steps is ==> 916000
# Episode * 459 * Avg Reward is ==> 0.7568390369415283 And Number of steps is ==> 918000
# Episode * 460 * Avg Reward is ==> 0.7530044317245483 And Number of steps is ==> 920000
# Episode * 461 * Avg Reward is ==> 0.7580810189247131 And Number of steps is ==> 922000
# Episode * 462 * Avg Reward is ==> 0.7638262510299683 And Number of steps is ==> 924000
# Episode * 463 * Avg Reward is ==> 0.7644689083099365 And Number of steps is ==> 926000
# Episode * 464 * Avg Reward is ==> 0.7829810380935669 And Number of steps is ==> 928000
# Accident!
# Episode * 465 * Avg Reward is ==> 0.7848401069641113 And Number of steps is ==> 930000
# Episode * 466 * Avg Reward is ==> 0.762073278427124 And Number of steps is ==> 932000
# Episode * 467 * Avg Reward is ==> 0.7562192678451538 And Number of steps is ==> 934000
# Episode * 468 * Avg Reward is ==> 0.7606615424156189 And Number of steps is ==> 936000
# Episode * 469 * Avg Reward is ==> 0.7914329767227173 And Number of steps is ==> 938000
# Episode * 470 * Avg Reward is ==> 0.7684157490730286 And Number of steps is ==> 940000
# Episode * 471 * Avg Reward is ==> 0.7609030604362488 And Number of steps is ==> 942000
# Episode * 472 * Avg Reward is ==> 0.7710505723953247 And Number of steps is ==> 944000
# Episode * 473 * Avg Reward is ==> 0.7722170948982239 And Number of steps is ==> 946000
# Episode * 474 * Avg Reward is ==> 0.7602326273918152 And Number of steps is ==> 948000
# Episode * 475 * Avg Reward is ==> 0.7765930891036987 And Number of steps is ==> 950000
# Episode * 476 * Avg Reward is ==> 0.7962191700935364 And Number of steps is ==> 952000
# Episode * 477 * Avg Reward is ==> 0.8047831654548645 And Number of steps is ==> 954000
# Episode * 478 * Avg Reward is ==> 0.8234800100326538 And Number of steps is ==> 956000
# Episode * 479 * Avg Reward is ==> 0.816209614276886 And Number of steps is ==> 958000
# Episode * 480 * Avg Reward is ==> 0.8458952903747559 And Number of steps is ==> 960000
# Episode * 481 * Avg Reward is ==> 0.8660499453544617 And Number of steps is ==> 962000
# Episode * 482 * Avg Reward is ==> 0.86468106508255 And Number of steps is ==> 964000
# Episode * 483 * Avg Reward is ==> 0.8642005920410156 And Number of steps is ==> 966000
# Episode * 484 * Avg Reward is ==> 0.8745257258415222 And Number of steps is ==> 968000
# Episode * 485 * Avg Reward is ==> 0.8718859553337097 And Number of steps is ==> 970000
# Episode * 486 * Avg Reward is ==> 0.8655701875686646 And Number of steps is ==> 972000
# Accident!
# Episode * 487 * Avg Reward is ==> 0.8138030171394348 And Number of steps is ==> 974000
# Episode * 488 * Avg Reward is ==> 0.7904541492462158 And Number of steps is ==> 976000
# Accident!
# Accident!
# Episode * 489 * Avg Reward is ==> 0.8147485852241516 And Number of steps is ==> 978000
# Episode * 490 * Avg Reward is ==> 0.7989258170127869 And Number of steps is ==> 980000
# Episode * 491 * Avg Reward is ==> 0.7865318655967712 And Number of steps is ==> 982000
# Accident!
# Episode * 492 * Avg Reward is ==> 0.7781381607055664 And Number of steps is ==> 984000
# Accident!
# Episode * 493 * Avg Reward is ==> 0.7586859464645386 And Number of steps is ==> 986000
# Episode * 494 * Avg Reward is ==> 0.7352056503295898 And Number of steps is ==> 988000
# Episode * 495 * Avg Reward is ==> 0.725540280342102 And Number of steps is ==> 990000
# Episode * 496 * Avg Reward is ==> 0.7512345910072327 And Number of steps is ==> 992000
# Episode * 497 * Avg Reward is ==> 0.8063606023788452 And Number of steps is ==> 994000
# Episode * 498 * Avg Reward is ==> 0.8374426960945129 And Number of steps is ==> 996000
# Episode * 499 * Avg Reward is ==> 0.8336564302444458 And Number of steps is ==> 998000
# Episode * 500 * Avg Reward is ==> 0.8418362736701965 And Number of steps is ==> 1000000
# Episode * 501 * Avg Reward is ==> 0.8381654620170593 And Number of steps is ==> 1002000
# Episode * 502 * Avg Reward is ==> 0.8418809771537781 And Number of steps is ==> 1004000
# Accident!
# Episode * 503 * Avg Reward is ==> 0.844488263130188 And Number of steps is ==> 1006000
# Episode * 504 * Avg Reward is ==> 0.8431209325790405 And Number of steps is ==> 1008000
# Episode * 505 * Avg Reward is ==> 0.8244528770446777 And Number of steps is ==> 1010000
# Episode * 506 * Avg Reward is ==> 0.8138287663459778 And Number of steps is ==> 1012000
# Episode * 507 * Avg Reward is ==> 0.8022306561470032 And Number of steps is ==> 1014000
# Episode * 508 * Avg Reward is ==> 0.7634415626525879 And Number of steps is ==> 1016000
# Accident!
# Episode * 509 * Avg Reward is ==> 0.6988455653190613 And Number of steps is ==> 1018000
# Episode * 510 * Avg Reward is ==> 0.6958719491958618 And Number of steps is ==> 1020000
# Accident!
# Episode * 511 * Avg Reward is ==> 0.6513168215751648 And Number of steps is ==> 1022000
# Accident!
# Accident!
# Episode * 512 * Avg Reward is ==> 0.5940335988998413 And Number of steps is ==> 1024000
# Accident!
# Episode * 513 * Avg Reward is ==> 0.5353215932846069 And Number of steps is ==> 1026000
# Accident!
# Episode * 514 * Avg Reward is ==> 0.5367717146873474 And Number of steps is ==> 1028000
# Episode * 515 * Avg Reward is ==> 0.5641883015632629 And Number of steps is ==> 1030000
# Accident!
# Episode * 516 * Avg Reward is ==> 0.5043935775756836 And Number of steps is ==> 1032000
# Episode * 517 * Avg Reward is ==> 0.5403250455856323 And Number of steps is ==> 1034000
# Episode * 518 * Avg Reward is ==> 0.5440863370895386 And Number of steps is ==> 1036000
# Episode * 519 * Avg Reward is ==> 0.6139853596687317 And Number of steps is ==> 1038000
# Accident!
# Accident!
# Episode * 520 * Avg Reward is ==> 0.5830056071281433 And Number of steps is ==> 1040000
# Episode * 521 * Avg Reward is ==> 0.6513270139694214 And Number of steps is ==> 1042000
# Episode * 522 * Avg Reward is ==> 0.7037988901138306 And Number of steps is ==> 1044000
# Episode * 523 * Avg Reward is ==> 0.8035072088241577 And Number of steps is ==> 1046000
# Episode * 524 * Avg Reward is ==> 0.8275127410888672 And Number of steps is ==> 1048000
# Episode * 525 * Avg Reward is ==> 0.8158577084541321 And Number of steps is ==> 1050000
# Episode * 526 * Avg Reward is ==> 0.8724783062934875 And Number of steps is ==> 1052000
# Episode * 527 * Avg Reward is ==> 0.8187692761421204 And Number of steps is ==> 1054000
# Episode * 528 * Avg Reward is ==> 0.837853729724884 And Number of steps is ==> 1056000
# Accident!
# Episode * 529 * Avg Reward is ==> 0.7683786153793335 And Number of steps is ==> 1058000
# Accident!
# Episode * 530 * Avg Reward is ==> 0.7629579305648804 And Number of steps is ==> 1060000
# Episode * 531 * Avg Reward is ==> 0.7618380784988403 And Number of steps is ==> 1062000
# Accident!
# Episode * 532 * Avg Reward is ==> 0.7209672927856445 And Number of steps is ==> 1064000
# Episode * 533 * Avg Reward is ==> 0.7066611647605896 And Number of steps is ==> 1066000
# Accident!
# Episode * 534 * Avg Reward is ==> 0.6374017000198364 And Number of steps is ==> 1068000
# Accident!
# Accident!
# Episode * 535 * Avg Reward is ==> 0.5992662310600281 And Number of steps is ==> 1070000
# Accident!
# Episode * 536 * Avg Reward is ==> 0.5801597237586975 And Number of steps is ==> 1072000
# Accident!
# Episode * 537 * Avg Reward is ==> 0.6230642199516296 And Number of steps is ==> 1074000
# Episode * 538 * Avg Reward is ==> 0.6320796012878418 And Number of steps is ==> 1076000
# Accident!
# Episode * 539 * Avg Reward is ==> 0.642461895942688 And Number of steps is ==> 1078000
# Episode * 540 * Avg Reward is ==> 0.7001262903213501 And Number of steps is ==> 1080000
# Episode * 541 * Avg Reward is ==> 0.702778697013855 And Number of steps is ==> 1082000
# Episode * 542 * Avg Reward is ==> 0.757508397102356 And Number of steps is ==> 1084000
# Episode * 543 * Avg Reward is ==> 0.7420312762260437 And Number of steps is ==> 1086000
# Episode * 544 * Avg Reward is ==> 0.7992109060287476 And Number of steps is ==> 1088000
# Episode * 545 * Avg Reward is ==> 0.8359625935554504 And Number of steps is ==> 1090000
# Episode * 546 * Avg Reward is ==> 0.8686275482177734 And Number of steps is ==> 1092000
# Episode * 547 * Avg Reward is ==> 0.8702044486999512 And Number of steps is ==> 1094000
# Episode * 548 * Avg Reward is ==> 0.8719173669815063 And Number of steps is ==> 1096000
# Episode * 549 * Avg Reward is ==> 0.924822986125946 And Number of steps is ==> 1098000
# Episode * 550 * Avg Reward is ==> 0.9272658228874207 And Number of steps is ==> 1100000
# Episode * 551 * Avg Reward is ==> 0.9378030896186829 And Number of steps is ==> 1102000
# Episode * 552 * Avg Reward is ==> 0.9159955978393555 And Number of steps is ==> 1104000
# Accident!
# Episode * 553 * Avg Reward is ==> 0.8724489212036133 And Number of steps is ==> 1106000
# Episode * 554 * Avg Reward is ==> 0.8892305493354797 And Number of steps is ==> 1108000
# Accident!
# Episode * 555 * Avg Reward is ==> 0.9046176075935364 And Number of steps is ==> 1110000
# Accident!
# Episode * 556 * Avg Reward is ==> 0.8492211103439331 And Number of steps is ==> 1112000
# Episode * 557 * Avg Reward is ==> 0.8570429682731628 And Number of steps is ==> 1114000
# Episode * 558 * Avg Reward is ==> 0.8381457328796387 And Number of steps is ==> 1116000
# Episode * 559 * Avg Reward is ==> 0.8351003527641296 And Number of steps is ==> 1118000
# Episode * 560 * Avg Reward is ==> 0.809538722038269 And Number of steps is ==> 1120000
# Episode * 561 * Avg Reward is ==> 0.7908995151519775 And Number of steps is ==> 1122000
# Accident!
# Accident!
# Episode * 562 * Avg Reward is ==> 0.7060534358024597 And Number of steps is ==> 1124000
# Episode * 563 * Avg Reward is ==> 0.758048415184021 And Number of steps is ==> 1126000
# Episode * 564 * Avg Reward is ==> 0.7603727579116821 And Number of steps is ==> 1128000
# Episode * 565 * Avg Reward is ==> 0.7567833662033081 And Number of steps is ==> 1130000
# Episode * 566 * Avg Reward is ==> 0.79351407289505 And Number of steps is ==> 1132000
# Episode * 567 * Avg Reward is ==> 0.7773321270942688 And Number of steps is ==> 1134000
# Accident!
# Episode * 568 * Avg Reward is ==> 0.7682600617408752 And Number of steps is ==> 1136000
# Episode * 569 * Avg Reward is ==> 0.7556293606758118 And Number of steps is ==> 1138000
# Episode * 570 * Avg Reward is ==> 0.7799969911575317 And Number of steps is ==> 1140000
# Episode * 571 * Avg Reward is ==> 0.7706468105316162 And Number of steps is ==> 1142000
# Episode * 572 * Avg Reward is ==> 0.8660727739334106 And Number of steps is ==> 1144000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11112/3291631189.py in <module>
#       2 import time
#       3 start = time.process_time()
# ----> 4 algo.train(1000)
#       5 algo.saving()
#       6 end = time.process_time()
#
# ~\AppData\Local\Temp/ipykernel_11112/870708302.py in train(self, nb_loop)
#      36         """
#      37         for ep in range(nb_loop):
# ---> 38             state_batch,action_batch,log_prob_batch = self.rollout.iterations_rand(self.actor_net,self.cov_mat,self.batch_size)
#      39             batch_rtgs = self.rollout.futur_rewards()
#      40             #batch_rews = self.rollout.immediate_rewards()
#
# ~\AppData\Local\Temp/ipykernel_11112/3094484176.py in iterations_rand(self, actor_net, cov_mat, batch_size)
#      74                     distribution_p = MultivariateNormal(parameters_based, cov_mat)
#      75                     action = distribution_p.sample()
# ---> 76                     log_proba = distribution_p.log_prob(action)
#      77                     action_all=np.array([])
#      78                     action_all=np.append(action_all,np.clip(action[0].detach().numpy(), -1.0, 1.0))
#
# ~\Anaconda3\envs\ppotest\lib\site-packages\torch\distributions\multivariate_normal.py in log_prob(self, value)
#     206             self._validate_sample(value)
#     207         diff = value - self.loc
# --> 208         M = _batch_mahalanobis(self._unbroadcasted_scale_tril, diff)
#     209         half_log_det = self._unbroadcasted_scale_tril.diagonal(dim1=-2, dim2=-1).log().sum(-1)
#     210         return -0.5 * (self._event_shape[0] * math.log(2 * math.pi) + M) - half_log_det
#
# ~\Anaconda3\envs\ppotest\lib\site-packages\torch\distributions\multivariate_normal.py in _batch_mahalanobis(bL, bx)
#      63     for i in range(bL_batch_dims):
#      64         permute_inv_dims += [outer_batch_dims + i, old_batch_dims + i]
# ---> 65     reshaped_M = permuted_M.permute(permute_inv_dims)  # shape = (..., 1, i, j, 1)
#      66     return reshaped_M.reshape(bx_batch_shape)
#      67
#
# KeyboardInterrupt:

# %%
algo.loading(11,1000)

# %%
#Stock an evaluation sample
states, actions, rewards = algo.evaluate(1000)
ep_action=states[:,0]
ep_speed_car=states[:,1]
ep_pos_car=states[:,2]
ep_speed_ped=states[:,3]
ep_pos_ped=states[:,4]
ep_time=states[:,9]
ep_reward=rewards
t=0

# %%
#acc_param = [(self.u_b[0]-self.l_b[0])/2.0, (self.u_b[0]+self.l_b[0])/2.0]
#ep_action=acc_param[0]*torch.clip(actions,-1.,1.)+acc_param[1]

# %%
#Show general information about the final algorithm performance: average speed, CO2 emission, end-time

LDV = pd.read_csv('LDV.csv', sep=';',names=["sp","acc","step","em_name","em_val"])
LDV.pop('step')
m = LDV == 0.0
LDV['acc'] = LDV['acc'].replace(1.27676e-15,0.0)
LDV['acc'] = LDV['acc'].astype(float)
LDV_array = np.array(LDV.values)

def info_co2(states,LDV):
    """
        Evaluate the CO2 emission per episode 
        :param states: state list
        :param LDV: CO2 emission chart
    """
    t=0
    total_emission=[]
    while t+1<len(ep_time):
        t_init=t
        emission_val=[]
        while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
            acc=math.trunc(((states[t,0].item()//0.2)*0.2)*10.)/10.
            speed=math.trunc(((states[t,1].item()//0.5)*0.5)*10.)/10.
            cond=(LDV.sp==speed)&(LDV.acc==acc)&(LDV.em_name=="CO2")
            res=LDV[cond]['em_val'].item() *0.3
            emission_val.append(res)
            t+=1
        total_emission.append(torch.sum(torch.tensor(emission_val),dim=0))
        t+=1
    torch_total_emission=torch.tensor(total_emission)
    total_emission_mean=torch.mean(torch_total_emission)
    total_emission_std=torch.std(torch_total_emission)
    print("\nThe average CO2 emission is {:.2f}mg and its standard deviation is {:.2f} mg".format(total_emission_mean.item(),total_emission_std.item()))
    
def get_average(states,LDV):
    ep_time=states[:,9]
    mean_speed=torch.mean(states[:,1])
    sqrt_speed=torch.std(states[:,1])
    print("The average car speed is {:.2f} m/s and its standard deviation is {:.2f} m/s".format(mean_speed.item(),sqrt_speed.item()))
    mean_acc=torch.mean(states[:,0])
    sqrt_acc=torch.std(states[:,0])
    print("\nThe average car acceleration is {:.2f} m/s2 and its standard deviation is {:.2f} m/s2".format(mean_acc.item(),sqrt_acc.item()))
    mean_speed_p=torch.mean(states[:,3])
    sqrt_speed_p=torch.std(states[:,3])
    print("\nThe average pedestrian speed is {:.2f} m/s and its standard deviation is {:.2f} m/s".format(mean_speed_p.item(),sqrt_speed_p.item()))    
    mean_reward=torch.mean(ep_reward)
    std_reward=torch.std(ep_reward)
    print("\nThe average reward is {:.2f} and its standard deviation is {:.2f}".format(mean_reward.item(),std_reward.item()))
    info_co2(states,LDV) #CO2 info
    temps=[]
    t=0
    while t+1<len(ep_time):
        temps_i=np.array([0.,0.]) #respectively: end-time car/pedestrian
        t_init=t
        while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
            if(states[t,2]<0.0 and states[t+1,2]>=0.0):
                temps_i[0]=(t-t_init)*0.3
            if(states[t,4]<5.0 and states[t+1,4]>=5.0):
                temps_i[1]=(t-t_init)*0.3
            t+=1
        if(temps_i[1]==0.0):
            temps_i[1]=(t-t_init)*0.3
        temps.append([(t-t_init)*0.3,temps_i[0],temps_i[1]])
        t+=1
    total_temps=torch.tensor([temps]).reshape((-1,3))
    total_temps_mean=torch.mean(total_temps,dim=0)
    print("\n Average End-times:")
    print("Total: {:.2f} s".format(total_temps_mean[0].item()))
    print("Car: {:.2f} s".format(total_temps_mean[1].item()))
    print("Pedestrian: {:.2f} s".format(total_temps_mean[2].item()))
get_average(states,LDV)
# Out:
# The average car speed is 6.63 m/s and its standard deviation is 3.36 m/s
#
# The average car acceleration is -0.02 m/s2 and its standard deviation is 1.59 m/s2
#
# The average pedestrian speed is 1.00 m/s and its standard deviation is 0.36 m/s
#
# The average reward is 1.17 and its standard deviation is 2.53
#
# The average CO2 emission is 21520.81mg and its standard deviation is 10262.01 mg
#
#  Average End-times:
# Total: 10.13 s
# Car: 5.11 s
# Pedestrian: 6.51 s

# %%
#Positions des agents
t=0
plt.title("Vehicle and Pedestrian Positions versus time")
plt.xlabel("time (s)")
plt.ylabel("position (m)")
while t+1<len(ep_time):
    t_init=t
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        t+=1
    plt.plot(ep_time[t_init:t],ep_pos_car[t_init:t])
    plt.plot(ep_time[t_init:t],ep_pos_ped[t_init:t])
    plt.axhline(y=5, color='r', linestyle='-.')
    plt.axhline(y=0, color='r', linestyle='-.')
    t+=1
_=plt.axhline(y=5, color='r', linestyle='-.')
_=plt.axhline(y=0, color='r', linestyle='-.')

# %%
#Accélération, Reward, Vitesse de la voiture
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(18, 4))

t=0
ax1.set_title("Car Acceleration versus time per episode")
ax1.set_xlabel("time (s)")
ax1.set_ylabel("acceleration (m/s2)")

ax2.set_title("Reward versus time per episode")
ax2.set_xlabel("time (s)")
ax2.set_ylabel("reward")

ax3.set_title("Car Speed versus time per episode")
ax3.set_xlabel("time (s)")
ax3.set_ylabel("speed (m/s)")

ax4.set_title('Pedestrian Speed')
ax4.set_xlabel("Position (m)")
ax4.set_ylabel("Speed (m/s)")
while t+1<len(ep_time):
    t_init=t
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        t+=1
    ax1.plot(ep_time[t_init:t],ep_action[t_init:t])
    ax2.plot(ep_time[t_init:t],ep_reward[t_init:t])
    ax3.plot(ep_time[t_init:t],ep_speed_car[t_init:t])
    ax4.plot(states[t_init:t,4],states[t_init:t,3])
    t+=1

# %%
#Seperate the episodes and the different behaviors
t=0
cross_speed=[]
wait_speed=[]
cross_acc=[]
wait_acc=[]
size_wait=25
size_cross=50

while t+1<len(ep_time):
    t_init=t
    choice=False
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        choice=choice+(ep_speed_car[t]<3.0)
        t+=1

    if(choice):
        min_l=min(t-t_init,size_cross)
        return_speed=np.array(ep_speed_car[t_init:t_init+min_l])
        return_acc=np.array(states[t_init:t_init+min_l,0])
        if(min_l<size_cross):
            return_speed=np.append(return_speed,[ep_speed_car[t-1]]*(size_cross-t+t_init))
            return_acc=np.append(return_acc,[states[t-1,0]]*(size_cross-t+t_init))
        cross_speed.append(return_speed)
        cross_acc.append(return_acc)
    else:
        min_l=min(t-t_init,size_wait)
        return_speed=np.array(ep_speed_car[t_init:t_init+min_l])
        return_acc=np.array(states[t_init:t_init+min_l,0])
        if(min_l<size_wait):
            return_speed=np.append(return_speed,[ep_speed_car[t-1]]*(size_wait-t+t_init))
            return_acc=np.append(return_acc,[states[t-1,0]]*(size_wait-t+t_init))
        wait_speed.append(return_speed)
        wait_acc.append(return_acc)
    t+=1
    
cross_speed=np.array(cross_speed)
wait_speed=np.array(wait_speed)
cross_acc=np.array(cross_acc)
wait_acc=np.array(wait_acc)

# %%
x1=[0.3*i for i in range(size_cross)]
mean_speed=np.mean(cross_speed,axis=0)
std_speed=np.std(cross_speed,axis=0)
mean_acc=np.mean(cross_acc,axis=0)
std_acc=np.std(cross_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')
#fig.savefig("PDF_results/car_cross_ppo11.pdf")

# %%
x1=[0.3*i for i in range(size_wait)]
mean_speed=np.mean(wait_speed,axis=0)
std_speed=np.std(wait_speed,axis=0)
mean_acc=np.mean(wait_acc,axis=0)
std_acc=np.std(wait_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')
#fig.savefig("PDF_results/car_wait_ppo11.pdf")

# %%
def estimation_value(x1,x2,x3,y1,y3):
    a=(y3-y1)/(x3-x1)
    b=(y1*x3 - y3*x1)/(x3-x1)
    return a*x2+b

def extract_estimations(positions, parameter, start_position, end_position, step_pos):
    size_position=int((end_position-start_position)/step_pos)
    length=len(positions)
    array_cross=np.array([0.0]*size_position)
    i_step=0
    i_pos=start_position
    i=0
    while(i_pos<positions[i_step]):
        array_cross[i]=parameter[i_step]
        i=i+1
        i_pos=i_pos+0.5
    while(i_step<length and i<size_position):
        while( i_step+1<length and i_pos>positions[i_step]):
            i_step=i_step+1
        array_cross[i]=estimation_value(positions[i_step-1],i_pos,positions[i_step],parameter[i_step-1],parameter[i_step])
        i=i+1
        i_pos=i_pos+0.5
    while(i<size_position):
        array_cross[i]=parameter[i_step-1]
        i=i+1
    return array_cross

# %%
#Seperate the episodes and the different behaviors
t=0
cross_speed=[]
wait_speed=[]
cross_acc=[]
wait_acc=[]
start_position=-32.5
end_position=32.5
while t+1<len(ep_time):
    
    t_init=t
    choice=False
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        choice=choice+(ep_speed_car[t]<2.0)
        t+=1
        
    if(choice):
        return_speed=extract_estimations(ep_pos_car[t_init:t], ep_speed_car[t_init:t],start_position,end_position,0.5)
        return_acc=extract_estimations(ep_pos_car[t_init:t], ep_action[t_init:t],start_position,end_position,0.5)
        cross_speed.append(return_speed)
        cross_acc.append(return_acc)
        
    else:
        return_speed=extract_estimations(ep_pos_car[t_init:t], ep_speed_car[t_init:t],start_position,end_position,0.5)
        return_acc=extract_estimations(ep_pos_car[t_init:t], ep_action[t_init:t],start_position,end_position,0.5)
        wait_speed.append(return_speed)
        wait_acc.append(return_acc)
    t+=1
    
cross_speed=np.array(cross_speed)
wait_speed=np.array(wait_speed)
cross_acc=np.array(cross_acc)
wait_acc=np.array(wait_acc)

# %%
size_position=int((end_position-start_position)/0.5)
x1=[i*0.5+start_position for i in range(0,size_position)]
mean_speed=np.mean(cross_speed,axis=0)
std_speed=np.std(cross_speed,axis=0)
mean_acc=np.mean(cross_acc,axis=0)
std_acc=np.std(cross_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Position (m)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Position (m)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')

# %%
x1=[i*0.5+start_position for i in range(0,size_position)]
mean_speed=np.mean(wait_speed,axis=0)
std_speed=np.std(wait_speed,axis=0)
mean_acc=np.mean(wait_acc,axis=0)
std_acc=np.std(wait_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Position (m)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Position (m)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')

# %%
#Showing Vehicle Acceleration Diagram, Vehicle Speed Diagram, Vehicle and Pedestrian Position Diagram
#All three over time in an episode
#t=0
if (t+1>=len(ep_time)):
    t=0
t_init=t
while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
    t+=1
fig, (ax1, ax2, ax3) = plt.subplots(1, 3,figsize=(20, 3))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.4,2.4)
ax1.plot(ep_time[t_init:t+1],ep_action[t_init:t+1],color='r')

ax2.set_title('Car and Pedestrian Position')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Position (m)")
ax2.plot(ep_time[t_init:t],ep_pos_car[t_init:t],label='car')
ax2.plot(ep_time[t_init:t+1],ep_pos_ped[t_init:t+1],label='pedestrian')
ax2.axhline(y=5, color='r', linestyle='-.')
ax2.axhline(y=0, color='r', linestyle='-.')
ax2.legend()

ax3.set_title('Car Speed')
ax3.set_xlabel("Time (s)")
ax3.set_ylabel("Speed (m/s)")
ax3.plot(ep_time[t_init:t+1],ep_speed_car[t_init:t+1],color='r')
t+=1

# %%
plt.title('Pedestrian Speed')
plt.xlabel("Position (m)")
plt.ylabel("Speed (m/s)")
plt.plot(states[t_init:t-10,4],states[t_init:t-10,3], color='olivedrab')
#plt.savefig("PDF_results/ped_speed.pdf")
