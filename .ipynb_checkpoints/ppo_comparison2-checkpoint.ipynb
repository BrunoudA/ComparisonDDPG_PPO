# %%
#1) Import libraries
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import namedtuple, deque
import Environments
from collections import OrderedDict
from torch.distributions import MultivariateNormal
import pandas as pd

# I use the work of Eric Yu to help me build this algorithm. Link: https://github.com/ericyangyu/PPO-for-Beginners

# %%
#2) Set up Neural Network functions and classes

class Model_PPO(nn.Module):
    """
        Class: actor NN
        :param np_inputs: size input of the NN (size state)
        :param nb_outputs: size output of the NN (size action)
    """  
    def __init__(self, np_inputs, nb_outputs):
        super(Model_PPO, self).__init__()   
        self.layer1 = nn.Linear(np_inputs, 64)
        self.layer2 = nn.Linear(64, 64)
        self.layer3 = nn.Linear(64, nb_outputs)
        torch.nn.init.uniform_(self.layer3.weight,0.003, 0.006)

    def forward(self, input1):
        """
        Forward NN : compute the NN with respect the current state
        :param input1: state
        :return: output of the NN, action
        """ 
        if isinstance(input1, np.ndarray):
            input1 = torch.tensor(input1, dtype=torch.float)
        activation1 = F.relu(self.layer1(input1))
        activation2 = F.relu(self.layer2(activation1))
        output = self.layer3(activation2)
        return output

# %%
#3) Rollout on the environment:

class Env_rollout:
    """ 
        Class : iterate on the environment
        :param env: our environment
        :param max_steps: max steps per episode
    """
    def __init__(self, env, max_steps):
        self.env = env
        self.max_steps = max_steps
        self.prev_state = env.reset()
        self.batch_obs=[]
        self.batch_acts=[]
        self.batch_log_probs=[]
        self.batch_rews = []
    
    def reset(self):
        """
        Reset: reinitilization (lists et environment).
        """
        self.prev_state = env.reset()
        self.batch_obs=[]
        self.batch_acts=[]
        self.batch_log_probs=[]
        self.batch_rews = []
    
    def iterations(self,actor_net, nbr_episodes):
        """
        Iterate on the environment.
        :param actor_net: current policy (actor NN)
        :param nbr_episodes: episode number
        :return: Tensors; state batch, action batch
        """
        for ep in range(nbr_episodes):
            ep_rews = []
            prev_state = self.env.reset()
            for step_ep in range(self.max_steps): 
                with torch.no_grad():
                    action = torch.squeeze(actor_net(torch.unsqueeze(torch.tensor(prev_state), dim=0).float()))
                    if(action.dim()==0):
                        action=torch.unsqueeze(action,dim=0)
                    action_all=np.array([])
                    action_all=np.append(action_all,np.clip(action[0].detach().numpy(), -1.0, 1.0))
                    #action_all=np.append(action_all,np.argmax(action[1:4].detach().numpy()))
                    state, reward, done, _ = self.env.step(action_all)
                    self.batch_obs.append(prev_state)
                    self.batch_acts.append(action_all)
                    ep_rews.append(reward)
                    prev_state = state
                if done:
                    break
            self.batch_rews.append(ep_rews)
        return torch.tensor(self.batch_obs, dtype=torch.float), torch.tensor(self.batch_acts, dtype=torch.float)
    
    def iterations_rand(self,actor_net, cov_mat, batch_size):
        """
        Iterate on the environment.
        :param actor_net: current policy (actor NN)
        :param cov_mat: covariance matrix used for exploration
        :param batch_size: batch size
        :return: Tensors; state batch, action batch, log_proba batch
        """
        t = 0
        while t<batch_size:
            ep_rews = []
            prev_state = self.env.reset()
            for step_ep in range(self.max_steps): 
                t += 1
                with torch.no_grad():
                    parameters_based = torch.squeeze(actor_net(torch.unsqueeze(torch.tensor(prev_state), dim=0).float()))
                    if(parameters_based.dim()==0):
                        parameters_based=torch.unsqueeze(parameters_based,dim=0)
                    distribution_p = MultivariateNormal(parameters_based, cov_mat)
                    action = distribution_p.sample()
                    log_proba = distribution_p.log_prob(action)
                    action_all=np.array([])
                    action_all=np.append(action_all,np.clip(action[0].detach().numpy(), -1.0, 1.0))
                    state, reward, done, _ = self.env.step(action_all)
                    self.batch_obs.append(prev_state)
                    self.batch_acts.append(action.detach().numpy())
                    self.batch_log_probs.append(log_proba)
                    ep_rews.append(reward)
                    prev_state = state
                if done:
                    break
            self.batch_rews.append(ep_rews)
        return torch.tensor(self.batch_obs, dtype=torch.float), torch.tensor(self.batch_acts, dtype=torch.float), torch.tensor(self.batch_log_probs, dtype=torch.float)

    def immediate_rewards(self):
        """
        Immediate rewards
        :return: Tensor; batch reward
        """
        batch_rewards = []
        for ep_rews in self.batch_rews:
            for rew in reversed(ep_rews):
                batch_rewards.insert(0,rew)
        return torch.tensor(batch_rewards, dtype=torch.float)
    
    def futur_rewards(self):
        """
        Expected futures rewards
        :return: Tensor; batch reward-to-go
        """
        batch_rtgs = []
        for ep_rews in reversed(self.batch_rews):
            episodic_reward=0.0
            for rew in reversed(ep_rews):
                episodic_reward= rew + 0.99*episodic_reward
                batch_rtgs.insert(0,episodic_reward)
        return torch.tensor(batch_rtgs, dtype=torch.float)

# %%
#4) Algorithm DDPG:
class Algo_PPO():
    """ 
    PPO algorithm : training and testing
    :param policy_class: policy (actor model)
    :param env: environment
    :param hyperparameters: other hyperparameters
    """
    def __init__(self, policy_class, env, **hyperparameters):
        
        self._init_hyperparameters(hyperparameters)
        self.actor_net = policy_class(self.num_states, self.num_actions)
        self.critic_net = policy_class(self.num_states, 1)
        self.optimizer_critic = optim.Adam(self.critic_net.parameters(), self.critic_lr)
        self.optimizer_actor = optim.Adam(self.actor_net.parameters(), self.actor_lr)
        self.change_std=0.0
        self.value_std=0.5
        self.cov_var = torch.full(size=(self.num_actions,), fill_value=self.value_std)
        self.cov_mat = torch.diag(self.cov_var)
        self.rollout = Env_rollout(env, self.max_steps)
        self.ep_reward_list=[]
    
    def evaluate(self, nbr_episodes):
        """
        Testing
        :param nbr_episodes: episode number 
        :return: state batch, action batch, and reward batch
        """
        self.rollout.reset()
        state_batch, action_batch = self.rollout.iterations(self.actor_net, nbr_episodes)
        rew_batch = self.rollout.immediate_rewards()
        return state_batch, action_batch, rew_batch
        
    def train(self, nb_loop):
        """ 
        Training
        :param nb_loop: number of batch iterations
        """
        self.change_std=self.value_std/float(nb_loop)
        for ep in range(nb_loop):
            state_batch,action_batch,log_prob_batch = self.rollout.iterations_rand(self.actor_net,self.cov_mat,self.batch_size)
            batch_rtgs = self.rollout.futur_rewards()
            self.value_std=max(self.value_std-self.change_std,0.1)
            self.cov_var = torch.full(size=(self.num_actions,), fill_value=self.value_std)
            self.cov_mat = torch.diag(self.cov_var)
            self.rollout.reset()
            for i in range(10):
                V_batch = torch.squeeze(self.critic_net(state_batch))
                advantage_batch = batch_rtgs - V_batch
                advantage_batch = (advantage_batch - advantage_batch.mean()) / (advantage_batch.std() + 1e-10)
                
                parameters_batch = torch.squeeze(self.actor_net(state_batch).unsqueeze(-1))
                if(parameters_batch.dim()==1):
                        parameters_batch=torch.unsqueeze(parameters_batch,dim=1)
                distribution_p = MultivariateNormal(parameters_batch, self.cov_mat)
                log_prob_current_batch = distribution_p.log_prob(action_batch)
                ratio_batch = torch.exp(log_prob_current_batch - log_prob_batch)
                ratio_loss = torch.mul(ratio_batch,advantage_batch)
                clip_loss = torch.mul(torch.clamp(ratio_loss, 0.8, 1.2),advantage_batch)
                actor_loss = (-torch.min(ratio_loss, clip_loss)).mean()

                criterion=nn.MSELoss(reduction='mean')
                critic_loss = criterion(V_batch.float(), batch_rtgs.float())
                self.optimizer_actor.zero_grad()
                actor_loss.backward(retain_graph=True)
                self.optimizer_actor.step()
                self.optimizer_critic.zero_grad()
                critic_loss.backward()
                self.optimizer_critic.step()
                
            state_batch, action_batch = self.rollout.iterations(self.actor_net, 30)
            batch_rews = self.rollout.immediate_rewards()
            self.ep_reward_list.append(batch_rews.mean().numpy())
            avg_reward = np.mean(self.ep_reward_list[-10:])
            self.rollout.reset()
            
            print("Episode * {} * Avg Reward is ==> {} And Number of steps is ==> {}".format(ep, avg_reward,ep*self.batch_size ))
            self.total_loop= self.total_loop +1
        path='load_model/parameters/ppo-{num_algo:02d}-{name}-{epoch:03d}000.npy'
        with open(path.format(num_algo=self.num_algo,epoch=int(self.total_loop/1000),name="reward"), 'wb') as f:
            np.save(f, np.array(self.ep_reward_list))
        print("Complete")
        
    def _init_hyperparameters(self, hyperparameters):
        """
        Initialize hyperparameters. 
        :param hyperparameters: hyperparameter list
        """
        self.num_algo = 1
        self.max_steps = 90
        self.total_loop = 0
        self.batch_size = 2000
        self.gamma = 0.99
        self.critic_lr = 3e-4
        self.actor_lr = 3e-4
        for param, val in hyperparameters.items():
            exec('self.' + param + ' = ' + str(val)) #juste trop fort
            
    def loading(self, num_algo, total_loop):
        """
        Loading NN weights 
        :param num_algo: algorithm number
        :param total_loop: number of total batch iterations
        """
        self.num_algo = num_algo
        self.total_loop = total_loop
        checkpoint_path1 = "load_model/weights/torch-ppo-{num_algo:02d}-actor-{epoch:03d}0.pth"
        self.actor_net.load_state_dict(torch.load(checkpoint_path1.format(epoch=int(self.total_loop/10), num_algo=self.num_algo)))
        checkpoint_path2 = "load_model/weights/torch-ppo-{num_algo:02d}-critic-{epoch:03d}0.pth"
        self.critic_net.load_state_dict(torch.load(checkpoint_path2.format(epoch=int(self.total_loop/10), num_algo=self.num_algo)))
    
    def saving(self):
        """
        Saving NN weights 
        """
        checkpoint_path = "load_model/weights/torch-ppo-{num_algo:02d}-actor-{epoch:03d}0.pth"
        torch.save(self.actor_net.state_dict(),checkpoint_path.format(epoch=int(self.total_loop/10), num_algo=self.num_algo))
        checkpoint_path = "load_model/weights/torch-ppo-{num_algo:02d}-critic-{epoch:03d}0.pth"
        torch.save(self.critic_net.state_dict(),checkpoint_path.format(epoch=int(self.total_loop/10), num_algo=self.num_algo))

# %%
#5) Computing part:
# Import environment
problem = "Crossway_comparison-v0"
u_b = [2.0, 11.0, -12.5, 1.1, -1.0]
l_b = [-4.0, 9.0, -32.5, 0.9, -2.0]

env = gym.make(problem,dt=0.3,Vm=2.5,tau=1.0,lower_bounds=l_b, upper_bounds=u_b,simulation="sin")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the algorithm
num_states = env.observation_space.shape[0]
num_actions = env.action_space.shape[0]
num_algo=12

algo=Algo_PPO(Model_PPO, env, num_algo= num_algo, num_states=num_states, num_actions=num_actions)
#algo.loading(1,1000)

# %%
#Training
import time
start = time.time()
algo.train(1000)
algo.saving()
end = time.time()
print("Running time: "+str(end-start))
# Out:
# Accident!
# Accident!
# Accident!
# Episode * 0 * Avg Reward is ==> -6.638319492340088 And Number of steps is ==> 0
# Accident!
# Episode * 1 * Avg Reward is ==> -7.065919399261475 And Number of steps is ==> 2000
# Episode * 2 * Avg Reward is ==> -6.953853607177734 And Number of steps is ==> 4000
# Episode * 3 * Avg Reward is ==> -6.775940418243408 And Number of steps is ==> 6000
# Accident!
# Accident!
# Episode * 4 * Avg Reward is ==> -6.5488386154174805 And Number of steps is ==> 8000
# Episode * 5 * Avg Reward is ==> -6.028810024261475 And Number of steps is ==> 10000
# Accident!
# Episode * 6 * Avg Reward is ==> -5.68768310546875 And Number of steps is ==> 12000
# Accident!
# Accident!
# Episode * 7 * Avg Reward is ==> -5.554475784301758 And Number of steps is ==> 14000
# Accident!
# Episode * 8 * Avg Reward is ==> -5.625293731689453 And Number of steps is ==> 16000
# Episode * 9 * Avg Reward is ==> -5.528526306152344 And Number of steps is ==> 18000
# Episode * 10 * Avg Reward is ==> -5.350152969360352 And Number of steps is ==> 20000
# Episode * 11 * Avg Reward is ==> -5.004083156585693 And Number of steps is ==> 22000
# Episode * 12 * Avg Reward is ==> -4.604173183441162 And Number of steps is ==> 24000
# Accident!
# Episode * 13 * Avg Reward is ==> -4.430655479431152 And Number of steps is ==> 26000
# Episode * 14 * Avg Reward is ==> -4.262436389923096 And Number of steps is ==> 28000
# Accident!
# Accident!
# Accident!
# Episode * 15 * Avg Reward is ==> -4.222965717315674 And Number of steps is ==> 30000
# Episode * 16 * Avg Reward is ==> -4.057902812957764 And Number of steps is ==> 32000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 17 * Avg Reward is ==> -3.874192714691162 And Number of steps is ==> 34000
# Episode * 18 * Avg Reward is ==> -3.5051302909851074 And Number of steps is ==> 36000
# Episode * 19 * Avg Reward is ==> -3.2179322242736816 And Number of steps is ==> 38000
# Accident!
# Episode * 20 * Avg Reward is ==> -2.8755087852478027 And Number of steps is ==> 40000
# Accident!
# Episode * 21 * Avg Reward is ==> -2.722342014312744 And Number of steps is ==> 42000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 22 * Avg Reward is ==> -2.665266513824463 And Number of steps is ==> 44000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 23 * Avg Reward is ==> -2.5158751010894775 And Number of steps is ==> 46000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 24 * Avg Reward is ==> -2.31095290184021 And Number of steps is ==> 48000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 25 * Avg Reward is ==> -2.380958080291748 And Number of steps is ==> 50000
# Accident!
# Accident!
# Accident!
# Episode * 26 * Avg Reward is ==> -2.4504201412200928 And Number of steps is ==> 52000
# Episode * 27 * Avg Reward is ==> -2.3488123416900635 And Number of steps is ==> 54000
# Accident!
# Accident!
# Accident!
# Episode * 28 * Avg Reward is ==> -2.347418785095215 And Number of steps is ==> 56000
# Accident!
# Accident!
# Episode * 29 * Avg Reward is ==> -2.333768606185913 And Number of steps is ==> 58000
# Accident!
# Accident!
# Episode * 30 * Avg Reward is ==> -2.3400964736938477 And Number of steps is ==> 60000
# Accident!
# Accident!
# Episode * 31 * Avg Reward is ==> -2.221625566482544 And Number of steps is ==> 62000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 32 * Avg Reward is ==> -2.180187463760376 And Number of steps is ==> 64000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 33 * Avg Reward is ==> -2.0116453170776367 And Number of steps is ==> 66000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 34 * Avg Reward is ==> -2.3039393424987793 And Number of steps is ==> 68000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 35 * Avg Reward is ==> -2.3087973594665527 And Number of steps is ==> 70000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 36 * Avg Reward is ==> -2.3086304664611816 And Number of steps is ==> 72000
# Episode * 37 * Avg Reward is ==> -2.2018585205078125 And Number of steps is ==> 74000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 38 * Avg Reward is ==> -2.1679627895355225 And Number of steps is ==> 76000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 39 * Avg Reward is ==> -2.2955586910247803 And Number of steps is ==> 78000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 40 * Avg Reward is ==> -2.3817620277404785 And Number of steps is ==> 80000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 41 * Avg Reward is ==> -2.545546531677246 And Number of steps is ==> 82000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 42 * Avg Reward is ==> -2.5561530590057373 And Number of steps is ==> 84000
# Accident!
# Episode * 43 * Avg Reward is ==> -2.541553020477295 And Number of steps is ==> 86000
# Accident!
# Accident!
# Accident!
# Episode * 44 * Avg Reward is ==> -2.182920455932617 And Number of steps is ==> 88000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 45 * Avg Reward is ==> -2.0573325157165527 And Number of steps is ==> 90000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 46 * Avg Reward is ==> -1.9865127801895142 And Number of steps is ==> 92000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 47 * Avg Reward is ==> -2.096831798553467 And Number of steps is ==> 94000
# Accident!
# Accident!
# Accident!
# Episode * 48 * Avg Reward is ==> -2.180161714553833 And Number of steps is ==> 96000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 49 * Avg Reward is ==> -2.0816097259521484 And Number of steps is ==> 98000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 50 * Avg Reward is ==> -2.0657172203063965 And Number of steps is ==> 100000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 51 * Avg Reward is ==> -2.677570104598999 And Number of steps is ==> 102000
# Accident!
# Episode * 52 * Avg Reward is ==> -3.06779146194458 And Number of steps is ==> 104000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 53 * Avg Reward is ==> -2.977318286895752 And Number of steps is ==> 106000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 54 * Avg Reward is ==> -3.010222911834717 And Number of steps is ==> 108000
# Accident!
# Accident!
# Accident!
# Episode * 55 * Avg Reward is ==> -2.8389477729797363 And Number of steps is ==> 110000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 56 * Avg Reward is ==> -2.8255507946014404 And Number of steps is ==> 112000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 57 * Avg Reward is ==> -2.7282824516296387 And Number of steps is ==> 114000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 58 * Avg Reward is ==> -2.60719633102417 And Number of steps is ==> 116000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 59 * Avg Reward is ==> -2.5345427989959717 And Number of steps is ==> 118000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 60 * Avg Reward is ==> -2.822502613067627 And Number of steps is ==> 120000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 61 * Avg Reward is ==> -2.176359176635742 And Number of steps is ==> 122000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 62 * Avg Reward is ==> -1.9586284160614014 And Number of steps is ==> 124000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 63 * Avg Reward is ==> -2.176685094833374 And Number of steps is ==> 126000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 64 * Avg Reward is ==> -2.179943561553955 And Number of steps is ==> 128000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 65 * Avg Reward is ==> -2.282487154006958 And Number of steps is ==> 130000
# Accident!
# Accident!
# Accident!
# Episode * 66 * Avg Reward is ==> -2.3706488609313965 And Number of steps is ==> 132000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 67 * Avg Reward is ==> -2.514029026031494 And Number of steps is ==> 134000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 68 * Avg Reward is ==> -2.3610987663269043 And Number of steps is ==> 136000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 69 * Avg Reward is ==> -2.525818347930908 And Number of steps is ==> 138000
# Accident!
# Accident!
# Episode * 70 * Avg Reward is ==> -2.179809093475342 And Number of steps is ==> 140000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 71 * Avg Reward is ==> -1.9916772842407227 And Number of steps is ==> 142000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 72 * Avg Reward is ==> -1.7342817783355713 And Number of steps is ==> 144000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 73 * Avg Reward is ==> -1.5526812076568604 And Number of steps is ==> 146000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 74 * Avg Reward is ==> -1.3971927165985107 And Number of steps is ==> 148000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 75 * Avg Reward is ==> -1.3211145401000977 And Number of steps is ==> 150000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 76 * Avg Reward is ==> -1.0969804525375366 And Number of steps is ==> 152000
# Accident!
# Accident!
# Accident!
# Episode * 77 * Avg Reward is ==> -0.9340351223945618 And Number of steps is ==> 154000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 78 * Avg Reward is ==> -0.9838182330131531 And Number of steps is ==> 156000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 79 * Avg Reward is ==> -0.824168860912323 And Number of steps is ==> 158000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 80 * Avg Reward is ==> -0.7715495228767395 And Number of steps is ==> 160000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 81 * Avg Reward is ==> -0.7258683443069458 And Number of steps is ==> 162000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 82 * Avg Reward is ==> -0.6805160045623779 And Number of steps is ==> 164000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 83 * Avg Reward is ==> -0.614719033241272 And Number of steps is ==> 166000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 84 * Avg Reward is ==> -0.5901792645454407 And Number of steps is ==> 168000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 85 * Avg Reward is ==> -0.5874167084693909 And Number of steps is ==> 170000
# Accident!
# Accident!
# Episode * 86 * Avg Reward is ==> -0.6052999496459961 And Number of steps is ==> 172000
# Accident!
# Accident!
# Accident!
# Episode * 87 * Avg Reward is ==> -0.5788425207138062 And Number of steps is ==> 174000
# Accident!
# Accident!
# Episode * 88 * Avg Reward is ==> -0.5276081562042236 And Number of steps is ==> 176000
# Accident!
# Accident!
# Accident!
# Episode * 89 * Avg Reward is ==> -0.4356256425380707 And Number of steps is ==> 178000
# Accident!
# Accident!
# Episode * 90 * Avg Reward is ==> -0.3454362750053406 And Number of steps is ==> 180000
# Accident!
# Accident!
# Episode * 91 * Avg Reward is ==> -0.38917359709739685 And Number of steps is ==> 182000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 92 * Avg Reward is ==> -0.34120720624923706 And Number of steps is ==> 184000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 93 * Avg Reward is ==> -0.3699861168861389 And Number of steps is ==> 186000
# Accident!
# Accident!
# Episode * 94 * Avg Reward is ==> -0.44133782386779785 And Number of steps is ==> 188000
# Episode * 95 * Avg Reward is ==> -0.3227681517601013 And Number of steps is ==> 190000
# Accident!
# Accident!
# Accident!
# Episode * 96 * Avg Reward is ==> -0.25105518102645874 And Number of steps is ==> 192000
# Accident!
# Accident!
# Episode * 97 * Avg Reward is ==> -0.25163203477859497 And Number of steps is ==> 194000
# Accident!
# Accident!
# Accident!
# Episode * 98 * Avg Reward is ==> -0.3101518750190735 And Number of steps is ==> 196000
# Episode * 99 * Avg Reward is ==> -0.35761263966560364 And Number of steps is ==> 198000
# Episode * 100 * Avg Reward is ==> -0.40597572922706604 And Number of steps is ==> 200000
# Accident!
# Episode * 101 * Avg Reward is ==> -0.3656125068664551 And Number of steps is ==> 202000
# Accident!
# Accident!
# Episode * 102 * Avg Reward is ==> -0.3194783329963684 And Number of steps is ==> 204000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 103 * Avg Reward is ==> -0.37754014134407043 And Number of steps is ==> 206000
# Accident!
# Accident!
# Episode * 104 * Avg Reward is ==> -0.27971914410591125 And Number of steps is ==> 208000
# Episode * 105 * Avg Reward is ==> -0.2393849641084671 And Number of steps is ==> 210000
# Accident!
# Accident!
# Episode * 106 * Avg Reward is ==> -0.1907908320426941 And Number of steps is ==> 212000
# Accident!
# Accident!
# Episode * 107 * Avg Reward is ==> -0.11709139496088028 And Number of steps is ==> 214000
# Accident!
# Accident!
# Episode * 108 * Avg Reward is ==> -0.06257738173007965 And Number of steps is ==> 216000
# Accident!
# Accident!
# Episode * 109 * Avg Reward is ==> -0.015147864818572998 And Number of steps is ==> 218000
# Accident!
# Accident!
# Accident!
# Episode * 110 * Avg Reward is ==> 0.07080180943012238 And Number of steps is ==> 220000
# Accident!
# Accident!
# Accident!
# Episode * 111 * Avg Reward is ==> 0.08103666454553604 And Number of steps is ==> 222000
# Episode * 112 * Avg Reward is ==> 0.10142260789871216 And Number of steps is ==> 224000
# Accident!
# Accident!
# Episode * 113 * Avg Reward is ==> 0.23380272090435028 And Number of steps is ==> 226000
# Accident!
# Episode * 114 * Avg Reward is ==> 0.18970121443271637 And Number of steps is ==> 228000
# Accident!
# Episode * 115 * Avg Reward is ==> 0.20179614424705505 And Number of steps is ==> 230000
# Accident!
# Accident!
# Accident!
# Episode * 116 * Avg Reward is ==> 0.22467437386512756 And Number of steps is ==> 232000
# Episode * 117 * Avg Reward is ==> 0.2636220455169678 And Number of steps is ==> 234000
# Accident!
# Accident!
# Episode * 118 * Avg Reward is ==> 0.3615263104438782 And Number of steps is ==> 236000
# Accident!
# Accident!
# Episode * 119 * Avg Reward is ==> 0.45559611916542053 And Number of steps is ==> 238000
# Accident!
# Episode * 120 * Avg Reward is ==> 0.47413697838783264 And Number of steps is ==> 240000
# Episode * 121 * Avg Reward is ==> 0.5417985320091248 And Number of steps is ==> 242000
# Episode * 122 * Avg Reward is ==> 0.5147456526756287 And Number of steps is ==> 244000
# Episode * 123 * Avg Reward is ==> 0.5281828045845032 And Number of steps is ==> 246000
# Accident!
# Episode * 124 * Avg Reward is ==> 0.5515937805175781 And Number of steps is ==> 248000
# Episode * 125 * Avg Reward is ==> 0.5667912364006042 And Number of steps is ==> 250000
# Accident!
# Episode * 126 * Avg Reward is ==> 0.5201413035392761 And Number of steps is ==> 252000
# Accident!
# Episode * 127 * Avg Reward is ==> 0.5160804390907288 And Number of steps is ==> 254000
# Accident!
# Accident!
# Episode * 128 * Avg Reward is ==> 0.5231720209121704 And Number of steps is ==> 256000
# Episode * 129 * Avg Reward is ==> 0.544065535068512 And Number of steps is ==> 258000
# Episode * 130 * Avg Reward is ==> 0.5674675703048706 And Number of steps is ==> 260000
# Episode * 131 * Avg Reward is ==> 0.5864619016647339 And Number of steps is ==> 262000
# Accident!
# Episode * 132 * Avg Reward is ==> 0.6363116502761841 And Number of steps is ==> 264000
# Accident!
# Episode * 133 * Avg Reward is ==> 0.6255778074264526 And Number of steps is ==> 266000
# Episode * 134 * Avg Reward is ==> 0.6918266415596008 And Number of steps is ==> 268000
# Episode * 135 * Avg Reward is ==> 0.6991527080535889 And Number of steps is ==> 270000
# Episode * 136 * Avg Reward is ==> 0.751833438873291 And Number of steps is ==> 272000
# Episode * 137 * Avg Reward is ==> 0.7662907838821411 And Number of steps is ==> 274000
# Accident!
# Episode * 138 * Avg Reward is ==> 0.7858158946037292 And Number of steps is ==> 276000
# Episode * 139 * Avg Reward is ==> 0.7973123788833618 And Number of steps is ==> 278000
# Episode * 140 * Avg Reward is ==> 0.8259608149528503 And Number of steps is ==> 280000
# Episode * 141 * Avg Reward is ==> 0.8635117411613464 And Number of steps is ==> 282000
# Accident!
# Accident!
# Accident!
# Episode * 142 * Avg Reward is ==> 0.888405442237854 And Number of steps is ==> 284000
# Episode * 143 * Avg Reward is ==> 0.9274789094924927 And Number of steps is ==> 286000
# Episode * 144 * Avg Reward is ==> 0.9165397882461548 And Number of steps is ==> 288000
# Accident!
# Episode * 145 * Avg Reward is ==> 0.8543475270271301 And Number of steps is ==> 290000
# Accident!
# Episode * 146 * Avg Reward is ==> 0.8121886253356934 And Number of steps is ==> 292000
# Accident!
# Episode * 147 * Avg Reward is ==> 0.806240439414978 And Number of steps is ==> 294000
# Accident!
# Episode * 148 * Avg Reward is ==> 0.782526969909668 And Number of steps is ==> 296000
# Episode * 149 * Avg Reward is ==> 0.7689312100410461 And Number of steps is ==> 298000
# Accident!
# Episode * 150 * Avg Reward is ==> 0.7001654505729675 And Number of steps is ==> 300000
# Episode * 151 * Avg Reward is ==> 0.688754141330719 And Number of steps is ==> 302000
# Accident!
# Episode * 152 * Avg Reward is ==> 0.5948749780654907 And Number of steps is ==> 304000
# Accident!
# Episode * 153 * Avg Reward is ==> 0.5737336874008179 And Number of steps is ==> 306000
# Accident!
# Episode * 154 * Avg Reward is ==> 0.5098657011985779 And Number of steps is ==> 308000
# Accident!
# Accident!
# Episode * 155 * Avg Reward is ==> 0.48974665999412537 And Number of steps is ==> 310000
# Accident!
# Episode * 156 * Avg Reward is ==> 0.4675441384315491 And Number of steps is ==> 312000
# Accident!
# Accident!
# Episode * 157 * Avg Reward is ==> 0.4210318624973297 And Number of steps is ==> 314000
# Episode * 158 * Avg Reward is ==> 0.43004417419433594 And Number of steps is ==> 316000
# Episode * 159 * Avg Reward is ==> 0.42987045645713806 And Number of steps is ==> 318000
# Episode * 160 * Avg Reward is ==> 0.5051454901695251 And Number of steps is ==> 320000
# Accident!
# Episode * 161 * Avg Reward is ==> 0.48063379526138306 And Number of steps is ==> 322000
# Episode * 162 * Avg Reward is ==> 0.55455082654953 And Number of steps is ==> 324000
# Episode * 163 * Avg Reward is ==> 0.566120445728302 And Number of steps is ==> 326000
# Episode * 164 * Avg Reward is ==> 0.6628208160400391 And Number of steps is ==> 328000
# Accident!
# Episode * 165 * Avg Reward is ==> 0.7443526983261108 And Number of steps is ==> 330000
# Episode * 166 * Avg Reward is ==> 0.8141493797302246 And Number of steps is ==> 332000
# Accident!
# Episode * 167 * Avg Reward is ==> 0.8699542880058289 And Number of steps is ==> 334000
# Accident!
# Episode * 168 * Avg Reward is ==> 0.8689765930175781 And Number of steps is ==> 336000
# Episode * 169 * Avg Reward is ==> 0.8724434971809387 And Number of steps is ==> 338000
# Episode * 170 * Avg Reward is ==> 0.8487740755081177 And Number of steps is ==> 340000
# Episode * 171 * Avg Reward is ==> 0.8570387959480286 And Number of steps is ==> 342000
# Episode * 172 * Avg Reward is ==> 0.8533931970596313 And Number of steps is ==> 344000
# Accident!
# Episode * 173 * Avg Reward is ==> 0.7719799280166626 And Number of steps is ==> 346000
# Accident!
# Episode * 174 * Avg Reward is ==> 0.7001243233680725 And Number of steps is ==> 348000
# Accident!
# Episode * 175 * Avg Reward is ==> 0.6720214486122131 And Number of steps is ==> 350000
# Accident!
# Episode * 176 * Avg Reward is ==> 0.6000611186027527 And Number of steps is ==> 352000
# Episode * 177 * Avg Reward is ==> 0.5895271897315979 And Number of steps is ==> 354000
# Accident!
# Episode * 178 * Avg Reward is ==> 0.5741173028945923 And Number of steps is ==> 356000
# Episode * 179 * Avg Reward is ==> 0.5676193833351135 And Number of steps is ==> 358000
# Accident!
# Episode * 180 * Avg Reward is ==> 0.5170222520828247 And Number of steps is ==> 360000
# Accident!
# Episode * 181 * Avg Reward is ==> 0.49763792753219604 And Number of steps is ==> 362000
# Episode * 182 * Avg Reward is ==> 0.4669881761074066 And Number of steps is ==> 364000
# Accident!
# Episode * 183 * Avg Reward is ==> 0.496244341135025 And Number of steps is ==> 366000
# Episode * 184 * Avg Reward is ==> 0.5150848627090454 And Number of steps is ==> 368000
# Episode * 185 * Avg Reward is ==> 0.5245855450630188 And Number of steps is ==> 370000
# Episode * 186 * Avg Reward is ==> 0.5621125102043152 And Number of steps is ==> 372000
# Episode * 187 * Avg Reward is ==> 0.5530787706375122 And Number of steps is ==> 374000
# Episode * 188 * Avg Reward is ==> 0.5640779733657837 And Number of steps is ==> 376000
# Episode * 189 * Avg Reward is ==> 0.5710991024971008 And Number of steps is ==> 378000
# Episode * 190 * Avg Reward is ==> 0.6388174891471863 And Number of steps is ==> 380000
# Episode * 191 * Avg Reward is ==> 0.6622118949890137 And Number of steps is ==> 382000
# Accident!
# Episode * 192 * Avg Reward is ==> 0.6375051140785217 And Number of steps is ==> 384000
# Accident!
# Episode * 193 * Avg Reward is ==> 0.6961614489555359 And Number of steps is ==> 386000
# Episode * 194 * Avg Reward is ==> 0.7142637968063354 And Number of steps is ==> 388000
# Episode * 195 * Avg Reward is ==> 0.7255481481552124 And Number of steps is ==> 390000
# Accident!
# Episode * 196 * Avg Reward is ==> 0.6969254016876221 And Number of steps is ==> 392000
# Episode * 197 * Avg Reward is ==> 0.7164124250411987 And Number of steps is ==> 394000
# Accident!
# Episode * 198 * Avg Reward is ==> 0.705306887626648 And Number of steps is ==> 396000
# Episode * 199 * Avg Reward is ==> 0.6955472230911255 And Number of steps is ==> 398000
# Episode * 200 * Avg Reward is ==> 0.6765916347503662 And Number of steps is ==> 400000
# Episode * 201 * Avg Reward is ==> 0.6639222502708435 And Number of steps is ==> 402000
# Episode * 202 * Avg Reward is ==> 0.7162136435508728 And Number of steps is ==> 404000
# Episode * 203 * Avg Reward is ==> 0.7104640603065491 And Number of steps is ==> 406000
# Episode * 204 * Avg Reward is ==> 0.724629282951355 And Number of steps is ==> 408000
# Episode * 205 * Avg Reward is ==> 0.7364320755004883 And Number of steps is ==> 410000
# Episode * 206 * Avg Reward is ==> 0.803907036781311 And Number of steps is ==> 412000
# Episode * 207 * Avg Reward is ==> 0.8048154711723328 And Number of steps is ==> 414000
# Episode * 208 * Avg Reward is ==> 0.8315424919128418 And Number of steps is ==> 416000
# Accident!
# Episode * 209 * Avg Reward is ==> 0.841766357421875 And Number of steps is ==> 418000
# Episode * 210 * Avg Reward is ==> 0.8391793966293335 And Number of steps is ==> 420000
# Episode * 211 * Avg Reward is ==> 0.8491876721382141 And Number of steps is ==> 422000
# Episode * 212 * Avg Reward is ==> 0.8629080057144165 And Number of steps is ==> 424000
# Episode * 213 * Avg Reward is ==> 0.8622080683708191 And Number of steps is ==> 426000
# Episode * 214 * Avg Reward is ==> 0.8697148561477661 And Number of steps is ==> 428000
# Episode * 215 * Avg Reward is ==> 0.8651048541069031 And Number of steps is ==> 430000
# Episode * 216 * Avg Reward is ==> 0.8645941615104675 And Number of steps is ==> 432000
# Episode * 217 * Avg Reward is ==> 0.8687968254089355 And Number of steps is ==> 434000
# Episode * 218 * Avg Reward is ==> 0.8488517999649048 And Number of steps is ==> 436000
# Episode * 219 * Avg Reward is ==> 0.8535928726196289 And Number of steps is ==> 438000
# Episode * 220 * Avg Reward is ==> 0.8685128092765808 And Number of steps is ==> 440000
# Episode * 221 * Avg Reward is ==> 0.8761900663375854 And Number of steps is ==> 442000
# Episode * 222 * Avg Reward is ==> 0.8717037439346313 And Number of steps is ==> 444000
# Accident!
# Episode * 223 * Avg Reward is ==> 0.8268338441848755 And Number of steps is ==> 446000
# Episode * 224 * Avg Reward is ==> 0.8084328770637512 And Number of steps is ==> 448000
# Episode * 225 * Avg Reward is ==> 0.8157702684402466 And Number of steps is ==> 450000
# Episode * 226 * Avg Reward is ==> 0.8054108619689941 And Number of steps is ==> 452000
# Accident!
# Episode * 227 * Avg Reward is ==> 0.7471901774406433 And Number of steps is ==> 454000
# Accident!
# Episode * 228 * Avg Reward is ==> 0.7532525062561035 And Number of steps is ==> 456000
# Accident!
# Episode * 229 * Avg Reward is ==> 0.6994435787200928 And Number of steps is ==> 458000
# Accident!
# Episode * 230 * Avg Reward is ==> 0.7262459397315979 And Number of steps is ==> 460000
# Episode * 231 * Avg Reward is ==> 0.7129595279693604 And Number of steps is ==> 462000
# Episode * 232 * Avg Reward is ==> 0.7131305932998657 And Number of steps is ==> 464000
# Episode * 233 * Avg Reward is ==> 0.7624754905700684 And Number of steps is ==> 466000
# Episode * 234 * Avg Reward is ==> 0.7710350751876831 And Number of steps is ==> 468000
# Episode * 235 * Avg Reward is ==> 0.7610721588134766 And Number of steps is ==> 470000
# Episode * 236 * Avg Reward is ==> 0.7597600221633911 And Number of steps is ==> 472000
# Episode * 237 * Avg Reward is ==> 0.8014358282089233 And Number of steps is ==> 474000
# Episode * 238 * Avg Reward is ==> 0.8094216585159302 And Number of steps is ==> 476000
# Episode * 239 * Avg Reward is ==> 0.8725902438163757 And Number of steps is ==> 478000
# Episode * 240 * Avg Reward is ==> 0.848624050617218 And Number of steps is ==> 480000
# Episode * 241 * Avg Reward is ==> 0.8628525733947754 And Number of steps is ==> 482000
# Episode * 242 * Avg Reward is ==> 0.8640670776367188 And Number of steps is ==> 484000
# Episode * 243 * Avg Reward is ==> 0.8843613862991333 And Number of steps is ==> 486000
# Episode * 244 * Avg Reward is ==> 0.8683171272277832 And Number of steps is ==> 488000
# Episode * 245 * Avg Reward is ==> 0.8617204427719116 And Number of steps is ==> 490000
# Episode * 246 * Avg Reward is ==> 0.8753589391708374 And Number of steps is ==> 492000
# Episode * 247 * Avg Reward is ==> 0.8972816467285156 And Number of steps is ==> 494000
# Episode * 248 * Avg Reward is ==> 0.8824726343154907 And Number of steps is ==> 496000
# Episode * 249 * Avg Reward is ==> 0.8656220436096191 And Number of steps is ==> 498000
# Episode * 250 * Avg Reward is ==> 0.8801237344741821 And Number of steps is ==> 500000
# Episode * 251 * Avg Reward is ==> 0.88566654920578 And Number of steps is ==> 502000
# Episode * 252 * Avg Reward is ==> 0.8967059254646301 And Number of steps is ==> 504000
# Episode * 253 * Avg Reward is ==> 0.9016004800796509 And Number of steps is ==> 506000
# Episode * 254 * Avg Reward is ==> 0.9204561114311218 And Number of steps is ==> 508000
# Accident!
# Episode * 255 * Avg Reward is ==> 0.8737446665763855 And Number of steps is ==> 510000
# Episode * 256 * Avg Reward is ==> 0.8645583391189575 And Number of steps is ==> 512000
# Episode * 257 * Avg Reward is ==> 0.8558584451675415 And Number of steps is ==> 514000
# Episode * 258 * Avg Reward is ==> 0.8588116765022278 And Number of steps is ==> 516000
# Episode * 259 * Avg Reward is ==> 0.8686453700065613 And Number of steps is ==> 518000
# Episode * 260 * Avg Reward is ==> 0.8515785932540894 And Number of steps is ==> 520000
# Episode * 261 * Avg Reward is ==> 0.8446618318557739 And Number of steps is ==> 522000
# Episode * 262 * Avg Reward is ==> 0.8255170583724976 And Number of steps is ==> 524000
# Episode * 263 * Avg Reward is ==> 0.7909356355667114 And Number of steps is ==> 526000
# Episode * 264 * Avg Reward is ==> 0.7890470027923584 And Number of steps is ==> 528000
# Episode * 265 * Avg Reward is ==> 0.8852764964103699 And Number of steps is ==> 530000
# Episode * 266 * Avg Reward is ==> 0.9000818133354187 And Number of steps is ==> 532000
# Episode * 267 * Avg Reward is ==> 0.8952967524528503 And Number of steps is ==> 534000
# Episode * 268 * Avg Reward is ==> 0.9137155413627625 And Number of steps is ==> 536000
# Episode * 269 * Avg Reward is ==> 0.9170625805854797 And Number of steps is ==> 538000
# Episode * 270 * Avg Reward is ==> 0.9404296875 And Number of steps is ==> 540000
# Episode * 271 * Avg Reward is ==> 0.959062397480011 And Number of steps is ==> 542000
# Episode * 272 * Avg Reward is ==> 0.9773688316345215 And Number of steps is ==> 544000
# Episode * 273 * Avg Reward is ==> 0.993850827217102 And Number of steps is ==> 546000
# Episode * 274 * Avg Reward is ==> 0.986157238483429 And Number of steps is ==> 548000
# Episode * 275 * Avg Reward is ==> 0.9526567459106445 And Number of steps is ==> 550000
# Episode * 276 * Avg Reward is ==> 0.9421588182449341 And Number of steps is ==> 552000
# Episode * 277 * Avg Reward is ==> 0.9381281137466431 And Number of steps is ==> 554000
# Episode * 278 * Avg Reward is ==> 0.9253591299057007 And Number of steps is ==> 556000
# Episode * 279 * Avg Reward is ==> 0.9177988767623901 And Number of steps is ==> 558000
# Episode * 280 * Avg Reward is ==> 0.9051191210746765 And Number of steps is ==> 560000
# Episode * 281 * Avg Reward is ==> 0.8909484148025513 And Number of steps is ==> 562000
# Accident!
# Episode * 282 * Avg Reward is ==> 0.8181706666946411 And Number of steps is ==> 564000
# Accident!
# Episode * 283 * Avg Reward is ==> 0.8137938380241394 And Number of steps is ==> 566000
# Episode * 284 * Avg Reward is ==> 0.8220130205154419 And Number of steps is ==> 568000
# Episode * 285 * Avg Reward is ==> 0.8125807046890259 And Number of steps is ==> 570000
# Episode * 286 * Avg Reward is ==> 0.8072562217712402 And Number of steps is ==> 572000
# Episode * 287 * Avg Reward is ==> 0.8143042325973511 And Number of steps is ==> 574000
# Episode * 288 * Avg Reward is ==> 0.8353574872016907 And Number of steps is ==> 576000
# Episode * 289 * Avg Reward is ==> 0.836779773235321 And Number of steps is ==> 578000
# Episode * 290 * Avg Reward is ==> 0.8292909860610962 And Number of steps is ==> 580000
# Episode * 291 * Avg Reward is ==> 0.8505474328994751 And Number of steps is ==> 582000
# Episode * 292 * Avg Reward is ==> 0.9047859311103821 And Number of steps is ==> 584000
# Episode * 293 * Avg Reward is ==> 0.8964737057685852 And Number of steps is ==> 586000
# Episode * 294 * Avg Reward is ==> 0.9030643701553345 And Number of steps is ==> 588000
# Episode * 295 * Avg Reward is ==> 0.9137288928031921 And Number of steps is ==> 590000
# Episode * 296 * Avg Reward is ==> 0.926214337348938 And Number of steps is ==> 592000
# Episode * 297 * Avg Reward is ==> 0.9258265495300293 And Number of steps is ==> 594000
# Episode * 298 * Avg Reward is ==> 0.9145095944404602 And Number of steps is ==> 596000
# Episode * 299 * Avg Reward is ==> 0.9383899569511414 And Number of steps is ==> 598000
# Episode * 300 * Avg Reward is ==> 0.949192225933075 And Number of steps is ==> 600000
# Episode * 301 * Avg Reward is ==> 0.9356980323791504 And Number of steps is ==> 602000
# Episode * 302 * Avg Reward is ==> 0.9430774450302124 And Number of steps is ==> 604000
# Episode * 303 * Avg Reward is ==> 0.9656573534011841 And Number of steps is ==> 606000
# Episode * 304 * Avg Reward is ==> 0.963448703289032 And Number of steps is ==> 608000
# Episode * 305 * Avg Reward is ==> 0.9762592315673828 And Number of steps is ==> 610000
# Accident!
# Episode * 306 * Avg Reward is ==> 0.9734500050544739 And Number of steps is ==> 612000
# Episode * 307 * Avg Reward is ==> 0.9917697906494141 And Number of steps is ==> 614000
# Episode * 308 * Avg Reward is ==> 1.0172786712646484 And Number of steps is ==> 616000
# Accident!
# Episode * 309 * Avg Reward is ==> 0.9888399243354797 And Number of steps is ==> 618000
# Episode * 310 * Avg Reward is ==> 0.9906072616577148 And Number of steps is ==> 620000
# Episode * 311 * Avg Reward is ==> 0.9907204508781433 And Number of steps is ==> 622000
# Episode * 312 * Avg Reward is ==> 1.0026285648345947 And Number of steps is ==> 624000
# Accident!
# Episode * 313 * Avg Reward is ==> 0.9979797601699829 And Number of steps is ==> 626000
# Episode * 314 * Avg Reward is ==> 0.997874915599823 And Number of steps is ==> 628000
# Episode * 315 * Avg Reward is ==> 0.9987345933914185 And Number of steps is ==> 630000
# Episode * 316 * Avg Reward is ==> 1.007137417793274 And Number of steps is ==> 632000
# Episode * 317 * Avg Reward is ==> 0.9978252649307251 And Number of steps is ==> 634000
# Episode * 318 * Avg Reward is ==> 0.9944551587104797 And Number of steps is ==> 636000
# Episode * 319 * Avg Reward is ==> 1.021917700767517 And Number of steps is ==> 638000
# Accident!
# Episode * 320 * Avg Reward is ==> 0.9637635946273804 And Number of steps is ==> 640000
# Episode * 321 * Avg Reward is ==> 0.9713306427001953 And Number of steps is ==> 642000
# Episode * 322 * Avg Reward is ==> 0.9780226945877075 And Number of steps is ==> 644000
# Episode * 323 * Avg Reward is ==> 0.9956209063529968 And Number of steps is ==> 646000
# Episode * 324 * Avg Reward is ==> 0.9818738698959351 And Number of steps is ==> 648000
# Episode * 325 * Avg Reward is ==> 0.9727241396903992 And Number of steps is ==> 650000
# Episode * 326 * Avg Reward is ==> 0.9765604734420776 And Number of steps is ==> 652000
# Episode * 327 * Avg Reward is ==> 0.9897276163101196 And Number of steps is ==> 654000
# Episode * 328 * Avg Reward is ==> 0.9930647015571594 And Number of steps is ==> 656000
# Episode * 329 * Avg Reward is ==> 0.9853470921516418 And Number of steps is ==> 658000
# Episode * 330 * Avg Reward is ==> 1.0425894260406494 And Number of steps is ==> 660000
# Episode * 331 * Avg Reward is ==> 1.040677785873413 And Number of steps is ==> 662000
# Episode * 332 * Avg Reward is ==> 1.0436335802078247 And Number of steps is ==> 664000
# Episode * 333 * Avg Reward is ==> 1.0295647382736206 And Number of steps is ==> 666000
# Episode * 334 * Avg Reward is ==> 1.0368101596832275 And Number of steps is ==> 668000
# Episode * 335 * Avg Reward is ==> 1.0317103862762451 And Number of steps is ==> 670000
# Episode * 336 * Avg Reward is ==> 1.0201199054718018 And Number of steps is ==> 672000
# Episode * 337 * Avg Reward is ==> 1.0189054012298584 And Number of steps is ==> 674000
# Episode * 338 * Avg Reward is ==> 1.0209028720855713 And Number of steps is ==> 676000
# Episode * 339 * Avg Reward is ==> 1.0331707000732422 And Number of steps is ==> 678000
# Episode * 340 * Avg Reward is ==> 1.0508849620819092 And Number of steps is ==> 680000
# Episode * 341 * Avg Reward is ==> 1.053223967552185 And Number of steps is ==> 682000
# Episode * 342 * Avg Reward is ==> 1.0501998662948608 And Number of steps is ==> 684000
# Accident!
# Episode * 343 * Avg Reward is ==> 0.9964770078659058 And Number of steps is ==> 686000
# Accident!
# Accident!
# Episode * 344 * Avg Reward is ==> 1.0062373876571655 And Number of steps is ==> 688000
# Episode * 345 * Avg Reward is ==> 1.0164579153060913 And Number of steps is ==> 690000
# Episode * 346 * Avg Reward is ==> 1.0279375314712524 And Number of steps is ==> 692000
# Accident!
# Episode * 347 * Avg Reward is ==> 1.0241700410842896 And Number of steps is ==> 694000
# Episode * 348 * Avg Reward is ==> 1.0196752548217773 And Number of steps is ==> 696000
# Episode * 349 * Avg Reward is ==> 1.0030099153518677 And Number of steps is ==> 698000
# Episode * 350 * Avg Reward is ==> 0.9963809847831726 And Number of steps is ==> 700000
# Episode * 351 * Avg Reward is ==> 1.0000427961349487 And Number of steps is ==> 702000
# Episode * 352 * Avg Reward is ==> 0.9893261194229126 And Number of steps is ==> 704000
# Episode * 353 * Avg Reward is ==> 1.0556811094284058 And Number of steps is ==> 706000
# Episode * 354 * Avg Reward is ==> 1.0635432004928589 And Number of steps is ==> 708000
# Episode * 355 * Avg Reward is ==> 1.0614709854125977 And Number of steps is ==> 710000
# Episode * 356 * Avg Reward is ==> 1.0561573505401611 And Number of steps is ==> 712000
# Episode * 357 * Avg Reward is ==> 1.0502302646636963 And Number of steps is ==> 714000
# Accident!
# Accident!
# Episode * 358 * Avg Reward is ==> 0.982932448387146 And Number of steps is ==> 716000
# Episode * 359 * Avg Reward is ==> 0.9691424369812012 And Number of steps is ==> 718000
# Episode * 360 * Avg Reward is ==> 0.989112377166748 And Number of steps is ==> 720000
# Episode * 361 * Avg Reward is ==> 0.9767446517944336 And Number of steps is ==> 722000
# Episode * 362 * Avg Reward is ==> 0.9781006574630737 And Number of steps is ==> 724000
# Episode * 363 * Avg Reward is ==> 0.987359344959259 And Number of steps is ==> 726000
# Episode * 364 * Avg Reward is ==> 0.9724982380867004 And Number of steps is ==> 728000
# Episode * 365 * Avg Reward is ==> 0.9817914962768555 And Number of steps is ==> 730000
# Episode * 366 * Avg Reward is ==> 0.9597989320755005 And Number of steps is ==> 732000
# Episode * 367 * Avg Reward is ==> 0.9557844400405884 And Number of steps is ==> 734000
# Accident!
# Episode * 368 * Avg Reward is ==> 1.002379059791565 And Number of steps is ==> 736000
# Episode * 369 * Avg Reward is ==> 1.0008100271224976 And Number of steps is ==> 738000
# Episode * 370 * Avg Reward is ==> 0.9759038686752319 And Number of steps is ==> 740000
# Episode * 371 * Avg Reward is ==> 0.9757503271102905 And Number of steps is ==> 742000
# Episode * 372 * Avg Reward is ==> 0.9579365849494934 And Number of steps is ==> 744000
# Episode * 373 * Avg Reward is ==> 0.9212309718132019 And Number of steps is ==> 746000
# Episode * 374 * Avg Reward is ==> 0.9123228788375854 And Number of steps is ==> 748000
# Episode * 375 * Avg Reward is ==> 0.9127230644226074 And Number of steps is ==> 750000
# Episode * 376 * Avg Reward is ==> 0.926838219165802 And Number of steps is ==> 752000
# Episode * 377 * Avg Reward is ==> 0.9210813641548157 And Number of steps is ==> 754000
# Episode * 378 * Avg Reward is ==> 0.9238877296447754 And Number of steps is ==> 756000
# Episode * 379 * Avg Reward is ==> 0.9319730997085571 And Number of steps is ==> 758000
# Episode * 380 * Avg Reward is ==> 0.9110232591629028 And Number of steps is ==> 760000
# Episode * 381 * Avg Reward is ==> 0.9132612347602844 And Number of steps is ==> 762000
# Episode * 382 * Avg Reward is ==> 0.9167326092720032 And Number of steps is ==> 764000
# Episode * 383 * Avg Reward is ==> 0.9402817487716675 And Number of steps is ==> 766000
# Accident!
# Episode * 384 * Avg Reward is ==> 0.9786151647567749 And Number of steps is ==> 768000
# Episode * 385 * Avg Reward is ==> 0.9580379724502563 And Number of steps is ==> 770000
# Episode * 386 * Avg Reward is ==> 0.9520832300186157 And Number of steps is ==> 772000
# Episode * 387 * Avg Reward is ==> 0.9684537649154663 And Number of steps is ==> 774000
# Episode * 388 * Avg Reward is ==> 0.9759122729301453 And Number of steps is ==> 776000
# Episode * 389 * Avg Reward is ==> 1.0090548992156982 And Number of steps is ==> 778000
# Episode * 390 * Avg Reward is ==> 1.029178261756897 And Number of steps is ==> 780000
# Episode * 391 * Avg Reward is ==> 1.0248647928237915 And Number of steps is ==> 782000
# Episode * 392 * Avg Reward is ==> 1.0274317264556885 And Number of steps is ==> 784000
# Episode * 393 * Avg Reward is ==> 1.0254626274108887 And Number of steps is ==> 786000
# Episode * 394 * Avg Reward is ==> 1.0089565515518188 And Number of steps is ==> 788000
# Episode * 395 * Avg Reward is ==> 1.024433970451355 And Number of steps is ==> 790000
# Episode * 396 * Avg Reward is ==> 1.0422167778015137 And Number of steps is ==> 792000
# Episode * 397 * Avg Reward is ==> 1.0430738925933838 And Number of steps is ==> 794000
# Episode * 398 * Avg Reward is ==> 1.0262188911437988 And Number of steps is ==> 796000
# Episode * 399 * Avg Reward is ==> 1.0060368776321411 And Number of steps is ==> 798000
# Episode * 400 * Avg Reward is ==> 1.0005481243133545 And Number of steps is ==> 800000
# Episode * 401 * Avg Reward is ==> 1.02642822265625 And Number of steps is ==> 802000
# Episode * 402 * Avg Reward is ==> 1.0466169118881226 And Number of steps is ==> 804000
# Episode * 403 * Avg Reward is ==> 1.048498272895813 And Number of steps is ==> 806000
# Episode * 404 * Avg Reward is ==> 1.056450605392456 And Number of steps is ==> 808000
# Episode * 405 * Avg Reward is ==> 1.0464857816696167 And Number of steps is ==> 810000
# Episode * 406 * Avg Reward is ==> 1.028235673904419 And Number of steps is ==> 812000
# Episode * 407 * Avg Reward is ==> 1.0188159942626953 And Number of steps is ==> 814000
# Episode * 408 * Avg Reward is ==> 1.0378119945526123 And Number of steps is ==> 816000
# Episode * 409 * Avg Reward is ==> 1.0437500476837158 And Number of steps is ==> 818000
# Episode * 410 * Avg Reward is ==> 1.055945634841919 And Number of steps is ==> 820000
# Accident!
# Episode * 411 * Avg Reward is ==> 1.043320655822754 And Number of steps is ==> 822000
# Episode * 412 * Avg Reward is ==> 1.0363653898239136 And Number of steps is ==> 824000
# Episode * 413 * Avg Reward is ==> 1.0329819917678833 And Number of steps is ==> 826000
# Episode * 414 * Avg Reward is ==> 1.0309457778930664 And Number of steps is ==> 828000
# Episode * 415 * Avg Reward is ==> 1.0363818407058716 And Number of steps is ==> 830000
# Episode * 416 * Avg Reward is ==> 1.060514211654663 And Number of steps is ==> 832000
# Episode * 417 * Avg Reward is ==> 1.0692371129989624 And Number of steps is ==> 834000
# Episode * 418 * Avg Reward is ==> 1.0589025020599365 And Number of steps is ==> 836000
# Episode * 419 * Avg Reward is ==> 1.0536826848983765 And Number of steps is ==> 838000
# Episode * 420 * Avg Reward is ==> 1.0401642322540283 And Number of steps is ==> 840000
# Episode * 421 * Avg Reward is ==> 1.0395162105560303 And Number of steps is ==> 842000
# Episode * 422 * Avg Reward is ==> 1.0404164791107178 And Number of steps is ==> 844000
# Episode * 423 * Avg Reward is ==> 1.0421875715255737 And Number of steps is ==> 846000
# Episode * 424 * Avg Reward is ==> 1.0351521968841553 And Number of steps is ==> 848000
# Episode * 425 * Avg Reward is ==> 1.0185304880142212 And Number of steps is ==> 850000
# Episode * 426 * Avg Reward is ==> 1.0306901931762695 And Number of steps is ==> 852000
# Episode * 427 * Avg Reward is ==> 1.028014063835144 And Number of steps is ==> 854000
# Episode * 428 * Avg Reward is ==> 1.0400949716567993 And Number of steps is ==> 856000
# Episode * 429 * Avg Reward is ==> 1.0623352527618408 And Number of steps is ==> 858000
# Accident!
# Episode * 430 * Avg Reward is ==> 1.0712916851043701 And Number of steps is ==> 860000
# Episode * 431 * Avg Reward is ==> 1.0593122243881226 And Number of steps is ==> 862000
# Episode * 432 * Avg Reward is ==> 1.0645619630813599 And Number of steps is ==> 864000
# Episode * 433 * Avg Reward is ==> 1.0539482831954956 And Number of steps is ==> 866000
# Episode * 434 * Avg Reward is ==> 1.0534316301345825 And Number of steps is ==> 868000
# Episode * 435 * Avg Reward is ==> 1.054462194442749 And Number of steps is ==> 870000
# Episode * 436 * Avg Reward is ==> 1.044385313987732 And Number of steps is ==> 872000
# Episode * 437 * Avg Reward is ==> 1.045962929725647 And Number of steps is ==> 874000
# Episode * 438 * Avg Reward is ==> 1.0428338050842285 And Number of steps is ==> 876000
# Episode * 439 * Avg Reward is ==> 1.020413875579834 And Number of steps is ==> 878000
# Episode * 440 * Avg Reward is ==> 1.0261995792388916 And Number of steps is ==> 880000
# Episode * 441 * Avg Reward is ==> 1.0371426343917847 And Number of steps is ==> 882000
# Episode * 442 * Avg Reward is ==> 1.0257807970046997 And Number of steps is ==> 884000
# Episode * 443 * Avg Reward is ==> 1.0239665508270264 And Number of steps is ==> 886000
# Episode * 444 * Avg Reward is ==> 1.0367448329925537 And Number of steps is ==> 888000
# Episode * 445 * Avg Reward is ==> 1.0528761148452759 And Number of steps is ==> 890000
# Episode * 446 * Avg Reward is ==> 1.0468754768371582 And Number of steps is ==> 892000
# Episode * 447 * Avg Reward is ==> 1.0517657995224 And Number of steps is ==> 894000
# Episode * 448 * Avg Reward is ==> 1.0567015409469604 And Number of steps is ==> 896000
# Episode * 449 * Avg Reward is ==> 1.0623290538787842 And Number of steps is ==> 898000
# Episode * 450 * Avg Reward is ==> 1.055468201637268 And Number of steps is ==> 900000
# Episode * 451 * Avg Reward is ==> 1.0625698566436768 And Number of steps is ==> 902000
# Episode * 452 * Avg Reward is ==> 1.0688871145248413 And Number of steps is ==> 904000
# Episode * 453 * Avg Reward is ==> 1.0850492715835571 And Number of steps is ==> 906000
# Episode * 454 * Avg Reward is ==> 1.0682560205459595 And Number of steps is ==> 908000
# Episode * 455 * Avg Reward is ==> 1.0739033222198486 And Number of steps is ==> 910000
# Episode * 456 * Avg Reward is ==> 1.0657141208648682 And Number of steps is ==> 912000
# Episode * 457 * Avg Reward is ==> 1.045849084854126 And Number of steps is ==> 914000
# Episode * 458 * Avg Reward is ==> 1.0482687950134277 And Number of steps is ==> 916000
# Episode * 459 * Avg Reward is ==> 1.0350769758224487 And Number of steps is ==> 918000
# Episode * 460 * Avg Reward is ==> 1.0478765964508057 And Number of steps is ==> 920000
# Episode * 461 * Avg Reward is ==> 1.0431464910507202 And Number of steps is ==> 922000
# Episode * 462 * Avg Reward is ==> 1.0717705488204956 And Number of steps is ==> 924000
# Episode * 463 * Avg Reward is ==> 1.0651795864105225 And Number of steps is ==> 926000
# Episode * 464 * Avg Reward is ==> 1.073190450668335 And Number of steps is ==> 928000
# Episode * 465 * Avg Reward is ==> 1.0746634006500244 And Number of steps is ==> 930000
# Episode * 466 * Avg Reward is ==> 1.081688642501831 And Number of steps is ==> 932000
# Episode * 467 * Avg Reward is ==> 1.1127493381500244 And Number of steps is ==> 934000
# Episode * 468 * Avg Reward is ==> 1.1186366081237793 And Number of steps is ==> 936000
# Episode * 469 * Avg Reward is ==> 1.1455278396606445 And Number of steps is ==> 938000
# Episode * 470 * Avg Reward is ==> 1.14877188205719 And Number of steps is ==> 940000
# Episode * 471 * Avg Reward is ==> 1.1536402702331543 And Number of steps is ==> 942000
# Episode * 472 * Avg Reward is ==> 1.1410294771194458 And Number of steps is ==> 944000
# Episode * 473 * Avg Reward is ==> 1.141231894493103 And Number of steps is ==> 946000
# Episode * 474 * Avg Reward is ==> 1.1345722675323486 And Number of steps is ==> 948000
# Episode * 475 * Avg Reward is ==> 1.136033058166504 And Number of steps is ==> 950000
# Episode * 476 * Avg Reward is ==> 1.1378203630447388 And Number of steps is ==> 952000
# Episode * 477 * Avg Reward is ==> 1.1247953176498413 And Number of steps is ==> 954000
# Episode * 478 * Avg Reward is ==> 1.1052954196929932 And Number of steps is ==> 956000
# Episode * 479 * Avg Reward is ==> 1.091472864151001 And Number of steps is ==> 958000
# Episode * 480 * Avg Reward is ==> 1.072482705116272 And Number of steps is ==> 960000
# Episode * 481 * Avg Reward is ==> 1.0750658512115479 And Number of steps is ==> 962000
# Episode * 482 * Avg Reward is ==> 1.0633419752120972 And Number of steps is ==> 964000
# Episode * 483 * Avg Reward is ==> 1.0508531332015991 And Number of steps is ==> 966000
# Episode * 484 * Avg Reward is ==> 1.0762803554534912 And Number of steps is ==> 968000
# Episode * 485 * Avg Reward is ==> 1.0578445196151733 And Number of steps is ==> 970000
# Episode * 486 * Avg Reward is ==> 1.0707042217254639 And Number of steps is ==> 972000
# Episode * 487 * Avg Reward is ==> 1.0758448839187622 And Number of steps is ==> 974000
# Episode * 488 * Avg Reward is ==> 1.0873360633850098 And Number of steps is ==> 976000
# Episode * 489 * Avg Reward is ==> 1.1087743043899536 And Number of steps is ==> 978000
# Episode * 490 * Avg Reward is ==> 1.1158864498138428 And Number of steps is ==> 980000
# Episode * 491 * Avg Reward is ==> 1.1080619096755981 And Number of steps is ==> 982000
# Episode * 492 * Avg Reward is ==> 1.115114688873291 And Number of steps is ==> 984000
# Episode * 493 * Avg Reward is ==> 1.136549949645996 And Number of steps is ==> 986000
# Episode * 494 * Avg Reward is ==> 1.114243745803833 And Number of steps is ==> 988000
# Accident!
# Episode * 495 * Avg Reward is ==> 1.1304795742034912 And Number of steps is ==> 990000
# Episode * 496 * Avg Reward is ==> 1.1153572797775269 And Number of steps is ==> 992000
# Episode * 497 * Avg Reward is ==> 1.1054927110671997 And Number of steps is ==> 994000
# Episode * 498 * Avg Reward is ==> 1.08622145652771 And Number of steps is ==> 996000
# ...
# Episode * 821 * Avg Reward is ==> 1.0503818988800049 And Number of steps is ==> 1642000
# Episode * 822 * Avg Reward is ==> 1.0498586893081665 And Number of steps is ==> 1644000
# Accident!
# Episode * 823 * Avg Reward is ==> 1.0370936393737793 And Number of steps is ==> 1646000
# Episode * 824 * Avg Reward is ==> 1.023280382156372 And Number of steps is ==> 1648000
# Episode * 825 * Avg Reward is ==> 1.034977674484253 And Number of steps is ==> 1650000
# Accident!
# Episode * 826 * Avg Reward is ==> 1.0886789560317993 And Number of steps is ==> 1652000
# Episode * 827 * Avg Reward is ==> 1.0921167135238647 And Number of steps is ==> 1654000
# Episode * 828 * Avg Reward is ==> 1.1007179021835327 And Number of steps is ==> 1656000
# Accident!
# Episode * 829 * Avg Reward is ==> 1.1118768453598022 And Number of steps is ==> 1658000
# Episode * 830 * Avg Reward is ==> 1.1074538230895996 And Number of steps is ==> 1660000
# Episode * 831 * Avg Reward is ==> 1.0968443155288696 And Number of steps is ==> 1662000
# Episode * 832 * Avg Reward is ==> 1.1080520153045654 And Number of steps is ==> 1664000
# Episode * 833 * Avg Reward is ==> 1.1210530996322632 And Number of steps is ==> 1666000
# Episode * 834 * Avg Reward is ==> 1.13303542137146 And Number of steps is ==> 1668000
# Episode * 835 * Avg Reward is ==> 1.1206555366516113 And Number of steps is ==> 1670000
# Episode * 836 * Avg Reward is ==> 1.1297281980514526 And Number of steps is ==> 1672000
# Episode * 837 * Avg Reward is ==> 1.1393201351165771 And Number of steps is ==> 1674000
# Accident!
# Episode * 838 * Avg Reward is ==> 1.0158329010009766 And Number of steps is ==> 1676000
# Episode * 839 * Avg Reward is ==> 1.0202555656433105 And Number of steps is ==> 1678000
# Episode * 840 * Avg Reward is ==> 1.040235161781311 And Number of steps is ==> 1680000
# Episode * 841 * Avg Reward is ==> 1.033543348312378 And Number of steps is ==> 1682000
# Episode * 842 * Avg Reward is ==> 1.0163140296936035 And Number of steps is ==> 1684000
# Episode * 843 * Avg Reward is ==> 1.0231683254241943 And Number of steps is ==> 1686000
# Episode * 844 * Avg Reward is ==> 1.0173027515411377 And Number of steps is ==> 1688000
# Episode * 845 * Avg Reward is ==> 1.0363303422927856 And Number of steps is ==> 1690000
# Episode * 846 * Avg Reward is ==> 1.0505578517913818 And Number of steps is ==> 1692000
# Episode * 847 * Avg Reward is ==> 1.0208314657211304 And Number of steps is ==> 1694000
# Episode * 848 * Avg Reward is ==> 1.1314551830291748 And Number of steps is ==> 1696000
# Episode * 849 * Avg Reward is ==> 1.1294188499450684 And Number of steps is ==> 1698000
# Episode * 850 * Avg Reward is ==> 1.1241538524627686 And Number of steps is ==> 1700000
# Episode * 851 * Avg Reward is ==> 1.1016895771026611 And Number of steps is ==> 1702000
# Episode * 852 * Avg Reward is ==> 1.1080098152160645 And Number of steps is ==> 1704000
# Episode * 853 * Avg Reward is ==> 1.1017986536026 And Number of steps is ==> 1706000
# Episode * 854 * Avg Reward is ==> 1.1260974407196045 And Number of steps is ==> 1708000
# Episode * 855 * Avg Reward is ==> 1.1123801469802856 And Number of steps is ==> 1710000
# Episode * 856 * Avg Reward is ==> 1.0935752391815186 And Number of steps is ==> 1712000
# Accident!
# Episode * 857 * Avg Reward is ==> 1.12342369556427 And Number of steps is ==> 1714000
# Episode * 858 * Avg Reward is ==> 1.1167834997177124 And Number of steps is ==> 1716000
# Episode * 859 * Avg Reward is ==> 1.1248176097869873 And Number of steps is ==> 1718000
# Episode * 860 * Avg Reward is ==> 1.121940016746521 And Number of steps is ==> 1720000
# Episode * 861 * Avg Reward is ==> 1.1441283226013184 And Number of steps is ==> 1722000
# Episode * 862 * Avg Reward is ==> 1.1497727632522583 And Number of steps is ==> 1724000
# Episode * 863 * Avg Reward is ==> 1.1509723663330078 And Number of steps is ==> 1726000
# Episode * 864 * Avg Reward is ==> 1.1190019845962524 And Number of steps is ==> 1728000
# Episode * 865 * Avg Reward is ==> 1.1218831539154053 And Number of steps is ==> 1730000
# Episode * 866 * Avg Reward is ==> 1.1026169061660767 And Number of steps is ==> 1732000
# Episode * 867 * Avg Reward is ==> 1.1001070737838745 And Number of steps is ==> 1734000
# Accident!
# Episode * 868 * Avg Reward is ==> 1.0956578254699707 And Number of steps is ==> 1736000
# Episode * 869 * Avg Reward is ==> 1.0688660144805908 And Number of steps is ==> 1738000
# Episode * 870 * Avg Reward is ==> 1.046425223350525 And Number of steps is ==> 1740000
# Episode * 871 * Avg Reward is ==> 1.052135705947876 And Number of steps is ==> 1742000
# Episode * 872 * Avg Reward is ==> 1.0439647436141968 And Number of steps is ==> 1744000
# Episode * 873 * Avg Reward is ==> 1.0411666631698608 And Number of steps is ==> 1746000
# Episode * 874 * Avg Reward is ==> 1.0507652759552002 And Number of steps is ==> 1748000
# Episode * 875 * Avg Reward is ==> 1.029724359512329 And Number of steps is ==> 1750000
# Episode * 876 * Avg Reward is ==> 1.0635907649993896 And Number of steps is ==> 1752000
# Episode * 877 * Avg Reward is ==> 1.0371407270431519 And Number of steps is ==> 1754000
# Episode * 878 * Avg Reward is ==> 1.0572865009307861 And Number of steps is ==> 1756000
# Episode * 879 * Avg Reward is ==> 1.0758659839630127 And Number of steps is ==> 1758000
# Episode * 880 * Avg Reward is ==> 1.1078330278396606 And Number of steps is ==> 1760000
# Episode * 881 * Avg Reward is ==> 1.1136797666549683 And Number of steps is ==> 1762000
# Episode * 882 * Avg Reward is ==> 1.1331738233566284 And Number of steps is ==> 1764000
# Episode * 883 * Avg Reward is ==> 1.1442874670028687 And Number of steps is ==> 1766000
# Episode * 884 * Avg Reward is ==> 1.1582953929901123 And Number of steps is ==> 1768000
# Episode * 885 * Avg Reward is ==> 1.1714659929275513 And Number of steps is ==> 1770000
# Episode * 886 * Avg Reward is ==> 1.1830304861068726 And Number of steps is ==> 1772000
# Episode * 887 * Avg Reward is ==> 1.2112326622009277 And Number of steps is ==> 1774000
# Episode * 888 * Avg Reward is ==> 1.1829078197479248 And Number of steps is ==> 1776000
# Episode * 889 * Avg Reward is ==> 1.206201195716858 And Number of steps is ==> 1778000
# Episode * 890 * Avg Reward is ==> 1.196799635887146 And Number of steps is ==> 1780000
# Episode * 891 * Avg Reward is ==> 1.1939198970794678 And Number of steps is ==> 1782000
# Episode * 892 * Avg Reward is ==> 1.1688642501831055 And Number of steps is ==> 1784000
# Episode * 893 * Avg Reward is ==> 1.1722643375396729 And Number of steps is ==> 1786000
# Episode * 894 * Avg Reward is ==> 1.1428495645523071 And Number of steps is ==> 1788000
# Episode * 895 * Avg Reward is ==> 1.1591804027557373 And Number of steps is ==> 1790000
# Episode * 896 * Avg Reward is ==> 1.1445802450180054 And Number of steps is ==> 1792000
# Episode * 897 * Avg Reward is ==> 1.1318986415863037 And Number of steps is ==> 1794000
# Episode * 898 * Avg Reward is ==> 1.154759168624878 And Number of steps is ==> 1796000
# Accident!
# Episode * 899 * Avg Reward is ==> 1.058657169342041 And Number of steps is ==> 1798000
# Episode * 900 * Avg Reward is ==> 1.0589522123336792 And Number of steps is ==> 1800000
# Accident!
# Episode * 901 * Avg Reward is ==> 1.0340807437896729 And Number of steps is ==> 1802000
# Episode * 902 * Avg Reward is ==> 1.0512168407440186 And Number of steps is ==> 1804000
# Episode * 903 * Avg Reward is ==> 1.0302926301956177 And Number of steps is ==> 1806000
# Episode * 904 * Avg Reward is ==> 1.0446937084197998 And Number of steps is ==> 1808000
# Episode * 905 * Avg Reward is ==> 1.040633201599121 And Number of steps is ==> 1810000
# Episode * 906 * Avg Reward is ==> 1.0597072839736938 And Number of steps is ==> 1812000
# Episode * 907 * Avg Reward is ==> 1.0620144605636597 And Number of steps is ==> 1814000
# Episode * 908 * Avg Reward is ==> 1.0621025562286377 And Number of steps is ==> 1816000
# Episode * 909 * Avg Reward is ==> 1.1489983797073364 And Number of steps is ==> 1818000
# Episode * 910 * Avg Reward is ==> 1.144242286682129 And Number of steps is ==> 1820000
# Episode * 911 * Avg Reward is ==> 1.163694977760315 And Number of steps is ==> 1822000
# Accident!
# Episode * 912 * Avg Reward is ==> 1.166382074356079 And Number of steps is ==> 1824000
# Accident!
# Episode * 913 * Avg Reward is ==> 1.1884269714355469 And Number of steps is ==> 1826000
# Episode * 914 * Avg Reward is ==> 1.1799012422561646 And Number of steps is ==> 1828000
# Episode * 915 * Avg Reward is ==> 1.1634550094604492 And Number of steps is ==> 1830000
# Episode * 916 * Avg Reward is ==> 1.1251039505004883 And Number of steps is ==> 1832000
# Accident!
# Episode * 917 * Avg Reward is ==> 1.1347273588180542 And Number of steps is ==> 1834000
# Episode * 918 * Avg Reward is ==> 1.1274888515472412 And Number of steps is ==> 1836000
# Episode * 919 * Avg Reward is ==> 1.125568151473999 And Number of steps is ==> 1838000
# Episode * 920 * Avg Reward is ==> 1.124171495437622 And Number of steps is ==> 1840000
# Episode * 921 * Avg Reward is ==> 1.0957738161087036 And Number of steps is ==> 1842000
# Episode * 922 * Avg Reward is ==> 1.0857678651809692 And Number of steps is ==> 1844000
# Episode * 923 * Avg Reward is ==> 1.0710690021514893 And Number of steps is ==> 1846000
# Episode * 924 * Avg Reward is ==> 1.0859968662261963 And Number of steps is ==> 1848000
# Episode * 925 * Avg Reward is ==> 1.0984653234481812 And Number of steps is ==> 1850000
# Episode * 926 * Avg Reward is ==> 1.1089117527008057 And Number of steps is ==> 1852000
# Episode * 927 * Avg Reward is ==> 1.0880252122879028 And Number of steps is ==> 1854000
# Episode * 928 * Avg Reward is ==> 1.091350793838501 And Number of steps is ==> 1856000
# Episode * 929 * Avg Reward is ==> 1.085205078125 And Number of steps is ==> 1858000
# Episode * 930 * Avg Reward is ==> 1.105759620666504 And Number of steps is ==> 1860000
# Episode * 931 * Avg Reward is ==> 1.11855947971344 And Number of steps is ==> 1862000
# Episode * 932 * Avg Reward is ==> 1.1175318956375122 And Number of steps is ==> 1864000
# Episode * 933 * Avg Reward is ==> 1.1091428995132446 And Number of steps is ==> 1866000
# Episode * 934 * Avg Reward is ==> 1.0995726585388184 And Number of steps is ==> 1868000
# Episode * 935 * Avg Reward is ==> 1.0928595066070557 And Number of steps is ==> 1870000
# Accident!
# Episode * 936 * Avg Reward is ==> 1.1059443950653076 And Number of steps is ==> 1872000
# Episode * 937 * Avg Reward is ==> 1.1235854625701904 And Number of steps is ==> 1874000
# Episode * 938 * Avg Reward is ==> 1.1209394931793213 And Number of steps is ==> 1876000
# Episode * 939 * Avg Reward is ==> 1.1249656677246094 And Number of steps is ==> 1878000
# Episode * 940 * Avg Reward is ==> 1.1053600311279297 And Number of steps is ==> 1880000
# Episode * 941 * Avg Reward is ==> 1.1149046421051025 And Number of steps is ==> 1882000
# Episode * 942 * Avg Reward is ==> 1.1203675270080566 And Number of steps is ==> 1884000
# Accident!
# Episode * 943 * Avg Reward is ==> 1.0784236192703247 And Number of steps is ==> 1886000
# Episode * 944 * Avg Reward is ==> 1.0735952854156494 And Number of steps is ==> 1888000
# Episode * 945 * Avg Reward is ==> 1.0841546058654785 And Number of steps is ==> 1890000
# Episode * 946 * Avg Reward is ==> 1.0647118091583252 And Number of steps is ==> 1892000
# Episode * 947 * Avg Reward is ==> 1.0551602840423584 And Number of steps is ==> 1894000
# Episode * 948 * Avg Reward is ==> 1.0516504049301147 And Number of steps is ==> 1896000
# Episode * 949 * Avg Reward is ==> 1.0456489324569702 And Number of steps is ==> 1898000
# Episode * 950 * Avg Reward is ==> 1.0372122526168823 And Number of steps is ==> 1900000
# Episode * 951 * Avg Reward is ==> 1.0208362340927124 And Number of steps is ==> 1902000
# Episode * 952 * Avg Reward is ==> 1.0098828077316284 And Number of steps is ==> 1904000
# Episode * 953 * Avg Reward is ==> 1.055816650390625 And Number of steps is ==> 1906000
# Episode * 954 * Avg Reward is ==> 1.0486335754394531 And Number of steps is ==> 1908000
# Episode * 955 * Avg Reward is ==> 1.0567944049835205 And Number of steps is ==> 1910000
# Episode * 956 * Avg Reward is ==> 1.0554368495941162 And Number of steps is ==> 1912000
# Episode * 957 * Avg Reward is ==> 1.0441347360610962 And Number of steps is ==> 1914000
# Episode * 958 * Avg Reward is ==> 1.0543138980865479 And Number of steps is ==> 1916000
# Episode * 959 * Avg Reward is ==> 1.067550539970398 And Number of steps is ==> 1918000
# Episode * 960 * Avg Reward is ==> 1.0644080638885498 And Number of steps is ==> 1920000
# Accident!
# Episode * 961 * Avg Reward is ==> 1.0940606594085693 And Number of steps is ==> 1922000
# Episode * 962 * Avg Reward is ==> 1.1057467460632324 And Number of steps is ==> 1924000
# Accident!
# Episode * 963 * Avg Reward is ==> 1.1065140962600708 And Number of steps is ==> 1926000
# Episode * 964 * Avg Reward is ==> 1.1164495944976807 And Number of steps is ==> 1928000
# Episode * 965 * Avg Reward is ==> 1.0940219163894653 And Number of steps is ==> 1930000
# Episode * 966 * Avg Reward is ==> 1.0897929668426514 And Number of steps is ==> 1932000
# Episode * 967 * Avg Reward is ==> 1.103175401687622 And Number of steps is ==> 1934000
# Episode * 968 * Avg Reward is ==> 1.0918766260147095 And Number of steps is ==> 1936000
# Episode * 969 * Avg Reward is ==> 1.0753021240234375 And Number of steps is ==> 1938000
# Episode * 970 * Avg Reward is ==> 1.094605565071106 And Number of steps is ==> 1940000
# Episode * 971 * Avg Reward is ==> 1.0921485424041748 And Number of steps is ==> 1942000
# Episode * 972 * Avg Reward is ==> 1.070651650428772 And Number of steps is ==> 1944000
# Episode * 973 * Avg Reward is ==> 1.078709602355957 And Number of steps is ==> 1946000
# Episode * 974 * Avg Reward is ==> 1.0969038009643555 And Number of steps is ==> 1948000
# Episode * 975 * Avg Reward is ==> 1.1114915609359741 And Number of steps is ==> 1950000
# Episode * 976 * Avg Reward is ==> 1.1126914024353027 And Number of steps is ==> 1952000
# Episode * 977 * Avg Reward is ==> 1.111958384513855 And Number of steps is ==> 1954000
# Episode * 978 * Avg Reward is ==> 1.110674262046814 And Number of steps is ==> 1956000
# Episode * 979 * Avg Reward is ==> 1.0968711376190186 And Number of steps is ==> 1958000
# Episode * 980 * Avg Reward is ==> 1.0797368288040161 And Number of steps is ==> 1960000
# Episode * 981 * Avg Reward is ==> 1.080869436264038 And Number of steps is ==> 1962000
# Accident!
# Episode * 982 * Avg Reward is ==> 1.1067779064178467 And Number of steps is ==> 1964000
# Episode * 983 * Avg Reward is ==> 1.0997570753097534 And Number of steps is ==> 1966000
# Episode * 984 * Avg Reward is ==> 1.0893657207489014 And Number of steps is ==> 1968000
# Episode * 985 * Avg Reward is ==> 1.0723549127578735 And Number of steps is ==> 1970000
# Episode * 986 * Avg Reward is ==> 1.0637359619140625 And Number of steps is ==> 1972000
# Episode * 987 * Avg Reward is ==> 1.0810575485229492 And Number of steps is ==> 1974000
# Episode * 988 * Avg Reward is ==> 1.091139554977417 And Number of steps is ==> 1976000
# Episode * 989 * Avg Reward is ==> 1.1018174886703491 And Number of steps is ==> 1978000
# Accident!
# Episode * 990 * Avg Reward is ==> 1.106480360031128 And Number of steps is ==> 1980000
# Episode * 991 * Avg Reward is ==> 1.1162259578704834 And Number of steps is ==> 1982000
# Episode * 992 * Avg Reward is ==> 1.094160795211792 And Number of steps is ==> 1984000
# Episode * 993 * Avg Reward is ==> 1.105927586555481 And Number of steps is ==> 1986000
# Episode * 994 * Avg Reward is ==> 1.1127102375030518 And Number of steps is ==> 1988000
# Episode * 995 * Avg Reward is ==> 1.1065889596939087 And Number of steps is ==> 1990000
# Episode * 996 * Avg Reward is ==> 1.1339638233184814 And Number of steps is ==> 1992000
# Episode * 997 * Avg Reward is ==> 1.1144955158233643 And Number of steps is ==> 1994000
# Episode * 998 * Avg Reward is ==> 1.137467384338379 And Number of steps is ==> 1996000
# Episode * 999 * Avg Reward is ==> 1.1482032537460327 And Number of steps is ==> 1998000
# Complete
# Running time: 1732.014310836792

# %%
#Stock an evaluation sample
states, actions, rewards = algo.evaluate(1000)
ep_action=states[:,0]
ep_speed_car=states[:,1]
ep_pos_car=states[:,2]
ep_speed_ped=states[:,3]
ep_pos_ped=states[:,4]
ep_time=states[:,9]
ep_reward=rewards
t=0

# %%
#Show general information about the final algorithm performance: average speed, CO2 emission, end-time

LDV = pd.read_csv('LDV.csv', sep=';',names=["sp","acc","step","em_name","em_val"])
LDV.pop('step')
m = LDV == 0.0
LDV['acc'] = LDV['acc'].replace(1.27676e-15,0.0)
LDV['acc'] = LDV['acc'].astype(float)
LDV_array = np.array(LDV.values)

def info_co2(states,LDV):
    """
        Evaluate the CO2 emission per episode 
        :param states: state list
        :param LDV: CO2 emission chart
    """
    t=0
    total_emission=[]
    while t+1<len(ep_time):
        t_init=t
        emission_val=[]
        while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
            acc=math.trunc(((states[t,0].item()//0.2)*0.2)*10.)/10.
            speed=math.trunc(((states[t,1].item()//0.5)*0.5)*10.)/10.
            cond=(LDV.sp==speed)&(LDV.acc==acc)&(LDV.em_name=="CO2")
            res=LDV[cond]['em_val'].item() *0.3
            emission_val.append(res)
            t+=1
        total_emission.append(torch.sum(torch.tensor(emission_val),dim=0))
        t+=1
    torch_total_emission=torch.tensor(total_emission)
    total_emission_mean=torch.mean(torch_total_emission)
    total_emission_std=torch.std(torch_total_emission)
    print("\nThe average CO2 emission is {:.2f}mg and its standard deviation is {:.2f} mg".format(total_emission_mean.item(),total_emission_std.item()))
    
def get_average(states,LDV):
    ep_time=states[:,9]
    mean_speed=torch.mean(states[:,1])
    sqrt_speed=torch.std(states[:,1])
    print("The average car speed is {:.2f} m/s and its standard deviation is {:.2f} m/s".format(mean_speed.item(),sqrt_speed.item()))
    mean_acc=torch.mean(states[:,0])
    sqrt_acc=torch.std(states[:,0])
    print("\nThe average car acceleration is {:.2f} m/s2 and its standard deviation is {:.2f} m/s2".format(mean_acc.item(),sqrt_acc.item()))
    mean_speed_p=torch.mean(states[:,3])
    sqrt_speed_p=torch.std(states[:,3])
    print("\nThe average pedestrian speed is {:.2f} m/s2 and its standard deviation is {:.2f} m/s2".format(mean_speed_p.item(),sqrt_speed_p.item()))    
    mean_reward=torch.mean(ep_reward)
    std_reward=torch.std(ep_reward)
    print("\nThe average reward is {:.2f} and its standard deviation is {:.2f}".format(mean_reward.item(),std_reward.item()))
    info_co2(states,LDV) #CO2 info
    temps=[]
    t=0
    while t+1<len(ep_time):
        temps_i=np.array([0.,0.]) #respectively: end-time car/pedestrian
        t_init=t
        while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
            if(states[t,2]<0.0 and states[t+1,2]>=0.0):
                temps_i[0]=(t-t_init)*0.3
            if(states[t,4]<5.0 and states[t+1,4]>=5.0):
                temps_i[1]=(t-t_init)*0.3
            t+=1
        if(temps_i[1]==0.0):
            temps_i[1]=(t-t_init)*0.3
        temps.append([(t-t_init)*0.3,temps_i[0],temps_i[1]])
        t+=1
    total_temps=torch.tensor([temps]).reshape((-1,3))
    total_temps_mean=torch.mean(total_temps,dim=0)
    print("\n Average End-times:")
    print("Total: {:.2f} s".format(total_temps_mean[0].item()))
    print("Car: {:.2f} s".format(total_temps_mean[1].item()))
    print("Pedestrian: {:.2f} s".format(total_temps_mean[2].item()))
get_average(states,LDV)
# Out:
# The average car speed is 6.93 m/s and its standard deviation is 3.37 m/s
#
# The average car acceleration is -0.00 m/s2 and its standard deviation is 1.56 m/s2
#
# The average pedestrian speed is 0.99 m/s2 and its standard deviation is 0.37 m/s2
#
# The average reward is 0.98 and its standard deviation is 2.46
#
# The average CO2 emission is 20467.13mg and its standard deviation is 10608.53 mg
#
#  Average End-times:
# Total: 9.91 s
# Car: 4.82 s
# Pedestrian: 6.62 s

# %%
#Positions des agents
t=0
plt.title("Vehicle and Pedestrian Positions versus time")
plt.xlabel("time (s)")
plt.ylabel("position (m)")
while t+1<len(ep_time):
    t_init=t
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        t+=1
    plt.plot(ep_time[t_init:t],ep_pos_car[t_init:t])
    plt.plot(ep_time[t_init:t],ep_pos_ped[t_init:t])
    plt.axhline(y=5, color='r', linestyle='-.')
    plt.axhline(y=0, color='r', linestyle='-.')
    t+=1
_=plt.axhline(y=5, color='r', linestyle='-.')
_=plt.axhline(y=0, color='r', linestyle='-.')

# %%
#Accélération, Reward, Vitesse de la voiture
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(18, 4))

t=0
ax1.set_title("Car Acceleration versus time per episode")
ax1.set_xlabel("time (s)")
ax1.set_ylabel("acceleration (m/s2)")

ax2.set_title("Reward versus time per episode")
ax2.set_xlabel("time (s)")
ax2.set_ylabel("reward")

ax3.set_title("Car Speed versus time per episode")
ax3.set_xlabel("time (s)")
ax3.set_ylabel("speed (m/s)")

ax4.set_title('Pedestrian Speed')
ax4.set_xlabel("Position (m)")
ax4.set_ylabel("Speed (m/s)")
while t+1<len(ep_time):
    t_init=t
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        t+=1
    ax1.plot(ep_time[t_init:t],ep_action[t_init:t])
    ax2.plot(ep_time[t_init:t],ep_reward[t_init:t])
    ax3.plot(ep_time[t_init:t],ep_speed_car[t_init:t])
    ax4.plot(states[t_init:t,4],states[t_init:t,3])
    t+=1

# %%
t=0
cross_speed=[]
wait_speed=[]
cross_acc=[]
wait_acc=[]
size_wait=17
size_cross=37

while t+1<len(ep_time):
    t_init=t
    choice=False
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        choice=choice+(ep_speed_car[t]<2.0)
        t+=1
    if(choice):
        cross_speed.append(np.array(ep_speed_car[t_init:t_init+size_cross]))
        cross_acc.append(np.array(states[t_init:t_init+size_cross,0]))
    else:
        wait_speed.append(np.array(ep_speed_car[t_init:t_init+size_wait]))
        wait_acc.append(np.array(states[t_init:t_init+size_wait,0]))
    t+=1
cross_speed=np.array(cross_speed)
wait_speed=np.array(wait_speed)
cross_acc=np.array(cross_acc)
wait_acc=np.array(wait_acc)

# %%
x1=[0.3*i for i in range(size_cross)]
mean_speed=np.mean(cross_speed,axis=0)
std_speed=np.std(cross_speed,axis=0)
mean_acc=np.mean(cross_acc,axis=0)
std_acc=np.std(cross_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')
#fig.savefig("PDF_results/car_cross_ppo.pdf")

# %%
x1=[0.3*i for i in range(size_wait)]
mean_speed=np.mean(wait_speed,axis=0)
std_speed=np.std(wait_speed,axis=0)
mean_acc=np.mean(wait_acc,axis=0)
std_acc=np.std(wait_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')
#fig.savefig("PDF_results/car_wait_ppo.pdf")

# %%
#Showing Vehicle Acceleration Diagram, Vehicle Speed Diagram, Vehicle and Pedestrian Position Diagram
#All three over time in an episode
#t=0
if (t+1>=len(ep_time)):
    t=0
t_init=t
while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
    t+=1
fig, (ax1, ax2, ax3) = plt.subplots(1, 3,figsize=(20, 3))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-1.1,1.1)
ax1.plot(ep_time[t_init:t+1],actions[t_init:t+1,0],color='r')

ax2.set_title('Car and Pedestrian Position')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Position (m)")
ax2.plot(ep_time[t_init:t],ep_pos_car[t_init:t],label='car')
ax2.plot(ep_time[t_init:t+1],ep_pos_ped[t_init:t+1],label='pedestrian')
ax2.axhline(y=5, color='r', linestyle='-.')
ax2.axhline(y=0, color='r', linestyle='-.')
ax2.legend()

ax3.set_title('Car Speed')
ax3.set_xlabel("Time (s)")
ax3.set_ylabel("Speed (m/s)")
ax3.plot(ep_time[t_init:t+1],ep_speed_car[t_init:t+1],color='r')
t+=1

# %%
plt.title('Pedestrian Speed')
plt.xlabel("Position (m)")
plt.ylabel("Speed (m/s)")
plt.plot(states[t_init:t-10,4],states[t_init:t-10,3], color='olivedrab')
#plt.savefig("PDF_results/ped_speed.pdf")
