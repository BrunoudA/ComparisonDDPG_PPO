# %%
#1) Import libraries
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import namedtuple, deque
import Environments
from collections import OrderedDict
from torch.distributions import MultivariateNormal
import pandas as pd

# I use the work of Eric Yu to help me build this algorithm. Link: https://github.com/ericyangyu/PPO-for-Beginners

# %%
#2) Set up Neural Network functions and classes

class Model_PPO(nn.Module):
    """
        Class: actor NN
        :param np_inputs: size input of the NN (size state)
        :param nb_outputs: size output of the NN (size action)
    """  
    def __init__(self, np_inputs, nb_outputs):
        super(Model_PPO, self).__init__()   
        self.layer1 = nn.Linear(np_inputs, 64)
        self.layer2 = nn.Linear(64, 64)
        self.layer3 = nn.Linear(64, nb_outputs)
        torch.nn.init.uniform_(self.layer3.weight,0.003, 0.006)

    def forward(self, input1):
        """
        Forward NN : compute the NN with respect the current state
        :param input1: state
        :return: output of the NN, action
        """ 
        if isinstance(input1, np.ndarray):
            input1 = torch.tensor(input1, dtype=torch.float)
        activation1 = F.relu(self.layer1(input1))
        activation2 = F.relu(self.layer2(activation1))
        output = self.layer3(activation2)
        return output

# %%
#3) Rollout on the environment:

class Env_rollout:
    """ 
        Class : iterate on the environment
        :param env: our environment
        :param max_steps: max steps per episode
    """
    def __init__(self, env, max_steps):
        self.env = env
        self.max_steps = max_steps
        self.prev_state = env.reset()
        self.batch_obs=[]
        self.batch_acts=[]
        self.batch_log_probs=[]
        self.batch_rews = []
    
    def reset(self):
        """
        Reset: reinitilization (lists et environment).
        """
        self.prev_state = env.reset()
        self.batch_obs=[]
        self.batch_acts=[]
        self.batch_log_probs=[]
        self.batch_rews = []
    
    def iterations(self,actor_net, nbr_episodes):
        """
        Iterate on the environment.
        :param actor_net: current policy (actor NN)
        :param nbr_episodes: episode number
        :return: Tensors; state batch, action batch
        """
        for ep in range(nbr_episodes):
            ep_rews = []
            prev_state = self.env.reset()
            for step_ep in range(self.max_steps): 
                with torch.no_grad():
                    action = torch.squeeze(actor_net(torch.unsqueeze(torch.tensor(prev_state), dim=0).float()))
                    if(action.dim()==0):
                        action=torch.unsqueeze(action,dim=0)
                    action_all=np.array([])
                    action_all=np.append(action_all,np.clip(action[0].detach().numpy(), -1.0, 1.0))
                    #action_all=np.append(action_all,np.argmax(action[1:4].detach().numpy()))
                    state, reward, done, _ = self.env.step(action_all)
                    self.batch_obs.append(prev_state)
                    self.batch_acts.append(action_all)
                    ep_rews.append(reward)
                    prev_state = state
                if done:
                    break
            self.batch_rews.append(ep_rews)
        return torch.tensor(self.batch_obs, dtype=torch.float), torch.tensor(self.batch_acts, dtype=torch.float)
    
    def iterations_rand(self,actor_net, cov_mat, batch_size):
        """
        Iterate on the environment.
        :param actor_net: current policy (actor NN)
        :param cov_mat: covariance matrix used for exploration
        :param batch_size: batch size
        :return: Tensors; state batch, action batch, log_proba batch
        """
        t = 0
        while t<batch_size:
            ep_rews = []
            prev_state = self.env.reset()
            for step_ep in range(self.max_steps): 
                t += 1
                with torch.no_grad():
                    parameters_based = torch.squeeze(actor_net(torch.unsqueeze(torch.tensor(prev_state), dim=0).float()))
                    if(parameters_based.dim()==0):
                        parameters_based=torch.unsqueeze(parameters_based,dim=0)
                    distribution_p = MultivariateNormal(parameters_based, cov_mat)
                    action = distribution_p.sample()
                    log_proba = distribution_p.log_prob(action)
                    action_all=np.array([])
                    action_all=np.append(action_all,np.clip(action[0].detach().numpy(), -1.0, 1.0))
                    state, reward, done, _ = self.env.step(action_all)
                    self.batch_obs.append(prev_state)
                    self.batch_acts.append(action.detach().numpy())
                    self.batch_log_probs.append(log_proba)
                    ep_rews.append(reward)
                    prev_state = state
                if done:
                    break
            self.batch_rews.append(ep_rews)
        return torch.tensor(self.batch_obs, dtype=torch.float), torch.tensor(self.batch_acts, dtype=torch.float), torch.tensor(self.batch_log_probs, dtype=torch.float)

    def immediate_rewards(self):
        """
        Immediate rewards
        :return: Tensor; batch reward
        """
        batch_rewards = []
        for ep_rews in self.batch_rews:
            for rew in reversed(ep_rews):
                batch_rewards.insert(0,rew)
        return torch.tensor(batch_rewards, dtype=torch.float)
    
    def futur_rewards(self):
        """
        Expected futures rewards
        :return: Tensor; batch reward-to-go
        """
        batch_rtgs = []
        for ep_rews in reversed(self.batch_rews):
            episodic_reward=0.0
            for rew in reversed(ep_rews):
                episodic_reward= rew + 0.99*episodic_reward
                batch_rtgs.insert(0,episodic_reward)
        return torch.tensor(batch_rtgs, dtype=torch.float)

# %%
#4) Algorithm DDPG:
class Algo_PPO():
    """ 
    PPO algorithm : training and testing
    :param policy_class: policy (actor model)
    :param env: environment
    :param hyperparameters: other hyperparameters
    """
    def __init__(self, policy_class, env, **hyperparameters):
        
        self._init_hyperparameters(hyperparameters)
        self.actor_net = policy_class(self.num_states, self.num_actions)
        self.critic_net = policy_class(self.num_states, 1)
        self.optimizer_critic = optim.Adam(self.critic_net.parameters(), self.critic_lr)
        self.optimizer_actor = optim.Adam(self.actor_net.parameters(), self.actor_lr)
        self.change_std=0.0
        self.value_std=0.5
        self.cov_var = torch.full(size=(self.num_actions,), fill_value=self.value_std)
        self.cov_mat = torch.diag(self.cov_var)
        self.rollout = Env_rollout(env, self.max_steps)
        self.ep_reward_list=[]
    
    def evaluate(self, nbr_episodes):
        """
        Testing
        :param nbr_episodes: episode number 
        :return: state batch, action batch, and reward batch
        """
        self.rollout.reset()
        state_batch, action_batch = self.rollout.iterations(self.actor_net, nbr_episodes)
        rew_batch = self.rollout.immediate_rewards()
        return state_batch, action_batch, rew_batch
        
    def train(self, nb_loop):
        """ 
        Training
        :param nb_loop: number of batch iterations
        """
        self.change_std=self.value_std/float(nb_loop)
        for ep in range(nb_loop):
            state_batch,action_batch,log_prob_batch = self.rollout.iterations_rand(self.actor_net,self.cov_mat,self.batch_size)
            batch_rtgs = self.rollout.futur_rewards()
            #self.value_std=max(self.value_std-self.change_std,0.1)
            #self.cov_var = torch.full(size=(self.num_actions,), fill_value=self.value_std)
            #self.cov_mat = torch.diag(self.cov_var)
            self.rollout.reset()
            for i in range(10):
                V_batch = torch.squeeze(self.critic_net(state_batch))
                advantage_batch = batch_rtgs - V_batch
                advantage_batch = (advantage_batch - advantage_batch.mean()) / (advantage_batch.std() + 1e-10)
                
                parameters_batch = torch.squeeze(self.actor_net(state_batch).unsqueeze(-1))
                if(parameters_batch.dim()==1):
                        parameters_batch=torch.unsqueeze(parameters_batch,dim=1)
                distribution_p = MultivariateNormal(parameters_batch, self.cov_mat)
                log_prob_current_batch = distribution_p.log_prob(action_batch)
                ratio_batch = torch.exp(log_prob_current_batch - log_prob_batch)
                ratio_loss = torch.mul(ratio_batch,advantage_batch)
                clip_loss = torch.mul(torch.clamp(ratio_loss, 0.8, 1.2),advantage_batch)
                actor_loss = (-torch.min(ratio_loss, clip_loss)).mean()

                criterion=nn.MSELoss(reduction='mean')
                critic_loss = criterion(V_batch.float(), batch_rtgs.float())
                self.optimizer_actor.zero_grad()
                actor_loss.backward(retain_graph=True)
                self.optimizer_actor.step()
                self.optimizer_critic.zero_grad()
                critic_loss.backward()
                self.optimizer_critic.step()
                
            state_batch, action_batch = self.rollout.iterations(self.actor_net, 30)
            batch_rews = self.rollout.immediate_rewards()
            self.ep_reward_list.append(batch_rews.mean().numpy())
            avg_reward = np.mean(self.ep_reward_list[-10:])
            self.rollout.reset()
            
            print("Episode * {} * Avg Reward is ==> {} And Number of steps is ==> {}".format(ep, avg_reward,ep*self.batch_size ))
            self.total_loop= self.total_loop +1
        path='load_model/parameters/ppo-{num_algo:02d}-{name}-{epoch:03d}000.npy'
        with open(path.format(num_algo=self.num_algo,epoch=int(self.total_loop/1000),name="reward"), 'wb') as f:
            np.save(f, np.array(self.ep_reward_list))
        print("Complete")
        
    def _init_hyperparameters(self, hyperparameters):
        """
        Initialize hyperparameters. 
        :param hyperparameters: hyperparameter list
        """
        self.num_algo = 1
        self.max_steps = 90
        self.total_loop = 0
        self.batch_size = 2000
        self.gamma = 0.99
        self.critic_lr = 3e-4
        self.actor_lr = 3e-4
        for param, val in hyperparameters.items():
            exec('self.' + param + ' = ' + str(val)) #juste trop fort
            
    def loading(self, num_algo, total_loop):
        """
        Loading NN weights 
        :param num_algo: algorithm number
        :param total_loop: number of total batch iterations
        """
        self.num_algo = num_algo
        self.total_loop = total_loop
        checkpoint_path1 = "load_model/weights/torch-ppo-{num_algo:02d}-actor-{epoch:03d}0.pth"
        self.actor_net.load_state_dict(torch.load(checkpoint_path1.format(epoch=int(self.total_loop/10), num_algo=self.num_algo)))
        checkpoint_path2 = "load_model/weights/torch-ppo-{num_algo:02d}-critic-{epoch:03d}0.pth"
        self.critic_net.load_state_dict(torch.load(checkpoint_path2.format(epoch=int(self.total_loop/10), num_algo=self.num_algo)))
    
    def saving(self):
        """
        Saving NN weights 
        """
        checkpoint_path = "load_model/weights/torch-ppo-{num_algo:02d}-actor-{epoch:03d}0.pth"
        torch.save(self.actor_net.state_dict(),checkpoint_path.format(epoch=int(self.total_loop/10), num_algo=self.num_algo))
        checkpoint_path = "load_model/weights/torch-ppo-{num_algo:02d}-critic-{epoch:03d}0.pth"
        torch.save(self.critic_net.state_dict(),checkpoint_path.format(epoch=int(self.total_loop/10), num_algo=self.num_algo))

# %%
#5) Computing part:
# Import environment
problem = "Crosswalk_comparison2-v0"
u_b = [2.0, 11.0, -12.5, 1.1, -1.0]
l_b = [-4.0, 9.0, -32.5, 0.9, -2.0]

env = gym.make(problem,dt=0.3,Vm=2.5,tau=1.0,lower_bounds=l_b, upper_bounds=u_b,simulation="sin")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the algorithm
num_states = env.observation_space.shape[0]
num_actions = env.action_space.shape[0]
num_algo=32

algo=Algo_PPO(Model_PPO, env, num_algo= num_algo, num_states=num_states, num_actions=num_actions)
#algo.loading(1,1000)
# Out:
# C:\Users\abrunoud\Anaconda3\envs\ppotest\lib\site-packages\gym\logger.py:34: UserWarning: WARN: Box bound precision lowered by casting to float32
#   warnings.warn(colorize("%s: %s" % ("WARN", msg % args), "yellow"))

# %%
#Training
import time
start = time.process_time()
algo.train(1000)
algo.saving()
end = time.process_time()
print("Running time: "+str(end-start))
# Out:
# Episode * 0 * Avg Reward is ==> -7.608620643615723 And Number of steps is ==> 0
# Episode * 1 * Avg Reward is ==> -6.695455551147461 And Number of steps is ==> 2000
# Accident!
# Episode * 2 * Avg Reward is ==> -5.911814212799072 And Number of steps is ==> 4000
# Accident!
# Accident!
# Episode * 3 * Avg Reward is ==> -6.207633972167969 And Number of steps is ==> 6000
# Accident!
# Episode * 4 * Avg Reward is ==> -6.697674751281738 And Number of steps is ==> 8000
# Accident!
# Accident!
# Accident!
# Episode * 5 * Avg Reward is ==> -6.899030685424805 And Number of steps is ==> 10000
# Accident!
# Accident!
# Episode * 6 * Avg Reward is ==> -7.3812079429626465 And Number of steps is ==> 12000
# Episode * 7 * Avg Reward is ==> -7.2688751220703125 And Number of steps is ==> 14000
# Accident!
# Episode * 8 * Avg Reward is ==> -7.362970352172852 And Number of steps is ==> 16000
# Episode * 9 * Avg Reward is ==> -7.427036285400391 And Number of steps is ==> 18000
# Episode * 10 * Avg Reward is ==> -7.361649990081787 And Number of steps is ==> 20000
# Episode * 11 * Avg Reward is ==> -7.270346164703369 And Number of steps is ==> 22000
# Episode * 12 * Avg Reward is ==> -7.468344688415527 And Number of steps is ==> 24000
# Episode * 13 * Avg Reward is ==> -7.3307366371154785 And Number of steps is ==> 26000
# Episode * 14 * Avg Reward is ==> -7.259587287902832 And Number of steps is ==> 28000
# Accident!
# Episode * 15 * Avg Reward is ==> -7.318060398101807 And Number of steps is ==> 30000
# Accident!
# Episode * 16 * Avg Reward is ==> -7.072324275970459 And Number of steps is ==> 32000
# Episode * 17 * Avg Reward is ==> -6.969559669494629 And Number of steps is ==> 34000
# Accident!
# Episode * 18 * Avg Reward is ==> -6.885610103607178 And Number of steps is ==> 36000
# Accident!
# Episode * 19 * Avg Reward is ==> -6.524285793304443 And Number of steps is ==> 38000
# Accident!
# Episode * 20 * Avg Reward is ==> -6.92874813079834 And Number of steps is ==> 40000
# Accident!
# Accident!
# Accident!
# Episode * 21 * Avg Reward is ==> -6.8733344078063965 And Number of steps is ==> 42000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 22 * Avg Reward is ==> -6.722440242767334 And Number of steps is ==> 44000
# Episode * 23 * Avg Reward is ==> -6.710691928863525 And Number of steps is ==> 46000
# Accident!
# Episode * 24 * Avg Reward is ==> -7.8265862464904785 And Number of steps is ==> 48000
# Accident!
# Accident!
# Accident!
# Episode * 25 * Avg Reward is ==> -7.467881679534912 And Number of steps is ==> 50000
# Accident!
# Accident!
# Episode * 26 * Avg Reward is ==> -7.219647407531738 And Number of steps is ==> 52000
# Accident!
# Accident!
# Episode * 27 * Avg Reward is ==> -7.224514961242676 And Number of steps is ==> 54000
# Accident!
# Accident!
# Accident!
# Episode * 28 * Avg Reward is ==> -7.184328556060791 And Number of steps is ==> 56000
# Accident!
# Accident!
# Episode * 29 * Avg Reward is ==> -7.349276542663574 And Number of steps is ==> 58000
# Accident!
# Accident!
# Accident!
# Episode * 30 * Avg Reward is ==> -6.856544494628906 And Number of steps is ==> 60000
# Accident!
# Accident!
# Episode * 31 * Avg Reward is ==> -6.955662727355957 And Number of steps is ==> 62000
# Accident!
# Accident!
# Episode * 32 * Avg Reward is ==> -6.995293617248535 And Number of steps is ==> 64000
# Accident!
# Accident!
# Accident!
# Episode * 33 * Avg Reward is ==> -7.068808078765869 And Number of steps is ==> 66000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 34 * Avg Reward is ==> -5.677737236022949 And Number of steps is ==> 68000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 35 * Avg Reward is ==> -5.813634395599365 And Number of steps is ==> 70000
# Accident!
# Accident!
# Accident!
# Episode * 36 * Avg Reward is ==> -5.763659954071045 And Number of steps is ==> 72000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 37 * Avg Reward is ==> -5.886720657348633 And Number of steps is ==> 74000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 38 * Avg Reward is ==> -5.762923240661621 And Number of steps is ==> 76000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 39 * Avg Reward is ==> -5.662407398223877 And Number of steps is ==> 78000
# Accident!
# Episode * 40 * Avg Reward is ==> -5.664459705352783 And Number of steps is ==> 80000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 41 * Avg Reward is ==> -5.626533031463623 And Number of steps is ==> 82000
# Accident!
# Episode * 42 * Avg Reward is ==> -5.561122417449951 And Number of steps is ==> 84000
# Accident!
# Accident!
# Episode * 43 * Avg Reward is ==> -5.423463821411133 And Number of steps is ==> 86000
# Accident!
# Accident!
# Accident!
# Episode * 44 * Avg Reward is ==> -5.43300724029541 And Number of steps is ==> 88000
# Accident!
# Accident!
# Episode * 45 * Avg Reward is ==> -5.300529479980469 And Number of steps is ==> 90000
# Accident!
# Accident!
# Episode * 46 * Avg Reward is ==> -5.242570400238037 And Number of steps is ==> 92000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 47 * Avg Reward is ==> -5.183844566345215 And Number of steps is ==> 94000
# Accident!
# Accident!
# Accident!
# Episode * 48 * Avg Reward is ==> -5.0255608558654785 And Number of steps is ==> 96000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 49 * Avg Reward is ==> -4.990665435791016 And Number of steps is ==> 98000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 50 * Avg Reward is ==> -4.818995475769043 And Number of steps is ==> 100000
# Accident!
# Accident!
# Accident!
# Episode * 51 * Avg Reward is ==> -4.755288600921631 And Number of steps is ==> 102000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 52 * Avg Reward is ==> -5.9071807861328125 And Number of steps is ==> 104000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 53 * Avg Reward is ==> -5.734766960144043 And Number of steps is ==> 106000
# Accident!
# Accident!
# Episode * 54 * Avg Reward is ==> -5.6967387199401855 And Number of steps is ==> 108000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 55 * Avg Reward is ==> -5.775948524475098 And Number of steps is ==> 110000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 56 * Avg Reward is ==> -5.951113224029541 And Number of steps is ==> 112000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 57 * Avg Reward is ==> -5.910470008850098 And Number of steps is ==> 114000
# Accident!
# Episode * 58 * Avg Reward is ==> -6.029746055603027 And Number of steps is ==> 116000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 59 * Avg Reward is ==> -6.0883049964904785 And Number of steps is ==> 118000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 60 * Avg Reward is ==> -6.112850666046143 And Number of steps is ==> 120000
# Accident!
# Accident!
# Accident!
# Episode * 61 * Avg Reward is ==> -6.19946813583374 And Number of steps is ==> 122000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 62 * Avg Reward is ==> -4.994110107421875 And Number of steps is ==> 124000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 63 * Avg Reward is ==> -5.142858505249023 And Number of steps is ==> 126000
# Accident!
# Accident!
# Accident!
# Episode * 64 * Avg Reward is ==> -5.2710466384887695 And Number of steps is ==> 128000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 65 * Avg Reward is ==> -5.247481346130371 And Number of steps is ==> 130000
# Accident!
# Accident!
# Accident!
# Episode * 66 * Avg Reward is ==> -5.374136924743652 And Number of steps is ==> 132000
# Accident!
# Accident!
# Accident!
# Episode * 67 * Avg Reward is ==> -5.322249412536621 And Number of steps is ==> 134000
# Accident!
# Accident!
# Episode * 68 * Avg Reward is ==> -5.3091912269592285 And Number of steps is ==> 136000
# Accident!
# Accident!
# Accident!
# Episode * 69 * Avg Reward is ==> -5.310133934020996 And Number of steps is ==> 138000
# Accident!
# Accident!
# Episode * 70 * Avg Reward is ==> -5.432204246520996 And Number of steps is ==> 140000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 71 * Avg Reward is ==> -5.697613716125488 And Number of steps is ==> 142000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 72 * Avg Reward is ==> -5.713540077209473 And Number of steps is ==> 144000
# Accident!
# Accident!
# Episode * 73 * Avg Reward is ==> -5.821694374084473 And Number of steps is ==> 146000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 74 * Avg Reward is ==> -5.803257465362549 And Number of steps is ==> 148000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 75 * Avg Reward is ==> -5.776937007904053 And Number of steps is ==> 150000
# Accident!
# Accident!
# Accident!
# Episode * 76 * Avg Reward is ==> -5.643520832061768 And Number of steps is ==> 152000
# Accident!
# Accident!
# Episode * 77 * Avg Reward is ==> -5.654059410095215 And Number of steps is ==> 154000
# Accident!
# Episode * 78 * Avg Reward is ==> -5.721554756164551 And Number of steps is ==> 156000
# Accident!
# Accident!
# Episode * 79 * Avg Reward is ==> -5.6933135986328125 And Number of steps is ==> 158000
# Accident!
# Accident!
# Episode * 80 * Avg Reward is ==> -5.453364372253418 And Number of steps is ==> 160000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 81 * Avg Reward is ==> -5.249904155731201 And Number of steps is ==> 162000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 82 * Avg Reward is ==> -5.356499671936035 And Number of steps is ==> 164000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 83 * Avg Reward is ==> -5.247346878051758 And Number of steps is ==> 166000
# Accident!
# Accident!
# Accident!
# Episode * 84 * Avg Reward is ==> -5.147793769836426 And Number of steps is ==> 168000
# Accident!
# Accident!
# Accident!
# Episode * 85 * Avg Reward is ==> -5.182109355926514 And Number of steps is ==> 170000
# Accident!
# Accident!
# Accident!
# Episode * 86 * Avg Reward is ==> -5.241520881652832 And Number of steps is ==> 172000
# Accident!
# Episode * 87 * Avg Reward is ==> -5.198378562927246 And Number of steps is ==> 174000
# Accident!
# Episode * 88 * Avg Reward is ==> -5.007323265075684 And Number of steps is ==> 176000
# Episode * 89 * Avg Reward is ==> -4.945874214172363 And Number of steps is ==> 178000
# Accident!
# Episode * 90 * Avg Reward is ==> -5.104850769042969 And Number of steps is ==> 180000
# Accident!
# Accident!
# Episode * 91 * Avg Reward is ==> -4.967918395996094 And Number of steps is ==> 182000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 92 * Avg Reward is ==> -4.993552207946777 And Number of steps is ==> 184000
# Accident!
# Accident!
# Accident!
# Episode * 93 * Avg Reward is ==> -5.11907958984375 And Number of steps is ==> 186000
# Accident!
# Accident!
# Episode * 94 * Avg Reward is ==> -5.097856044769287 And Number of steps is ==> 188000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 95 * Avg Reward is ==> -5.050800800323486 And Number of steps is ==> 190000
# Accident!
# Accident!
# Episode * 96 * Avg Reward is ==> -4.810314655303955 And Number of steps is ==> 192000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 97 * Avg Reward is ==> -4.829108238220215 And Number of steps is ==> 194000
# Accident!
# Accident!
# Accident!
# Episode * 98 * Avg Reward is ==> -4.884369850158691 And Number of steps is ==> 196000
# Accident!
# Episode * 99 * Avg Reward is ==> -4.920252323150635 And Number of steps is ==> 198000
# Accident!
# Accident!
# Episode * 100 * Avg Reward is ==> -4.731219291687012 And Number of steps is ==> 200000
# Accident!
# Accident!
# Episode * 101 * Avg Reward is ==> -4.70855712890625 And Number of steps is ==> 202000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 102 * Avg Reward is ==> -4.633936405181885 And Number of steps is ==> 204000
# Accident!
# Accident!
# Episode * 103 * Avg Reward is ==> -4.424814224243164 And Number of steps is ==> 206000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 104 * Avg Reward is ==> -4.439981937408447 And Number of steps is ==> 208000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 105 * Avg Reward is ==> -4.442862510681152 And Number of steps is ==> 210000
# Accident!
# Accident!
# Episode * 106 * Avg Reward is ==> -4.568711280822754 And Number of steps is ==> 212000
# Accident!
# Episode * 107 * Avg Reward is ==> -4.720288276672363 And Number of steps is ==> 214000
# Accident!
# Episode * 108 * Avg Reward is ==> -4.75980281829834 And Number of steps is ==> 216000
# Episode * 109 * Avg Reward is ==> -4.701866626739502 And Number of steps is ==> 218000
# Accident!
# Episode * 110 * Avg Reward is ==> -4.818830966949463 And Number of steps is ==> 220000
# Accident!
# Accident!
# Accident!
# Episode * 111 * Avg Reward is ==> -4.906800746917725 And Number of steps is ==> 222000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 112 * Avg Reward is ==> -5.042240142822266 And Number of steps is ==> 224000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 113 * Avg Reward is ==> -5.148869514465332 And Number of steps is ==> 226000
# Episode * 114 * Avg Reward is ==> -5.066036224365234 And Number of steps is ==> 228000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 115 * Avg Reward is ==> -4.955625057220459 And Number of steps is ==> 230000
# Accident!
# Accident!
# Episode * 116 * Avg Reward is ==> -4.786288261413574 And Number of steps is ==> 232000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 117 * Avg Reward is ==> -4.701107025146484 And Number of steps is ==> 234000
# Accident!
# Accident!
# Accident!
# Episode * 118 * Avg Reward is ==> -4.678572654724121 And Number of steps is ==> 236000
# Episode * 119 * Avg Reward is ==> -4.649456977844238 And Number of steps is ==> 238000
# Accident!
# Accident!
# Accident!
# Episode * 120 * Avg Reward is ==> -4.64868688583374 And Number of steps is ==> 240000
# Accident!
# Accident!
# Accident!
# Episode * 121 * Avg Reward is ==> -4.583245754241943 And Number of steps is ==> 242000
# Accident!
# Accident!
# Episode * 122 * Avg Reward is ==> -4.449132442474365 And Number of steps is ==> 244000
# Accident!
# Accident!
# Episode * 123 * Avg Reward is ==> -4.472792625427246 And Number of steps is ==> 246000
# Accident!
# Accident!
# Accident!
# Episode * 124 * Avg Reward is ==> -4.594674587249756 And Number of steps is ==> 248000
# Accident!
# Accident!
# Episode * 125 * Avg Reward is ==> -4.583143711090088 And Number of steps is ==> 250000
# Accident!
# Accident!
# Accident!
# Episode * 126 * Avg Reward is ==> -4.680627346038818 And Number of steps is ==> 252000
# Accident!
# Accident!
# Episode * 127 * Avg Reward is ==> -4.546473979949951 And Number of steps is ==> 254000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 128 * Avg Reward is ==> -4.552745342254639 And Number of steps is ==> 256000
# Accident!
# Episode * 129 * Avg Reward is ==> -4.609142780303955 And Number of steps is ==> 258000
# Accident!
# Accident!
# Accident!
# Episode * 130 * Avg Reward is ==> -4.790527820587158 And Number of steps is ==> 260000
# Accident!
# Episode * 131 * Avg Reward is ==> -4.777748107910156 And Number of steps is ==> 262000
# Accident!
# Accident!
# Episode * 132 * Avg Reward is ==> -4.616544723510742 And Number of steps is ==> 264000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 133 * Avg Reward is ==> -4.675041198730469 And Number of steps is ==> 266000
# Accident!
# Episode * 134 * Avg Reward is ==> -4.568119525909424 And Number of steps is ==> 268000
# Accident!
# Accident!
# Accident!
# Episode * 135 * Avg Reward is ==> -4.4928364753723145 And Number of steps is ==> 270000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 136 * Avg Reward is ==> -4.431960105895996 And Number of steps is ==> 272000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 137 * Avg Reward is ==> -4.3889570236206055 And Number of steps is ==> 274000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 138 * Avg Reward is ==> -4.4197001457214355 And Number of steps is ==> 276000
# Accident!
# Episode * 139 * Avg Reward is ==> -4.433682441711426 And Number of steps is ==> 278000
# Accident!
# Accident!
# Episode * 140 * Avg Reward is ==> -4.225996494293213 And Number of steps is ==> 280000
# Accident!
# Accident!
# Episode * 141 * Avg Reward is ==> -4.151327133178711 And Number of steps is ==> 282000
# Accident!
# Accident!
# Episode * 142 * Avg Reward is ==> -4.326831340789795 And Number of steps is ==> 284000
# Accident!
# Accident!
# Episode * 143 * Avg Reward is ==> -4.178752422332764 And Number of steps is ==> 286000
# Accident!
# Episode * 144 * Avg Reward is ==> -4.195315361022949 And Number of steps is ==> 288000
# Accident!
# Accident!
# Accident!
# Episode * 145 * Avg Reward is ==> -4.475092887878418 And Number of steps is ==> 290000
# Accident!
# Episode * 146 * Avg Reward is ==> -4.556771278381348 And Number of steps is ==> 292000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 147 * Avg Reward is ==> -4.733532905578613 And Number of steps is ==> 294000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 148 * Avg Reward is ==> -4.7015814781188965 And Number of steps is ==> 296000
# Accident!
# Accident!
# Episode * 149 * Avg Reward is ==> -4.718737602233887 And Number of steps is ==> 298000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 150 * Avg Reward is ==> -4.973961353302002 And Number of steps is ==> 300000
# Accident!
# Accident!
# Accident!
# Episode * 151 * Avg Reward is ==> -5.064211368560791 And Number of steps is ==> 302000
# Accident!
# Accident!
# Accident!
# Episode * 152 * Avg Reward is ==> -5.243685722351074 And Number of steps is ==> 304000
# Accident!
# Episode * 153 * Avg Reward is ==> -5.285947322845459 And Number of steps is ==> 306000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 154 * Avg Reward is ==> -5.364960193634033 And Number of steps is ==> 308000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 155 * Avg Reward is ==> -5.238171577453613 And Number of steps is ==> 310000
# Episode * 156 * Avg Reward is ==> -5.087277412414551 And Number of steps is ==> 312000
# Accident!
# Accident!
# Episode * 157 * Avg Reward is ==> -4.978163719177246 And Number of steps is ==> 314000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 158 * Avg Reward is ==> -4.949395656585693 And Number of steps is ==> 316000
# Accident!
# Accident!
# Episode * 159 * Avg Reward is ==> -4.886408805847168 And Number of steps is ==> 318000
# Accident!
# Accident!
# Accident!
# Episode * 160 * Avg Reward is ==> -4.623137474060059 And Number of steps is ==> 320000
# Accident!
# Episode * 161 * Avg Reward is ==> -4.701000690460205 And Number of steps is ==> 322000
# Accident!
# Episode * 162 * Avg Reward is ==> -4.457425117492676 And Number of steps is ==> 324000
# Episode * 163 * Avg Reward is ==> -4.388277530670166 And Number of steps is ==> 326000
# Accident!
# Episode * 164 * Avg Reward is ==> -4.277276039123535 And Number of steps is ==> 328000
# Accident!
# Episode * 165 * Avg Reward is ==> -4.204174041748047 And Number of steps is ==> 330000
# Accident!
# Episode * 166 * Avg Reward is ==> -4.287386417388916 And Number of steps is ==> 332000
# Accident!
# Accident!
# Accident!
# Episode * 167 * Avg Reward is ==> -4.336880683898926 And Number of steps is ==> 334000
# Accident!
# Accident!
# Accident!
# Episode * 168 * Avg Reward is ==> -4.406308174133301 And Number of steps is ==> 336000
# Accident!
# Accident!
# Accident!
# Episode * 169 * Avg Reward is ==> -4.328763008117676 And Number of steps is ==> 338000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 170 * Avg Reward is ==> -4.532670021057129 And Number of steps is ==> 340000
# Accident!
# Episode * 171 * Avg Reward is ==> -4.357234954833984 And Number of steps is ==> 342000
# Accident!
# Episode * 172 * Avg Reward is ==> -4.507811546325684 And Number of steps is ==> 344000
# Accident!
# Accident!
# Accident!
# Episode * 173 * Avg Reward is ==> -4.628117561340332 And Number of steps is ==> 346000
# Accident!
# Episode * 174 * Avg Reward is ==> -4.660297393798828 And Number of steps is ==> 348000
# Accident!
# Accident!
# Accident!
# Episode * 175 * Avg Reward is ==> -4.728056907653809 And Number of steps is ==> 350000
# Accident!
# Accident!
# Episode * 176 * Avg Reward is ==> -4.7910261154174805 And Number of steps is ==> 352000
# Accident!
# Accident!
# Accident!
# Episode * 177 * Avg Reward is ==> -4.760814189910889 And Number of steps is ==> 354000
# Accident!
# Accident!
# Episode * 178 * Avg Reward is ==> -4.695084571838379 And Number of steps is ==> 356000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 179 * Avg Reward is ==> -4.746477127075195 And Number of steps is ==> 358000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 180 * Avg Reward is ==> -4.5489325523376465 And Number of steps is ==> 360000
# Accident!
# Accident!
# Accident!
# Episode * 181 * Avg Reward is ==> -4.774292945861816 And Number of steps is ==> 362000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 182 * Avg Reward is ==> -4.738777160644531 And Number of steps is ==> 364000
# Episode * 183 * Avg Reward is ==> -4.742413520812988 And Number of steps is ==> 366000
# Accident!
# Accident!
# Episode * 184 * Avg Reward is ==> -4.716317176818848 And Number of steps is ==> 368000
# Accident!
# Accident!
# Episode * 185 * Avg Reward is ==> -4.735698223114014 And Number of steps is ==> 370000
# Accident!
# Accident!
# Episode * 186 * Avg Reward is ==> -4.7071943283081055 And Number of steps is ==> 372000
# Episode * 187 * Avg Reward is ==> -4.640953540802002 And Number of steps is ==> 374000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 188 * Avg Reward is ==> -4.5778703689575195 And Number of steps is ==> 376000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 189 * Avg Reward is ==> -4.573888301849365 And Number of steps is ==> 378000
# Accident!
# Episode * 190 * Avg Reward is ==> -4.618751049041748 And Number of steps is ==> 380000
# Accident!
# Accident!
# Episode * 191 * Avg Reward is ==> -4.491499900817871 And Number of steps is ==> 382000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 192 * Avg Reward is ==> -4.37602424621582 And Number of steps is ==> 384000
# Accident!
# Accident!
# Episode * 193 * Avg Reward is ==> -4.293837070465088 And Number of steps is ==> 386000
# Accident!
# Accident!
# Episode * 194 * Avg Reward is ==> -4.290877342224121 And Number of steps is ==> 388000
# Accident!
# Episode * 195 * Avg Reward is ==> -4.1514387130737305 And Number of steps is ==> 390000
# Accident!
# Accident!
# Accident!
# Episode * 196 * Avg Reward is ==> -4.197931289672852 And Number of steps is ==> 392000
# Episode * 197 * Avg Reward is ==> -4.120031356811523 And Number of steps is ==> 394000
# Accident!
# Accident!
# Accident!
# Episode * 198 * Avg Reward is ==> -4.167250156402588 And Number of steps is ==> 396000
# Accident!
# Episode * 199 * Avg Reward is ==> -4.18477725982666 And Number of steps is ==> 398000
# Accident!
# Episode * 200 * Avg Reward is ==> -4.123196125030518 And Number of steps is ==> 400000
# Accident!
# Accident!
# Episode * 201 * Avg Reward is ==> -4.090796947479248 And Number of steps is ==> 402000
# Accident!
# Accident!
# Episode * 202 * Avg Reward is ==> -4.137030124664307 And Number of steps is ==> 404000
# Accident!
# Episode * 203 * Avg Reward is ==> -4.176833152770996 And Number of steps is ==> 406000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 204 * Avg Reward is ==> -4.288778781890869 And Number of steps is ==> 408000
# Accident!
# Episode * 205 * Avg Reward is ==> -4.313032150268555 And Number of steps is ==> 410000
# Episode * 206 * Avg Reward is ==> -4.2515058517456055 And Number of steps is ==> 412000
# Accident!
# Accident!
# Episode * 207 * Avg Reward is ==> -4.373721122741699 And Number of steps is ==> 414000
# Accident!
# Accident!
# Episode * 208 * Avg Reward is ==> -4.437028408050537 And Number of steps is ==> 416000
# Accident!
# Accident!
# Episode * 209 * Avg Reward is ==> -4.545328617095947 And Number of steps is ==> 418000
# Accident!
# Episode * 210 * Avg Reward is ==> -4.605626583099365 And Number of steps is ==> 420000
# Episode * 211 * Avg Reward is ==> -4.677114486694336 And Number of steps is ==> 422000
# Accident!
# Episode * 212 * Avg Reward is ==> -4.6239118576049805 And Number of steps is ==> 424000
# Accident!
# Accident!
# Episode * 213 * Avg Reward is ==> -4.620687484741211 And Number of steps is ==> 426000
# Accident!
# Accident!
# Episode * 214 * Avg Reward is ==> -4.556978225708008 And Number of steps is ==> 428000
# Accident!
# Episode * 215 * Avg Reward is ==> -4.671544551849365 And Number of steps is ==> 430000
# Accident!
# Accident!
# Episode * 216 * Avg Reward is ==> -4.635164260864258 And Number of steps is ==> 432000
# Episode * 217 * Avg Reward is ==> -4.630570888519287 And Number of steps is ==> 434000
# Episode * 218 * Avg Reward is ==> -4.554956912994385 And Number of steps is ==> 436000
# Episode * 219 * Avg Reward is ==> -4.508166313171387 And Number of steps is ==> 438000
# Accident!
# Episode * 220 * Avg Reward is ==> -4.481074333190918 And Number of steps is ==> 440000
# Episode * 221 * Avg Reward is ==> -4.44256067276001 And Number of steps is ==> 442000
# Accident!
# Episode * 222 * Avg Reward is ==> -4.489474296569824 And Number of steps is ==> 444000
# Episode * 223 * Avg Reward is ==> -4.43014669418335 And Number of steps is ==> 446000
# Episode * 224 * Avg Reward is ==> -4.499791145324707 And Number of steps is ==> 448000
# Accident!
# Accident!
# Accident!
# Episode * 225 * Avg Reward is ==> -4.411398887634277 And Number of steps is ==> 450000
# Episode * 226 * Avg Reward is ==> -4.479329586029053 And Number of steps is ==> 452000
# Accident!
# Accident!
# Episode * 227 * Avg Reward is ==> -4.414377212524414 And Number of steps is ==> 454000
# Accident!
# Accident!
# Accident!
# Episode * 228 * Avg Reward is ==> -4.51649284362793 And Number of steps is ==> 456000
# Accident!
# Accident!
# Episode * 229 * Avg Reward is ==> -4.4064202308654785 And Number of steps is ==> 458000
# Episode * 230 * Avg Reward is ==> -4.404627323150635 And Number of steps is ==> 460000
# Accident!
# Accident!
# Accident!
# Episode * 231 * Avg Reward is ==> -4.481027126312256 And Number of steps is ==> 462000
# Accident!
# Episode * 232 * Avg Reward is ==> -4.45035457611084 And Number of steps is ==> 464000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 233 * Avg Reward is ==> -4.593237400054932 And Number of steps is ==> 466000
# Accident!
# Episode * 234 * Avg Reward is ==> -4.547792911529541 And Number of steps is ==> 468000
# Accident!
# Accident!
# Episode * 235 * Avg Reward is ==> -4.633301734924316 And Number of steps is ==> 470000
# Episode * 236 * Avg Reward is ==> -4.533222198486328 And Number of steps is ==> 472000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 237 * Avg Reward is ==> -4.7631635665893555 And Number of steps is ==> 474000
# Accident!
# Accident!
# Episode * 238 * Avg Reward is ==> -4.739330291748047 And Number of steps is ==> 476000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 239 * Avg Reward is ==> -4.880053520202637 And Number of steps is ==> 478000
# Accident!
# Accident!
# Accident!
# Episode * 240 * Avg Reward is ==> -4.9551801681518555 And Number of steps is ==> 480000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 241 * Avg Reward is ==> -4.768684387207031 And Number of steps is ==> 482000
# Accident!
# Accident!
# Episode * 242 * Avg Reward is ==> -4.778347969055176 And Number of steps is ==> 484000
# Accident!
# Episode * 243 * Avg Reward is ==> -4.767035484313965 And Number of steps is ==> 486000
# Episode * 244 * Avg Reward is ==> -4.787732124328613 And Number of steps is ==> 488000
# Accident!
# Episode * 245 * Avg Reward is ==> -4.872443675994873 And Number of steps is ==> 490000
# Accident!
# Accident!
# Episode * 246 * Avg Reward is ==> -5.046505928039551 And Number of steps is ==> 492000
# Episode * 247 * Avg Reward is ==> -4.909433841705322 And Number of steps is ==> 494000
# Accident!
# Episode * 248 * Avg Reward is ==> -4.858410835266113 And Number of steps is ==> 496000
# Accident!
# Accident!
# Episode * 249 * Avg Reward is ==> -4.812569618225098 And Number of steps is ==> 498000
# Episode * 250 * Avg Reward is ==> -4.695715427398682 And Number of steps is ==> 500000
# Accident!
# Episode * 251 * Avg Reward is ==> -4.773672580718994 And Number of steps is ==> 502000
# Accident!
# Episode * 252 * Avg Reward is ==> -4.745398998260498 And Number of steps is ==> 504000
# Episode * 253 * Avg Reward is ==> -4.6431989669799805 And Number of steps is ==> 506000
# Accident!
# Episode * 254 * Avg Reward is ==> -4.56015157699585 And Number of steps is ==> 508000
# Accident!
# Episode * 255 * Avg Reward is ==> -4.471730709075928 And Number of steps is ==> 510000
# Accident!
# Accident!
# Accident!
# Episode * 256 * Avg Reward is ==> -4.210018157958984 And Number of steps is ==> 512000
# Accident!
# Episode * 257 * Avg Reward is ==> -4.121593952178955 And Number of steps is ==> 514000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 258 * Avg Reward is ==> -4.198122978210449 And Number of steps is ==> 516000
# Accident!
# Episode * 259 * Avg Reward is ==> -4.167305946350098 And Number of steps is ==> 518000
# Accident!
# Accident!
# Accident!
# Episode * 260 * Avg Reward is ==> -4.337602138519287 And Number of steps is ==> 520000
# Accident!
# Accident!
# Episode * 261 * Avg Reward is ==> -4.2978835105896 And Number of steps is ==> 522000
# Accident!
# Episode * 262 * Avg Reward is ==> -4.380039691925049 And Number of steps is ==> 524000
# Accident!
# Accident!
# Accident!
# Episode * 263 * Avg Reward is ==> -4.290148735046387 And Number of steps is ==> 526000
# Accident!
# Accident!
# Episode * 264 * Avg Reward is ==> -4.358355522155762 And Number of steps is ==> 528000
# Accident!
# Accident!
# Episode * 265 * Avg Reward is ==> -4.3049116134643555 And Number of steps is ==> 530000
# Accident!
# Accident!
# Accident!
# Episode * 266 * Avg Reward is ==> -4.398641586303711 And Number of steps is ==> 532000
# Accident!
# Accident!
# Episode * 267 * Avg Reward is ==> -4.34366512298584 And Number of steps is ==> 534000
# Accident!
# Episode * 268 * Avg Reward is ==> -4.2527360916137695 And Number of steps is ==> 536000
# Episode * 269 * Avg Reward is ==> -4.1754984855651855 And Number of steps is ==> 538000
# Accident!
# Accident!
# Accident!
# Episode * 270 * Avg Reward is ==> -3.9177451133728027 And Number of steps is ==> 540000
# Accident!
# Accident!
# Accident!
# Episode * 271 * Avg Reward is ==> -3.865450620651245 And Number of steps is ==> 542000
# Episode * 272 * Avg Reward is ==> -3.7519733905792236 And Number of steps is ==> 544000
# Accident!
# Accident!
# Episode * 273 * Avg Reward is ==> -3.7263495922088623 And Number of steps is ==> 546000
# Episode * 274 * Avg Reward is ==> -3.6068577766418457 And Number of steps is ==> 548000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 275 * Avg Reward is ==> -3.502150058746338 And Number of steps is ==> 550000
# Accident!
# Accident!
# Episode * 276 * Avg Reward is ==> -3.438084363937378 And Number of steps is ==> 552000
# Accident!
# Accident!
# Episode * 277 * Avg Reward is ==> -3.448927640914917 And Number of steps is ==> 554000
# Episode * 278 * Avg Reward is ==> -3.4246482849121094 And Number of steps is ==> 556000
# Episode * 279 * Avg Reward is ==> -3.3299248218536377 And Number of steps is ==> 558000
# Episode * 280 * Avg Reward is ==> -3.401371479034424 And Number of steps is ==> 560000
# Accident!
# Accident!
# Episode * 281 * Avg Reward is ==> -3.423776626586914 And Number of steps is ==> 562000
# Accident!
# Accident!
# Episode * 282 * Avg Reward is ==> -3.3464198112487793 And Number of steps is ==> 564000
# Accident!
# Accident!
# Episode * 283 * Avg Reward is ==> -3.4191622734069824 And Number of steps is ==> 566000
# Accident!
# Accident!
# Accident!
# Episode * 284 * Avg Reward is ==> -3.4036383628845215 And Number of steps is ==> 568000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 285 * Avg Reward is ==> -3.447658061981201 And Number of steps is ==> 570000
# Episode * 286 * Avg Reward is ==> -3.494473695755005 And Number of steps is ==> 572000
# Accident!
# Accident!
# Accident!
# Episode * 287 * Avg Reward is ==> -3.5179200172424316 And Number of steps is ==> 574000
# Accident!
# Accident!
# Accident!
# Episode * 288 * Avg Reward is ==> -3.5029754638671875 And Number of steps is ==> 576000
# Accident!
# Episode * 289 * Avg Reward is ==> -3.551405668258667 And Number of steps is ==> 578000
# Accident!
# Accident!
# Episode * 290 * Avg Reward is ==> -3.47257661819458 And Number of steps is ==> 580000
# Accident!
# Accident!
# Episode * 291 * Avg Reward is ==> -3.549644947052002 And Number of steps is ==> 582000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 292 * Avg Reward is ==> -3.6210086345672607 And Number of steps is ==> 584000
# Accident!
# Episode * 293 * Avg Reward is ==> -3.6317005157470703 And Number of steps is ==> 586000
# Accident!
# Accident!
# Episode * 294 * Avg Reward is ==> -3.6908252239227295 And Number of steps is ==> 588000
# Accident!
# Accident!
# Episode * 295 * Avg Reward is ==> -3.722339630126953 And Number of steps is ==> 590000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 296 * Avg Reward is ==> -3.7293007373809814 And Number of steps is ==> 592000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 297 * Avg Reward is ==> -3.886474132537842 And Number of steps is ==> 594000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 298 * Avg Reward is ==> -3.817444324493408 And Number of steps is ==> 596000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 299 * Avg Reward is ==> -3.9190735816955566 And Number of steps is ==> 598000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 300 * Avg Reward is ==> -3.941861629486084 And Number of steps is ==> 600000
# Accident!
# Accident!
# Accident!
# Episode * 301 * Avg Reward is ==> -3.853295087814331 And Number of steps is ==> 602000
# Accident!
# Accident!
# Accident!
# Episode * 302 * Avg Reward is ==> -3.7860617637634277 And Number of steps is ==> 604000
# Accident!
# Accident!
# Accident!
# Episode * 303 * Avg Reward is ==> -3.6593174934387207 And Number of steps is ==> 606000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 304 * Avg Reward is ==> -3.601545810699463 And Number of steps is ==> 608000
# Accident!
# Accident!
# Accident!
# Episode * 305 * Avg Reward is ==> -3.525749921798706 And Number of steps is ==> 610000
# Accident!
# Episode * 306 * Avg Reward is ==> -3.524346113204956 And Number of steps is ==> 612000
# Episode * 307 * Avg Reward is ==> -3.2438511848449707 And Number of steps is ==> 614000
# Episode * 308 * Avg Reward is ==> -3.1995556354522705 And Number of steps is ==> 616000
# Accident!
# Accident!
# Accident!
# Episode * 309 * Avg Reward is ==> -3.1409876346588135 And Number of steps is ==> 618000
# Accident!
# Episode * 310 * Avg Reward is ==> -3.1135854721069336 And Number of steps is ==> 620000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 311 * Avg Reward is ==> -3.15346622467041 And Number of steps is ==> 622000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 312 * Avg Reward is ==> -3.210855007171631 And Number of steps is ==> 624000
# Accident!
# Episode * 313 * Avg Reward is ==> -3.2407984733581543 And Number of steps is ==> 626000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 314 * Avg Reward is ==> -3.2295138835906982 And Number of steps is ==> 628000
# Accident!
# Accident!
# Accident!
# Episode * 315 * Avg Reward is ==> -3.235085964202881 And Number of steps is ==> 630000
# Accident!
# Episode * 316 * Avg Reward is ==> -3.1768691539764404 And Number of steps is ==> 632000
# Accident!
# Accident!
# Accident!
# Episode * 317 * Avg Reward is ==> -3.1908555030822754 And Number of steps is ==> 634000
# Episode * 318 * Avg Reward is ==> -3.2519607543945312 And Number of steps is ==> 636000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 319 * Avg Reward is ==> -3.197617769241333 And Number of steps is ==> 638000
# Accident!
# Episode * 320 * Avg Reward is ==> -3.155163288116455 And Number of steps is ==> 640000
# Episode * 321 * Avg Reward is ==> -3.0328598022460938 And Number of steps is ==> 642000
# Episode * 322 * Avg Reward is ==> -2.931522846221924 And Number of steps is ==> 644000
# Accident!
# Accident!
# Accident!
# Episode * 323 * Avg Reward is ==> -2.7854340076446533 And Number of steps is ==> 646000
# Accident!
# Episode * 324 * Avg Reward is ==> -2.7329578399658203 And Number of steps is ==> 648000
# Accident!
# Episode * 325 * Avg Reward is ==> -2.677694082260132 And Number of steps is ==> 650000
# Accident!
# Episode * 326 * Avg Reward is ==> -2.583199977874756 And Number of steps is ==> 652000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 327 * Avg Reward is ==> -2.5286149978637695 And Number of steps is ==> 654000
# Accident!
# Accident!
# Accident!
# Episode * 328 * Avg Reward is ==> -2.4431040287017822 And Number of steps is ==> 656000
# Accident!
# Accident!
# Accident!
# Episode * 329 * Avg Reward is ==> -2.424455165863037 And Number of steps is ==> 658000
# Accident!
# Accident!
# Accident!
# Episode * 330 * Avg Reward is ==> -2.562030553817749 And Number of steps is ==> 660000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 331 * Avg Reward is ==> -2.6565256118774414 And Number of steps is ==> 662000
# Accident!
# Accident!
# Episode * 332 * Avg Reward is ==> -2.62443208694458 And Number of steps is ==> 664000
# Accident!
# Episode * 333 * Avg Reward is ==> -2.6039156913757324 And Number of steps is ==> 666000
# Accident!
# Episode * 334 * Avg Reward is ==> -2.528709888458252 And Number of steps is ==> 668000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 335 * Avg Reward is ==> -2.452799081802368 And Number of steps is ==> 670000
# Accident!
# Episode * 336 * Avg Reward is ==> -2.5063111782073975 And Number of steps is ==> 672000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 337 * Avg Reward is ==> -2.578646421432495 And Number of steps is ==> 674000
# Accident!
# Accident!
# Episode * 338 * Avg Reward is ==> -2.481645107269287 And Number of steps is ==> 676000
# Accident!
# Episode * 339 * Avg Reward is ==> -2.4000799655914307 And Number of steps is ==> 678000
# Accident!
# Episode * 340 * Avg Reward is ==> -2.2080631256103516 And Number of steps is ==> 680000
# Accident!
# Episode * 341 * Avg Reward is ==> -2.048369884490967 And Number of steps is ==> 682000
# Episode * 342 * Avg Reward is ==> -1.9672925472259521 And Number of steps is ==> 684000
# Accident!
# Accident!
# Episode * 343 * Avg Reward is ==> -1.9784523248672485 And Number of steps is ==> 686000
# Episode * 344 * Avg Reward is ==> -1.9600547552108765 And Number of steps is ==> 688000
# Episode * 345 * Avg Reward is ==> -1.934857726097107 And Number of steps is ==> 690000
# Episode * 346 * Avg Reward is ==> -1.8275871276855469 And Number of steps is ==> 692000
# Episode * 347 * Avg Reward is ==> -1.697763442993164 And Number of steps is ==> 694000
# Episode * 348 * Avg Reward is ==> -1.721475601196289 And Number of steps is ==> 696000
# Episode * 349 * Avg Reward is ==> -1.6959102153778076 And Number of steps is ==> 698000
# Accident!
# Episode * 350 * Avg Reward is ==> -1.7177164554595947 And Number of steps is ==> 700000
# Accident!
# Episode * 351 * Avg Reward is ==> -1.753622055053711 And Number of steps is ==> 702000
# Episode * 352 * Avg Reward is ==> -1.7548258304595947 And Number of steps is ==> 704000
# Episode * 353 * Avg Reward is ==> -1.7301985025405884 And Number of steps is ==> 706000
# Accident!
# Accident!
# Accident!
# Episode * 354 * Avg Reward is ==> -1.7072474956512451 And Number of steps is ==> 708000
# Episode * 355 * Avg Reward is ==> -1.683192491531372 And Number of steps is ==> 710000
# Episode * 356 * Avg Reward is ==> -1.6745113134384155 And Number of steps is ==> 712000
# Episode * 357 * Avg Reward is ==> -1.6752582788467407 And Number of steps is ==> 714000
# Episode * 358 * Avg Reward is ==> -1.642149567604065 And Number of steps is ==> 716000
# Episode * 359 * Avg Reward is ==> -1.6560323238372803 And Number of steps is ==> 718000
# Episode * 360 * Avg Reward is ==> -1.5977627038955688 And Number of steps is ==> 720000
# Episode * 361 * Avg Reward is ==> -1.5108762979507446 And Number of steps is ==> 722000
# Episode * 362 * Avg Reward is ==> -1.5077855587005615 And Number of steps is ==> 724000
# Episode * 363 * Avg Reward is ==> -1.503065824508667 And Number of steps is ==> 726000
# Episode * 364 * Avg Reward is ==> -1.4549720287322998 And Number of steps is ==> 728000
# Accident!
# Episode * 365 * Avg Reward is ==> -1.492814540863037 And Number of steps is ==> 730000
# Episode * 366 * Avg Reward is ==> -1.4893219470977783 And Number of steps is ==> 732000
# Episode * 367 * Avg Reward is ==> -1.438088297843933 And Number of steps is ==> 734000
# Episode * 368 * Avg Reward is ==> -1.432414174079895 And Number of steps is ==> 736000
# Episode * 369 * Avg Reward is ==> -1.388592004776001 And Number of steps is ==> 738000
# Accident!
# Episode * 370 * Avg Reward is ==> -1.3803329467773438 And Number of steps is ==> 740000
# Episode * 371 * Avg Reward is ==> -1.3832496404647827 And Number of steps is ==> 742000
# Episode * 372 * Avg Reward is ==> -1.3707091808319092 And Number of steps is ==> 744000
# Episode * 373 * Avg Reward is ==> -1.3533339500427246 And Number of steps is ==> 746000
# Episode * 374 * Avg Reward is ==> -1.339929223060608 And Number of steps is ==> 748000
# Episode * 375 * Avg Reward is ==> -1.28572678565979 And Number of steps is ==> 750000
# Episode * 376 * Avg Reward is ==> -1.3056252002716064 And Number of steps is ==> 752000
# Episode * 377 * Avg Reward is ==> -1.329673409461975 And Number of steps is ==> 754000
# Accident!
# Episode * 378 * Avg Reward is ==> -1.3206909894943237 And Number of steps is ==> 756000
# Episode * 379 * Avg Reward is ==> -1.3162909746170044 And Number of steps is ==> 758000
# Episode * 380 * Avg Reward is ==> -1.31840181350708 And Number of steps is ==> 760000
# Episode * 381 * Avg Reward is ==> -1.2958271503448486 And Number of steps is ==> 762000
# Episode * 382 * Avg Reward is ==> -1.257767915725708 And Number of steps is ==> 764000
# Episode * 383 * Avg Reward is ==> -1.2629783153533936 And Number of steps is ==> 766000
# Episode * 384 * Avg Reward is ==> -1.2768137454986572 And Number of steps is ==> 768000
# Episode * 385 * Avg Reward is ==> -1.2671784162521362 And Number of steps is ==> 770000
# Episode * 386 * Avg Reward is ==> -1.2233779430389404 And Number of steps is ==> 772000
# Accident!
# Episode * 387 * Avg Reward is ==> -1.2068970203399658 And Number of steps is ==> 774000
# Episode * 388 * Avg Reward is ==> -1.1991980075836182 And Number of steps is ==> 776000
# Episode * 389 * Avg Reward is ==> -1.2120238542556763 And Number of steps is ==> 778000
# Episode * 390 * Avg Reward is ==> -1.208512306213379 And Number of steps is ==> 780000
# Episode * 391 * Avg Reward is ==> -1.214637041091919 And Number of steps is ==> 782000
# Episode * 392 * Avg Reward is ==> -1.2330029010772705 And Number of steps is ==> 784000
# Accident!
# Episode * 393 * Avg Reward is ==> -1.284057378768921 And Number of steps is ==> 786000
# Episode * 394 * Avg Reward is ==> -1.271693229675293 And Number of steps is ==> 788000
# Episode * 395 * Avg Reward is ==> -1.2657248973846436 And Number of steps is ==> 790000
# Accident!
# Episode * 396 * Avg Reward is ==> -1.323114275932312 And Number of steps is ==> 792000
# Accident!
# Episode * 397 * Avg Reward is ==> -1.3978121280670166 And Number of steps is ==> 794000
# Episode * 398 * Avg Reward is ==> -1.407621145248413 And Number of steps is ==> 796000
# Accident!
# Accident!
# Episode * 399 * Avg Reward is ==> -1.4015940427780151 And Number of steps is ==> 798000
# Episode * 400 * Avg Reward is ==> -1.394221305847168 And Number of steps is ==> 800000
# Episode * 401 * Avg Reward is ==> -1.4208695888519287 And Number of steps is ==> 802000
# Episode * 402 * Avg Reward is ==> -1.4323478937149048 And Number of steps is ==> 804000
# Episode * 403 * Avg Reward is ==> -1.3825746774673462 And Number of steps is ==> 806000
# Episode * 404 * Avg Reward is ==> -1.3809940814971924 And Number of steps is ==> 808000
# Episode * 405 * Avg Reward is ==> -1.4111464023590088 And Number of steps is ==> 810000
# Accident!
# Accident!
# Episode * 406 * Avg Reward is ==> -1.4688199758529663 And Number of steps is ==> 812000
# Episode * 407 * Avg Reward is ==> -1.4052990674972534 And Number of steps is ==> 814000
# Episode * 408 * Avg Reward is ==> -1.3991295099258423 And Number of steps is ==> 816000
# Episode * 409 * Avg Reward is ==> -1.3879152536392212 And Number of steps is ==> 818000
# Episode * 410 * Avg Reward is ==> -1.3851611614227295 And Number of steps is ==> 820000
# Episode * 411 * Avg Reward is ==> -1.347264289855957 And Number of steps is ==> 822000
# Episode * 412 * Avg Reward is ==> -1.3347762823104858 And Number of steps is ==> 824000
# Accident!
# Episode * 413 * Avg Reward is ==> -1.3137421607971191 And Number of steps is ==> 826000
# Episode * 414 * Avg Reward is ==> -1.3042597770690918 And Number of steps is ==> 828000
# Episode * 415 * Avg Reward is ==> -1.2686686515808105 And Number of steps is ==> 830000
# Accident!
# Episode * 416 * Avg Reward is ==> -1.2022104263305664 And Number of steps is ==> 832000
# Episode * 417 * Avg Reward is ==> -1.195841908454895 And Number of steps is ==> 834000
# Episode * 418 * Avg Reward is ==> -1.2025933265686035 And Number of steps is ==> 836000
# Episode * 419 * Avg Reward is ==> -1.2007511854171753 And Number of steps is ==> 838000
# Episode * 420 * Avg Reward is ==> -1.221152901649475 And Number of steps is ==> 840000
# Episode * 421 * Avg Reward is ==> -1.2493407726287842 And Number of steps is ==> 842000
# Episode * 422 * Avg Reward is ==> -1.221064805984497 And Number of steps is ==> 844000
# Accident!
# Episode * 423 * Avg Reward is ==> -1.2282214164733887 And Number of steps is ==> 846000
# Episode * 424 * Avg Reward is ==> -1.240755319595337 And Number of steps is ==> 848000
# Episode * 425 * Avg Reward is ==> -1.2546911239624023 And Number of steps is ==> 850000
# Episode * 426 * Avg Reward is ==> -1.200168251991272 And Number of steps is ==> 852000
# Episode * 427 * Avg Reward is ==> -1.1853550672531128 And Number of steps is ==> 854000
# Episode * 428 * Avg Reward is ==> -1.181071400642395 And Number of steps is ==> 856000
# Episode * 429 * Avg Reward is ==> -1.1647694110870361 And Number of steps is ==> 858000
# Episode * 430 * Avg Reward is ==> -1.1307995319366455 And Number of steps is ==> 860000
# Episode * 431 * Avg Reward is ==> -1.1033737659454346 And Number of steps is ==> 862000
# Episode * 432 * Avg Reward is ==> -1.1265431642532349 And Number of steps is ==> 864000
# Episode * 433 * Avg Reward is ==> -1.1252717971801758 And Number of steps is ==> 866000
# Accident!
# Episode * 434 * Avg Reward is ==> -1.113647699356079 And Number of steps is ==> 868000
# Episode * 435 * Avg Reward is ==> -1.1103143692016602 And Number of steps is ==> 870000
# Episode * 436 * Avg Reward is ==> -1.0991878509521484 And Number of steps is ==> 872000
# Accident!
# Episode * 437 * Avg Reward is ==> -1.1845067739486694 And Number of steps is ==> 874000
# Accident!
# Episode * 438 * Avg Reward is ==> -1.2292766571044922 And Number of steps is ==> 876000
# Episode * 439 * Avg Reward is ==> -1.2497010231018066 And Number of steps is ==> 878000
# Episode * 440 * Avg Reward is ==> -1.2695966958999634 And Number of steps is ==> 880000
# Episode * 441 * Avg Reward is ==> -1.2687782049179077 And Number of steps is ==> 882000
# Episode * 442 * Avg Reward is ==> -1.2537158727645874 And Number of steps is ==> 884000
# Accident!
# Episode * 443 * Avg Reward is ==> -1.249721646308899 And Number of steps is ==> 886000
# Episode * 444 * Avg Reward is ==> -1.2436144351959229 And Number of steps is ==> 888000
# Episode * 445 * Avg Reward is ==> -1.2433807849884033 And Number of steps is ==> 890000
# Episode * 446 * Avg Reward is ==> -1.2317883968353271 And Number of steps is ==> 892000
# Episode * 447 * Avg Reward is ==> -1.146046757698059 And Number of steps is ==> 894000
# Episode * 448 * Avg Reward is ==> -1.0789169073104858 And Number of steps is ==> 896000
# Episode * 449 * Avg Reward is ==> -1.0819085836410522 And Number of steps is ==> 898000
# Episode * 450 * Avg Reward is ==> -1.0677331686019897 And Number of steps is ==> 900000
# Accident!
# Episode * 451 * Avg Reward is ==> -1.0621421337127686 And Number of steps is ==> 902000
# Episode * 452 * Avg Reward is ==> -1.0774847269058228 And Number of steps is ==> 904000
# Episode * 453 * Avg Reward is ==> -1.080385446548462 And Number of steps is ==> 906000
# Episode * 454 * Avg Reward is ==> -1.080681562423706 And Number of steps is ==> 908000
# Accident!
# Episode * 455 * Avg Reward is ==> -1.0764867067337036 And Number of steps is ==> 910000
# Accident!
# Episode * 456 * Avg Reward is ==> -1.0934990644454956 And Number of steps is ==> 912000
# Accident!
# ...
# Episode * 823 * Avg Reward is ==> -1.0911587476730347 And Number of steps is ==> 1646000
# Episode * 824 * Avg Reward is ==> -1.0759114027023315 And Number of steps is ==> 1648000
# Accident!
# Episode * 825 * Avg Reward is ==> -1.1158909797668457 And Number of steps is ==> 1650000
# Episode * 826 * Avg Reward is ==> -1.1253397464752197 And Number of steps is ==> 1652000
# Episode * 827 * Avg Reward is ==> -1.1212208271026611 And Number of steps is ==> 1654000
# Episode * 828 * Avg Reward is ==> -1.1033697128295898 And Number of steps is ==> 1656000
# Episode * 829 * Avg Reward is ==> -1.103933572769165 And Number of steps is ==> 1658000
# Episode * 830 * Avg Reward is ==> -1.1166307926177979 And Number of steps is ==> 1660000
# Episode * 831 * Avg Reward is ==> -1.108717679977417 And Number of steps is ==> 1662000
# Episode * 832 * Avg Reward is ==> -1.122581958770752 And Number of steps is ==> 1664000
# Episode * 833 * Avg Reward is ==> -1.1393181085586548 And Number of steps is ==> 1666000
# Episode * 834 * Avg Reward is ==> -1.134783148765564 And Number of steps is ==> 1668000
# Episode * 835 * Avg Reward is ==> -1.097015619277954 And Number of steps is ==> 1670000
# Episode * 836 * Avg Reward is ==> -1.0910382270812988 And Number of steps is ==> 1672000
# Episode * 837 * Avg Reward is ==> -1.0853015184402466 And Number of steps is ==> 1674000
# Episode * 838 * Avg Reward is ==> -1.0921179056167603 And Number of steps is ==> 1676000
# Episode * 839 * Avg Reward is ==> -1.0972731113433838 And Number of steps is ==> 1678000
# Episode * 840 * Avg Reward is ==> -1.1051874160766602 And Number of steps is ==> 1680000
# Episode * 841 * Avg Reward is ==> -1.1216070652008057 And Number of steps is ==> 1682000
# Episode * 842 * Avg Reward is ==> -1.1192504167556763 And Number of steps is ==> 1684000
# Episode * 843 * Avg Reward is ==> -1.1073803901672363 And Number of steps is ==> 1686000
# Episode * 844 * Avg Reward is ==> -1.1384352445602417 And Number of steps is ==> 1688000
# Accident!
# Episode * 845 * Avg Reward is ==> -1.1070221662521362 And Number of steps is ==> 1690000
# Episode * 846 * Avg Reward is ==> -1.0792583227157593 And Number of steps is ==> 1692000
# Episode * 847 * Avg Reward is ==> -1.0946638584136963 And Number of steps is ==> 1694000
# Episode * 848 * Avg Reward is ==> -1.1096320152282715 And Number of steps is ==> 1696000
# Episode * 849 * Avg Reward is ==> -1.120436429977417 And Number of steps is ==> 1698000
# Episode * 850 * Avg Reward is ==> -1.1160099506378174 And Number of steps is ==> 1700000
# Episode * 851 * Avg Reward is ==> -1.1110608577728271 And Number of steps is ==> 1702000
# Episode * 852 * Avg Reward is ==> -1.117242693901062 And Number of steps is ==> 1704000
# Episode * 853 * Avg Reward is ==> -1.1310385465621948 And Number of steps is ==> 1706000
# Accident!
# Episode * 854 * Avg Reward is ==> -1.13431715965271 And Number of steps is ==> 1708000
# Episode * 855 * Avg Reward is ==> -1.1630889177322388 And Number of steps is ==> 1710000
# Episode * 856 * Avg Reward is ==> -1.1866273880004883 And Number of steps is ==> 1712000
# Episode * 857 * Avg Reward is ==> -1.182651400566101 And Number of steps is ==> 1714000
# Episode * 858 * Avg Reward is ==> -1.1496150493621826 And Number of steps is ==> 1716000
# Episode * 859 * Avg Reward is ==> -1.1350139379501343 And Number of steps is ==> 1718000
# Accident!
# Episode * 860 * Avg Reward is ==> -1.1107516288757324 And Number of steps is ==> 1720000
# Episode * 861 * Avg Reward is ==> -1.1050350666046143 And Number of steps is ==> 1722000
# Episode * 862 * Avg Reward is ==> -1.1093599796295166 And Number of steps is ==> 1724000
# Episode * 863 * Avg Reward is ==> -1.1175823211669922 And Number of steps is ==> 1726000
# Episode * 864 * Avg Reward is ==> -1.110211968421936 And Number of steps is ==> 1728000
# Episode * 865 * Avg Reward is ==> -1.0931594371795654 And Number of steps is ==> 1730000
# Episode * 866 * Avg Reward is ==> -1.0770384073257446 And Number of steps is ==> 1732000
# Episode * 867 * Avg Reward is ==> -1.0674283504486084 And Number of steps is ==> 1734000
# Episode * 868 * Avg Reward is ==> -1.0811944007873535 And Number of steps is ==> 1736000
# Episode * 869 * Avg Reward is ==> -1.0795968770980835 And Number of steps is ==> 1738000
# Episode * 870 * Avg Reward is ==> -1.0894943475723267 And Number of steps is ==> 1740000
# Episode * 871 * Avg Reward is ==> -1.1006962060928345 And Number of steps is ==> 1742000
# Episode * 872 * Avg Reward is ==> -1.115513801574707 And Number of steps is ==> 1744000
# Episode * 873 * Avg Reward is ==> -1.1052210330963135 And Number of steps is ==> 1746000
# Episode * 874 * Avg Reward is ==> -1.0952614545822144 And Number of steps is ==> 1748000
# Episode * 875 * Avg Reward is ==> -1.094109296798706 And Number of steps is ==> 1750000
# Episode * 876 * Avg Reward is ==> -1.0944377183914185 And Number of steps is ==> 1752000
# Episode * 877 * Avg Reward is ==> -1.1212886571884155 And Number of steps is ==> 1754000
# Episode * 878 * Avg Reward is ==> -1.1293151378631592 And Number of steps is ==> 1756000
# Episode * 879 * Avg Reward is ==> -1.1231799125671387 And Number of steps is ==> 1758000
# Episode * 880 * Avg Reward is ==> -1.106736183166504 And Number of steps is ==> 1760000
# Episode * 881 * Avg Reward is ==> -1.0767924785614014 And Number of steps is ==> 1762000
# Episode * 882 * Avg Reward is ==> -1.0503976345062256 And Number of steps is ==> 1764000
# Episode * 883 * Avg Reward is ==> -1.0582071542739868 And Number of steps is ==> 1766000
# Episode * 884 * Avg Reward is ==> -1.0537160634994507 And Number of steps is ==> 1768000
# Episode * 885 * Avg Reward is ==> -1.065632700920105 And Number of steps is ==> 1770000
# Episode * 886 * Avg Reward is ==> -1.075921893119812 And Number of steps is ==> 1772000
# Episode * 887 * Avg Reward is ==> -1.062125563621521 And Number of steps is ==> 1774000
# Episode * 888 * Avg Reward is ==> -1.0506564378738403 And Number of steps is ==> 1776000
# Episode * 889 * Avg Reward is ==> -1.0486971139907837 And Number of steps is ==> 1778000
# Episode * 890 * Avg Reward is ==> -1.0741727352142334 And Number of steps is ==> 1780000
# Episode * 891 * Avg Reward is ==> -1.100890874862671 And Number of steps is ==> 1782000
# Episode * 892 * Avg Reward is ==> -1.1163380146026611 And Number of steps is ==> 1784000
# Episode * 893 * Avg Reward is ==> -1.0973732471466064 And Number of steps is ==> 1786000
# Episode * 894 * Avg Reward is ==> -1.1095529794692993 And Number of steps is ==> 1788000
# Episode * 895 * Avg Reward is ==> -1.1159002780914307 And Number of steps is ==> 1790000
# Episode * 896 * Avg Reward is ==> -1.1112754344940186 And Number of steps is ==> 1792000
# Episode * 897 * Avg Reward is ==> -1.110600233078003 And Number of steps is ==> 1794000
# Episode * 898 * Avg Reward is ==> -1.1132924556732178 And Number of steps is ==> 1796000
# Episode * 899 * Avg Reward is ==> -1.125051498413086 And Number of steps is ==> 1798000
# Episode * 900 * Avg Reward is ==> -1.110970139503479 And Number of steps is ==> 1800000
# Episode * 901 * Avg Reward is ==> -1.1011366844177246 And Number of steps is ==> 1802000
# Episode * 902 * Avg Reward is ==> -1.1025153398513794 And Number of steps is ==> 1804000
# Episode * 903 * Avg Reward is ==> -1.1153593063354492 And Number of steps is ==> 1806000
# Episode * 904 * Avg Reward is ==> -1.125454068183899 And Number of steps is ==> 1808000
# Episode * 905 * Avg Reward is ==> -1.1231191158294678 And Number of steps is ==> 1810000
# Episode * 906 * Avg Reward is ==> -1.1317418813705444 And Number of steps is ==> 1812000
# Episode * 907 * Avg Reward is ==> -1.1377776861190796 And Number of steps is ==> 1814000
# Episode * 908 * Avg Reward is ==> -1.15187668800354 And Number of steps is ==> 1816000
# Episode * 909 * Avg Reward is ==> -1.139803171157837 And Number of steps is ==> 1818000
# Episode * 910 * Avg Reward is ==> -1.1223145723342896 And Number of steps is ==> 1820000
# Episode * 911 * Avg Reward is ==> -1.119014024734497 And Number of steps is ==> 1822000
# Episode * 912 * Avg Reward is ==> -1.104579210281372 And Number of steps is ==> 1824000
# Episode * 913 * Avg Reward is ==> -1.0895565748214722 And Number of steps is ==> 1826000
# Episode * 914 * Avg Reward is ==> -1.039865255355835 And Number of steps is ==> 1828000
# Episode * 915 * Avg Reward is ==> -1.0369199514389038 And Number of steps is ==> 1830000
# Episode * 916 * Avg Reward is ==> -1.0337520837783813 And Number of steps is ==> 1832000
# Episode * 917 * Avg Reward is ==> -1.0246121883392334 And Number of steps is ==> 1834000
# Accident!
# Episode * 918 * Avg Reward is ==> -1.0048496723175049 And Number of steps is ==> 1836000
# Episode * 919 * Avg Reward is ==> -0.9896117448806763 And Number of steps is ==> 1838000
# Episode * 920 * Avg Reward is ==> -1.000592827796936 And Number of steps is ==> 1840000
# Episode * 921 * Avg Reward is ==> -1.0106737613677979 And Number of steps is ==> 1842000
# Accident!
# Episode * 922 * Avg Reward is ==> -1.0024367570877075 And Number of steps is ==> 1844000
# Episode * 923 * Avg Reward is ==> -1.0128600597381592 And Number of steps is ==> 1846000
# Episode * 924 * Avg Reward is ==> -1.0781923532485962 And Number of steps is ==> 1848000
# Episode * 925 * Avg Reward is ==> -1.0763524770736694 And Number of steps is ==> 1850000
# Episode * 926 * Avg Reward is ==> -1.1121479272842407 And Number of steps is ==> 1852000
# Episode * 927 * Avg Reward is ==> -1.1082812547683716 And Number of steps is ==> 1854000
# Episode * 928 * Avg Reward is ==> -1.1224982738494873 And Number of steps is ==> 1856000
# Episode * 929 * Avg Reward is ==> -1.1414813995361328 And Number of steps is ==> 1858000
# Episode * 930 * Avg Reward is ==> -1.1437771320343018 And Number of steps is ==> 1860000
# Episode * 931 * Avg Reward is ==> -1.1329243183135986 And Number of steps is ==> 1862000
# Accident!
# Accident!
# Episode * 932 * Avg Reward is ==> -1.195512056350708 And Number of steps is ==> 1864000
# Episode * 933 * Avg Reward is ==> -1.2071036100387573 And Number of steps is ==> 1866000
# Episode * 934 * Avg Reward is ==> -1.1728044748306274 And Number of steps is ==> 1868000
# Episode * 935 * Avg Reward is ==> -1.1884782314300537 And Number of steps is ==> 1870000
# Episode * 936 * Avg Reward is ==> -1.164711356163025 And Number of steps is ==> 1872000
# Episode * 937 * Avg Reward is ==> -1.2190455198287964 And Number of steps is ==> 1874000
# Episode * 938 * Avg Reward is ==> -1.2181978225708008 And Number of steps is ==> 1876000
# Episode * 939 * Avg Reward is ==> -1.2209528684616089 And Number of steps is ==> 1878000
# Episode * 940 * Avg Reward is ==> -1.2351068258285522 And Number of steps is ==> 1880000
# Episode * 941 * Avg Reward is ==> -1.2728302478790283 And Number of steps is ==> 1882000
# Episode * 942 * Avg Reward is ==> -1.2218668460845947 And Number of steps is ==> 1884000
# Episode * 943 * Avg Reward is ==> -1.215829610824585 And Number of steps is ==> 1886000
# Episode * 944 * Avg Reward is ==> -1.2366827726364136 And Number of steps is ==> 1888000
# Episode * 945 * Avg Reward is ==> -1.221291422843933 And Number of steps is ==> 1890000
# Episode * 946 * Avg Reward is ==> -1.2542110681533813 And Number of steps is ==> 1892000
# Episode * 947 * Avg Reward is ==> -1.2056204080581665 And Number of steps is ==> 1894000
# Episode * 948 * Avg Reward is ==> -1.1769192218780518 And Number of steps is ==> 1896000
# Episode * 949 * Avg Reward is ==> -1.1631191968917847 And Number of steps is ==> 1898000
# Episode * 950 * Avg Reward is ==> -1.1465427875518799 And Number of steps is ==> 1900000
# Episode * 951 * Avg Reward is ==> -1.1052662134170532 And Number of steps is ==> 1902000
# Episode * 952 * Avg Reward is ==> -1.1150062084197998 And Number of steps is ==> 1904000
# Accident!
# Episode * 953 * Avg Reward is ==> -1.1292345523834229 And Number of steps is ==> 1906000
# Episode * 954 * Avg Reward is ==> -1.1043469905853271 And Number of steps is ==> 1908000
# Episode * 955 * Avg Reward is ==> -1.10326087474823 And Number of steps is ==> 1910000
# Episode * 956 * Avg Reward is ==> -1.0305767059326172 And Number of steps is ==> 1912000
# Accident!
# Episode * 957 * Avg Reward is ==> -1.0988987684249878 And Number of steps is ==> 1914000
# Episode * 958 * Avg Reward is ==> -1.1224995851516724 And Number of steps is ==> 1916000
# Episode * 959 * Avg Reward is ==> -1.1450036764144897 And Number of steps is ==> 1918000
# Episode * 960 * Avg Reward is ==> -1.1704444885253906 And Number of steps is ==> 1920000
# Accident!
# Accident!
# Accident!
# Episode * 961 * Avg Reward is ==> -1.2302299737930298 And Number of steps is ==> 1922000
# Episode * 962 * Avg Reward is ==> -1.2295955419540405 And Number of steps is ==> 1924000
# Episode * 963 * Avg Reward is ==> -1.214905858039856 And Number of steps is ==> 1926000
# Accident!
# Episode * 964 * Avg Reward is ==> -1.2850956916809082 And Number of steps is ==> 1928000
# Episode * 965 * Avg Reward is ==> -1.2951422929763794 And Number of steps is ==> 1930000
# Episode * 966 * Avg Reward is ==> -1.3382920026779175 And Number of steps is ==> 1932000
# Episode * 967 * Avg Reward is ==> -1.2780739068984985 And Number of steps is ==> 1934000
# Episode * 968 * Avg Reward is ==> -1.2884421348571777 And Number of steps is ==> 1936000
# Episode * 969 * Avg Reward is ==> -1.2901265621185303 And Number of steps is ==> 1938000
# Episode * 970 * Avg Reward is ==> -1.275215744972229 And Number of steps is ==> 1940000
# Episode * 971 * Avg Reward is ==> -1.244099497795105 And Number of steps is ==> 1942000
# Episode * 972 * Avg Reward is ==> -1.235701560974121 And Number of steps is ==> 1944000
# Episode * 973 * Avg Reward is ==> -1.2267402410507202 And Number of steps is ==> 1946000
# Episode * 974 * Avg Reward is ==> -1.1701362133026123 And Number of steps is ==> 1948000
# Episode * 975 * Avg Reward is ==> -1.1989479064941406 And Number of steps is ==> 1950000
# Episode * 976 * Avg Reward is ==> -1.1872111558914185 And Number of steps is ==> 1952000
# Episode * 977 * Avg Reward is ==> -1.1857057809829712 And Number of steps is ==> 1954000
# Episode * 978 * Avg Reward is ==> -1.1704992055892944 And Number of steps is ==> 1956000
# Episode * 979 * Avg Reward is ==> -1.156407356262207 And Number of steps is ==> 1958000
# Episode * 980 * Avg Reward is ==> -1.1444694995880127 And Number of steps is ==> 1960000
# Episode * 981 * Avg Reward is ==> -1.1320439577102661 And Number of steps is ==> 1962000
# Episode * 982 * Avg Reward is ==> -1.1335643529891968 And Number of steps is ==> 1964000
# Episode * 983 * Avg Reward is ==> -1.1365382671356201 And Number of steps is ==> 1966000
# Episode * 984 * Avg Reward is ==> -1.1329208612442017 And Number of steps is ==> 1968000
# Episode * 985 * Avg Reward is ==> -1.1122305393218994 And Number of steps is ==> 1970000
# Episode * 986 * Avg Reward is ==> -1.108276605606079 And Number of steps is ==> 1972000
# Episode * 987 * Avg Reward is ==> -1.0892144441604614 And Number of steps is ==> 1974000
# Episode * 988 * Avg Reward is ==> -1.1041237115859985 And Number of steps is ==> 1976000
# Episode * 989 * Avg Reward is ==> -1.1066277027130127 And Number of steps is ==> 1978000
# Episode * 990 * Avg Reward is ==> -1.128896713256836 And Number of steps is ==> 1980000
# Episode * 991 * Avg Reward is ==> -1.1231917142868042 And Number of steps is ==> 1982000
# Episode * 992 * Avg Reward is ==> -1.1230463981628418 And Number of steps is ==> 1984000
# Accident!
# Episode * 993 * Avg Reward is ==> -1.1468106508255005 And Number of steps is ==> 1986000
# Episode * 994 * Avg Reward is ==> -1.1516852378845215 And Number of steps is ==> 1988000
# Episode * 995 * Avg Reward is ==> -1.1443686485290527 And Number of steps is ==> 1990000
# Accident!
# Accident!
# Episode * 996 * Avg Reward is ==> -1.2053637504577637 And Number of steps is ==> 1992000
# Episode * 997 * Avg Reward is ==> -1.2145774364471436 And Number of steps is ==> 1994000
# Episode * 998 * Avg Reward is ==> -1.2038133144378662 And Number of steps is ==> 1996000
# Episode * 999 * Avg Reward is ==> -1.222892165184021 And Number of steps is ==> 1998000
# Complete
# Running time: 2190.203125

# %%
algo.loading(12,1000)

# %%
#Stock an evaluation sample
states, actions, rewards = algo.evaluate(100)
ep_action=states[:,0]
ep_speed_car=states[:,1]
ep_pos_car=states[:,2]
ep_speed_ped=states[:,3]
ep_pos_ped=states[:,4]
ep_time=states[:,9]
ep_reward=rewards
t=0

# %%
#Show general information about the final algorithm performance: average speed, CO2 emission, end-time

LDV = pd.read_csv('LDV.csv', sep=';',names=["sp","acc","step","em_name","em_val"])
LDV.pop('step')
m = LDV == 0.0
LDV['acc'] = LDV['acc'].replace(1.27676e-15,0.0)
LDV['acc'] = LDV['acc'].astype(float)
LDV_array = np.array(LDV.values)

def info_co2(states,LDV):
    """
        Evaluate the CO2 emission per episode 
        :param states: state list
        :param LDV: CO2 emission chart
    """
    t=0
    total_emission=[]
    while t+1<len(ep_time):
        t_init=t
        emission_val=[]
        while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
            acc=math.trunc(((states[t,0].item()//0.2)*0.2)*10.)/10.
            speed=math.trunc(((states[t,1].item()//0.5)*0.5)*10.)/10.
            cond=(LDV.sp==speed)&(LDV.acc==acc)&(LDV.em_name=="CO2")
            res=LDV[cond]['em_val'].item() *0.3
            emission_val.append(res)
            t+=1
        total_emission.append(torch.sum(torch.tensor(emission_val),dim=0))
        t+=1
    torch_total_emission=torch.tensor(total_emission)
    total_emission_mean=torch.mean(torch_total_emission)
    total_emission_std=torch.std(torch_total_emission)
    print("\nThe average CO2 emission is {:.2f}mg and its standard deviation is {:.2f} mg".format(total_emission_mean.item(),total_emission_std.item()))
    
def get_average(states,LDV):
    ep_time=states[:,9]
    mean_speed=torch.mean(states[:,1])
    sqrt_speed=torch.std(states[:,1])
    print("The average car speed is {:.2f} m/s and its standard deviation is {:.2f} m/s".format(mean_speed.item(),sqrt_speed.item()))
    mean_acc=torch.mean(states[:,0])
    sqrt_acc=torch.std(states[:,0])
    print("\nThe average car acceleration is {:.2f} m/s2 and its standard deviation is {:.2f} m/s2".format(mean_acc.item(),sqrt_acc.item()))
    mean_speed_p=torch.mean(states[:,3])
    sqrt_speed_p=torch.std(states[:,3])
    print("\nThe average pedestrian speed is {:.2f} m/s2 and its standard deviation is {:.2f} m/s2".format(mean_speed_p.item(),sqrt_speed_p.item()))    
    mean_reward=torch.mean(ep_reward)
    std_reward=torch.std(ep_reward)
    print("\nThe average reward is {:.2f} and its standard deviation is {:.2f}".format(mean_reward.item(),std_reward.item()))
    info_co2(states,LDV) #CO2 info
    temps=[]
    t=0
    while t+1<len(ep_time):
        temps_i=np.array([0.,0.]) #respectively: end-time car/pedestrian
        t_init=t
        while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
            if(states[t,2]<0.0 and states[t+1,2]>=0.0):
                temps_i[0]=(t-t_init)*0.3
            if(states[t,4]<5.0 and states[t+1,4]>=5.0):
                temps_i[1]=(t-t_init)*0.3
            t+=1
        if(temps_i[1]==0.0):
            temps_i[1]=(t-t_init)*0.3
        temps.append([(t-t_init)*0.3,temps_i[0],temps_i[1]])
        t+=1
    total_temps=torch.tensor([temps]).reshape((-1,3))
    total_temps_mean=torch.mean(total_temps,dim=0)
    print("\n Average End-times:")
    print("Total: {:.2f} s".format(total_temps_mean[0].item()))
    print("Car: {:.2f} s".format(total_temps_mean[1].item()))
    print("Pedestrian: {:.2f} s".format(total_temps_mean[2].item()))
get_average(states,LDV)
# Out:
# The average car speed is 7.34 m/s and its standard deviation is 3.60 m/s
#
# The average car acceleration is 0.04 m/s2 and its standard deviation is 1.83 m/s2
#
# The average pedestrian speed is 1.00 m/s2 and its standard deviation is 0.36 m/s2
#
# The average reward is -1.16 and its standard deviation is 2.06
#
# The average CO2 emission is 24399.39mg and its standard deviation is 7352.83 mg
#
#  Average End-times:
# Total: 9.52 s
# Car: 4.42 s
# Pedestrian: 6.50 s

# %%
#Positions des agents
t=0
plt.title("Vehicle and Pedestrian Positions versus time")
plt.xlabel("time (s)")
plt.ylabel("position (m)")
while t+1<len(ep_time):
    t_init=t
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        t+=1
    plt.plot(ep_time[t_init:t],ep_pos_car[t_init:t])
    plt.plot(ep_time[t_init:t],ep_pos_ped[t_init:t])
    plt.axhline(y=5, color='r', linestyle='-.')
    plt.axhline(y=0, color='r', linestyle='-.')
    t+=1
_=plt.axhline(y=5, color='r', linestyle='-.')
_=plt.axhline(y=0, color='r', linestyle='-.')

# %%
#Accélération, Reward, Vitesse de la voiture
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(18, 4))

t=0
ax1.set_title("Car Acceleration versus time per episode")
ax1.set_xlabel("time (s)")
ax1.set_ylabel("acceleration (m/s2)")

ax2.set_title("Reward versus time per episode")
ax2.set_xlabel("time (s)")
ax2.set_ylabel("reward")

ax3.set_title("Car Speed versus time per episode")
ax3.set_xlabel("time (s)")
ax3.set_ylabel("speed (m/s)")

ax4.set_title('Pedestrian Speed')
ax4.set_xlabel("Position (m)")
ax4.set_ylabel("Speed (m/s)")
while t+1<len(ep_time):
    t_init=t
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        t+=1
    ax1.plot(ep_time[t_init:t],ep_action[t_init:t])
    ax2.plot(ep_time[t_init:t],ep_reward[t_init:t])
    ax3.plot(ep_time[t_init:t],ep_speed_car[t_init:t])
    ax4.plot(states[t_init:t,4],states[t_init:t,3])
    t+=1

# %%
#Seperate the episodes and the different behaviors
t=0
cross_speed=[]
wait_speed=[]
cross_acc=[]
wait_acc=[]
size_wait=20
size_cross=40

while t+1<len(ep_time):
    t_init=t
    choice=False
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        choice=choice+(ep_speed_car[t]<2.0)
        t+=1

    if(choice):
        min_l=min(t-t_init,size_cross)
        return_speed=np.array(ep_speed_car[t_init:t_init+min_l])
        return_acc=np.array(states[t_init:t_init+min_l,0])
        if(min_l<size_cross):
            return_speed=np.append(return_speed,[ep_speed_car[t-1]]*(size_cross-t+t_init))
            return_acc=np.append(return_acc,[states[t-1,0]]*(size_cross-t+t_init))
        cross_speed.append(return_speed)
        cross_acc.append(return_acc)
    else:
        min_l=min(t-t_init,size_wait)
        return_speed=np.array(ep_speed_car[t_init:t_init+min_l])
        return_acc=np.array(states[t_init:t_init+min_l,0])
        if(min_l<size_wait):
            return_speed=np.append(return_speed,[ep_speed_car[t-1]]*(size_wait-t+t_init))
            return_acc=np.append(return_acc,[states[t-1,0]]*(size_wait-t+t_init))
        wait_speed.append(return_speed)
        wait_acc.append(return_acc)
    t+=1
    
cross_speed=np.array(cross_speed)
wait_speed=np.array(wait_speed)
cross_acc=np.array(cross_acc)
wait_acc=np.array(wait_acc)

# %%
x1=[0.3*i for i in range(size_cross)]
mean_speed=np.mean(cross_speed,axis=0)
std_speed=np.std(cross_speed,axis=0)
mean_acc=np.mean(cross_acc,axis=0)
std_acc=np.std(cross_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')
fig.savefig("PDF_results/car_cross_ppo12.pdf")

# %%
x1=[0.3*i for i in range(size_wait)]
mean_speed=np.mean(wait_speed,axis=0)
std_speed=np.std(wait_speed,axis=0)
mean_acc=np.mean(wait_acc,axis=0)
std_acc=np.std(wait_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')
fig.savefig("PDF_results/car_wait_ppo12.pdf")

# %%
#Showing Vehicle Acceleration Diagram, Vehicle Speed Diagram, Vehicle and Pedestrian Position Diagram
#All three over time in an episode
#t=0
if (t+1>=len(ep_time)):
    t=0
t_init=t
while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
    t+=1
fig, (ax1, ax2, ax3) = plt.subplots(1, 3,figsize=(20, 3))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-1.1,1.1)
ax1.plot(ep_time[t_init:t+1],actions[t_init:t+1,0],color='r')

ax2.set_title('Car and Pedestrian Position')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Position (m)")
ax2.plot(ep_time[t_init:t],ep_pos_car[t_init:t],label='car')
ax2.plot(ep_time[t_init:t+1],ep_pos_ped[t_init:t+1],label='pedestrian')
ax2.axhline(y=5, color='r', linestyle='-.')
ax2.axhline(y=0, color='r', linestyle='-.')
ax2.legend()

ax3.set_title('Car Speed')
ax3.set_xlabel("Time (s)")
ax3.set_ylabel("Speed (m/s)")
ax3.plot(ep_time[t_init:t+1],ep_speed_car[t_init:t+1],color='r')
t+=1

# %%
def estimation_value(x1,x2,x3,y1,y3):
    a=(y3-y1)/(x3-x1)
    b=(y1*x3 - y3*x1)/(x3-x1)
    return a*x2+b

def extract_estimations(positions, parameter, start_position, end_position, step_pos):
    size_position=int((end_position-start_position)/step_pos)
    length=len(positions)
    array_cross=np.array([0.0]*size_position)
    i_step=0
    i_pos=start_position
    i=0
    while(i_pos<positions[i_step]):
        array_cross[i]=parameter[i_step]
        i=i+1
        i_pos=i_pos+0.5
    while(i_step<length and i<size_position):
        while( i_step+1<length and i_pos>positions[i_step]):
            i_step=i_step+1
        array_cross[i]=estimation_value(positions[i_step-1],i_pos,positions[i_step],parameter[i_step-1],parameter[i_step])
        i=i+1
        i_pos=i_pos+0.5
    while(i<size_position):
        array_cross[i]=parameter[i_step-1]
        i=i+1
    return array_cross

# %%
#Seperate the episodes and the different behaviors
t=0
cross_speed=[]
wait_speed=[]
cross_acc=[]
wait_acc=[]
start_position=-32.5
end_position=32.5
while t+1<len(ep_time):
    
    t_init=t
    choice=False
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        choice=choice+(ep_speed_car[t]<2.0)
        t+=1
        
    if(choice):
        return_speed=extract_estimations(ep_pos_car[t_init:t], ep_speed_car[t_init:t],start_position,end_position,0.5)
        return_acc=extract_estimations(ep_pos_car[t_init:t], ep_action[t_init:t],start_position,end_position,0.5)
        cross_speed.append(return_speed)
        cross_acc.append(return_acc)
        
    else:
        return_speed=extract_estimations(ep_pos_car[t_init:t], ep_speed_car[t_init:t],start_position,end_position,0.5)
        return_acc=extract_estimations(ep_pos_car[t_init:t], ep_action[t_init:t],start_position,end_position,0.5)
        wait_speed.append(return_speed)
        wait_acc.append(return_acc)
    t+=1
    
cross_speed=np.array(cross_speed)
wait_speed=np.array(wait_speed)
cross_acc=np.array(cross_acc)
wait_acc=np.array(wait_acc)

# %%
size_position=int((end_position-start_position)/0.5)
x1=[i*0.5+start_position for i in range(0,size_position)]
mean_speed=np.mean(cross_speed,axis=0)
std_speed=np.std(cross_speed,axis=0)
mean_acc=np.mean(cross_acc,axis=0)
std_acc=np.std(cross_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Position (m)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Position (m)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')

# %%
x1=[i*0.5+start_position for i in range(0,size_position)]
mean_speed=np.mean(wait_speed,axis=0)
std_speed=np.std(wait_speed,axis=0)
mean_acc=np.mean(wait_acc,axis=0)
std_acc=np.std(wait_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Position (m)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Position (m)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')

# %%
plt.title('Pedestrian Speed')
plt.xlabel("Position (m)")
plt.ylabel("Speed (m/s)")
plt.plot(states[t_init:t-10,4],states[t_init:t-10,3], color='olivedrab')
#plt.savefig("PDF_results/ped_speed.pdf")
