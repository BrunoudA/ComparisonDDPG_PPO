# %%
#1) Import libraries
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from collections import namedtuple, deque
import Environments
from collections import OrderedDict
from torch.distributions import MultivariateNormal
import pandas as pd

# I use the work of Eric Yu to help me build this algorithm. Link: https://github.com/ericyangyu/PPO-for-Beginners

# %%
#2) Set up Neural Network functions and classes

class Model_PPO(nn.Module):
    """
        Class: actor NN
        :param np_inputs: size input of the NN (size state)
        :param nb_outputs: size output of the NN (size action)
    """  
    def __init__(self, np_inputs, nb_outputs):
        super(Model_PPO, self).__init__()   
        self.layer1 = nn.Linear(np_inputs, 64)
        self.layer2 = nn.Linear(64, 64)
        self.layer3 = nn.Linear(64, nb_outputs)
        torch.nn.init.uniform_(self.layer3.weight,0.003, 0.006)

    def forward(self, input1):
        """
        Forward NN : compute the NN with respect the current state
        :param input1: state
        :return: output of the NN, action
        """ 
        if isinstance(input1, np.ndarray):
            input1 = torch.tensor(input1, dtype=torch.float)
        activation1 = F.relu(self.layer1(input1))
        activation2 = F.relu(self.layer2(activation1))
        output = self.layer3(activation2)
        return output

# %%
#3) Rollout on the environment:

class Env_rollout:
    """ 
        Class : iterate on the environment
        :param env: our environment
        :param max_steps: max steps per episode
    """
    def __init__(self, env, max_steps):
        self.env = env
        self.max_steps = max_steps
        self.prev_state = env.reset()
        self.batch_obs=[]
        self.batch_acts=[]
        self.batch_log_probs=[]
        self.batch_rews = []
    
    def reset(self):
        """
        Reset: reinitilization (lists et environment).
        """
        self.prev_state = env.reset()
        self.batch_obs=[]
        self.batch_acts=[]
        self.batch_log_probs=[]
        self.batch_rews = []
    
    def iterations(self,actor_net, nbr_episodes):
        """
        Iterate on the environment.
        :param actor_net: current policy (actor NN)
        :param nbr_episodes: episode number
        :return: Tensors; state batch, action batch
        """
        for ep in range(nbr_episodes):
            ep_rews = []
            prev_state = self.env.reset()
            for step_ep in range(self.max_steps): 
                with torch.no_grad():
                    action = torch.squeeze(actor_net(torch.unsqueeze(torch.tensor(prev_state), dim=0).float()))
                    if(action.dim()==0):
                        action=torch.unsqueeze(action,dim=0)
                    action_all=np.array([])
                    action_all=np.append(action_all,np.clip(action[0].detach().numpy(), -1.0, 1.0))
                    #action_all=np.append(action_all,np.argmax(action[1:4].detach().numpy()))
                    state, reward, done, _ = self.env.step(action_all)
                    self.batch_obs.append(prev_state)
                    self.batch_acts.append(action_all)
                    ep_rews.append(reward)
                    prev_state = state
                if done:
                    break
            self.batch_rews.append(ep_rews)
        return torch.tensor(self.batch_obs, dtype=torch.float), torch.tensor(self.batch_acts, dtype=torch.float)
    
    def iterations_rand(self,actor_net, cov_mat, batch_size):
        """
        Iterate on the environment.
        :param actor_net: current policy (actor NN)
        :param cov_mat: covariance matrix used for exploration
        :param batch_size: batch size
        :return: Tensors; state batch, action batch, log_proba batch
        """
        t = 0
        while t<batch_size:
            ep_rews = []
            prev_state = self.env.reset()
            for step_ep in range(self.max_steps): 
                t += 1
                with torch.no_grad():
                    parameters_based = torch.squeeze(actor_net(torch.unsqueeze(torch.tensor(prev_state), dim=0).float()))
                    if(parameters_based.dim()==0):
                        parameters_based=torch.unsqueeze(parameters_based,dim=0)
                    distribution_p = MultivariateNormal(parameters_based, cov_mat)
                    action = distribution_p.sample()
                    log_proba = distribution_p.log_prob(action)
                    action_all=np.array([])
                    action_all=np.append(action_all,np.clip(action[0].detach().numpy(), -1.0, 1.0))
                    state, reward, done, _ = self.env.step(action_all)
                    self.batch_obs.append(prev_state)
                    self.batch_acts.append(action.detach().numpy())
                    self.batch_log_probs.append(log_proba)
                    ep_rews.append(reward)
                    prev_state = state
                if done:
                    break
            self.batch_rews.append(ep_rews)
        return torch.tensor(self.batch_obs, dtype=torch.float), torch.tensor(self.batch_acts, dtype=torch.float), torch.tensor(self.batch_log_probs, dtype=torch.float)

    def immediate_rewards(self):
        """
        Immediate rewards
        :return: Tensor; batch reward
        """
        batch_rewards = []
        for ep_rews in self.batch_rews:
            for rew in reversed(ep_rews):
                batch_rewards.insert(0,rew)
        return torch.tensor(batch_rewards, dtype=torch.float)
    
    def futur_rewards(self):
        """
        Expected futures rewards
        :return: Tensor; batch reward-to-go
        """
        batch_rtgs = []
        for ep_rews in reversed(self.batch_rews):
            episodic_reward=0.0
            for rew in reversed(ep_rews):
                episodic_reward= rew + 0.99*episodic_reward
                batch_rtgs.insert(0,episodic_reward)
        return torch.tensor(batch_rtgs, dtype=torch.float)

# %%
#4) Algorithm DDPG:
class Algo_PPO():
    """ 
    PPO algorithm : training and testing
    :param policy_class: policy (actor model)
    :param env: environment
    :param hyperparameters: other hyperparameters
    """
    def __init__(self, policy_class, env, **hyperparameters):
        
        self._init_hyperparameters(hyperparameters)
        self.actor_net = policy_class(self.num_states, self.num_actions)
        self.critic_net = policy_class(self.num_states, 1)
        self.optimizer_critic = optim.Adam(self.critic_net.parameters(), self.critic_lr)
        self.optimizer_actor = optim.Adam(self.actor_net.parameters(), self.actor_lr)
        self.change_std=0.0
        self.value_std=0.5
        self.cov_var = torch.full(size=(self.num_actions,), fill_value=self.value_std)
        self.cov_mat = torch.diag(self.cov_var)
        self.rollout = Env_rollout(env, self.max_steps)
        self.ep_reward_list=[]
    
    def evaluate(self, nbr_episodes):
        """
        Testing
        :param nbr_episodes: episode number 
        :return: state batch, action batch, and reward batch
        """
        self.rollout.reset()
        state_batch, action_batch = self.rollout.iterations(self.actor_net, nbr_episodes)
        rew_batch = self.rollout.immediate_rewards()
        return state_batch, action_batch, rew_batch
        
    def train(self, nb_loop):
        """ 
        Training
        :param nb_loop: number of batch iterations
        """
        self.change_std=self.value_std/float(nb_loop)
        for ep in range(nb_loop):
            state_batch,action_batch,log_prob_batch = self.rollout.iterations_rand(self.actor_net,self.cov_mat,self.batch_size)
            batch_rtgs = self.rollout.futur_rewards()
            #self.value_std=max(self.value_std-self.change_std,0.1)
            #self.cov_var = torch.full(size=(self.num_actions,), fill_value=self.value_std)
            #self.cov_mat = torch.diag(self.cov_var)
            self.rollout.reset()
            for i in range(10):
                V_batch = torch.squeeze(self.critic_net(state_batch))
                advantage_batch = batch_rtgs - V_batch
                advantage_batch = (advantage_batch - advantage_batch.mean()) / (advantage_batch.std() + 1e-10)
                
                parameters_batch = torch.squeeze(self.actor_net(state_batch).unsqueeze(-1))
                if(parameters_batch.dim()==1):
                        parameters_batch=torch.unsqueeze(parameters_batch,dim=1)
                distribution_p = MultivariateNormal(parameters_batch, self.cov_mat)
                log_prob_current_batch = distribution_p.log_prob(action_batch)
                ratio_batch = torch.exp(log_prob_current_batch - log_prob_batch)
                ratio_loss = torch.mul(ratio_batch,advantage_batch)
                clip_loss = torch.mul(torch.clamp(ratio_loss, 0.8, 1.2),advantage_batch)
                actor_loss = (-torch.min(ratio_loss, clip_loss)).mean()

                criterion=nn.MSELoss(reduction='mean')
                critic_loss = criterion(V_batch.float(), batch_rtgs.float())
                self.optimizer_actor.zero_grad()
                actor_loss.backward(retain_graph=True)
                self.optimizer_actor.step()
                self.optimizer_critic.zero_grad()
                critic_loss.backward()
                self.optimizer_critic.step()
                
            state_batch, action_batch = self.rollout.iterations(self.actor_net, 30)
            batch_rews = self.rollout.immediate_rewards()
            self.ep_reward_list.append(batch_rews.mean().numpy())
            avg_reward = np.mean(self.ep_reward_list[-10:])
            self.rollout.reset()
            
            print("Episode * {} * Avg Reward is ==> {} And Number of steps is ==> {}".format(ep, avg_reward,ep*self.batch_size ))
            self.total_loop= self.total_loop +1
        path='load_model/parameters/ppo-{num_algo:02d}-{name}-{epoch:03d}000.npy'
        with open(path.format(num_algo=self.num_algo,epoch=int(self.total_loop/1000),name="reward"), 'wb') as f:
            np.save(f, np.array(self.ep_reward_list))
        print("Complete")
        
    def _init_hyperparameters(self, hyperparameters):
        """
        Initialize hyperparameters. 
        :param hyperparameters: hyperparameter list
        """
        self.num_algo = 1
        self.max_steps = 90
        self.total_loop = 0
        self.batch_size = 2000
        self.gamma = 0.99
        self.critic_lr = 3e-4
        self.actor_lr = 3e-4
        for param, val in hyperparameters.items():
            exec('self.' + param + ' = ' + str(val)) #juste trop fort
            
    def loading(self, num_algo, total_loop):
        """
        Loading NN weights 
        :param num_algo: algorithm number
        :param total_loop: number of total batch iterations
        """
        self.num_algo = num_algo
        self.total_loop = total_loop
        checkpoint_path1 = "load_model/weights/torch-ppo-{num_algo:02d}-actor-{epoch:03d}0.pth"
        self.actor_net.load_state_dict(torch.load(checkpoint_path1.format(epoch=int(self.total_loop/10), num_algo=self.num_algo)))
        checkpoint_path2 = "load_model/weights/torch-ppo-{num_algo:02d}-critic-{epoch:03d}0.pth"
        self.critic_net.load_state_dict(torch.load(checkpoint_path2.format(epoch=int(self.total_loop/10), num_algo=self.num_algo)))
    
    def saving(self):
        """
        Saving NN weights 
        """
        checkpoint_path = "load_model/weights/torch-ppo-{num_algo:02d}-actor-{epoch:03d}0.pth"
        torch.save(self.actor_net.state_dict(),checkpoint_path.format(epoch=int(self.total_loop/10), num_algo=self.num_algo))
        checkpoint_path = "load_model/weights/torch-ppo-{num_algo:02d}-critic-{epoch:03d}0.pth"
        torch.save(self.critic_net.state_dict(),checkpoint_path.format(epoch=int(self.total_loop/10), num_algo=self.num_algo))

# %%
#5) Computing part:
# Import environment
problem = "Crosswalk_comparison2-v0"
u_b = [2.0, 11.0, -12.5, 1.1, -1.0]
l_b = [-4.0, 9.0, -32.5, 0.9, -2.0]

env = gym.make(problem,dt=0.3,Vm=2.5,tau=1.0,lower_bounds=l_b, upper_bounds=u_b,simulation="sin")
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Initialize the algorithm
num_states = env.observation_space.shape[0]
num_actions = env.action_space.shape[0]
num_algo=33

algo=Algo_PPO(Model_PPO, env, num_algo= num_algo, num_states=num_states, num_actions=num_actions)
#algo.loading(1,1000)
# Out:
# C:\Users\zouil\anaconda3\envs\pytch\lib\site-packages\gym\spaces\box.py:74: UserWarning: WARN: Box bound precision lowered by casting to float32
#   "Box bound precision lowered by casting to {}".format(self.dtype)

# %%
#Training
import time
start = time.process_time()
algo.train(1000)
algo.saving()
end = time.process_time()
print("Running time: "+str(end-start))
# Out:
# Accident!
# Episode * 0 * Avg Reward is ==> -23.630346298217773 And Number of steps is ==> 0
# Episode * 1 * Avg Reward is ==> -27.979042053222656 And Number of steps is ==> 2000
# Episode * 2 * Avg Reward is ==> -27.70025062561035 And Number of steps is ==> 4000
# Episode * 3 * Avg Reward is ==> -26.806705474853516 And Number of steps is ==> 6000
# Episode * 4 * Avg Reward is ==> -25.519699096679688 And Number of steps is ==> 8000
# Accident!
# Episode * 5 * Avg Reward is ==> -24.199867248535156 And Number of steps is ==> 10000
# Episode * 6 * Avg Reward is ==> -23.412790298461914 And Number of steps is ==> 12000
# Accident!
# Episode * 7 * Avg Reward is ==> -23.85806655883789 And Number of steps is ==> 14000
# Episode * 8 * Avg Reward is ==> -23.958328247070312 And Number of steps is ==> 16000
# Episode * 9 * Avg Reward is ==> -24.5231876373291 And Number of steps is ==> 18000
# Episode * 10 * Avg Reward is ==> -24.598398208618164 And Number of steps is ==> 20000
# Episode * 11 * Avg Reward is ==> -23.829614639282227 And Number of steps is ==> 22000
# Episode * 12 * Avg Reward is ==> -23.725400924682617 And Number of steps is ==> 24000
# Episode * 13 * Avg Reward is ==> -23.200519561767578 And Number of steps is ==> 26000
# Episode * 14 * Avg Reward is ==> -23.068321228027344 And Number of steps is ==> 28000
# Episode * 15 * Avg Reward is ==> -23.67931365966797 And Number of steps is ==> 30000
# Episode * 16 * Avg Reward is ==> -23.650737762451172 And Number of steps is ==> 32000
# Episode * 17 * Avg Reward is ==> -22.907129287719727 And Number of steps is ==> 34000
# Episode * 18 * Avg Reward is ==> -22.00126838684082 And Number of steps is ==> 36000
# Episode * 19 * Avg Reward is ==> -20.847646713256836 And Number of steps is ==> 38000
# Episode * 20 * Avg Reward is ==> -20.19156265258789 And Number of steps is ==> 40000
# Episode * 21 * Avg Reward is ==> -20.285335540771484 And Number of steps is ==> 42000
# Episode * 22 * Avg Reward is ==> -19.650548934936523 And Number of steps is ==> 44000
# Episode * 23 * Avg Reward is ==> -19.383647918701172 And Number of steps is ==> 46000
# Accident!
# Episode * 24 * Avg Reward is ==> -19.534080505371094 And Number of steps is ==> 48000
# Episode * 25 * Avg Reward is ==> -19.0937442779541 And Number of steps is ==> 50000
# Episode * 26 * Avg Reward is ==> -19.095624923706055 And Number of steps is ==> 52000
# Accident!
# Accident!
# Episode * 27 * Avg Reward is ==> -19.098186492919922 And Number of steps is ==> 54000
# Accident!
# Episode * 28 * Avg Reward is ==> -19.262592315673828 And Number of steps is ==> 56000
# Episode * 29 * Avg Reward is ==> -19.393505096435547 And Number of steps is ==> 58000
# Accident!
# Episode * 30 * Avg Reward is ==> -19.090028762817383 And Number of steps is ==> 60000
# Episode * 31 * Avg Reward is ==> -18.85201644897461 And Number of steps is ==> 62000
# Accident!
# Episode * 32 * Avg Reward is ==> -18.63189697265625 And Number of steps is ==> 64000
# Episode * 33 * Avg Reward is ==> -18.40349578857422 And Number of steps is ==> 66000
# Accident!
# Accident!
# Episode * 34 * Avg Reward is ==> -18.51150894165039 And Number of steps is ==> 68000
# Accident!
# Episode * 35 * Avg Reward is ==> -18.392868041992188 And Number of steps is ==> 70000
# Episode * 36 * Avg Reward is ==> -18.203582763671875 And Number of steps is ==> 72000
# Episode * 37 * Avg Reward is ==> -17.839324951171875 And Number of steps is ==> 74000
# Episode * 38 * Avg Reward is ==> -17.656856536865234 And Number of steps is ==> 76000
# Accident!
# Episode * 39 * Avg Reward is ==> -17.25630760192871 And Number of steps is ==> 78000
# Episode * 40 * Avg Reward is ==> -17.291431427001953 And Number of steps is ==> 80000
# Accident!
# Accident!
# Episode * 41 * Avg Reward is ==> -16.223440170288086 And Number of steps is ==> 82000
# Accident!
# Episode * 42 * Avg Reward is ==> -15.964227676391602 And Number of steps is ==> 84000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 43 * Avg Reward is ==> -15.86951732635498 And Number of steps is ==> 86000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 44 * Avg Reward is ==> -15.760343551635742 And Number of steps is ==> 88000
# Accident!
# Accident!
# Accident!
# Episode * 45 * Avg Reward is ==> -15.732406616210938 And Number of steps is ==> 90000
# Accident!
# Accident!
# Episode * 46 * Avg Reward is ==> -16.02782440185547 And Number of steps is ==> 92000
# Accident!
# Accident!
# Episode * 47 * Avg Reward is ==> -15.767965316772461 And Number of steps is ==> 94000
# Accident!
# Episode * 48 * Avg Reward is ==> -15.718515396118164 And Number of steps is ==> 96000
# Accident!
# Accident!
# Accident!
# Episode * 49 * Avg Reward is ==> -15.827471733093262 And Number of steps is ==> 98000
# Accident!
# Episode * 50 * Avg Reward is ==> -15.81950855255127 And Number of steps is ==> 100000
# Accident!
# Accident!
# Episode * 51 * Avg Reward is ==> -15.992918014526367 And Number of steps is ==> 102000
# Episode * 52 * Avg Reward is ==> -16.018003463745117 And Number of steps is ==> 104000
# Accident!
# Accident!
# Episode * 53 * Avg Reward is ==> -16.147659301757812 And Number of steps is ==> 106000
# Accident!
# Accident!
# Episode * 54 * Avg Reward is ==> -16.16534423828125 And Number of steps is ==> 108000
# Accident!
# Accident!
# Episode * 55 * Avg Reward is ==> -15.924139022827148 And Number of steps is ==> 110000
# Accident!
# Accident!
# Accident!
# Episode * 56 * Avg Reward is ==> -17.834787368774414 And Number of steps is ==> 112000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 57 * Avg Reward is ==> -18.481435775756836 And Number of steps is ==> 114000
# Accident!
# Accident!
# Accident!
# Episode * 58 * Avg Reward is ==> -18.61811065673828 And Number of steps is ==> 116000
# Episode * 59 * Avg Reward is ==> -18.618227005004883 And Number of steps is ==> 118000
# Accident!
# Accident!
# Accident!
# Episode * 60 * Avg Reward is ==> -18.281627655029297 And Number of steps is ==> 120000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 61 * Avg Reward is ==> -18.24960708618164 And Number of steps is ==> 122000
# Episode * 62 * Avg Reward is ==> -17.9320125579834 And Number of steps is ==> 124000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 63 * Avg Reward is ==> -20.130491256713867 And Number of steps is ==> 126000
# Accident!
# Accident!
# Accident!
# Episode * 64 * Avg Reward is ==> -19.58354377746582 And Number of steps is ==> 128000
# Accident!
# Accident!
# Accident!
# Episode * 65 * Avg Reward is ==> -19.848730087280273 And Number of steps is ==> 130000
# Episode * 66 * Avg Reward is ==> -17.462757110595703 And Number of steps is ==> 132000
# Accident!
# Accident!
# Episode * 67 * Avg Reward is ==> -16.591339111328125 And Number of steps is ==> 134000
# Episode * 68 * Avg Reward is ==> -16.253185272216797 And Number of steps is ==> 136000
# Accident!
# Accident!
# Episode * 69 * Avg Reward is ==> -15.841694831848145 And Number of steps is ==> 138000
# Accident!
# Episode * 70 * Avg Reward is ==> -15.888694763183594 And Number of steps is ==> 140000
# Accident!
# Accident!
# Accident!
# Episode * 71 * Avg Reward is ==> -16.059307098388672 And Number of steps is ==> 142000
# Episode * 72 * Avg Reward is ==> -15.970890998840332 And Number of steps is ==> 144000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 73 * Avg Reward is ==> -13.576667785644531 And Number of steps is ==> 146000
# Accident!
# Episode * 74 * Avg Reward is ==> -13.912020683288574 And Number of steps is ==> 148000
# Episode * 75 * Avg Reward is ==> -13.32396125793457 And Number of steps is ==> 150000
# Accident!
# Accident!
# Accident!
# Episode * 76 * Avg Reward is ==> -13.344900131225586 And Number of steps is ==> 152000
# Accident!
# Accident!
# Episode * 77 * Avg Reward is ==> -13.530413627624512 And Number of steps is ==> 154000
# Accident!
# Accident!
# Accident!
# Episode * 78 * Avg Reward is ==> -13.71342658996582 And Number of steps is ==> 156000
# Accident!
# Episode * 79 * Avg Reward is ==> -13.395289421081543 And Number of steps is ==> 158000
# Episode * 80 * Avg Reward is ==> -13.319188117980957 And Number of steps is ==> 160000
# Accident!
# Accident!
# Episode * 81 * Avg Reward is ==> -13.354228019714355 And Number of steps is ==> 162000
# Accident!
# Episode * 82 * Avg Reward is ==> -13.60076904296875 And Number of steps is ==> 164000
# Episode * 83 * Avg Reward is ==> -13.658726692199707 And Number of steps is ==> 166000
# Accident!
# Episode * 84 * Avg Reward is ==> -13.25792407989502 And Number of steps is ==> 168000
# Accident!
# Episode * 85 * Avg Reward is ==> -14.115762710571289 And Number of steps is ==> 170000
# Episode * 86 * Avg Reward is ==> -14.02137565612793 And Number of steps is ==> 172000
# Accident!
# Accident!
# Accident!
# Episode * 87 * Avg Reward is ==> -14.090791702270508 And Number of steps is ==> 174000
# Accident!
# Accident!
# Accident!
# Episode * 88 * Avg Reward is ==> -14.437112808227539 And Number of steps is ==> 176000
# Accident!
# Episode * 89 * Avg Reward is ==> -14.903124809265137 And Number of steps is ==> 178000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 90 * Avg Reward is ==> -15.64314079284668 And Number of steps is ==> 180000
# Episode * 91 * Avg Reward is ==> -15.62855339050293 And Number of steps is ==> 182000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 92 * Avg Reward is ==> -16.23309898376465 And Number of steps is ==> 184000
# Accident!
# Episode * 93 * Avg Reward is ==> -16.804615020751953 And Number of steps is ==> 186000
# Accident!
# Episode * 94 * Avg Reward is ==> -16.6780948638916 And Number of steps is ==> 188000
# Accident!
# Accident!
# Accident!
# Episode * 95 * Avg Reward is ==> -16.51326560974121 And Number of steps is ==> 190000
# Episode * 96 * Avg Reward is ==> -16.18088722229004 And Number of steps is ==> 192000
# Accident!
# Accident!
# Episode * 97 * Avg Reward is ==> -16.276721954345703 And Number of steps is ==> 194000
# Accident!
# Episode * 98 * Avg Reward is ==> -15.65185546875 And Number of steps is ==> 196000
# Episode * 99 * Avg Reward is ==> -16.155513763427734 And Number of steps is ==> 198000
# Accident!
# Accident!
# Episode * 100 * Avg Reward is ==> -16.007530212402344 And Number of steps is ==> 200000
# Episode * 101 * Avg Reward is ==> -16.088871002197266 And Number of steps is ==> 202000
# Episode * 102 * Avg Reward is ==> -15.095730781555176 And Number of steps is ==> 204000
# Accident!
# Episode * 103 * Avg Reward is ==> -14.178805351257324 And Number of steps is ==> 206000
# Accident!
# Accident!
# Episode * 104 * Avg Reward is ==> -14.271041870117188 And Number of steps is ==> 208000
# Accident!
# Accident!
# Episode * 105 * Avg Reward is ==> -13.30444049835205 And Number of steps is ==> 210000
# Episode * 106 * Avg Reward is ==> -13.957901000976562 And Number of steps is ==> 212000
# Accident!
# Accident!
# Episode * 107 * Avg Reward is ==> -13.630224227905273 And Number of steps is ==> 214000
# Accident!
# Episode * 108 * Avg Reward is ==> -13.89561653137207 And Number of steps is ==> 216000
# Accident!
# Accident!
# Episode * 109 * Avg Reward is ==> -13.895896911621094 And Number of steps is ==> 218000
# Accident!
# Accident!
# Episode * 110 * Avg Reward is ==> -13.593648910522461 And Number of steps is ==> 220000
# Episode * 111 * Avg Reward is ==> -12.920292854309082 And Number of steps is ==> 222000
# Accident!
# Accident!
# Episode * 112 * Avg Reward is ==> -13.415498733520508 And Number of steps is ==> 224000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 113 * Avg Reward is ==> -14.037895202636719 And Number of steps is ==> 226000
# Accident!
# Accident!
# Accident!
# Episode * 114 * Avg Reward is ==> -13.953097343444824 And Number of steps is ==> 228000
# Accident!
# Episode * 115 * Avg Reward is ==> -14.8456392288208 And Number of steps is ==> 230000
# Accident!
# Accident!
# Episode * 116 * Avg Reward is ==> -14.53532886505127 And Number of steps is ==> 232000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 117 * Avg Reward is ==> -15.110101699829102 And Number of steps is ==> 234000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 118 * Avg Reward is ==> -15.038846015930176 And Number of steps is ==> 236000
# Accident!
# Accident!
# Accident!
# Episode * 119 * Avg Reward is ==> -14.782109260559082 And Number of steps is ==> 238000
# Accident!
# Accident!
# Accident!
# Episode * 120 * Avg Reward is ==> -15.097770690917969 And Number of steps is ==> 240000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 121 * Avg Reward is ==> -15.909173965454102 And Number of steps is ==> 242000
# Accident!
# Accident!
# Accident!
# Episode * 122 * Avg Reward is ==> -16.033920288085938 And Number of steps is ==> 244000
# Accident!
# Accident!
# Accident!
# Episode * 123 * Avg Reward is ==> -16.43900489807129 And Number of steps is ==> 246000
# Accident!
# Accident!
# Accident!
# Episode * 124 * Avg Reward is ==> -16.834667205810547 And Number of steps is ==> 248000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 125 * Avg Reward is ==> -16.620176315307617 And Number of steps is ==> 250000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 126 * Avg Reward is ==> -16.74005699157715 And Number of steps is ==> 252000
# Episode * 127 * Avg Reward is ==> -16.197959899902344 And Number of steps is ==> 254000
# Accident!
# Episode * 128 * Avg Reward is ==> -15.780601501464844 And Number of steps is ==> 256000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 129 * Avg Reward is ==> -15.344228744506836 And Number of steps is ==> 258000
# Accident!
# Episode * 130 * Avg Reward is ==> -14.894655227661133 And Number of steps is ==> 260000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 131 * Avg Reward is ==> -14.111332893371582 And Number of steps is ==> 262000
# Episode * 132 * Avg Reward is ==> -13.932184219360352 And Number of steps is ==> 264000
# Episode * 133 * Avg Reward is ==> -13.309106826782227 And Number of steps is ==> 266000
# Episode * 134 * Avg Reward is ==> -13.254773139953613 And Number of steps is ==> 268000
# Accident!
# Accident!
# Episode * 135 * Avg Reward is ==> -13.023368835449219 And Number of steps is ==> 270000
# Accident!
# Accident!
# Episode * 136 * Avg Reward is ==> -12.811243057250977 And Number of steps is ==> 272000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 137 * Avg Reward is ==> -13.42637825012207 And Number of steps is ==> 274000
# Accident!
# Accident!
# Episode * 138 * Avg Reward is ==> -14.056829452514648 And Number of steps is ==> 276000
# Accident!
# Episode * 139 * Avg Reward is ==> -14.402542114257812 And Number of steps is ==> 278000
# Accident!
# Episode * 140 * Avg Reward is ==> -14.83324909210205 And Number of steps is ==> 280000
# Episode * 141 * Avg Reward is ==> -15.692358016967773 And Number of steps is ==> 282000
# Episode * 142 * Avg Reward is ==> -15.642840385437012 And Number of steps is ==> 284000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 143 * Avg Reward is ==> -16.52297592163086 And Number of steps is ==> 286000
# Episode * 144 * Avg Reward is ==> -16.151966094970703 And Number of steps is ==> 288000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 145 * Avg Reward is ==> -16.222335815429688 And Number of steps is ==> 290000
# Accident!
# Episode * 146 * Avg Reward is ==> -16.229202270507812 And Number of steps is ==> 292000
# Accident!
# Accident!
# Episode * 147 * Avg Reward is ==> -16.01030158996582 And Number of steps is ==> 294000
# Accident!
# Accident!
# Episode * 148 * Avg Reward is ==> -15.44275951385498 And Number of steps is ==> 296000
# Episode * 149 * Avg Reward is ==> -15.069971084594727 And Number of steps is ==> 298000
# Episode * 150 * Avg Reward is ==> -15.037808418273926 And Number of steps is ==> 300000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 151 * Avg Reward is ==> -14.468469619750977 And Number of steps is ==> 302000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 152 * Avg Reward is ==> -14.814699172973633 And Number of steps is ==> 304000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 153 * Avg Reward is ==> -13.810397148132324 And Number of steps is ==> 306000
# Accident!
# Accident!
# Accident!
# Episode * 154 * Avg Reward is ==> -14.41313648223877 And Number of steps is ==> 308000
# Episode * 155 * Avg Reward is ==> -14.193275451660156 And Number of steps is ==> 310000
# Accident!
# Accident!
# Accident!
# Episode * 156 * Avg Reward is ==> -14.4231595993042 And Number of steps is ==> 312000
# Accident!
# Accident!
# Accident!
# Episode * 157 * Avg Reward is ==> -14.130891799926758 And Number of steps is ==> 314000
# Accident!
# Episode * 158 * Avg Reward is ==> -14.596231460571289 And Number of steps is ==> 316000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 159 * Avg Reward is ==> -14.654680252075195 And Number of steps is ==> 318000
# Accident!
# Accident!
# Accident!
# Episode * 160 * Avg Reward is ==> -14.069814682006836 And Number of steps is ==> 320000
# Accident!
# Accident!
# Accident!
# Episode * 161 * Avg Reward is ==> -13.956494331359863 And Number of steps is ==> 322000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 162 * Avg Reward is ==> -13.73756217956543 And Number of steps is ==> 324000
# Accident!
# Episode * 163 * Avg Reward is ==> -13.744369506835938 And Number of steps is ==> 326000
# Accident!
# Episode * 164 * Avg Reward is ==> -13.047399520874023 And Number of steps is ==> 328000
# Episode * 165 * Avg Reward is ==> -13.622489929199219 And Number of steps is ==> 330000
# Accident!
# Accident!
# Accident!
# Episode * 166 * Avg Reward is ==> -13.77814769744873 And Number of steps is ==> 332000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 167 * Avg Reward is ==> -14.513542175292969 And Number of steps is ==> 334000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 168 * Avg Reward is ==> -14.427637100219727 And Number of steps is ==> 336000
# Accident!
# Accident!
# Episode * 169 * Avg Reward is ==> -14.78877067565918 And Number of steps is ==> 338000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 170 * Avg Reward is ==> -15.069089889526367 And Number of steps is ==> 340000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 171 * Avg Reward is ==> -15.272236824035645 And Number of steps is ==> 342000
# Accident!
# Accident!
# Episode * 172 * Avg Reward is ==> -15.096372604370117 And Number of steps is ==> 344000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 173 * Avg Reward is ==> -15.425994873046875 And Number of steps is ==> 346000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 174 * Avg Reward is ==> -16.00411605834961 And Number of steps is ==> 348000
# Accident!
# Episode * 175 * Avg Reward is ==> -15.553375244140625 And Number of steps is ==> 350000
# Accident!
# Accident!
# Accident!
# Episode * 176 * Avg Reward is ==> -15.183476448059082 And Number of steps is ==> 352000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 177 * Avg Reward is ==> -14.701272964477539 And Number of steps is ==> 354000
# Accident!
# Accident!
# Episode * 178 * Avg Reward is ==> -14.614669799804688 And Number of steps is ==> 356000
# Accident!
# Episode * 179 * Avg Reward is ==> -14.1218900680542 And Number of steps is ==> 358000
# Episode * 180 * Avg Reward is ==> -13.940106391906738 And Number of steps is ==> 360000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 181 * Avg Reward is ==> -13.756489753723145 And Number of steps is ==> 362000
# Accident!
# Accident!
# Episode * 182 * Avg Reward is ==> -13.679733276367188 And Number of steps is ==> 364000
# Accident!
# Accident!
# Episode * 183 * Avg Reward is ==> -13.497961044311523 And Number of steps is ==> 366000
# Accident!
# Episode * 184 * Avg Reward is ==> -13.329452514648438 And Number of steps is ==> 368000
# Accident!
# Accident!
# Accident!
# Episode * 185 * Avg Reward is ==> -13.122980117797852 And Number of steps is ==> 370000
# Accident!
# Accident!
# Episode * 186 * Avg Reward is ==> -13.214442253112793 And Number of steps is ==> 372000
# Accident!
# Accident!
# Episode * 187 * Avg Reward is ==> -12.855341911315918 And Number of steps is ==> 374000
# Episode * 188 * Avg Reward is ==> -12.56575870513916 And Number of steps is ==> 376000
# Accident!
# Accident!
# Episode * 189 * Avg Reward is ==> -12.806071281433105 And Number of steps is ==> 378000
# Episode * 190 * Avg Reward is ==> -12.683056831359863 And Number of steps is ==> 380000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 191 * Avg Reward is ==> -12.712728500366211 And Number of steps is ==> 382000
# Episode * 192 * Avg Reward is ==> -12.466781616210938 And Number of steps is ==> 384000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 193 * Avg Reward is ==> -12.270626068115234 And Number of steps is ==> 386000
# Episode * 194 * Avg Reward is ==> -12.015768051147461 And Number of steps is ==> 388000
# Episode * 195 * Avg Reward is ==> -12.231892585754395 And Number of steps is ==> 390000
# Accident!
# Accident!
# Accident!
# Episode * 196 * Avg Reward is ==> -11.795820236206055 And Number of steps is ==> 392000
# Accident!
# Episode * 197 * Avg Reward is ==> -11.967187881469727 And Number of steps is ==> 394000
# Accident!
# Episode * 198 * Avg Reward is ==> -12.438325881958008 And Number of steps is ==> 396000
# Accident!
# Accident!
# Accident!
# Episode * 199 * Avg Reward is ==> -12.149274826049805 And Number of steps is ==> 398000
# Episode * 200 * Avg Reward is ==> -12.339987754821777 And Number of steps is ==> 400000
# Accident!
# Episode * 201 * Avg Reward is ==> -12.132499694824219 And Number of steps is ==> 402000
# Episode * 202 * Avg Reward is ==> -12.244635581970215 And Number of steps is ==> 404000
# Accident!
# Accident!
# Episode * 203 * Avg Reward is ==> -12.786249160766602 And Number of steps is ==> 406000
# Accident!
# Accident!
# Episode * 204 * Avg Reward is ==> -13.012155532836914 And Number of steps is ==> 408000
# Accident!
# Episode * 205 * Avg Reward is ==> -12.622766494750977 And Number of steps is ==> 410000
# Episode * 206 * Avg Reward is ==> -12.682845115661621 And Number of steps is ==> 412000
# Accident!
# Accident!
# Accident!
# Episode * 207 * Avg Reward is ==> -12.349576950073242 And Number of steps is ==> 414000
# Episode * 208 * Avg Reward is ==> -11.805286407470703 And Number of steps is ==> 416000
# Accident!
# Episode * 209 * Avg Reward is ==> -12.100956916809082 And Number of steps is ==> 418000
# Accident!
# Episode * 210 * Avg Reward is ==> -11.877102851867676 And Number of steps is ==> 420000
# Episode * 211 * Avg Reward is ==> -12.381349563598633 And Number of steps is ==> 422000
# Accident!
# Episode * 212 * Avg Reward is ==> -12.446028709411621 And Number of steps is ==> 424000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 213 * Avg Reward is ==> -11.909149169921875 And Number of steps is ==> 426000
# Accident!
# Episode * 214 * Avg Reward is ==> -11.490118980407715 And Number of steps is ==> 428000
# Accident!
# Episode * 215 * Avg Reward is ==> -11.407742500305176 And Number of steps is ==> 430000
# Episode * 216 * Avg Reward is ==> -11.76780891418457 And Number of steps is ==> 432000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 217 * Avg Reward is ==> -12.424639701843262 And Number of steps is ==> 434000
# Accident!
# Episode * 218 * Avg Reward is ==> -12.961160659790039 And Number of steps is ==> 436000
# Accident!
# Accident!
# Accident!
# Episode * 219 * Avg Reward is ==> -12.889785766601562 And Number of steps is ==> 438000
# Accident!
# Episode * 220 * Avg Reward is ==> -13.286822319030762 And Number of steps is ==> 440000
# Accident!
# Accident!
# Episode * 221 * Avg Reward is ==> -13.191983222961426 And Number of steps is ==> 442000
# Accident!
# Accident!
# Episode * 222 * Avg Reward is ==> -13.400749206542969 And Number of steps is ==> 444000
# Accident!
# Episode * 223 * Avg Reward is ==> -13.279645919799805 And Number of steps is ==> 446000
# Episode * 224 * Avg Reward is ==> -13.574792861938477 And Number of steps is ==> 448000
# Accident!
# Episode * 225 * Avg Reward is ==> -14.045183181762695 And Number of steps is ==> 450000
# Accident!
# Episode * 226 * Avg Reward is ==> -14.013532638549805 And Number of steps is ==> 452000
# Episode * 227 * Avg Reward is ==> -13.529765129089355 And Number of steps is ==> 454000
# Episode * 228 * Avg Reward is ==> -12.993322372436523 And Number of steps is ==> 456000
# Accident!
# Episode * 229 * Avg Reward is ==> -13.291468620300293 And Number of steps is ==> 458000
# Episode * 230 * Avg Reward is ==> -12.606694221496582 And Number of steps is ==> 460000
# Episode * 231 * Avg Reward is ==> -12.576289176940918 And Number of steps is ==> 462000
# Accident!
# Episode * 232 * Avg Reward is ==> -12.249504089355469 And Number of steps is ==> 464000
# Accident!
# Episode * 233 * Avg Reward is ==> -12.410837173461914 And Number of steps is ==> 466000
# Episode * 234 * Avg Reward is ==> -12.206737518310547 And Number of steps is ==> 468000
# Accident!
# Accident!
# Episode * 235 * Avg Reward is ==> -12.116059303283691 And Number of steps is ==> 470000
# Episode * 236 * Avg Reward is ==> -11.986663818359375 And Number of steps is ==> 472000
# Episode * 237 * Avg Reward is ==> -11.906771659851074 And Number of steps is ==> 474000
# Episode * 238 * Avg Reward is ==> -12.361265182495117 And Number of steps is ==> 476000
# Episode * 239 * Avg Reward is ==> -11.75155258178711 And Number of steps is ==> 478000
# Accident!
# Episode * 240 * Avg Reward is ==> -12.510396003723145 And Number of steps is ==> 480000
# Episode * 241 * Avg Reward is ==> -12.18344497680664 And Number of steps is ==> 482000
# Accident!
# Accident!
# Episode * 242 * Avg Reward is ==> -12.313720703125 And Number of steps is ==> 484000
# Accident!
# Episode * 243 * Avg Reward is ==> -12.116161346435547 And Number of steps is ==> 486000
# Accident!
# Episode * 244 * Avg Reward is ==> -11.770779609680176 And Number of steps is ==> 488000
# Episode * 245 * Avg Reward is ==> -11.612255096435547 And Number of steps is ==> 490000
# Accident!
# Episode * 246 * Avg Reward is ==> -11.485612869262695 And Number of steps is ==> 492000
# Accident!
# Episode * 247 * Avg Reward is ==> -11.75882339477539 And Number of steps is ==> 494000
# Accident!
# Episode * 248 * Avg Reward is ==> -11.351678848266602 And Number of steps is ==> 496000
# Accident!
# Episode * 249 * Avg Reward is ==> -11.491140365600586 And Number of steps is ==> 498000
# Accident!
# Accident!
# Episode * 250 * Avg Reward is ==> -11.102303504943848 And Number of steps is ==> 500000
# Accident!
# Episode * 251 * Avg Reward is ==> -11.160070419311523 And Number of steps is ==> 502000
# Episode * 252 * Avg Reward is ==> -11.10416030883789 And Number of steps is ==> 504000
# Episode * 253 * Avg Reward is ==> -11.20576286315918 And Number of steps is ==> 506000
# Episode * 254 * Avg Reward is ==> -11.226244926452637 And Number of steps is ==> 508000
# Accident!
# Episode * 255 * Avg Reward is ==> -11.096101760864258 And Number of steps is ==> 510000
# Accident!
# Accident!
# Episode * 256 * Avg Reward is ==> -10.960278511047363 And Number of steps is ==> 512000
# Accident!
# Accident!
# Episode * 257 * Avg Reward is ==> -10.470209121704102 And Number of steps is ==> 514000
# Episode * 258 * Avg Reward is ==> -10.498530387878418 And Number of steps is ==> 516000
# Episode * 259 * Avg Reward is ==> -10.528661727905273 And Number of steps is ==> 518000
# Episode * 260 * Avg Reward is ==> -10.629024505615234 And Number of steps is ==> 520000
# Accident!
# Episode * 261 * Avg Reward is ==> -10.64416217803955 And Number of steps is ==> 522000
# Accident!
# Accident!
# Accident!
# Episode * 262 * Avg Reward is ==> -11.05667781829834 And Number of steps is ==> 524000
# Accident!
# Episode * 263 * Avg Reward is ==> -10.942524909973145 And Number of steps is ==> 526000
# Accident!
# Accident!
# Episode * 264 * Avg Reward is ==> -11.180058479309082 And Number of steps is ==> 528000
# Accident!
# Episode * 265 * Avg Reward is ==> -11.442505836486816 And Number of steps is ==> 530000
# Accident!
# Episode * 266 * Avg Reward is ==> -11.74099349975586 And Number of steps is ==> 532000
# Accident!
# Accident!
# Accident!
# Episode * 267 * Avg Reward is ==> -11.744227409362793 And Number of steps is ==> 534000
# Episode * 268 * Avg Reward is ==> -11.865678787231445 And Number of steps is ==> 536000
# Accident!
# Episode * 269 * Avg Reward is ==> -11.780872344970703 And Number of steps is ==> 538000
# Accident!
# Episode * 270 * Avg Reward is ==> -11.995925903320312 And Number of steps is ==> 540000
# Accident!
# Episode * 271 * Avg Reward is ==> -12.362574577331543 And Number of steps is ==> 542000
# Episode * 272 * Avg Reward is ==> -11.982912063598633 And Number of steps is ==> 544000
# Accident!
# Episode * 273 * Avg Reward is ==> -12.2715482711792 And Number of steps is ==> 546000
# Accident!
# Episode * 274 * Avg Reward is ==> -12.172882080078125 And Number of steps is ==> 548000
# Episode * 275 * Avg Reward is ==> -12.330111503601074 And Number of steps is ==> 550000
# Accident!
# Episode * 276 * Avg Reward is ==> -12.024872779846191 And Number of steps is ==> 552000
# Accident!
# Episode * 277 * Avg Reward is ==> -12.202333450317383 And Number of steps is ==> 554000
# Episode * 278 * Avg Reward is ==> -12.312397003173828 And Number of steps is ==> 556000
# Accident!
# Episode * 279 * Avg Reward is ==> -12.554594039916992 And Number of steps is ==> 558000
# Episode * 280 * Avg Reward is ==> -12.268243789672852 And Number of steps is ==> 560000
# Episode * 281 * Avg Reward is ==> -11.867013931274414 And Number of steps is ==> 562000
# Episode * 282 * Avg Reward is ==> -11.885457992553711 And Number of steps is ==> 564000
# Accident!
# Episode * 283 * Avg Reward is ==> -11.488975524902344 And Number of steps is ==> 566000
# Episode * 284 * Avg Reward is ==> -11.688314437866211 And Number of steps is ==> 568000
# Episode * 285 * Avg Reward is ==> -11.615716934204102 And Number of steps is ==> 570000
# Episode * 286 * Avg Reward is ==> -11.850784301757812 And Number of steps is ==> 572000
# Accident!
# Episode * 287 * Avg Reward is ==> -12.019009590148926 And Number of steps is ==> 574000
# Episode * 288 * Avg Reward is ==> -12.023401260375977 And Number of steps is ==> 576000
# Accident!
# Episode * 289 * Avg Reward is ==> -12.136252403259277 And Number of steps is ==> 578000
# Episode * 290 * Avg Reward is ==> -12.160907745361328 And Number of steps is ==> 580000
# Accident!
# Episode * 291 * Avg Reward is ==> -12.051593780517578 And Number of steps is ==> 582000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 292 * Avg Reward is ==> -11.98022174835205 And Number of steps is ==> 584000
# Accident!
# Episode * 293 * Avg Reward is ==> -12.385189056396484 And Number of steps is ==> 586000
# Accident!
# Accident!
# Episode * 294 * Avg Reward is ==> -12.517967224121094 And Number of steps is ==> 588000
# Accident!
# Accident!
# Episode * 295 * Avg Reward is ==> -12.279101371765137 And Number of steps is ==> 590000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 296 * Avg Reward is ==> -12.315714836120605 And Number of steps is ==> 592000
# Accident!
# Episode * 297 * Avg Reward is ==> -12.366586685180664 And Number of steps is ==> 594000
# Accident!
# Accident!
# Accident!
# Episode * 298 * Avg Reward is ==> -12.400182723999023 And Number of steps is ==> 596000
# Episode * 299 * Avg Reward is ==> -11.883167266845703 And Number of steps is ==> 598000
# Accident!
# Episode * 300 * Avg Reward is ==> -11.945619583129883 And Number of steps is ==> 600000
# Accident!
# Accident!
# Episode * 301 * Avg Reward is ==> -12.179826736450195 And Number of steps is ==> 602000
# Accident!
# Episode * 302 * Avg Reward is ==> -12.418329238891602 And Number of steps is ==> 604000
# Episode * 303 * Avg Reward is ==> -12.323282241821289 And Number of steps is ==> 606000
# Episode * 304 * Avg Reward is ==> -11.898726463317871 And Number of steps is ==> 608000
# Episode * 305 * Avg Reward is ==> -12.05435562133789 And Number of steps is ==> 610000
# Accident!
# Accident!
# Accident!
# Episode * 306 * Avg Reward is ==> -12.00556755065918 And Number of steps is ==> 612000
# Accident!
# Episode * 307 * Avg Reward is ==> -11.83430290222168 And Number of steps is ==> 614000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 308 * Avg Reward is ==> -12.022622108459473 And Number of steps is ==> 616000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 309 * Avg Reward is ==> -12.462407112121582 And Number of steps is ==> 618000
# Accident!
# Accident!
# Episode * 310 * Avg Reward is ==> -12.211149215698242 And Number of steps is ==> 620000
# Accident!
# Accident!
# Episode * 311 * Avg Reward is ==> -11.998310089111328 And Number of steps is ==> 622000
# Accident!
# Accident!
# Episode * 312 * Avg Reward is ==> -11.650578498840332 And Number of steps is ==> 624000
# Episode * 313 * Avg Reward is ==> -11.46202278137207 And Number of steps is ==> 626000
# Accident!
# Episode * 314 * Avg Reward is ==> -11.820699691772461 And Number of steps is ==> 628000
# Accident!
# Accident!
# Accident!
# Episode * 315 * Avg Reward is ==> -11.789599418640137 And Number of steps is ==> 630000
# Episode * 316 * Avg Reward is ==> -11.955836296081543 And Number of steps is ==> 632000
# Accident!
# Episode * 317 * Avg Reward is ==> -11.853876113891602 And Number of steps is ==> 634000
# Episode * 318 * Avg Reward is ==> -11.70437240600586 And Number of steps is ==> 636000
# Accident!
# Episode * 319 * Avg Reward is ==> -11.826475143432617 And Number of steps is ==> 638000
# Episode * 320 * Avg Reward is ==> -12.015462875366211 And Number of steps is ==> 640000
# Episode * 321 * Avg Reward is ==> -11.86679458618164 And Number of steps is ==> 642000
# Accident!
# Episode * 322 * Avg Reward is ==> -12.023025512695312 And Number of steps is ==> 644000
# Accident!
# Episode * 323 * Avg Reward is ==> -11.926559448242188 And Number of steps is ==> 646000
# Accident!
# Episode * 324 * Avg Reward is ==> -11.45627212524414 And Number of steps is ==> 648000
# Accident!
# Accident!
# Episode * 325 * Avg Reward is ==> -11.654415130615234 And Number of steps is ==> 650000
# Accident!
# Episode * 326 * Avg Reward is ==> -11.38416862487793 And Number of steps is ==> 652000
# Accident!
# Accident!
# Episode * 327 * Avg Reward is ==> -11.674806594848633 And Number of steps is ==> 654000
# Accident!
# Episode * 328 * Avg Reward is ==> -11.348085403442383 And Number of steps is ==> 656000
# Episode * 329 * Avg Reward is ==> -10.787813186645508 And Number of steps is ==> 658000
# Accident!
# Episode * 330 * Avg Reward is ==> -10.536654472351074 And Number of steps is ==> 660000
# Episode * 331 * Avg Reward is ==> -10.519787788391113 And Number of steps is ==> 662000
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 332 * Avg Reward is ==> -10.477076530456543 And Number of steps is ==> 664000
# Accident!
# Accident!
# Episode * 333 * Avg Reward is ==> -10.748562812805176 And Number of steps is ==> 666000
# Episode * 334 * Avg Reward is ==> -11.187339782714844 And Number of steps is ==> 668000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 335 * Avg Reward is ==> -10.683084487915039 And Number of steps is ==> 670000
# Accident!
# Accident!
# Episode * 336 * Avg Reward is ==> -10.547417640686035 And Number of steps is ==> 672000
# Accident!
# Episode * 337 * Avg Reward is ==> -10.113993644714355 And Number of steps is ==> 674000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 338 * Avg Reward is ==> -10.187641143798828 And Number of steps is ==> 676000
# Accident!
# Episode * 339 * Avg Reward is ==> -10.46947193145752 And Number of steps is ==> 678000
# Accident!
# Episode * 340 * Avg Reward is ==> -10.301312446594238 And Number of steps is ==> 680000
# Accident!
# Episode * 341 * Avg Reward is ==> -10.631608009338379 And Number of steps is ==> 682000
# Episode * 342 * Avg Reward is ==> -10.883621215820312 And Number of steps is ==> 684000
# Accident!
# Accident!
# Episode * 343 * Avg Reward is ==> -11.074019432067871 And Number of steps is ==> 686000
# Accident!
# Episode * 344 * Avg Reward is ==> -10.675474166870117 And Number of steps is ==> 688000
# Accident!
# Episode * 345 * Avg Reward is ==> -10.808340072631836 And Number of steps is ==> 690000
# Accident!
# Episode * 346 * Avg Reward is ==> -11.269105911254883 And Number of steps is ==> 692000
# Accident!
# Episode * 347 * Avg Reward is ==> -11.564475059509277 And Number of steps is ==> 694000
# Accident!
# Episode * 348 * Avg Reward is ==> -11.666496276855469 And Number of steps is ==> 696000
# Accident!
# Accident!
# Accident!
# Episode * 349 * Avg Reward is ==> -12.07239818572998 And Number of steps is ==> 698000
# Accident!
# Episode * 350 * Avg Reward is ==> -12.324151992797852 And Number of steps is ==> 700000
# Episode * 351 * Avg Reward is ==> -12.047410011291504 And Number of steps is ==> 702000
# Episode * 352 * Avg Reward is ==> -11.974451065063477 And Number of steps is ==> 704000
# Episode * 353 * Avg Reward is ==> -11.337224960327148 And Number of steps is ==> 706000
# Accident!
# Episode * 354 * Avg Reward is ==> -11.879048347473145 And Number of steps is ==> 708000
# Episode * 355 * Avg Reward is ==> -11.873934745788574 And Number of steps is ==> 710000
# Accident!
# Episode * 356 * Avg Reward is ==> -11.827261924743652 And Number of steps is ==> 712000
# Accident!
# Episode * 357 * Avg Reward is ==> -11.62314510345459 And Number of steps is ==> 714000
# Episode * 358 * Avg Reward is ==> -11.740768432617188 And Number of steps is ==> 716000
# Episode * 359 * Avg Reward is ==> -11.556449890136719 And Number of steps is ==> 718000
# Accident!
# Episode * 360 * Avg Reward is ==> -11.95736026763916 And Number of steps is ==> 720000
# Accident!
# Accident!
# Episode * 361 * Avg Reward is ==> -12.492155075073242 And Number of steps is ==> 722000
# Accident!
# Episode * 362 * Avg Reward is ==> -12.561583518981934 And Number of steps is ==> 724000
# Accident!
# Accident!
# Episode * 363 * Avg Reward is ==> -13.138559341430664 And Number of steps is ==> 726000
# Accident!
# Accident!
# Episode * 364 * Avg Reward is ==> -12.765807151794434 And Number of steps is ==> 728000
# Accident!
# Accident!
# Episode * 365 * Avg Reward is ==> -12.598214149475098 And Number of steps is ==> 730000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 366 * Avg Reward is ==> -12.581134796142578 And Number of steps is ==> 732000
# Accident!
# Accident!
# Episode * 367 * Avg Reward is ==> -12.917177200317383 And Number of steps is ==> 734000
# Accident!
# Accident!
# Episode * 368 * Avg Reward is ==> -12.53148078918457 And Number of steps is ==> 736000
# Accident!
# Accident!
# Accident!
# Episode * 369 * Avg Reward is ==> -12.343816757202148 And Number of steps is ==> 738000
# Accident!
# Accident!
# Accident!
# Episode * 370 * Avg Reward is ==> -12.001585006713867 And Number of steps is ==> 740000
# Episode * 371 * Avg Reward is ==> -11.700767517089844 And Number of steps is ==> 742000
# Accident!
# Episode * 372 * Avg Reward is ==> -11.448240280151367 And Number of steps is ==> 744000
# Accident!
# Accident!
# Accident!
# Episode * 373 * Avg Reward is ==> -11.122797966003418 And Number of steps is ==> 746000
# Accident!
# Episode * 374 * Avg Reward is ==> -11.262225151062012 And Number of steps is ==> 748000
# Accident!
# Episode * 375 * Avg Reward is ==> -11.555807113647461 And Number of steps is ==> 750000
# Accident!
# Episode * 376 * Avg Reward is ==> -11.58769702911377 And Number of steps is ==> 752000
# Episode * 377 * Avg Reward is ==> -11.378893852233887 And Number of steps is ==> 754000
# Accident!
# Episode * 378 * Avg Reward is ==> -12.037014961242676 And Number of steps is ==> 756000
# Episode * 379 * Avg Reward is ==> -11.845038414001465 And Number of steps is ==> 758000
# Episode * 380 * Avg Reward is ==> -11.96818733215332 And Number of steps is ==> 760000
# Episode * 381 * Avg Reward is ==> -11.885370254516602 And Number of steps is ==> 762000
# Accident!
# Accident!
# Episode * 382 * Avg Reward is ==> -12.255895614624023 And Number of steps is ==> 764000
# Accident!
# Accident!
# Episode * 383 * Avg Reward is ==> -12.546987533569336 And Number of steps is ==> 766000
# Episode * 384 * Avg Reward is ==> -12.448616981506348 And Number of steps is ==> 768000
# Accident!
# Episode * 385 * Avg Reward is ==> -12.456160545349121 And Number of steps is ==> 770000
# Accident!
# Episode * 386 * Avg Reward is ==> -12.320209503173828 And Number of steps is ==> 772000
# Episode * 387 * Avg Reward is ==> -12.156458854675293 And Number of steps is ==> 774000
# Episode * 388 * Avg Reward is ==> -11.53984260559082 And Number of steps is ==> 776000
# Accident!
# Episode * 389 * Avg Reward is ==> -11.925923347473145 And Number of steps is ==> 778000
# Accident!
# Accident!
# Episode * 390 * Avg Reward is ==> -12.132667541503906 And Number of steps is ==> 780000
# Accident!
# Episode * 391 * Avg Reward is ==> -12.217684745788574 And Number of steps is ==> 782000
# Episode * 392 * Avg Reward is ==> -11.965497970581055 And Number of steps is ==> 784000
# Accident!
# Episode * 393 * Avg Reward is ==> -11.863293647766113 And Number of steps is ==> 786000
# Accident!
# Episode * 394 * Avg Reward is ==> -11.933355331420898 And Number of steps is ==> 788000
# Accident!
# Episode * 395 * Avg Reward is ==> -12.218342781066895 And Number of steps is ==> 790000
# Accident!
# Accident!
# Episode * 396 * Avg Reward is ==> -12.073317527770996 And Number of steps is ==> 792000
# Accident!
# Episode * 397 * Avg Reward is ==> -12.279507637023926 And Number of steps is ==> 794000
# Accident!
# Accident!
# Episode * 398 * Avg Reward is ==> -12.60012435913086 And Number of steps is ==> 796000
# Accident!
# Episode * 399 * Avg Reward is ==> -12.436999320983887 And Number of steps is ==> 798000
# Accident!
# Accident!
# Episode * 400 * Avg Reward is ==> -11.911344528198242 And Number of steps is ==> 800000
# Accident!
# Episode * 401 * Avg Reward is ==> -11.76717758178711 And Number of steps is ==> 802000
# Episode * 402 * Avg Reward is ==> -11.660109519958496 And Number of steps is ==> 804000
# Episode * 403 * Avg Reward is ==> -11.561165809631348 And Number of steps is ==> 806000
# Accident!
# Accident!
# Episode * 404 * Avg Reward is ==> -11.247407913208008 And Number of steps is ==> 808000
# Accident!
# Accident!
# Episode * 405 * Avg Reward is ==> -10.887414932250977 And Number of steps is ==> 810000
# Accident!
# Episode * 406 * Avg Reward is ==> -10.972314834594727 And Number of steps is ==> 812000
# Episode * 407 * Avg Reward is ==> -11.123550415039062 And Number of steps is ==> 814000
# Accident!
# Episode * 408 * Avg Reward is ==> -11.101195335388184 And Number of steps is ==> 816000
# Episode * 409 * Avg Reward is ==> -10.993326187133789 And Number of steps is ==> 818000
# Accident!
# Episode * 410 * Avg Reward is ==> -11.160136222839355 And Number of steps is ==> 820000
# Accident!
# Episode * 411 * Avg Reward is ==> -11.1466064453125 And Number of steps is ==> 822000
# Accident!
# Episode * 412 * Avg Reward is ==> -11.335786819458008 And Number of steps is ==> 824000
# Accident!
# Episode * 413 * Avg Reward is ==> -11.25745677947998 And Number of steps is ==> 826000
# Episode * 414 * Avg Reward is ==> -11.674383163452148 And Number of steps is ==> 828000
# Episode * 415 * Avg Reward is ==> -11.795129776000977 And Number of steps is ==> 830000
# Episode * 416 * Avg Reward is ==> -11.872809410095215 And Number of steps is ==> 832000
# Episode * 417 * Avg Reward is ==> -11.943830490112305 And Number of steps is ==> 834000
# Episode * 418 * Avg Reward is ==> -11.848326683044434 And Number of steps is ==> 836000
# Accident!
# Episode * 419 * Avg Reward is ==> -11.794951438903809 And Number of steps is ==> 838000
# Accident!
# Accident!
# Accident!
# Episode * 420 * Avg Reward is ==> -11.652463912963867 And Number of steps is ==> 840000
# Episode * 421 * Avg Reward is ==> -11.709653854370117 And Number of steps is ==> 842000
# Episode * 422 * Avg Reward is ==> -11.538969039916992 And Number of steps is ==> 844000
# Accident!
# Episode * 423 * Avg Reward is ==> -11.793123245239258 And Number of steps is ==> 846000
# Accident!
# Episode * 424 * Avg Reward is ==> -11.454748153686523 And Number of steps is ==> 848000
# Episode * 425 * Avg Reward is ==> -11.564496994018555 And Number of steps is ==> 850000
# Accident!
# Episode * 426 * Avg Reward is ==> -11.122193336486816 And Number of steps is ==> 852000
# Episode * 427 * Avg Reward is ==> -10.767792701721191 And Number of steps is ==> 854000
# Episode * 428 * Avg Reward is ==> -10.68415641784668 And Number of steps is ==> 856000
# Episode * 429 * Avg Reward is ==> -11.047686576843262 And Number of steps is ==> 858000
# Episode * 430 * Avg Reward is ==> -11.160542488098145 And Number of steps is ==> 860000
# Accident!
# Accident!
# Episode * 431 * Avg Reward is ==> -11.367341041564941 And Number of steps is ==> 862000
# Accident!
# Accident!
# Episode * 432 * Avg Reward is ==> -11.145801544189453 And Number of steps is ==> 864000
# Episode * 433 * Avg Reward is ==> -10.882017135620117 And Number of steps is ==> 866000
# Accident!
# Episode * 434 * Avg Reward is ==> -10.974093437194824 And Number of steps is ==> 868000
# Accident!
# Accident!
# Episode * 435 * Avg Reward is ==> -10.703655242919922 And Number of steps is ==> 870000
# Accident!
# Accident!
# Episode * 436 * Avg Reward is ==> -11.111169815063477 And Number of steps is ==> 872000
# Accident!
# Accident!
# Episode * 437 * Avg Reward is ==> -11.087433815002441 And Number of steps is ==> 874000
# Accident!
# Accident!
# Episode * 438 * Avg Reward is ==> -11.111631393432617 And Number of steps is ==> 876000
# Accident!
# Episode * 439 * Avg Reward is ==> -10.4174222946167 And Number of steps is ==> 878000
# Episode * 440 * Avg Reward is ==> -10.510122299194336 And Number of steps is ==> 880000
# Episode * 441 * Avg Reward is ==> -10.356444358825684 And Number of steps is ==> 882000
# Episode * 442 * Avg Reward is ==> -10.272007942199707 And Number of steps is ==> 884000
# Accident!
# Episode * 443 * Avg Reward is ==> -10.53039836883545 And Number of steps is ==> 886000
# Accident!
# Accident!
# Episode * 444 * Avg Reward is ==> -10.514354705810547 And Number of steps is ==> 888000
# Accident!
# Episode * 445 * Avg Reward is ==> -10.733996391296387 And Number of steps is ==> 890000
# Accident!
# Episode * 446 * Avg Reward is ==> -10.64738655090332 And Number of steps is ==> 892000
# Accident!
# Episode * 447 * Avg Reward is ==> -10.936732292175293 And Number of steps is ==> 894000
# Accident!
# Accident!
# Episode * 448 * Avg Reward is ==> -10.788359642028809 And Number of steps is ==> 896000
# Accident!
# Accident!
# Episode * 449 * Avg Reward is ==> -11.210981369018555 And Number of steps is ==> 898000
# Accident!
# Episode * 450 * Avg Reward is ==> -11.400299072265625 And Number of steps is ==> 900000
# Accident!
# Episode * 451 * Avg Reward is ==> -11.159346580505371 And Number of steps is ==> 902000
# Accident!
# Episode * 452 * Avg Reward is ==> -11.150299072265625 And Number of steps is ==> 904000
# Accident!
# Accident!
# Accident!
# Episode * 453 * Avg Reward is ==> -10.990865707397461 And Number of steps is ==> 906000
# Accident!
# Accident!
# Accident!
# Episode * 454 * Avg Reward is ==> -11.273833274841309 And Number of steps is ==> 908000
# Accident!
# Accident!
# Episode * 455 * Avg Reward is ==> -11.538415908813477 And Number of steps is ==> 910000
# Accident!
# Accident!
# Episode * 456 * Avg Reward is ==> -11.798181533813477 And Number of steps is ==> 912000
# Accident!
# Episode * 457 * Avg Reward is ==> -11.408462524414062 And Number of steps is ==> 914000
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Accident!
# Episode * 458 * Avg Reward is ==> -11.431702613830566 And Number of steps is ==> 916000
# Accident!
# Accident!
# Episode * 459 * Avg Reward is ==> -11.285430908203125 And Number of steps is ==> 918000
# Accident!
# Accident!
# Episode * 460 * Avg Reward is ==> -10.875600814819336 And Number of steps is ==> 920000
# Accident!
# Episode * 461 * Avg Reward is ==> -10.970022201538086 And Number of steps is ==> 922000
# Episode * 462 * Avg Reward is ==> -11.137121200561523 And Number of steps is ==> 924000
# Accident!
# Accident!
# Episode * 463 * Avg Reward is ==> -10.93667984008789 And Number of steps is ==> 926000
# Episode * 464 * Avg Reward is ==> -10.662498474121094 And Number of steps is ==> 928000
# Episode * 465 * Avg Reward is ==> -10.371173858642578 And Number of steps is ==> 930000
# Episode * 466 * Avg Reward is ==> -10.027204513549805 And Number of steps is ==> 932000
# Episode * 467 * Avg Reward is ==> -10.433228492736816 And Number of steps is ==> 934000
# Episode * 468 * Avg Reward is ==> -10.652639389038086 And Number of steps is ==> 936000
# Episode * 469 * Avg Reward is ==> -10.487349510192871 And Number of steps is ==> 938000
# Episode * 470 * Avg Reward is ==> -10.766351699829102 And Number of steps is ==> 940000
# Episode * 471 * Avg Reward is ==> -10.848295211791992 And Number of steps is ==> 942000
# Episode * 472 * Avg Reward is ==> -10.611013412475586 And Number of steps is ==> 944000
# Accident!
# Accident!
# ...
# Accident!
# Episode * 508 * Avg Reward is ==> -11.104059219360352 And Number of steps is ==> 1016000
# Episode * 509 * Avg Reward is ==> -11.068405151367188 And Number of steps is ==> 1018000
# Accident!
# Episode * 510 * Avg Reward is ==> -10.896499633789062 And Number of steps is ==> 1020000
# Episode * 511 * Avg Reward is ==> -10.580606460571289 And Number of steps is ==> 1022000
# Accident!
# Episode * 512 * Avg Reward is ==> -10.444334030151367 And Number of steps is ==> 1024000
# Accident!
# Episode * 513 * Avg Reward is ==> -10.58411979675293 And Number of steps is ==> 1026000
# Accident!
# Episode * 514 * Avg Reward is ==> -10.72929859161377 And Number of steps is ==> 1028000
# Episode * 515 * Avg Reward is ==> -11.002752304077148 And Number of steps is ==> 1030000
# Episode * 516 * Avg Reward is ==> -10.365286827087402 And Number of steps is ==> 1032000
# Accident!
# Episode * 517 * Avg Reward is ==> -10.270785331726074 And Number of steps is ==> 1034000
# Episode * 518 * Avg Reward is ==> -10.109648704528809 And Number of steps is ==> 1036000
# Accident!
# Episode * 519 * Avg Reward is ==> -9.793661117553711 And Number of steps is ==> 1038000
# Accident!
# Episode * 520 * Avg Reward is ==> -9.987539291381836 And Number of steps is ==> 1040000
# Accident!
# Accident!
# Accident!
# Episode * 521 * Avg Reward is ==> -9.998603820800781 And Number of steps is ==> 1042000
# Accident!
# Accident!
# Accident!
# Episode * 522 * Avg Reward is ==> -10.199275970458984 And Number of steps is ==> 1044000
# Accident!
# Episode * 523 * Avg Reward is ==> -10.336541175842285 And Number of steps is ==> 1046000
# Accident!
# Episode * 524 * Avg Reward is ==> -10.492696762084961 And Number of steps is ==> 1048000
# Accident!
# Accident!
# Episode * 525 * Avg Reward is ==> -10.472517013549805 And Number of steps is ==> 1050000
# Accident!
# Accident!
# Episode * 526 * Avg Reward is ==> -10.843002319335938 And Number of steps is ==> 1052000
# Episode * 527 * Avg Reward is ==> -10.641226768493652 And Number of steps is ==> 1054000
# Accident!
# Episode * 528 * Avg Reward is ==> -10.609883308410645 And Number of steps is ==> 1056000
# Accident!
# Episode * 529 * Avg Reward is ==> -10.620326042175293 And Number of steps is ==> 1058000
# Accident!
# Episode * 530 * Avg Reward is ==> -10.772157669067383 And Number of steps is ==> 1060000
# Accident!
# Episode * 531 * Avg Reward is ==> -10.892557144165039 And Number of steps is ==> 1062000
# Accident!
# Accident!
# Episode * 532 * Avg Reward is ==> -11.023321151733398 And Number of steps is ==> 1064000
# Accident!
# Accident!
# Episode * 533 * Avg Reward is ==> -11.061795234680176 And Number of steps is ==> 1066000
# Episode * 534 * Avg Reward is ==> -11.121393203735352 And Number of steps is ==> 1068000
# Episode * 535 * Avg Reward is ==> -11.162063598632812 And Number of steps is ==> 1070000
# Accident!
# Accident!
# Accident!
# Episode * 536 * Avg Reward is ==> -11.138934135437012 And Number of steps is ==> 1072000
# Accident!
# Accident!
# Episode * 537 * Avg Reward is ==> -11.725435256958008 And Number of steps is ==> 1074000
# Episode * 538 * Avg Reward is ==> -11.897954940795898 And Number of steps is ==> 1076000
# Episode * 539 * Avg Reward is ==> -12.096531867980957 And Number of steps is ==> 1078000
# Accident!
# Episode * 540 * Avg Reward is ==> -11.826929092407227 And Number of steps is ==> 1080000
# Episode * 541 * Avg Reward is ==> -11.885335922241211 And Number of steps is ==> 1082000
# Accident!
# Episode * 542 * Avg Reward is ==> -11.774514198303223 And Number of steps is ==> 1084000
# Accident!
# Accident!
# Accident!
# Episode * 543 * Avg Reward is ==> -11.63080883026123 And Number of steps is ==> 1086000
# Episode * 544 * Avg Reward is ==> -11.790716171264648 And Number of steps is ==> 1088000
# Episode * 545 * Avg Reward is ==> -11.470674514770508 And Number of steps is ==> 1090000
# Accident!
# Episode * 546 * Avg Reward is ==> -11.676923751831055 And Number of steps is ==> 1092000
# Episode * 547 * Avg Reward is ==> -11.664732933044434 And Number of steps is ==> 1094000
# Episode * 548 * Avg Reward is ==> -11.565847396850586 And Number of steps is ==> 1096000
# Accident!
# Accident!
# Episode * 549 * Avg Reward is ==> -11.768278121948242 And Number of steps is ==> 1098000
# Episode * 550 * Avg Reward is ==> -11.827643394470215 And Number of steps is ==> 1100000
# Accident!
# Episode * 551 * Avg Reward is ==> -11.744200706481934 And Number of steps is ==> 1102000
# Accident!
# Episode * 552 * Avg Reward is ==> -12.008148193359375 And Number of steps is ==> 1104000
# Accident!
# Episode * 553 * Avg Reward is ==> -11.789003372192383 And Number of steps is ==> 1106000
# Episode * 554 * Avg Reward is ==> -11.220677375793457 And Number of steps is ==> 1108000
# Accident!
# Accident!
# Episode * 555 * Avg Reward is ==> -11.23691463470459 And Number of steps is ==> 1110000
# Episode * 556 * Avg Reward is ==> -11.074592590332031 And Number of steps is ==> 1112000
# Accident!
# Accident!
# Accident!
# Episode * 557 * Avg Reward is ==> -11.044292449951172 And Number of steps is ==> 1114000
# Accident!
# Episode * 558 * Avg Reward is ==> -11.331225395202637 And Number of steps is ==> 1116000
# Accident!
# Accident!
# Episode * 559 * Avg Reward is ==> -11.295408248901367 And Number of steps is ==> 1118000
# Episode * 560 * Avg Reward is ==> -11.28995132446289 And Number of steps is ==> 1120000
# Accident!
# Episode * 561 * Avg Reward is ==> -11.668659210205078 And Number of steps is ==> 1122000
# Episode * 562 * Avg Reward is ==> -11.571820259094238 And Number of steps is ==> 1124000
# Accident!
# Episode * 563 * Avg Reward is ==> -11.958521842956543 And Number of steps is ==> 1126000
# Episode * 564 * Avg Reward is ==> -12.103002548217773 And Number of steps is ==> 1128000
# Accident!
# Episode * 565 * Avg Reward is ==> -12.022107124328613 And Number of steps is ==> 1130000
# Episode * 566 * Avg Reward is ==> -12.153557777404785 And Number of steps is ==> 1132000
# Accident!
# Accident!
# Accident!
# Episode * 567 * Avg Reward is ==> -12.074949264526367 And Number of steps is ==> 1134000
# Episode * 568 * Avg Reward is ==> -12.088396072387695 And Number of steps is ==> 1136000
# Episode * 569 * Avg Reward is ==> -11.994181632995605 And Number of steps is ==> 1138000
# Episode * 570 * Avg Reward is ==> -12.309103012084961 And Number of steps is ==> 1140000
# Episode * 571 * Avg Reward is ==> -12.001724243164062 And Number of steps is ==> 1142000
# Episode * 572 * Avg Reward is ==> -11.651052474975586 And Number of steps is ==> 1144000
# Episode * 573 * Avg Reward is ==> -11.60681438446045 And Number of steps is ==> 1146000
# Accident!
# Accident!
# Episode * 574 * Avg Reward is ==> -12.01542854309082 And Number of steps is ==> 1148000
# Accident!
# Accident!
# Accident!
# Episode * 575 * Avg Reward is ==> -12.688199043273926 And Number of steps is ==> 1150000
# Episode * 576 * Avg Reward is ==> -12.460038185119629 And Number of steps is ==> 1152000
# Accident!
# Accident!
# Accident!
# Episode * 577 * Avg Reward is ==> -12.615262031555176 And Number of steps is ==> 1154000
# Accident!
# Episode * 578 * Avg Reward is ==> -12.509010314941406 And Number of steps is ==> 1156000
# Episode * 579 * Avg Reward is ==> -12.682398796081543 And Number of steps is ==> 1158000
# Accident!
# Accident!
# Episode * 580 * Avg Reward is ==> -12.584799766540527 And Number of steps is ==> 1160000
# Episode * 581 * Avg Reward is ==> -12.528489112854004 And Number of steps is ==> 1162000
# Episode * 582 * Avg Reward is ==> -12.8917875289917 And Number of steps is ==> 1164000
# Accident!
# Accident!
# Episode * 583 * Avg Reward is ==> -13.238238334655762 And Number of steps is ==> 1166000
# Episode * 584 * Avg Reward is ==> -13.116472244262695 And Number of steps is ==> 1168000
# Episode * 585 * Avg Reward is ==> -12.587599754333496 And Number of steps is ==> 1170000
# Episode * 586 * Avg Reward is ==> -12.867228507995605 And Number of steps is ==> 1172000
# Episode * 587 * Avg Reward is ==> -12.720843315124512 And Number of steps is ==> 1174000
# Episode * 588 * Avg Reward is ==> -12.538175582885742 And Number of steps is ==> 1176000
# Accident!
# Episode * 589 * Avg Reward is ==> -12.272284507751465 And Number of steps is ==> 1178000
# Accident!
# Episode * 590 * Avg Reward is ==> -12.365998268127441 And Number of steps is ==> 1180000
# Accident!
# Accident!
# Episode * 591 * Avg Reward is ==> -12.967290878295898 And Number of steps is ==> 1182000
# Accident!
# Episode * 592 * Avg Reward is ==> -12.547029495239258 And Number of steps is ==> 1184000
# Episode * 593 * Avg Reward is ==> -12.404134750366211 And Number of steps is ==> 1186000
# Accident!
# Episode * 594 * Avg Reward is ==> -12.608607292175293 And Number of steps is ==> 1188000
# Episode * 595 * Avg Reward is ==> -12.677316665649414 And Number of steps is ==> 1190000
# Episode * 596 * Avg Reward is ==> -12.41737174987793 And Number of steps is ==> 1192000
# Accident!
# Episode * 597 * Avg Reward is ==> -12.433103561401367 And Number of steps is ==> 1194000
# Episode * 598 * Avg Reward is ==> -12.49596118927002 And Number of steps is ==> 1196000
# Accident!
# Episode * 599 * Avg Reward is ==> -12.712112426757812 And Number of steps is ==> 1198000
# Accident!
# Accident!
# Episode * 600 * Avg Reward is ==> -12.484233856201172 And Number of steps is ==> 1200000
# Accident!
# Accident!
# Episode * 601 * Avg Reward is ==> -11.950202941894531 And Number of steps is ==> 1202000
# Episode * 602 * Avg Reward is ==> -11.794797897338867 And Number of steps is ==> 1204000
# Accident!
# Accident!
# Accident!
# Episode * 603 * Avg Reward is ==> -11.593050003051758 And Number of steps is ==> 1206000
# Accident!
# Accident!
# Episode * 604 * Avg Reward is ==> -11.432231903076172 And Number of steps is ==> 1208000
# Episode * 605 * Avg Reward is ==> -11.169012069702148 And Number of steps is ==> 1210000
# Episode * 606 * Avg Reward is ==> -11.104607582092285 And Number of steps is ==> 1212000
# Episode * 607 * Avg Reward is ==> -10.708399772644043 And Number of steps is ==> 1214000
# Episode * 608 * Avg Reward is ==> -10.762611389160156 And Number of steps is ==> 1216000
# Accident!
# Episode * 609 * Avg Reward is ==> -10.501880645751953 And Number of steps is ==> 1218000
# Episode * 610 * Avg Reward is ==> -10.27638053894043 And Number of steps is ==> 1220000
# Episode * 611 * Avg Reward is ==> -10.517435073852539 And Number of steps is ==> 1222000
# Accident!
# Accident!
# Accident!
# Episode * 612 * Avg Reward is ==> -11.017868995666504 And Number of steps is ==> 1224000
# Accident!
# Accident!
# Accident!
# Episode * 613 * Avg Reward is ==> -11.12247085571289 And Number of steps is ==> 1226000
# Accident!
# Episode * 614 * Avg Reward is ==> -10.739316940307617 And Number of steps is ==> 1228000
# Accident!
# Episode * 615 * Avg Reward is ==> -10.751520156860352 And Number of steps is ==> 1230000
# Accident!
# Episode * 616 * Avg Reward is ==> -10.866581916809082 And Number of steps is ==> 1232000
# Episode * 617 * Avg Reward is ==> -10.830519676208496 And Number of steps is ==> 1234000
# Accident!
# Accident!
# Episode * 618 * Avg Reward is ==> -10.769753456115723 And Number of steps is ==> 1236000
# Episode * 619 * Avg Reward is ==> -10.917670249938965 And Number of steps is ==> 1238000
# Accident!
# Episode * 620 * Avg Reward is ==> -10.998412132263184 And Number of steps is ==> 1240000
# Accident!
# Accident!
# Accident!
# Episode * 621 * Avg Reward is ==> -10.953868865966797 And Number of steps is ==> 1242000
# Episode * 622 * Avg Reward is ==> -10.965814590454102 And Number of steps is ==> 1244000
# Episode * 623 * Avg Reward is ==> -10.624202728271484 And Number of steps is ==> 1246000
# Accident!
# Accident!
# Episode * 624 * Avg Reward is ==> -10.668876647949219 And Number of steps is ==> 1248000
# Episode * 625 * Avg Reward is ==> -10.889291763305664 And Number of steps is ==> 1250000
# Accident!
# Episode * 626 * Avg Reward is ==> -10.768774032592773 And Number of steps is ==> 1252000
# Episode * 627 * Avg Reward is ==> -10.888580322265625 And Number of steps is ==> 1254000
# Episode * 628 * Avg Reward is ==> -11.097738265991211 And Number of steps is ==> 1256000
# Episode * 629 * Avg Reward is ==> -10.81376838684082 And Number of steps is ==> 1258000
# Accident!
# Accident!
# Episode * 630 * Avg Reward is ==> -11.13585090637207 And Number of steps is ==> 1260000
# Episode * 631 * Avg Reward is ==> -11.070181846618652 And Number of steps is ==> 1262000
# Accident!
# Episode * 632 * Avg Reward is ==> -10.97387981414795 And Number of steps is ==> 1264000
# Accident!
# Accident!
# Episode * 633 * Avg Reward is ==> -11.194942474365234 And Number of steps is ==> 1266000
# Episode * 634 * Avg Reward is ==> -11.468884468078613 And Number of steps is ==> 1268000
# Accident!
# Accident!
# Episode * 635 * Avg Reward is ==> -12.00261402130127 And Number of steps is ==> 1270000
# Episode * 636 * Avg Reward is ==> -11.78150463104248 And Number of steps is ==> 1272000
# Episode * 637 * Avg Reward is ==> -12.102319717407227 And Number of steps is ==> 1274000
# Episode * 638 * Avg Reward is ==> -12.010334968566895 And Number of steps is ==> 1276000
# Episode * 639 * Avg Reward is ==> -12.220588684082031 And Number of steps is ==> 1278000
# Accident!
# Episode * 640 * Avg Reward is ==> -11.925041198730469 And Number of steps is ==> 1280000
# Accident!
# Accident!
# Episode * 641 * Avg Reward is ==> -11.842443466186523 And Number of steps is ==> 1282000
# Accident!
# Episode * 642 * Avg Reward is ==> -11.747945785522461 And Number of steps is ==> 1284000
# Accident!
# Episode * 643 * Avg Reward is ==> -11.916266441345215 And Number of steps is ==> 1286000
# Accident!
# Episode * 644 * Avg Reward is ==> -11.716501235961914 And Number of steps is ==> 1288000
# Accident!
# Episode * 645 * Avg Reward is ==> -11.578299522399902 And Number of steps is ==> 1290000
# Episode * 646 * Avg Reward is ==> -12.139215469360352 And Number of steps is ==> 1292000
# Accident!
# Accident!
# Episode * 647 * Avg Reward is ==> -12.540149688720703 And Number of steps is ==> 1294000
# Accident!
# Accident!
# Episode * 648 * Avg Reward is ==> -12.607221603393555 And Number of steps is ==> 1296000
# Episode * 649 * Avg Reward is ==> -12.80828857421875 And Number of steps is ==> 1298000
# Accident!
# Episode * 650 * Avg Reward is ==> -13.004794120788574 And Number of steps is ==> 1300000
# Episode * 651 * Avg Reward is ==> -12.956071853637695 And Number of steps is ==> 1302000
# Episode * 652 * Avg Reward is ==> -13.051673889160156 And Number of steps is ==> 1304000
# Episode * 653 * Avg Reward is ==> -12.677013397216797 And Number of steps is ==> 1306000
# Episode * 654 * Avg Reward is ==> -12.9019136428833 And Number of steps is ==> 1308000
# Episode * 655 * Avg Reward is ==> -12.706502914428711 And Number of steps is ==> 1310000
# Episode * 656 * Avg Reward is ==> -12.38218879699707 And Number of steps is ==> 1312000
# Episode * 657 * Avg Reward is ==> -11.812746047973633 And Number of steps is ==> 1314000
# Episode * 658 * Avg Reward is ==> -11.839555740356445 And Number of steps is ==> 1316000
# Episode * 659 * Avg Reward is ==> -11.444866180419922 And Number of steps is ==> 1318000
# Accident!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4428/3291631189.py in <module>
#       2 import time
#       3 start = time.process_time()
# ----> 4 algo.train(1000)
#       5 algo.saving()
#       6 end = time.process_time()
#
# ~\AppData\Local\Temp/ipykernel_4428/3113738693.py in train(self, nb_loop)
#      69                 self.optimizer_critic.step()
#      70
# ---> 71             state_batch, action_batch = self.rollout.iterations(self.actor_net, 30)
#      72             batch_rews = self.rollout.immediate_rewards()
#      73             self.ep_reward_list.append(batch_rews.mean().numpy())
#
# ~\AppData\Local\Temp/ipykernel_4428/3094484176.py in iterations(self, actor_net, nbr_episodes)
#      38             for step_ep in range(self.max_steps):
#      39                 with torch.no_grad():
# ---> 40                     action = torch.squeeze(actor_net(torch.unsqueeze(torch.tensor(prev_state), dim=0).float()))
#      41                     if(action.dim()==0):
#      42                         action=torch.unsqueeze(action,dim=0)
#
# KeyboardInterrupt:

# %%
algo.loading(12,1000)

# %%
#Stock an evaluation sample
states, actions, rewards = algo.evaluate(100)
ep_action=states[:,0]
ep_speed_car=states[:,1]
ep_pos_car=states[:,2]
ep_speed_ped=states[:,3]
ep_pos_ped=states[:,4]
ep_time=states[:,9]
ep_reward=rewards
t=0

# %%
#Show general information about the final algorithm performance: average speed, CO2 emission, end-time

LDV = pd.read_csv('LDV.csv', sep=';',names=["sp","acc","step","em_name","em_val"])
LDV.pop('step')
m = LDV == 0.0
LDV['acc'] = LDV['acc'].replace(1.27676e-15,0.0)
LDV['acc'] = LDV['acc'].astype(float)
LDV_array = np.array(LDV.values)

def info_co2(states,LDV):
    """
        Evaluate the CO2 emission per episode 
        :param states: state list
        :param LDV: CO2 emission chart
    """
    t=0
    total_emission=[]
    while t+1<len(ep_time):
        t_init=t
        emission_val=[]
        while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
            acc=math.trunc(((states[t,0].item()//0.2)*0.2)*10.)/10.
            speed=math.trunc(((states[t,1].item()//0.5)*0.5)*10.)/10.
            cond=(LDV.sp==speed)&(LDV.acc==acc)&(LDV.em_name=="CO2")
            res=LDV[cond]['em_val'].item() *0.3
            emission_val.append(res)
            t+=1
        total_emission.append(torch.sum(torch.tensor(emission_val),dim=0))
        t+=1
    torch_total_emission=torch.tensor(total_emission)
    total_emission_mean=torch.mean(torch_total_emission)
    total_emission_std=torch.std(torch_total_emission)
    print("\nThe average CO2 emission is {:.2f}mg and its standard deviation is {:.2f} mg".format(total_emission_mean.item(),total_emission_std.item()))
    
def get_average(states,LDV):
    ep_time=states[:,9]
    mean_speed=torch.mean(states[:,1])
    sqrt_speed=torch.std(states[:,1])
    print("The average car speed is {:.2f} m/s and its standard deviation is {:.2f} m/s".format(mean_speed.item(),sqrt_speed.item()))
    mean_acc=torch.mean(states[:,0])
    sqrt_acc=torch.std(states[:,0])
    print("\nThe average car acceleration is {:.2f} m/s2 and its standard deviation is {:.2f} m/s2".format(mean_acc.item(),sqrt_acc.item()))
    mean_speed_p=torch.mean(states[:,3])
    sqrt_speed_p=torch.std(states[:,3])
    print("\nThe average pedestrian speed is {:.2f} m/s2 and its standard deviation is {:.2f} m/s2".format(mean_speed_p.item(),sqrt_speed_p.item()))    
    mean_reward=torch.mean(ep_reward)
    std_reward=torch.std(ep_reward)
    print("\nThe average reward is {:.2f} and its standard deviation is {:.2f}".format(mean_reward.item(),std_reward.item()))
    info_co2(states,LDV) #CO2 info
    temps=[]
    t=0
    while t+1<len(ep_time):
        temps_i=np.array([0.,0.]) #respectively: end-time car/pedestrian
        t_init=t
        while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
            if(states[t,2]<0.0 and states[t+1,2]>=0.0):
                temps_i[0]=(t-t_init)*0.3
            if(states[t,4]<5.0 and states[t+1,4]>=5.0):
                temps_i[1]=(t-t_init)*0.3
            t+=1
        if(temps_i[1]==0.0):
            temps_i[1]=(t-t_init)*0.3
        temps.append([(t-t_init)*0.3,temps_i[0],temps_i[1]])
        t+=1
    total_temps=torch.tensor([temps]).reshape((-1,3))
    total_temps_mean=torch.mean(total_temps,dim=0)
    print("\n Average End-times:")
    print("Total: {:.2f} s".format(total_temps_mean[0].item()))
    print("Car: {:.2f} s".format(total_temps_mean[1].item()))
    print("Pedestrian: {:.2f} s".format(total_temps_mean[2].item()))
get_average(states,LDV)
# Out:
# The average car speed is 7.37 m/s and its standard deviation is 3.85 m/s
#
# The average car acceleration is 0.04 m/s2 and its standard deviation is 1.79 m/s2
#
# The average pedestrian speed is 0.98 m/s2 and its standard deviation is 0.39 m/s2
#
# The average reward is -0.72 and its standard deviation is 2.47
#
# The average CO2 emission is 23008.21mg and its standard deviation is 9133.60 mg
#
#  Average End-times:
# Total: 9.90 s
# Car: 4.76 s
# Pedestrian: 6.70 s

# %%
#Positions des agents
t=0
plt.title("Vehicle and Pedestrian Positions versus time")
plt.xlabel("time (s)")
plt.ylabel("position (m)")
while t+1<len(ep_time):
    t_init=t
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        t+=1
    plt.plot(ep_time[t_init:t],ep_pos_car[t_init:t])
    plt.plot(ep_time[t_init:t],ep_pos_ped[t_init:t])
    plt.axhline(y=5, color='r', linestyle='-.')
    plt.axhline(y=0, color='r', linestyle='-.')
    t+=1
_=plt.axhline(y=5, color='r', linestyle='-.')
_=plt.axhline(y=0, color='r', linestyle='-.')

# %%
#Accélération, Reward, Vitesse de la voiture
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4,figsize=(18, 4))

t=0
ax1.set_title("Car Acceleration versus time per episode")
ax1.set_xlabel("time (s)")
ax1.set_ylabel("acceleration (m/s2)")

ax2.set_title("Reward versus time per episode")
ax2.set_xlabel("time (s)")
ax2.set_ylabel("reward")

ax3.set_title("Car Speed versus time per episode")
ax3.set_xlabel("time (s)")
ax3.set_ylabel("speed (m/s)")

ax4.set_title('Pedestrian Speed')
ax4.set_xlabel("Position (m)")
ax4.set_ylabel("Speed (m/s)")
while t+1<len(ep_time):
    t_init=t
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        t+=1
    ax1.plot(ep_time[t_init:t],ep_action[t_init:t])
    ax2.plot(ep_time[t_init:t],ep_reward[t_init:t])
    ax3.plot(ep_time[t_init:t],ep_speed_car[t_init:t])
    ax4.plot(states[t_init:t,4],states[t_init:t,3])
    t+=1

# %%
#Seperate the episodes and the different behaviors
t=0
cross_speed=[]
wait_speed=[]
cross_acc=[]
wait_acc=[]
size_wait=20
size_cross=40

while t+1<len(ep_time):
    t_init=t
    choice=False
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        choice=choice+(ep_speed_car[t]<2.0)
        t+=1

    if(choice):
        min_l=min(t-t_init,size_cross)
        return_speed=np.array(ep_speed_car[t_init:t_init+min_l])
        return_acc=np.array(states[t_init:t_init+min_l,0])
        if(min_l<size_cross):
            return_speed=np.append(return_speed,[ep_speed_car[t-1]]*(size_cross-t+t_init))
            return_acc=np.append(return_acc,[states[t-1,0]]*(size_cross-t+t_init))
        cross_speed.append(return_speed)
        cross_acc.append(return_acc)
    else:
        min_l=min(t-t_init,size_wait)
        return_speed=np.array(ep_speed_car[t_init:t_init+min_l])
        return_acc=np.array(states[t_init:t_init+min_l,0])
        if(min_l<size_wait):
            return_speed=np.append(return_speed,[ep_speed_car[t-1]]*(size_wait-t+t_init))
            return_acc=np.append(return_acc,[states[t-1,0]]*(size_wait-t+t_init))
        wait_speed.append(return_speed)
        wait_acc.append(return_acc)
    t+=1
    
cross_speed=np.array(cross_speed)
wait_speed=np.array(wait_speed)
cross_acc=np.array(cross_acc)
wait_acc=np.array(wait_acc)

# %%
x1=[0.3*i for i in range(size_cross)]
mean_speed=np.mean(cross_speed,axis=0)
std_speed=np.std(cross_speed,axis=0)
mean_acc=np.mean(cross_acc,axis=0)
std_acc=np.std(cross_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')
fig.savefig("PDF_results/car_cross_ppo12.pdf")

# %%
x1=[0.3*i for i in range(size_wait)]
mean_speed=np.mean(wait_speed,axis=0)
std_speed=np.std(wait_speed,axis=0)
mean_acc=np.mean(wait_acc,axis=0)
std_acc=np.std(wait_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')
fig.savefig("PDF_results/car_wait_ppo12.pdf")

# %%
#Showing Vehicle Acceleration Diagram, Vehicle Speed Diagram, Vehicle and Pedestrian Position Diagram
#All three over time in an episode
#t=0
if (t+1>=len(ep_time)):
    t=0
t_init=t
while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
    t+=1
fig, (ax1, ax2, ax3) = plt.subplots(1, 3,figsize=(20, 3))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-1.1,1.1)
ax1.plot(ep_time[t_init:t+1],actions[t_init:t+1,0],color='r')

ax2.set_title('Car and Pedestrian Position')
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Position (m)")
ax2.plot(ep_time[t_init:t],ep_pos_car[t_init:t],label='car')
ax2.plot(ep_time[t_init:t+1],ep_pos_ped[t_init:t+1],label='pedestrian')
ax2.axhline(y=5, color='r', linestyle='-.')
ax2.axhline(y=0, color='r', linestyle='-.')
ax2.legend()

ax3.set_title('Car Speed')
ax3.set_xlabel("Time (s)")
ax3.set_ylabel("Speed (m/s)")
ax3.plot(ep_time[t_init:t+1],ep_speed_car[t_init:t+1],color='r')
t+=1

# %%
def estimation_value(x1,x2,x3,y1,y3):
    a=(y3-y1)/(x3-x1)
    b=(y1*x3 - y3*x1)/(x3-x1)
    return a*x2+b

def extract_estimations(positions, parameter, start_position, end_position, step_pos):
    size_position=int((end_position-start_position)/step_pos)
    length=len(positions)
    array_cross=np.array([0.0]*size_position)
    i_step=0
    i_pos=start_position
    i=0
    while(i_pos<positions[i_step]):
        array_cross[i]=parameter[i_step]
        i=i+1
        i_pos=i_pos+0.5
    while(i_step<length and i<size_position):
        while( i_step+1<length and i_pos>positions[i_step]):
            i_step=i_step+1
        array_cross[i]=estimation_value(positions[i_step-1],i_pos,positions[i_step],parameter[i_step-1],parameter[i_step])
        i=i+1
        i_pos=i_pos+0.5
    while(i<size_position):
        array_cross[i]=parameter[i_step-1]
        i=i+1
    return array_cross

# %%
#Seperate the episodes and the different behaviors
t=0
cross_speed=[]
wait_speed=[]
cross_acc=[]
wait_acc=[]
start_position=-32.5
end_position=32.5
while t+1<len(ep_time):
    
    t_init=t
    choice=False
    while t+1<len(ep_time) and ep_time[t]<ep_time[t+1]:
        choice=choice+(ep_speed_car[t]<2.0)
        t+=1
        
    if(choice):
        return_speed=extract_estimations(ep_pos_car[t_init:t], ep_speed_car[t_init:t],start_position,end_position,0.5)
        return_acc=extract_estimations(ep_pos_car[t_init:t], ep_action[t_init:t],start_position,end_position,0.5)
        cross_speed.append(return_speed)
        cross_acc.append(return_acc)
        
    else:
        return_speed=extract_estimations(ep_pos_car[t_init:t], ep_speed_car[t_init:t],start_position,end_position,0.5)
        return_acc=extract_estimations(ep_pos_car[t_init:t], ep_action[t_init:t],start_position,end_position,0.5)
        wait_speed.append(return_speed)
        wait_acc.append(return_acc)
    t+=1
    
cross_speed=np.array(cross_speed)
wait_speed=np.array(wait_speed)
cross_acc=np.array(cross_acc)
wait_acc=np.array(wait_acc)

# %%
size_position=int((end_position-start_position)/0.5)
x1=[i*0.5+start_position for i in range(0,size_position)]
mean_speed=np.mean(cross_speed,axis=0)
std_speed=np.std(cross_speed,axis=0)
mean_acc=np.mean(cross_acc,axis=0)
std_acc=np.std(cross_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Position (m)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Position (m)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')

# %%
x1=[i*0.5+start_position for i in range(0,size_position)]
mean_speed=np.mean(wait_speed,axis=0)
std_speed=np.std(wait_speed,axis=0)
mean_acc=np.mean(wait_acc,axis=0)
std_acc=np.std(wait_acc,axis=0)

fig, (ax1, ax2) = plt.subplots(1, 2,figsize=(10, 2))
ax1.set_title('Car Acceleration')
ax1.set_xlabel("Position (m)")
ax1.set_ylabel("Acceleration (m/s2)")
ax1.set_ylim(-4.5,2.5)
ax1.plot(x1,mean_acc,color='cornflowerblue')
ax1.fill_between(x1, (mean_acc-std_acc), (mean_acc+std_acc), color='cornflowerblue', alpha=0.1)
ax1.grid(True,color='lightgrey')

ax2.set_title('Car Speed')
ax2.set_xlabel("Position (m)")
ax2.set_ylabel("Speed (m/s)")
ax2.set_ylim(-1.0,12.0)
ax2.axhline(y=mean_speed[0], color='r', linestyle='-.')
ax2.plot(x1,mean_speed,color='cornflowerblue')
ax2.fill_between(x1, (mean_speed-std_speed), (mean_speed+std_speed), color='cornflowerblue', alpha=0.1)

ax2.grid(True,color='lightgrey')

# %%
plt.title('Pedestrian Speed')
plt.xlabel("Position (m)")
plt.ylabel("Speed (m/s)")
plt.plot(states[t_init:t-10,4],states[t_init:t-10,3], color='olivedrab')
#plt.savefig("PDF_results/ped_speed.pdf")
